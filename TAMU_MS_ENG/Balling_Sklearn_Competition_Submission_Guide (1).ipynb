# %% [markdown]
# <p align="center"><img width="50%" src="https://aimodelsharecontent.s3.amazonaws.com/aimodshare_banner.jpg" /></p>
#
#
# ---

# %% [markdown]
# ## Model Submission Guide: Alloy Balling Competition
# Let's share our models to a centralized leaderboard, so that we can collaborate and learn from the model experimentation process...
#
# **Instructions:**
# 1.   Get data in and set up X_train / X_test / y_train
# 2.   Preprocess data using function
# 3. Fit model on preprocessed data and save preprocessor function and model
# 4. Generate predictions from X_test data and submit model to competition
# 5. Repeat submission process to improve place on leaderboard

# %% [markdown]
# ## 1. Get data in and set up X_train, X_test, y_train objects

# %%
#install aimodelshare library
! pip install aimodelshare --upgrade

# %%
# Get competition data (loaded to your working directory)
from aimodelshare import download_data
download_data('public.ecr.aws/y2e2a1d6/balling_competition_data-repository:latest')
# Out:
# Downloading [==>                                              ]
#
# Data downloaded successfully.

# %%
# Separate data into X_train, y_train, and X_test
import pandas as pd
X_train=pd.read_csv("balling_competition_data/X_train.csv")
y_train=pd.read_csv("balling_competition_data/y_train.csv").values
X_test=pd.read_csv("balling_competition_data/X_test.csv")
X_train.head()
# Out:
#    Solid/Spread   LED [J/m]  Dwell Time [s]
# 0      2.492745  333.333333        0.000167
# 1      3.698290  268.421053        0.000105
# 2      3.795608   61.038961        0.000052
# 3     57.568953  242.424242        0.000242
# 4      3.698290   80.800000        0.000040

# %% [markdown]
# ##2.   Preprocess data using function/ Write and Save Preprocessor function

# %%
# Write function to transform data with preprocessor 
# In this case we use panda's fillna in our preprocessor function to replace missing values with column means

def preprocessor(data):
    preprocessed_data=data.fillna({'Solid/Spread': 26.428271, 'LED [J/m]': 233.049568, 'Dwell Time [s]': 0.000125})

    return preprocessed_data.values #return preprocessed numpy array

# %%
# check shape of X data after preprocessing it using our new function
preprocessor(X_train).shape
# Out:
# (1871, 3)

# %% [markdown]
# ##3. Fit model on preprocessed data and save preprocessor function and model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import AdaBoostClassifier
from sklearn import preprocessing
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.calibration import calibration_curve

# Separate data into X_train, y_train, and X_test
import pandas as pd
X_train=pd.read_csv("balling_competition_data/X_train.csv")
y_train=pd.read_csv("balling_competition_data/y_train.csv").values
X_test=pd.read_csv("balling_competition_data/X_test.csv")
X_train.head()

#Apply SMOTE to training set
over = SMOTE(k_neighbors=5,sampling_strategy=.5,random_state=30)
under = RandomUnderSampler(sampling_strategy=.5,random_state=30)
steps = [('o', over), ('u', under)]
pipeline = Pipeline(steps=steps)
X_train, y_train = pipeline.fit_resample(X_train, y_train)

#Train AdaBoost classifier
model = AdaBoostClassifier(n_estimators=200, random_state=30)
model = model.fit(preprocessor(X_train), y_train)

model.score(preprocessor(X_train), y_train) # Fit score, 0-1 scale.
# Out:
# 0.8732681336593318

# %% [markdown]
# #### Save preprocessor function to local "preprocessor.zip" file

# %%
import aimodelshare as ai
ai.export_preprocessor(preprocessor,"")
# Out:
# Your preprocessor is now saved to 'preprocessor.zip'

# %% [markdown]
# #### Save model to local ".onnx" file

# %%
# Save sklearn model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

# Check how many preprocessed input features are there?
from skl2onnx.common.data_types import FloatTensorType

feature_count=preprocessor(X_test).shape[1] #Get count of preprocessed features
initial_type = [('float_input', FloatTensorType([None, feature_count]))]  #Insert correct number of preprocessed features

onnx_model = model_to_onnx(model, framework='sklearn',
                          initial_types=initial_type,
                          transfer_learning=False,
                          deep_learning=False)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %% [markdown]
# ## 4. Generate predictions from X_test data and submit model to competition

# %%
#Set credentials using modelshare.org username/password

from aimodelshare.aws import set_credentials

#This is the unique playground id that powers this Playground -- make sure to update the id for different competitions
playground_id="https://ov8kxwsss6.execute-api.us-east-2.amazonaws.com/prod/m"

set_credentials(apiurl=playground_id)
# Out:
# AI Modelshare Username:··········
# AI Modelshare Password:··········
# AI Model Share login credentials set successfully.

# %%
#Instantiate Competition
import aimodelshare as ai
mycompetition= ai.Competition(playground_id)

# %%
#Submit Model 1: 

#-- Generate predicted values (a list of predicted labels "survived" or "died") (Model 1)
prediction_labels = model.predict(preprocessor(X_test))

# Submit Model 1 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# Insert search tags to help users find your model (optional): adaboost
# Provide any useful notes about your model (optional): untuned, adaboost
#
# Your model has been submitted as model version 4
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:2712

# %%
# Get leaderboard to explore current best model architectures

# Get raw data in pandas data frame
data = mycompetition.get_leaderboard()

# Stylize leaderboard data
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_8dcdd_row0_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 86.9%, transparent 86.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8dcdd_row0_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 75.4%, transparent 75.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8dcdd_row0_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 73.4%, transparent 73.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8dcdd_row0_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 78.1%, transparent 78.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8dcdd_row0_col4, #T_8dcdd_row0_col5, #T_8dcdd_row0_col6, #T_8dcdd_row0_col7, #T_8dcdd_row0_col8, #T_8dcdd_row0_col9, #T_8dcdd_row0_col10, #T_8dcdd_row0_col11, #T_8dcdd_row1_col4, #T_8dcdd_row1_col5, #T_8dcdd_row1_col6, #T_8dcdd_row1_col7, #T_8dcdd_row1_col8, #T_8dcdd_row1_col9, #T_8dcdd_row1_col10, #T_8dcdd_row1_col11, #T_8dcdd_row2_col4, #T_8dcdd_row2_col5, #T_8dcdd_row2_col6, #T_8dcdd_row2_col7, #T_8dcdd_row2_col8, #T_8dcdd_row2_col9, #T_8dcdd_row2_col10, #T_8dcdd_row2_col11, #T_8dcdd_row3_col4, #T_8dcdd_row3_col5, #T_8dcdd_row3_col6, #T_8dcdd_row3_col7, #T_8dcdd_row3_col8, #T_8dcdd_row3_col9, #T_8dcdd_row3_col10, #T_8dcdd_row3_col11 {
#   text-align: center;
# }
# #T_8dcdd_row1_col0, #T_8dcdd_row3_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 85.9%, transparent 85.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8dcdd_row1_col1, #T_8dcdd_row3_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 46.2%, transparent 46.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8dcdd_row1_col2, #T_8dcdd_row3_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 42.9%, transparent 42.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8dcdd_row1_col3, #T_8dcdd_row3_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 50.0%, transparent 50.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8dcdd_row2_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 49.0%, transparent 49.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8dcdd_row2_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 45.0%, transparent 45.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8dcdd_row2_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 55.4%, transparent 55.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8dcdd_row2_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 60.8%, transparent 60.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# </style>
# <table id="T_8dcdd_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >accuracy</th>
#       <th class="col_heading level0 col1" >f1_score</th>
#       <th class="col_heading level0 col2" >precision</th>
#       <th class="col_heading level0 col3" >recall</th>
#       <th class="col_heading level0 col4" >ml_framework</th>
#       <th class="col_heading level0 col5" >transfer_learning</th>
#       <th class="col_heading level0 col6" >deep_learning</th>
#       <th class="col_heading level0 col7" >model_type</th>
#       <th class="col_heading level0 col8" >num_params</th>
#       <th class="col_heading level0 col9" >optimizer</th>
#       <th class="col_heading level0 col10" >username</th>
#       <th class="col_heading level0 col11" >version</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8dcdd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8dcdd_row0_col0" class="data row0 col0" >86.86%</td>
#       <td id="T_8dcdd_row0_col1" class="data row0 col1" >75.39%</td>
#       <td id="T_8dcdd_row0_col2" class="data row0 col2" >73.45%</td>
#       <td id="T_8dcdd_row0_col3" class="data row0 col3" >78.10%</td>
#       <td id="T_8dcdd_row0_col4" class="data row0 col4" >sklearn</td>
#       <td id="T_8dcdd_row0_col5" class="data row0 col5" >False</td>
#       <td id="T_8dcdd_row0_col6" class="data row0 col6" >False</td>
#       <td id="T_8dcdd_row0_col7" class="data row0 col7" >AdaBoostClassifier</td>
#       <td id="T_8dcdd_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_8dcdd_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_8dcdd_row0_col10" class="data row0 col10" >mikedparrott</td>
#       <td id="T_8dcdd_row0_col11" class="data row0 col11" >4</td>
#     </tr>
#     <tr>
#       <th id="T_8dcdd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8dcdd_row1_col0" class="data row1 col0" >85.90%</td>
#       <td id="T_8dcdd_row1_col1" class="data row1 col1" >46.21%</td>
#       <td id="T_8dcdd_row1_col2" class="data row1 col2" >42.95%</td>
#       <td id="T_8dcdd_row1_col3" class="data row1 col3" >50.00%</td>
#       <td id="T_8dcdd_row1_col4" class="data row1 col4" >sklearn</td>
#       <td id="T_8dcdd_row1_col5" class="data row1 col5" >False</td>
#       <td id="T_8dcdd_row1_col6" class="data row1 col6" >False</td>
#       <td id="T_8dcdd_row1_col7" class="data row1 col7" >LogisticRegression</td>
#       <td id="T_8dcdd_row1_col8" class="data row1 col8" >3.000000</td>
#       <td id="T_8dcdd_row1_col9" class="data row1 col9" >liblinear</td>
#       <td id="T_8dcdd_row1_col10" class="data row1 col10" >mikedparrott</td>
#       <td id="T_8dcdd_row1_col11" class="data row1 col11" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8dcdd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8dcdd_row2_col0" class="data row2 col0" >49.04%</td>
#       <td id="T_8dcdd_row2_col1" class="data row2 col1" >44.95%</td>
#       <td id="T_8dcdd_row2_col2" class="data row2 col2" >55.41%</td>
#       <td id="T_8dcdd_row2_col3" class="data row2 col3" >60.84%</td>
#       <td id="T_8dcdd_row2_col4" class="data row2 col4" >sklearn</td>
#       <td id="T_8dcdd_row2_col5" class="data row2 col5" >False</td>
#       <td id="T_8dcdd_row2_col6" class="data row2 col6" >False</td>
#       <td id="T_8dcdd_row2_col7" class="data row2 col7" >LogisticRegression</td>
#       <td id="T_8dcdd_row2_col8" class="data row2 col8" >3.000000</td>
#       <td id="T_8dcdd_row2_col9" class="data row2 col9" >lbfgs</td>
#       <td id="T_8dcdd_row2_col10" class="data row2 col10" >mikedparrott</td>
#       <td id="T_8dcdd_row2_col11" class="data row2 col11" >2</td>
#     </tr>
#     <tr>
#       <th id="T_8dcdd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8dcdd_row3_col0" class="data row3 col0" >85.90%</td>
#       <td id="T_8dcdd_row3_col1" class="data row3 col1" >46.21%</td>
#       <td id="T_8dcdd_row3_col2" class="data row3 col2" >42.95%</td>
#       <td id="T_8dcdd_row3_col3" class="data row3 col3" >50.00%</td>
#       <td id="T_8dcdd_row3_col4" class="data row3 col4" >sklearn</td>
#       <td id="T_8dcdd_row3_col5" class="data row3 col5" >False</td>
#       <td id="T_8dcdd_row3_col6" class="data row3 col6" >False</td>
#       <td id="T_8dcdd_row3_col7" class="data row3 col7" >LogisticRegression</td>
#       <td id="T_8dcdd_row3_col8" class="data row3 col8" >3.000000</td>
#       <td id="T_8dcdd_row3_col9" class="data row3 col9" >liblinear</td>
#       <td id="T_8dcdd_row3_col10" class="data row3 col10" >mikedparrott</td>
#       <td id="T_8dcdd_row3_col11" class="data row3 col11" >3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 5. Repeat submission process to improve place on leaderboard

# %%
# Train and submit model 2 using same preprocessor (note that you could save a new preprocessor, but we will use the same one for this example).
from sklearn.linear_model import LogisticRegression

model_2 = LogisticRegression(C=.01, penalty='l2')
model_2.fit(preprocessor(X_train), y_train) # Fitting to the training set.
model_2.score(preprocessor(X_train), y_train) # Fit score, 0-1 scale.
# Out:
# 0.6666666666666666

# %%
# Save sklearn model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

feature_count=preprocessor(X_test).shape[1] #Get count of preprocessed features
initial_type = [('float_input', FloatTensorType([None, feature_count]))]  # Insert correct number of preprocessed features

onnx_model = model_to_onnx(model_2, framework='sklearn',
                          initial_types=initial_type,
                          transfer_learning=False,
                          deep_learning=False)

with open("model2.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Submit Model 2: 

#-- Generate predicted y values (Model 2)
prediction_labels = model_2.predict(preprocessor(X_test))

# Submit Model 2 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model2.onnx",
                                 prediction_submission=prediction_labels,
                                 preprocessor_filepath="preprocessor.zip")
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 4
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:1656

# %%
# Compare two or more models
data=mycompetition.compare_models([1,2], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style type="text/css">
# #T_80460_ caption {
#   color: black;
#   font-size: 18px;
# }
# #T_80460_row0_col2, #T_80460_row0_col3, #T_80460_row1_col3, #T_80460_row9_col2, #T_80460_row11_col2 {
#   background: tomato;
# }
# </style>
# <table id="T_80460_">
#   <caption>Model type: LogisticRegression</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >param_name</th>
#       <th class="col_heading level0 col1" >default_value</th>
#       <th class="col_heading level0 col2" >model_version_1</th>
#       <th class="col_heading level0 col3" >model_version_2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80460_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_80460_row0_col0" class="data row0 col0" >C</td>
#       <td id="T_80460_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_80460_row0_col2" class="data row0 col2" >10</td>
#       <td id="T_80460_row0_col3" class="data row0 col3" >0.010000</td>
#     </tr>
#     <tr>
#       <th id="T_80460_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_80460_row1_col0" class="data row1 col0" >class_weight</td>
#       <td id="T_80460_row1_col1" class="data row1 col1" >None</td>
#       <td id="T_80460_row1_col2" class="data row1 col2" >None</td>
#       <td id="T_80460_row1_col3" class="data row1 col3" >balanced</td>
#     </tr>
#     <tr>
#       <th id="T_80460_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_80460_row2_col0" class="data row2 col0" >dual</td>
#       <td id="T_80460_row2_col1" class="data row2 col1" >False</td>
#       <td id="T_80460_row2_col2" class="data row2 col2" >False</td>
#       <td id="T_80460_row2_col3" class="data row2 col3" >False</td>
#     </tr>
#     <tr>
#       <th id="T_80460_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_80460_row3_col0" class="data row3 col0" >fit_intercept</td>
#       <td id="T_80460_row3_col1" class="data row3 col1" >True</td>
#       <td id="T_80460_row3_col2" class="data row3 col2" >True</td>
#       <td id="T_80460_row3_col3" class="data row3 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_80460_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_80460_row4_col0" class="data row4 col0" >intercept_scaling</td>
#       <td id="T_80460_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_80460_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_80460_row4_col3" class="data row4 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_80460_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_80460_row5_col0" class="data row5 col0" >l1_ratio</td>
#       <td id="T_80460_row5_col1" class="data row5 col1" >None</td>
#       <td id="T_80460_row5_col2" class="data row5 col2" >None</td>
#       <td id="T_80460_row5_col3" class="data row5 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_80460_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_80460_row6_col0" class="data row6 col0" >max_iter</td>
#       <td id="T_80460_row6_col1" class="data row6 col1" >100</td>
#       <td id="T_80460_row6_col2" class="data row6 col2" >100</td>
#       <td id="T_80460_row6_col3" class="data row6 col3" >100</td>
#     </tr>
#     <tr>
#       <th id="T_80460_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_80460_row7_col0" class="data row7 col0" >multi_class</td>
#       <td id="T_80460_row7_col1" class="data row7 col1" >auto</td>
#       <td id="T_80460_row7_col2" class="data row7 col2" >auto</td>
#       <td id="T_80460_row7_col3" class="data row7 col3" >auto</td>
#     </tr>
#     <tr>
#       <th id="T_80460_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_80460_row8_col0" class="data row8 col0" >n_jobs</td>
#       <td id="T_80460_row8_col1" class="data row8 col1" >None</td>
#       <td id="T_80460_row8_col2" class="data row8 col2" >None</td>
#       <td id="T_80460_row8_col3" class="data row8 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_80460_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_80460_row9_col0" class="data row9 col0" >penalty</td>
#       <td id="T_80460_row9_col1" class="data row9 col1" >l2</td>
#       <td id="T_80460_row9_col2" class="data row9 col2" >l1</td>
#       <td id="T_80460_row9_col3" class="data row9 col3" >l2</td>
#     </tr>
#     <tr>
#       <th id="T_80460_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_80460_row10_col0" class="data row10 col0" >random_state</td>
#       <td id="T_80460_row10_col1" class="data row10 col1" >None</td>
#       <td id="T_80460_row10_col2" class="data row10 col2" >None</td>
#       <td id="T_80460_row10_col3" class="data row10 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_80460_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_80460_row11_col0" class="data row11 col0" >solver</td>
#       <td id="T_80460_row11_col1" class="data row11 col1" >lbfgs</td>
#       <td id="T_80460_row11_col2" class="data row11 col2" >liblinear</td>
#       <td id="T_80460_row11_col3" class="data row11 col3" >lbfgs</td>
#     </tr>
#     <tr>
#       <th id="T_80460_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_80460_row12_col0" class="data row12 col0" >tol</td>
#       <td id="T_80460_row12_col1" class="data row12 col1" >0.000100</td>
#       <td id="T_80460_row12_col2" class="data row12 col2" >0.000100</td>
#       <td id="T_80460_row12_col3" class="data row12 col3" >0.000100</td>
#     </tr>
#     <tr>
#       <th id="T_80460_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_80460_row13_col0" class="data row13 col0" >verbose</td>
#       <td id="T_80460_row13_col1" class="data row13 col1" >0</td>
#       <td id="T_80460_row13_col2" class="data row13 col2" >0</td>
#       <td id="T_80460_row13_col3" class="data row13 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_80460_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_80460_row14_col0" class="data row14 col0" >warm_start</td>
#       <td id="T_80460_row14_col1" class="data row14 col1" >False</td>
#       <td id="T_80460_row14_col2" class="data row14 col2" >False</td>
#       <td id="T_80460_row14_col3" class="data row14 col3" >False</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Submit a third model using GridSearchCV

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
import numpy as np

param_grid = {'n_estimators': np.arange(100, 300, 500),'max_depth':[1, 3, 5]} #np.arange creates sequence of numbers for each k value

gridmodel = GridSearchCV(RandomForestClassifier(), param_grid=param_grid, cv=10)

#use meta model methods to fit score and predict model:
gridmodel.fit(preprocessor(X_train), y_train)

#extract best score and parameter by calling objects "best_score_" and "best_params_"
print("best mean cross-validation score: {:.3f}".format(gridmodel.best_score_))
print("best parameters: {}".format(gridmodel.best_params_))
# Out:
# best mean cross-validation score: 0.825
# best parameters: {'max_depth': 5, 'n_estimators': 100}

# %%
# Save sklearn model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

feature_count=preprocessor(X_test).shape[1] #Get count of preprocessed features
initial_type = [('float_input', FloatTensorType([None, feature_count]))]  # Insert correct number of preprocessed features

onnx_model = model_to_onnx(gridmodel, framework='sklearn',
                          initial_types=initial_type,
                          transfer_learning=False,
                          deep_learning=False)

with open("gridmodel.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Submit Model 3: 

#-- Generate predicted values
prediction_labels = gridmodel.predict(preprocessor(X_test))

# Submit to Competition Leaderboard
mycompetition.submit_model(model_filepath = "gridmodel.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# Insert search tags to help users find your model (optional): random forest, tuned
# Provide any useful notes about your model (optional): random forest, tuned with gridsearchcv
#
# Your model has been submitted as model version 5
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:2712

# %%
# Get leaderboard

data = mycompetition.get_leaderboard()
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_a2ae7_row0_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 86.9%, transparent 86.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_a2ae7_row0_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 75.4%, transparent 75.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_a2ae7_row0_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 73.4%, transparent 73.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_a2ae7_row0_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 78.1%, transparent 78.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_a2ae7_row0_col4, #T_a2ae7_row0_col5, #T_a2ae7_row0_col6, #T_a2ae7_row0_col7, #T_a2ae7_row0_col8, #T_a2ae7_row0_col9, #T_a2ae7_row0_col10, #T_a2ae7_row0_col11, #T_a2ae7_row1_col4, #T_a2ae7_row1_col5, #T_a2ae7_row1_col6, #T_a2ae7_row1_col7, #T_a2ae7_row1_col8, #T_a2ae7_row1_col9, #T_a2ae7_row1_col10, #T_a2ae7_row1_col11, #T_a2ae7_row2_col4, #T_a2ae7_row2_col5, #T_a2ae7_row2_col6, #T_a2ae7_row2_col7, #T_a2ae7_row2_col8, #T_a2ae7_row2_col9, #T_a2ae7_row2_col10, #T_a2ae7_row2_col11, #T_a2ae7_row3_col4, #T_a2ae7_row3_col5, #T_a2ae7_row3_col6, #T_a2ae7_row3_col7, #T_a2ae7_row3_col8, #T_a2ae7_row3_col9, #T_a2ae7_row3_col10, #T_a2ae7_row3_col11, #T_a2ae7_row4_col4, #T_a2ae7_row4_col5, #T_a2ae7_row4_col6, #T_a2ae7_row4_col7, #T_a2ae7_row4_col8, #T_a2ae7_row4_col9, #T_a2ae7_row4_col10, #T_a2ae7_row4_col11, #T_a2ae7_row5_col4, #T_a2ae7_row5_col5, #T_a2ae7_row5_col6, #T_a2ae7_row5_col7, #T_a2ae7_row5_col8, #T_a2ae7_row5_col9, #T_a2ae7_row5_col10, #T_a2ae7_row5_col11 {
#   text-align: center;
# }
# #T_a2ae7_row1_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 86.5%, transparent 86.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_a2ae7_row1_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 74.1%, transparent 74.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_a2ae7_row1_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 72.7%, transparent 72.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_a2ae7_row1_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 76.0%, transparent 76.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_a2ae7_row2_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 84.6%, transparent 84.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_a2ae7_row2_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 70.9%, transparent 70.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_a2ae7_row2_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 69.5%, transparent 69.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_a2ae7_row2_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 73.0%, transparent 73.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_a2ae7_row3_col0, #T_a2ae7_row4_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 85.9%, transparent 85.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_a2ae7_row3_col1, #T_a2ae7_row4_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 46.2%, transparent 46.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_a2ae7_row3_col2, #T_a2ae7_row4_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 42.9%, transparent 42.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_a2ae7_row3_col3, #T_a2ae7_row4_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 50.0%, transparent 50.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_a2ae7_row5_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 49.0%, transparent 49.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_a2ae7_row5_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 45.0%, transparent 45.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_a2ae7_row5_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 55.4%, transparent 55.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_a2ae7_row5_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 60.8%, transparent 60.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# </style>
# <table id="T_a2ae7_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >accuracy</th>
#       <th class="col_heading level0 col1" >f1_score</th>
#       <th class="col_heading level0 col2" >precision</th>
#       <th class="col_heading level0 col3" >recall</th>
#       <th class="col_heading level0 col4" >ml_framework</th>
#       <th class="col_heading level0 col5" >transfer_learning</th>
#       <th class="col_heading level0 col6" >deep_learning</th>
#       <th class="col_heading level0 col7" >model_type</th>
#       <th class="col_heading level0 col8" >num_params</th>
#       <th class="col_heading level0 col9" >optimizer</th>
#       <th class="col_heading level0 col10" >username</th>
#       <th class="col_heading level0 col11" >version</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2ae7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a2ae7_row0_col0" class="data row0 col0" >86.86%</td>
#       <td id="T_a2ae7_row0_col1" class="data row0 col1" >75.39%</td>
#       <td id="T_a2ae7_row0_col2" class="data row0 col2" >73.45%</td>
#       <td id="T_a2ae7_row0_col3" class="data row0 col3" >78.10%</td>
#       <td id="T_a2ae7_row0_col4" class="data row0 col4" >sklearn</td>
#       <td id="T_a2ae7_row0_col5" class="data row0 col5" >False</td>
#       <td id="T_a2ae7_row0_col6" class="data row0 col6" >False</td>
#       <td id="T_a2ae7_row0_col7" class="data row0 col7" >AdaBoostClassifier</td>
#       <td id="T_a2ae7_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_a2ae7_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_a2ae7_row0_col10" class="data row0 col10" >mikedparrott</td>
#       <td id="T_a2ae7_row0_col11" class="data row0 col11" >4</td>
#     </tr>
#     <tr>
#       <th id="T_a2ae7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a2ae7_row1_col0" class="data row1 col0" >86.54%</td>
#       <td id="T_a2ae7_row1_col1" class="data row1 col1" >74.15%</td>
#       <td id="T_a2ae7_row1_col2" class="data row1 col2" >72.69%</td>
#       <td id="T_a2ae7_row1_col3" class="data row1 col3" >76.02%</td>
#       <td id="T_a2ae7_row1_col4" class="data row1 col4" >sklearn</td>
#       <td id="T_a2ae7_row1_col5" class="data row1 col5" >False</td>
#       <td id="T_a2ae7_row1_col6" class="data row1 col6" >False</td>
#       <td id="T_a2ae7_row1_col7" class="data row1 col7" >RandomForestClassifier</td>
#       <td id="T_a2ae7_row1_col8" class="data row1 col8" >nan</td>
#       <td id="T_a2ae7_row1_col9" class="data row1 col9" >nan</td>
#       <td id="T_a2ae7_row1_col10" class="data row1 col10" >mikedparrott</td>
#       <td id="T_a2ae7_row1_col11" class="data row1 col11" >5</td>
#     </tr>
#     <tr>
#       <th id="T_a2ae7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a2ae7_row2_col0" class="data row2 col0" >84.62%</td>
#       <td id="T_a2ae7_row2_col1" class="data row2 col1" >70.95%</td>
#       <td id="T_a2ae7_row2_col2" class="data row2 col2" >69.47%</td>
#       <td id="T_a2ae7_row2_col3" class="data row2 col3" >73.00%</td>
#       <td id="T_a2ae7_row2_col4" class="data row2 col4" >sklearn</td>
#       <td id="T_a2ae7_row2_col5" class="data row2 col5" >False</td>
#       <td id="T_a2ae7_r

# %%
# Compare two or more models
data=mycompetition.compare_models([1,2,4,5], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style type="text/css">
# #T_7ad4b_ caption {
#   color: black;
#   font-size: 18px;
# }
# #T_7ad4b_row0_col2, #T_7ad4b_row0_col3, #T_7ad4b_row1_col3, #T_7ad4b_row9_col2, #T_7ad4b_row11_col2 {
#   background: tomato;
# }
# </style>
# <table id="T_7ad4b_">
#   <caption>Model type: LogisticRegression</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >param_name</th>
#       <th class="col_heading level0 col1" >default_value</th>
#       <th class="col_heading level0 col2" >model_version_1</th>
#       <th class="col_heading level0 col3" >model_version_2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ad4b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7ad4b_row0_col0" class="data row0 col0" >C</td>
#       <td id="T_7ad4b_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_7ad4b_row0_col2" class="data row0 col2" >10</td>
#       <td id="T_7ad4b_row0_col3" class="data row0 col3" >0.010000</td>
#     </tr>
#     <tr>
#       <th id="T_7ad4b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7ad4b_row1_col0" class="data row1 col0" >class_weight</td>
#       <td id="T_7ad4b_row1_col1" class="data row1 col1" >None</td>
#       <td id="T_7ad4b_row1_col2" class="data row1 col2" >None</td>
#       <td id="T_7ad4b_row1_col3" class="data row1 col3" >balanced</td>
#     </tr>
#     <tr>
#       <th id="T_7ad4b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7ad4b_row2_col0" class="data row2 col0" >dual</td>
#       <td id="T_7ad4b_row2_col1" class="data row2 col1" >False</td>
#       <td id="T_7ad4b_row2_col2" class="data row2 col2" >False</td>
#       <td id="T_7ad4b_row2_col3" class="data row2 col3" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7ad4b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7ad4b_row3_col0" class="data row3 col0" >fit_intercept</td>
#       <td id="T_7ad4b_row3_col1" class="data row3 col1" >True</td>
#       <td id="T_7ad4b_row3_col2" class="data row3 col2" >True</td>
#       <td id="T_7ad4b_row3_col3" class="data row3 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_7ad4b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7ad4b_row4_col0" class="data row4 col0" >intercept_scaling</td>
#       <td id="T_7ad4b_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_7ad4b_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_7ad4b_row4_col3" class="data row4 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7ad4b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7ad4b_row5_col0" class="data row5 col0" >l1_ratio</td>
#       <td id="T_7ad4b_row5_col1" class="data row5 col1" >None</td>
#       <td id="T_7ad4b_row5_col2" class="data row5 col2" >None</td>
#       <td id="T_7ad4b_row5_col3" class="data row5 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7ad4b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7ad4b_row6_col0" class="data row6 col0" >max_iter</td>
#       <td id="T_7ad4b_row6_col1" class="data row6 col1" >100</td>
#       <td id="T_7ad4b_row6_col2" class="data row6 col2" >100</td>
#       <td id="T_7ad4b_row6_col3" class="data row6 col3" >100</td>
#     </tr>
#     <tr>
#       <th id="T_7ad4b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7ad4b_row7_col0" class="data row7 col0" >multi_class</td>
#       <td id="T_7ad4b_row7_col1" class="data row7 col1" >auto</td>
#       <td id="T_7ad4b_row7_col2" class="data row7 col2" >auto</td>
#       <td id="T_7ad4b_row7_col3" class="data row7 col3" >auto</td>
#     </tr>
#     <tr>
#       <th id="T_7ad4b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7ad4b_row8_col0" class="data row8 col0" >n_jobs</td>
#       <td id="T_7ad4b_row8_col1" class="data row8 col1" >None</td>
#       <td id="T_7ad4b_row8_col2" class="data row8 col2" >None</td>
#       <td id="T_7ad4b_row8_col3" class="data row8 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7ad4b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7ad4b_row9_col0" class="data row9 col0" >penalty</td>
#       <td id="T_7ad4b_row9_col1" class="data row9 col1" >l2</td>
#       <td id="T_7ad4b_row9_col2" class="data row9 col2" >l1</td>
#       <td id="T_7ad4b_row9_col3" class="data row9 col3" >l2</td>
#     </tr>
#     <tr>
#       <th id="T_7ad4b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7ad4b_row10_col0" class="data row10 col0" >random_state</td>
#       <td id="T_7ad4b_row10_col1" class="data row10 col1" >None</td>
#       <td id="T_7ad4b_row10_col2" class="data row10 col2" >None</td>
#       <td id="T_7ad4b_row10_col3" class="data row10 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7ad4b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7ad4b_row11_col0" class="data row11 col0" >solver</td>
#       <td id="T_7ad4b_row11_col1" class="data row11 col1" >lbfgs</td>
#       <td id="T_7ad4b_row11_col2" class="data row11 col2" >liblinear</td>
#       <td id="T_7ad4b_row11_col3" class="data row11 col3" >lbfgs</td>
#     </tr>
#     <tr>
#       <th id="T_7ad4b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7ad4b_row12_col0" class="data row12 col0" >tol</td>
#       <td id="T_7ad4b_row12_col1" class="data row12 col1" >0.000100</td>
#       <td id="T_7ad4b_row12_col2" class="data row12 col2" >0.000100</td>
#       <td id="T_7ad4b_row12_col3" class="data row12 col3" >0.000100</td>
#     </tr>
#     <tr>
#       <th id="T_7ad4b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_7ad4b_row13_col0" class="data row13 col0" >verbose</td>
#       <td id="T_7ad4b_row13_col1" class="data row13 col1" >0</td>
#       <td id="T_7ad4b_row13_col2" class="data row13 col2" >0</td>
#       <td id="T_7ad4b_row13_col3" class="data row13 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7ad4b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_7ad4b_row14_col0" class="data row14 col0" >warm_start</td>
#       <td id="T_7ad4b_row14_col1" class="data row14 col1" >False</td>
#       <td id="T_7ad4b_row14_col2" class="data row14 col2" >False</td>
#       <td id="T_7ad4b_row14_col3" class="data row14 col3" >False</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_73f1b_ caption {
#   color: black;
#   font-size: 18px;
# }
# #T_73f1b_row3_col2, #T_73f1b_row4_col2 {
#   background: tomato;
# }
# </style>
# <table id="T_73f1b_">
#   <caption>Model type: AdaBoostClassifier</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >param_name</th>
#       <th class="col_heading level0 col1" >default_value</th>
#       <th class="col_heading level0 col2" >model_version_4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73f1b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_73f1b_row0_col0" class="data row0 col0" >algorithm</td>
#       <td id="T_73f1b_row0_col1" class="data row0 col1" >SAMME.R</td>
#       <td id="T_73f1b_row0_col2" class="data row0 col2" >SAMME.R</td>
#     </tr>
#     <tr>
#       <th id="T_73f1b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_73f1b_row1_col0" class="data row1 col0" >base_estimator</td>
#       <td id="T_73f1b_row1_col1" class="data row1 col1" >None</td>
#       <td id="T_73f1b_row1_col2" class="data row1 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_73f1b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_73f1b_row2_col0" class="data row2 col0" >learning_rate</td>
#       <td id="T_73f1b_row2_col1" class="data row2 col1" >1.000000</td>
#       <td id="T_73f1b_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_73f1b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_73f1b_row3_col0" class="data row3 col0" >n_estimators</td>
#       <td id="T_73f1b_row3_col1" class="data row3 col1" >50</td>
#       <td id="T_73f1b_row3_col2" class="data row3 col2" >200</td>
#     </tr>
#     <tr>
#       <th id="T_73f1b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_73f1b_row4_col0" class="data row4 col0" >random_state</td>
#       <td id="T_73f1b_row4_col1" class="data row4 col1" >None</td>
#       <td id="T_73f1b_row4_col2" class="data row4 col2" >30</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_f7f48_ caption {
#   color: black;
#   font-size: 18px;
# }
# #T_f7f48_row4_col2 {
#   background: tomato;
# }
# </style>
# <table id="T_f7f48_">
#   <caption>Model type: RandomForestClassifier</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >param_name</th>
#       <th class="col_heading level0 col1" >default_value</th>
#       <th class="col_heading level0 col2" >model_version_5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f7f48_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f7f48_row0_col0" class="data row0 col0" >bootstrap</td>
#       <td id="T_f7f48_row0_col1" class="data row0 col1" >True</td>
#       <td id="T_f7f48_row0_col2" class="data row0 col2" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f7f48_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f7f48_row1_col0" class="data row1 col0" >ccp_alpha</td>
#       <td id="T_f7f48_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_f7f48_row1_col2" class="data row1 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f7f48_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f7f48_row2_col0" class="data row2 col0" >class_weight</td>
#       <td id="T_f7f48_row2_col1" class="data row2 col1" >None</td>
#       <td id="T_f7f48_row2_col2" class="data row2 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f7f48_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f7f48_row3_col0" class="data row3 col0" >criterion</td>
#       <td id="T_f7f48_row3_col1" class="data row3 col1" >gini</td>
#       <td id="T_f7f48_row3_col2" class="data row3 col2" >gini</td>
#     </tr>
#     <tr>
#       <th id="T_f7f48_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f7f48_row4_col0" class="data row4 col0" >max_depth</td>
#       <td id="T_f7f48_row4_col1" class="data row4 col1" >None</td>
#       <td id="T_f7f48_row4_col2" class="data row4 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_f7f48_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f7f48_row5_col0" class="data row5 col0" >max_features</td>
#       <td id="T_f7f48_row5_col1" class="data row5 col1" >auto</td>
#       <td id="T_f7f48_row5_col2" class="data row5 col2" >auto</td>
#     </tr>
#     <tr>
#       <th id="T_f7f48_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f7f48_row6_col0" class="data row6 col0" >max_leaf_nodes</td>
#       <td id="T_f7f48_row6_col1" class="data row6 col1" >None</td>
#       <td id="T_f7f48_row6_col2" class="data row6 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f7f48_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f7f48_row7_col0" class="data row7 col0" >max_samples</td>
#       <td id="T_f7f48_row7_col1" class="data row7 col1" >None</td>
#       <td id="T_f7f48_row7_col2" class="data row7 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f7f48_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f7f48_row8_col0" class="data row8 col0" >min_impurity_decrease</td>
#       <td id="T_f7f48_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_f7f48_row8_col2" class="data row8 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f7f48_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f7f48_row9_col0" class="data row9 col0" >min_impurity_split</td>
#       <td id="T_f7f48_row9_col1" class="data row9 col1" >None</td>
#       <td id="T_f7f48_row9_col2" class="data row9 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f7f48_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f7f48_row10_col0" class="data row10 col0" >min_samples_leaf</td>
#       <td id="T_f7f48_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_f7f48_row10_col2" class="data row10 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f7f48_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f7f48_row11_col0" class="data row11 col0" >min_samples_split</td>
#       <td id="T_f7f48_row11_col1" class="data row11 col1" >2</td>
#       <td id="T_f7f48_row11_col2" class="data row11 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_f7f48_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f7f48_row12_col0" class="data row12 col0" >min_weight_fraction_leaf</td>
#       <td id="T_f7f48_row12_col1" class="data row12 col1" >0.000000</td>
#       <td id="T_f7f48_row12_col2" class="data row12 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f7f48_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f7f48_row13_col0" class="data row13 col0" >n_estimators</td>
#       <td id="T_f7f48_row13_col1" class="data row13 col1" >100</td>
#       <td id="T_f7f48_row13_col2" class="data row13 col2" >100</td>
#     </tr>
#     <tr>
#       <th id="T_f7f48_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f7f48_row14_col0" class="data row14 col0" >n_jobs</td>
#       <td id="T_f7f48_row14_col1" class="data row14 col1" >None</td>
#       <td id="T_f7f48_row14_col2" class="data row14 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f7f48_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f7f48_row15_col0" class="data row15 col0" >oob_score</td>
#       <td id="T_f7f48_row15_col1" class="data row15 col1" >False</td>
#       <td id="T_f7f48_row15_col2" class="data row15 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f7f48_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f7f48_row16_col0" class="data row16 col0" >random_state</td>
#       <td id="T_f7f48_row16_col1" class="data row16 col1" >None</td>
#       <td id="T_f7f48_row16_col2" class="data row16 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f7f48_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f7f48_row17_col0" class="data row17 col0" >verbose</td>
#       <td id="T_f7f48_row17_col1" class="data row17 col1" >0</td>
#       <td id="T_f7f48_row17_col2" class="data row17 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f7f48_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f7f48_row18_col0" class="data row18 col0" >warm_start</td>
#       <td id="T_f7f48_row18_col1" class="data row18 col1" >False</td>
#       <td id="T_f7f48_row18_col2" class="data row18 col2" >False</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Here are several classic ML architectures you can consider choosing from to experiment with next:
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier

#Example code to fit model:
model = GradientBoostingClassifier(n_estimators=50, learning_rate=1.0,
    max_depth=1, random_state=0).fit(preprocessor(X_train), y_train)
model.score(preprocessor(X_train), y_train)

# Save sklearn model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

feature_count=preprocessor(X_test).shape[1] #Get count of preprocessed features
initial_type = [('float_input', FloatTensorType([None, feature_count]))]  # Insert correct number of preprocessed features

onnx_model = model_to_onnx(model, framework='sklearn',
                          initial_types=initial_type,
                          transfer_learning=False,
                          deep_learning=False)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

#-- Generate predicted values (a list of predicted labels "real" or "fake")
prediction_labels = model.predict(preprocessor(X_test))

# Submit model to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 6
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:2712

# %% [markdown]
# # Submit tf.keras deep learning model

# %%
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation

model = Sequential()
model.add(Dense(64, input_dim=3, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))

model.add(Dense(2, activation='softmax')) 
                                            
# Compile model
model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])


y_train_onehot=pd.get_dummies(y_train)
# Fitting the NN to the Training set
model.fit(preprocessor(X_train), y_train_onehot, 
               batch_size = 20, 
               epochs = 3, validation_split=0.25)
# Out:
# Epoch 1/3
# 92/92 [==============================] - 1s 7ms/step - loss: 1.5373 - accuracy: 0.8440 - val_loss: 4.1031 - val_accuracy: 0.0000e+00
# Epoch 2/3
# 92/92 [==============================] - 0s 3ms/step - loss: 0.4660 - accuracy: 0.8880 - val_loss: 2.4636 - val_accuracy: 0.0000e+00
# Epoch 3/3
# 92/92 [==============================] - 0s 3ms/step - loss: 0.3870 - accuracy: 0.8880 - val_loss: 1.5939 - val_accuracy: 0.0033

# %%
list(y_train_onehot.columns)
# Out:
# [0, 1]

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model = model_to_onnx(model, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Submit Model: 

#-- Generate predicted y values
#Note: Keras predict returns the predicted column index location for classification models
prediction_column_index=model.predict(preprocessor(X_test)).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [list(y_train_onehot.columns)[i] for i in prediction_column_index]

# Submit Model 1 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# 20/20 [==============================] - 0s 2ms/step
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 8
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:2712

# %%
# Get leaderboard

data = mycompetition.get_leaderboard()
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_60472_row0_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 86.9%, transparent 86.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_60472_row0_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 75.4%, transparent 75.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_60472_row0_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 73.4%, transparent 73.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_60472_row0_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 78.1%, transparent 78.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_60472_row0_col4, #T_60472_row0_col5, #T_60472_row0_col6, #T_60472_row0_col7, #T_60472_row0_col8, #T_60472_row0_col9, #T_60472_row0_col10, #T_60472_row0_col11, #T_60472_row0_col12, #T_60472_row0_col13, #T_60472_row0_col14, #T_60472_row0_col15, #T_60472_row0_col16, #T_60472_row0_col17, #T_60472_row1_col4, #T_60472_row1_col5, #T_60472_row1_col6, #T_60472_row1_col7, #T_60472_row1_col8, #T_60472_row1_col9, #T_60472_row1_col10, #T_60472_row1_col11, #T_60472_row1_col12, #T_60472_row1_col13, #T_60472_row1_col14, #T_60472_row1_col15, #T_60472_row1_col16, #T_60472_row1_col17, #T_60472_row2_col4, #T_60472_row2_col5, #T_60472_row2_col6, #T_60472_row2_col7, #T_60472_row2_col8, #T_60472_row2_col9, #T_60472_row2_col10, #T_60472_row2_col11, #T_60472_row2_col12, #T_60472_row2_col13, #T_60472_row2_col14, #T_60472_row2_col15, #T_60472_row2_col16, #T_60472_row2_col17, #T_60472_row3_col4, #T_60472_row3_col5, #T_60472_row3_col6, #T_60472_row3_col7, #T_60472_row3_col8, #T_60472_row3_col9, #T_60472_row3_col10, #T_60472_row3_col11, #T_60472_row3_col12, #T_60472_row3_col13, #T_60472_row3_col14, #T_60472_row3_col15, #T_60472_row3_col16, #T_60472_row3_col17, #T_60472_row4_col4, #T_60472_row4_col5, #T_60472_row4_col6, #T_60472_row4_col7, #T_60472_row4_col8, #T_60472_row4_col9, #T_60472_row4_col10, #T_60472_row4_col11, #T_60472_row4_col12, #T_60472_row4_col13, #T_60472_row4_col14, #T_60472_row4_col15, #T_60472_row4_col16, #T_60472_row4_col17, #T_60472_row5_col4, #T_60472_row5_col5, #T_60472_row5_col6, #T_60472_row5_col7, #T_60472_row5_col8, #T_60472_row5_col9, #T_60472_row5_col10, #T_60472_row5_col11, #T_60472_row5_col12, #T_60472_row5_col13, #T_60472_row5_col14, #T_60472_row5_col15, #T_60472_row5_col16, #T_60472_row5_col17, #T_60472_row6_col4, #T_60472_row6_col5, #T_60472_row6_col6, #T_60472_row6_col7, #T_60472_row6_col8, #T_60472_row6_col9, #T_60472_row6_col10, #T_60472_row6_col11, #T_60472_row6_col12, #T_60472_row6_col13, #T_60472_row6_col14, #T_60472_row6_col15, #T_60472_row6_col16, #T_60472_row6_col17, #T_60472_row7_col4, #T_60472_row7_col5, #T_60472_row7_col6, #T_60472_row7_col7, #T_60472_row7_col8, #T_60472_row7_col9, #T_60472_row7_col10, #T_60472_row7_col11, #T_60472_row7_col12, #T_60472_row7_col13, #T_60472_row7_col14, #T_60472_row7_col15, #T_60472_row7_col16, #T_60472_row7_col17 {
#   text-align: center;
# }
# #T_60472_row1_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 86.5%, transparent 86.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_60472_row1_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 74.1%, transparent 74.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_60472_row1_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 72.7%, transparent 72.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_60472_row1_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 76.0%, transparent 76.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_60472_row2_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 84.6%, transparent 84.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_60472_row2_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 70.9%, transparent 70.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_60472_row2_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 69.5%, transparent 69.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_60472_row2_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 73.0%, transparent 73.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_60472_row3_col0, #T_60472_row4_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 85.9%, transparent 85.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_60472_row3_col1, #T_60472_row4_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 46.2%, transparent 46.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_60472_row3_col2, #T_60472_row4_col2, #T_60472_row6_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 42.9%, transparent 42.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_60472_row3_col3, #T_60472_row4_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 50.0%, transparent 50.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_60472_row5_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 49.0%, transparent 49.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_60472_row5_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 45.0%, transparent 45.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_60472_row5_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 55.4%, transparent 55.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_60472_row5_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 60.8%, transparent 60.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_60472_row6_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 85.3%, transparent 85.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_60472_row6_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 46.0%, transparent 46.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_60472_row6_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 49.6%, transparent 49.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_60472_row7_col0, #T_60472_row7_col1, #T_60472_row7_col2, #T_60472_row7_col3 {
#   text-align: center;
#   color: #251e1b;
#   font-size: 12px;
# }
# </style>
# <table id="T_60472_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >accuracy</th>
#       <th class="col_heading level0 col1" >f1_score</th>
#       <th class="col_heading level0 col2" >precision</th>
#       <th class="col_heading level0 col3" >recall</th>
#       <th class="col_heading level0 col4" >ml_framework</th>
#       <th class="col_heading level0 col5" >transfer_learning</th>
#       <th class="col_heading level0 col6" >deep_learning</th>
#       <th class="col_heading level0 col7" >model_type</th>
#       <th class="col_heading level0 col8" >depth</th>
#       <th class="col_heading level0 col9" >num_params</th>
#       <th class="col_heading level0 col10" >dense_layers</th>
#       <th class="col_heading level0 col11" >relu_act</th>
#       <th class="col_heading level0 col12" >softmax_act</th>
#       <th class="col_heading level0 col13" >loss</th>
#       <th class="col_heading level0 col14" >optimizer</th>
#       <th class="col_heading level0 col15" >memory_size</th>
#       <th class="col_heading level0 col16" >username</th>
#       <th class="col_heading level0 col17" >version</th>
#     </tr>
#   </thead>
#   <tb

# %% [markdown]
# ## What if I just want to submit predictions?
# Or a model architecture doesn't submit.
# Answer:  Just submit predictions without a model or preprocessor object

# %%
# Submit Model 1 to Competition Leaderboard
mycompetition.submit_model(model_filepath = None,
                                 preprocessor_filepath=None,
                                 prediction_submission=prediction_labels)
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 9
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:2712
