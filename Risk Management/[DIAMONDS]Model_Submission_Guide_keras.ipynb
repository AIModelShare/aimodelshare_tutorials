# %% [markdown]
# <p align="center"><img width="50%" src="https://aimodelsharecontent.s3.amazonaws.com/aimodshare_banner.jpg" /></p>
#
#
# ---

# %% [markdown]
# <p align="center"><h1 align="center">Diamond Price Prediction Competition </h1>
#
# ---
# Let's share our models to a centralized leaderboard, so that we can collaborate and learn from the model experimentation process...
#
# **Instructions:**
# 1.   Get data in and set up X_train / X_test / y_train
# 2.   Preprocess data  with Sklearn Column Transformer/ Write and Save Preprocessor function
# 3. Fit model on preprocessed data and save preprocessor function and model
# 4. Generate predictions from X_test data and submit model to competition
# 5. Repeat submission process to improve place on leaderboard

# %% [markdown]
# ## 1. Get data in and set up X_train, X_test, y_train objects

# %%
#install aimodelshare library
! pip install aimodelshare --upgrade

# %%
# Get competition data
from aimodelshare import download_data
download_data('public.ecr.aws/y2e2a1d6/diamonds_competition_data-repository:latest')
# Out:
# Downloading [=======================================>         ]
#
# Data downloaded successfully.

# %%
# Separate data into X_train, y_train, and X_test
import pandas as pd

X_train = pd.read_csv("diamonds_competition_data/X_train.csv")
y_train = pd.read_csv("diamonds_competition_data/y_train.csv", squeeze = True)

X_test=pd.read_csv("diamonds_competition_data/X_test.csv")

X_train.head()
# Out:
#    carat      cut color clarity  depth  table     x     y     z
# 0   0.90     Good     E     SI2   64.1   57.0  6.07  6.09  3.90
# 1   1.54  Premium     G     VS2   61.1   59.0  7.44  7.40  4.53
# 2   0.52    Ideal     D     SI1   62.4   56.0  5.17  5.12  3.21
# 3   0.85    Ideal     E     SI1   63.0   56.0  6.00  6.04  3.79
# 4   0.35    Ideal     D     VS2   60.9   57.0  4.55  4.51  2.76

# %% [markdown]
# ##2.   Preprocess data using Sklearn Column Transformer / Write and Save Preprocessor function

# %%
# Simple Preprocessor with sklearn 
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

numeric_features = ['carat', 'depth', 'table', 'x', 'y', 'z']
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')), 
    ('scaler', StandardScaler())])

categorical_features = ['cut', 'color', 'clarity']

# Replacing missing values with Modal value and then one-hot encoding.
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# Final preprocessor object set up with ColumnTransformer...

preprocess = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# fit preprocessor to your data
preprocess = preprocess.fit(X_train)

# %%
# Write function to transform data with preprocessor 
# In this case we use sklearn's Column transformer in our preprocessor function

def preprocessor(data):
    preprocessed_data=preprocess.transform(data)
    return preprocessed_data

# %%
# check shape of X data 
preprocessor(X_train).shape
# Out:
# (43152, 26)

# %% [markdown]
# ##3. Fit model on preprocessed data and save preprocessor function and model

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
import keras

feature_count=preprocessor(X_train).shape[1] #count features in input data

model = Sequential()
model.add(Dense(64, input_dim=feature_count, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))

model.add(Dense(1, kernel_initializer='normal')) 
                                            
# Compile model
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])

# Fitting the NN to the Training set
model.fit(preprocessor(X_train), y_train, 
               batch_size = 60, 
               epochs = 15, validation_split=0.35)

# %% [markdown]
# #### Save preprocessor function to local "preprocessor.zip" file

# %%
import aimodelshare as ai
ai.export_preprocessor(preprocessor,"")
# Out:
# Your preprocessor is now saved to 'preprocessor.zip'

# %% [markdown]
# #### Save model to local ".onnx" file

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

# Check how many preprocessed input features there are
from skl2onnx.common.data_types import FloatTensorType

onnx_model = model_to_onnx(model, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %% [markdown]
# ## 4. Generate predictions from X_test data and submit model to competition

# %%
#Set credentials using modelshare.org username/password

from aimodelshare.aws import set_credentials
    
apiurl="https://csyks5i22a.execute-api.us-east-1.amazonaws.com/prod/m" #This is the unique rest api that powers this Diamond Price Prediction Playground

set_credentials(apiurl=apiurl)
# Out:
# AI Modelshare Username:··········
# AI Modelshare Password:··········
# AI Model Share login credentials set successfully.

# %%
#Instantiate Compet
" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >mse</th>
#       <th class="col_heading level0 col1" >rmse</th>
#       <th class="col_heading level0 col2" >mae</th>
#       <th class="col_heading level0 col3" >r2</th>
#       <th class="col_heading level0 col4" >ml_framework</th>
#       <th class="col_heading level0 col5" >transfer_learning</th>
#       <th class="col_heading level0 col6" >deep_learning</th>
#       <th class="col_heading level0 col7" >model_type</th>
#       <th class="col_heading level0 col8" >depth</th>
#       <th class="col_heading level0 col9" >num_params</th>
#       <th class="col_heading level0 col10" >dense_layers</th>
#       <th class="col_heading level0 col11" >relu_act</th>
#       <th class="col_heading level0 col12" >loss</th>
#       <th class="col_heading level0 col13" >optimizer</th>
#       <th class="col_heading level0 col14" >memory_size</th>
#       <th class="col_heading level0 col15" >username</th>
#       <th class="col_heading level0 col16" >version</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_02ddb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_02ddb_row0_col0" class="data row0 col0" >411729.36</td>
#       <td id="T_02ddb_row0_col1" class="data row0 col1" >641.66</td>
#       <td id="T_02ddb_row0_col2" class="data row0 col2" >341.78</td>
#       <td id="T_02ddb_row0_col3" class="data row0 col3" >0.97</td>
#       <td id="T_02ddb_row0_col4" class="data row0 col4" >keras</td>
#       <td id="T_02ddb_row0_col5" class="data row0 col5" >False</td>
#       <td id="T_02ddb_row0_col6" class="data row0 col6" >True</td>
#       <td id="T_02ddb_row0_col7" class="data row0 col7" >Sequential</td>
#       <td id="T_02ddb_row0_col8" class="data row0 col8" >4.000000</td>
#       <td id="T_02ddb_row0_col9" class="data row0 col9" >10113.000000</td>
#       <td id="T_02ddb_row0_col10" class="data row0 col10" >4.000000</td>
#       <td id="T_02ddb_row0_col11" class="data row0 col11" >3.000000</td>
#       <td id="T_02ddb_row0_col12" class="data row0 col12" >str</td>
#       <td id="T_02ddb_row0_col13" class="data row0 col13" >Adam</td>
#       <td id="T_02ddb_row0_col14" class="data row0 col14" >41504.000000</td>
#       <td id="T_02ddb_row0_col15" class="data row0 col15" >ML_Risk_Mgmnt</td>
#       <td id="T_02ddb_row0_col16" class="data row0 col16" >5</td>
#     </tr>
#     <tr>
#       <th id="T_02ddb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_02ddb_row1_col0" class="data row1 col0" >1865445.56</td>
#       <td id="T_02ddb_row1_col1" class="data row1 col1" >1365.81</td>
#       <td id="T_02ddb_row1_col2" class="data row1 col2" >773.38</td>
#       <td id="T_02ddb_row1_col3" class="data row1 col3" >0.88</td>
#       <td id="T_02ddb_row1_col4" class="data row1 col4" >sklearn</td>
#       <td id="T_02ddb_row1_col5" class="data row1 col5" >False</td>
#       <td id="T_02ddb_row1_co

# %% [markdown]
# ## 5. Repeat submission process to improve place on leaderboard

# %%
# Create model 2  -- Model with Dropout regularization
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout,BatchNormalization

feature_count=preprocessor(X_train).shape[1] #count features in input data

model_2 = Sequential()
model_2.add(Dense(64, input_dim=feature_count))
model_2.add(BatchNormalization())
model_2.add(Activation('relu'))
model_2.add(Dense(64))
model_2.add(BatchNormalization())
model_2.add(Activation('relu'))
model_2.add(Dense(64))
model_2.add(BatchNormalization())
model_2.add(Activation('relu'))
model_2.add(Dense(1, kernel_initializer='normal')) 
                                            
# Compile model
model_2.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])

# Fitting the NN to the Training set
model_2.fit(preprocessor(X_train), y_train, 
               batch_size = 120, 
               epochs = 10, validation_split=0.35)

# %%
# Save Model 2 to .onnx file

onnx_model = model_to_onnx(model_2, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

# Save model to local .onnx file
with open("model_2.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
# Submit Model 2

#-- Generate predicted y values (Model 2)
prediction_labels = model_2.predict(preprocessor(X_test))

# Submit Model 2 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model_2.onnx",
                                 prediction_submission=prediction_labels,
                                 preprocessor_filepath="preprocessor.zip")
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 6
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:1747

# %%
# Compare two or more models
data=mycompetition.compare_models([5, 6], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style type="text/css">
# #T_70f05_ caption {
#   color: black;
#   font-size: 18px;
# }
# #T_70f05_row0_col0, #T_70f05_row0_col3, #T_70f05_row1_col0, #T_70f05_row2_col0, #T_70f05_row3_col0, #T_70f05_row3_col3, #T_70f05_row6_col3, #T_70f05_row9_col3 {
#   background: #fff2ae;
#   color: black;
#   color: black;
# }
# #T_70f05_row0_col1, #T_70f05_row0_col2, #T_70f05_row0_col4, #T_70f05_row0_col5, #T_70f05_row1_col1, #T_70f05_row1_col2, #T_70f05_row1_col4, #T_70f05_row1_col5, #T_70f05_row2_col1, #T_70f05_row2_col2, #T_70f05_row2_col4, #T_70f05_row2_col5, #T_70f05_row3_col1, #T_70f05_row3_col2, #T_70f05_row3_col4, #T_70f05_row3_col5, #T_70f05_row4_col0, #T_70f05_row4_col1, #T_70f05_row4_col2, #T_70f05_row4_col4, #T_70f05_row4_col5, #T_70f05_row5_col0, #T_70f05_row5_col1, #T_70f05_row5_col2, #T_70f05_row5_col4, #T_70f05_row5_col5, #T_70f05_row6_col0, #T_70f05_row6_col1, #T_70f05_row6_col2, #T_70f05_row6_col4, #T_70f05_row6_col5, #T_70f05_row7_col0, #T_70f05_row7_col1, #T_70f05_row7_col2, #T_70f05_row7_col4, #T_70f05_row7_col5, #T_70f05_row8_col0, #T_70f05_row8_col1, #T_70f05_row8_col2, #T_70f05_row8_col4, #T_70f05_row8_col5, #T_70f05_row9_col0, #T_70f05_row9_col1, #T_70f05_row9_col2, #T_70f05_row9_col4, #T_70f05_row9_col5 {
#   background: white;
#   color: black;
#   color: black;
# }
# #T_70f05_row1_col3, #T_70f05_row4_col3, #T_70f05_row7_col3 {
#   background: #cbd5e8;
#   color: black;
#   color: black;
# }
# #T_70f05_row2_col3, #T_70f05_row5_col3, #T_70f05_row8_col3 {
#   background: nan;
#   color: black;
#   color: black;
# }
# </style>
# <table id="T_70f05_">
#   <caption>Model type: Neural Network</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model_5_Layer</th>
#       <th class="col_heading level0 col1" >Model_5_Shape</th>
#       <th class="col_heading level0 col2" >Model_5_Params</th>
#       <th class="col_heading level0 col3" >Model_6_Layer</th>
#       <th class="col_heading level0 col4" >Model_6_Shape</th>
#       <th class="col_heading level0 col5" >Model_6_Params</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70f05_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_70f05_row0_col0" class="data row0 col0" >Dense</td>
#       <td id="T_70f05_row0_col1" class="data row0 col1" >[None, 64]</td>
#       <td id="T_70f05_row0_col2" class="data row0 col2" >1728.000000</td>
#       <td id="T_70f05_row0_col3" class="data row0 col3" >Dense</td>
#       <td id="T_70f05_row0_col4" class="data row0 col4" >[None, 64]</td>
#       <td id="T_70f05_row0_col5" class="data row0 col5" >1728</td>
#     </tr>
#     <tr>
#       <th id="T_70f05_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_70f05_row1_col0" class="data row1 col0" >Dense</td>
#       <td id="T_70f05_row1_col1" class="data row1 col1" >[None, 64]</td>
#       <td id="T_70f05_row1_col2" class="data row1 col2" >4160.000000</td>
#       <td id="T_70f05_row1_col3" class="data row1 col3" >BatchNormalization</td>
#       <td id="T_70f05_row1_col4" class="data row1 col4" >[None, 64]</td>
#       <td id="T_70f05_row1_col5" class="data row1 col5" >256</td>
#     </tr>
#     <tr>
#       <th id="T_70f05_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_70f05_row2_col0" class="data row2 col0" >Dense</td>
#       <td id="T_70f05_row2_col1" class="data row2 col1" >[None, 64]</td>
#       <td id="T_70f05_row2_col2" class="data row2 col2" >4160.000000</td>
#       <td id="T_70f05_row2_col3" class="data row2 col3" >Activation</td>
#       <td id="T_70f05_row2_col4" class="data row2 col4" >[None, 64]</td>
#       <td id="T_70f05_row2_col5" class="data row2 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_70f05_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_70f05_row3_col0" class="data row3 col0" >Dense</td>
#       <td id="T_70f05_row3_col1" class="data row3 col1" >[None, 1]</td>
#       <td id="T_70f05_row3_col2" class="data row3 col2" >65.000000</td>
#       <td id="T_70f05_row3_col3" class="data row3 col3" >Dense</td>
#       <td id="T_70f05_row3_col4" class="data row3 col4" >[None, 64]</td>
#       <td id="T_70f05_row3_col5" class="data row3 col5" >4160</td>
#     </tr>
#     <tr>
#       <th id="T_70f05_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_70f05_row4_col0" class="data row4 col0" >None</td>
#       <td id="T_70f05_row4_col1" class="data row4 col1" >None</td>
#       <td id="T_70f05_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_70f05_row4_col3" class="data row4 col3" >BatchNormalization</td>
#       <td id="T_70f05_row4_col4" class="data row4 col4" >[None, 64]</td>
#       <td id="T_70f05_row4_col5" class="data row4 col5" >256</td>
#     </tr>
#     <tr>
#       <th id="T_70f05_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_70f05_row5_col0" class="data row5 col0" >None</td>
#       <td id="T_70f05_row5_col1" class="data row5 col1" >None</td>
#       <td id="T_70f05_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_70f05_row5_col3" class="data row5 col3" >Activation</td>
#       <td id="T_70f05_row5_col4" class="data row5 col4" >[None, 64]</td>
#       <td id="T_70f05_row5_col5" class="data row5 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_70f05_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_70f05_row6_col0" class="data row6 col0" >None</td>
#       <td id="T_70f05_row6_col1" class="data row6 col1" >None</td>
#       <td id="T_70f05_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_70f05_row6_col3" class="data row6 col3" >Dense</td>
#       <td id="T_70f05_row6_col4" class="data row6 col4" >[None, 64]</td>
#       <td id="T_70f05_row6_col5" class="data row6 col5" >4160</td>
#     </tr>
#     <tr>
#       <th id="T_70f05_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_70f05_row7_col0" class="data row7 col0" >None</td>
#       <td id="T_70f05_row7_col1" class="data row7 col1" >None</td>
#       <td id="T_70f05_row7_col2" class="data row7 col2" >nan</td>
#       <td id="T_70f05_row7_col3" class="data row7 col3" >BatchNormalization</td>
#       <td id="T_70f05_row7_col4" class="data row7 col4" >[None, 64]</td>
#       <td id="T_70f05_row7_col5" class="data row7 col5" >256</td>
#     </tr>
#     <tr>
#       <th id="T_70f05_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_70f05_row8_col0" class="data row8 col0" >None</td>
#       <td id="T_70f05_row8_col1" class="data row8 col1" >None</td>
#       <td id="T_70f05_row8_col2" class="data row8 col2" >nan</td>
#       <td id="T_70f05_row8_col3" class="data row8 col3" >Activation</td>
#       <td id="T_70f05_row8_col4" class="data row8 col4" >[None, 64]</td>
#       <td id="T_70f05_row8_col5" class="data row8 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_70f05_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_70f05_row9_col0" class="data row9 col0" >None</td>
#       <td id="T_70f05_row9_col1" class="data row9 col1" >None</td>
#       <td id="T_70f05_row9_col2" class="data row9 col2" >nan</td>
#       <td id="T_70f05_row9_col3" class="data row9 col3" >Dense</td>
#       <td id="T_70f05_row9_col4" class="data row9 col4" >[None, 1]</td>
#       <td id="T_70f05_row9_col5" class="data row9 col5" >65</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Optional: Tune model within range of hyperparameters with Keras Tuner
#
# *Simple example shown below. Consult [documentation](https://keras.io/guides/keras_tuner/getting_started/) to see full functionality.*

# %%
! pip install keras_tuner

# %%
#Separate validation data 
from sklearn.model_selection import train_test_split
x_train_split, x_val, y_train_split, y_val = train_test_split(
     X_train, y_train, test_size=0.2, random_state=42)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, BatchNormalization
from keras.regularizers import l1, l2, l1_l2
import keras_tuner as kt

feature_count=preprocessor(X_train).shape[1] #count features in input data

#Define model structure & parameter search space with function
def build_model(hp):
    model = keras.Sequential()
    model.add(Dense(64, input_dim=feature_count, activation='relu', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
    model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
    model.add(Dense(units=hp.Int("units", min_value=32, max_value=512, step=32), #range 32-512 inclusive, minimum step between tested values is 32
                    activation='relu', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
    model.add(Dense(1, kernel_initializer='normal')) 
    model.compile(
        loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])
    return model                                          

#initialize the tuner (which will search through parameters)
tuner = kt.RandomSearch(
    hypermodel=build_model, 
    objective="mean_squared_error", # objective to optimize
    max_trials=3, #max number of trials to run during search
    executions_per_trial=3, #higher number reduces variance of results; guages model performance more accurately 
    overwrite=True,
    directory="tuning_model",
    project_name="tuning_units",
)

tuner.search(preprocessor(x_train_split), y_train_split, epochs=2, validation_data=(preprocessor(x_val), y_val))
# Out:
# Trial 3 Complete [00h 00m 26s]
# mean_squared_error: 880985.5625
#
# Best mean_squared_error So Far: 814806.8541666666
# Total elapsed time: 00h 01m 37s

# %%
# Build model with best hyperparameters

# Get the top 2 hyperparameters.
best_hps = tuner.get_best_hyperparameters(5)
# Build the model with the best hp.
tuned_model = build_model(best_hps[0])
# Fit with the entire dataset.
tuned_model.fit(x=preprocessor(X_train), y=y_train, epochs=5)
# Out:
# Epoch 1/5
# 1349/1349 [==============================] - 3s 2ms/step - loss: 3654157.0000 - mean_squared_error: 3654150.2500
# Epoch 2/5
# 1349/1349 [==============================] - 3s 2ms/step - loss: 874315.8125 - mean_squared_error: 874304.1875
# Epoch 3/5
# 1349/1349 [==============================] - 3s 2ms/step - loss: 706191.1875 - mean_squared_error: 706176.4375
# Epoch 4/5
# 1349/1349 [==============================] - 3s 2ms/step - loss: 607547.6875 - mean_squared_error: 607530.7500
# Epoch 5/5
# 1349/1349 [==============================] - 3s 2ms/step - loss: 540794.0000 - mean_squared_error: 540774.8750

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model = model_to_onnx(tuned_model, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("tuned_model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Submit Model 3: 

#-- Generate predicted values
prediction_labels = tuned_model.predict(preprocessor(X_test))

# Submit Model 3 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "tuned_model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version
col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 2.6%, transparent 2.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c8d0f_row1_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 16.3%, transparent 16.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c8d0f_row1_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 11.8%, transparent 11.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c8d0f_row1_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 99.2%, transparent 99.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c8d0f_row2_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 9.3%, transparent 9.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c8d0f_row2_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 30.5%, transparent 30.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c8d0f_row2_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 24.3%, transparent 24.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c8d0f_row2_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 90.6%, transparent 90.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c8d0f_row3_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 9.5%, transparent 9.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c8d0f_row3_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 30.8%, transparent 30.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c8d0f_row3_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 24.4%, transparent 24.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c8d0f_row3_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 90.4%, transparent 90.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c8d0f_row4_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 9.6%, transparent 9.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c8d0f_row4_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 31.0%, transparent 31.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c8d0f_row4_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 26.2%, transparent 26.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c8d0f_row4_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 90.2%, transparent 90.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c8d0f_row5_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 12.9%, transparent 12.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c8d0f_row5_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 36.0%, transparent 36.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c8d0f_row5_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 31.6%, transparent 31.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c8d0f_row5_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 85.9%, transparent 85.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c8d0f_row6_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 100.0%, transparent 100.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c8d0f_row6_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 100.0%, transparent 100.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c8d0f_row6_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 100.0%, transparent 100.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c8d0f_row6_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   color: #251e1b;
#   font-size: 12px;
# }
# </style>
# <table id="T_c8d0f_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >mse</th>
#       <th class="col_heading level0 col1" >rmse</th>
#       <th class="col_heading level0 col2" >mae</th>
#       <th class="col_heading level0 col3" >r2</th>
#       <th class="col_heading level0 col4" >ml_framework</th>
#       <th class="col_heading level0 col5" >transfer_learning</th>
#       <th class="col_heading level0 col6" >deep_learning</th>
#       <th class="col_heading level0 col7" >model_type</th>
#       <th class="col_heading level0 col8" >depth</th>
#       <th class="col_heading level0 col9" >num_params</th>
#       <th class="col_heading level0 col10" >batchnormalization_layers</th>
#       <th class="col_heading level0 col11" >dense_layers</th>
#       <th class="col_heading level0 col12" >relu_act</th>
#       <t

# %%
# Compare two or more models
data=mycompetition.compare_models([5, 6, 7], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style type="text/css">
# #T_649d3_ caption {
#   color: black;
#   font-size: 18px;
# }
# #T_649d3_row0_col0, #T_649d3_row0_col3, #T_649d3_row0_col6, #T_649d3_row1_col0, #T_649d3_row1_col6, #T_649d3_row2_col0, #T_649d3_row2_col6, #T_649d3_row3_col0, #T_649d3_row3_col3, #T_649d3_row3_col6, #T_649d3_row6_col3, #T_649d3_row9_col3 {
#   background: #fff2ae;
#   color: black;
#   color: black;
# }
# #T_649d3_row0_col1, #T_649d3_row0_col2, #T_649d3_row0_col4, #T_649d3_row0_col5, #T_649d3_row0_col7, #T_649d3_row0_col8, #T_649d3_row1_col1, #T_649d3_row1_col2, #T_649d3_row1_col4, #T_649d3_row1_col5, #T_649d3_row1_col7, #T_649d3_row1_col8, #T_649d3_row2_col1, #T_649d3_row2_col2, #T_649d3_row2_col4, #T_649d3_row2_col5, #T_649d3_row2_col7, #T_649d3_row2_col8, #T_649d3_row3_col1, #T_649d3_row3_col2, #T_649d3_row3_col4, #T_649d3_row3_col5, #T_649d3_row3_col7, #T_649d3_row3_col8, #T_649d3_row4_col0, #T_649d3_row4_col1, #T_649d3_row4_col2, #T_649d3_row4_col4, #T_649d3_row4_col5, #T_649d3_row4_col6, #T_649d3_row4_col7, #T_649d3_row4_col8, #T_649d3_row5_col0, #T_649d3_row5_col1, #T_649d3_row5_col2, #T_649d3_row5_col4, #T_649d3_row5_col5, #T_649d3_row5_col6, #T_649d3_row5_col7, #T_649d3_row5_col8, #T_649d3_row6_col0, #T_649d3_row6_col1, #T_649d3_row6_col2, #T_649d3_row6_col4, #T_649d3_row6_col5, #T_649d3_row6_col6, #T_649d3_row6_col7, #T_649d3_row6_col8, #T_649d3_row7_col0, #T_649d3_row7_col1, #T_649d3_row7_col2, #T_649d3_row7_col4, #T_649d3_row7_col5, #T_649d3_row7_col6, #T_649d3_row7_col7, #T_649d3_row7_col8, #T_649d3_row8_col0, #T_649d3_row8_col1, #T_649d3_row8_col2, #T_649d3_row8_col4, #T_649d3_row8_col5, #T_649d3_row8_col6, #T_649d3_row8_col7, #T_649d3_row8_col8, #T_649d3_row9_col0, #T_649d3_row9_col1, #T_649d3_row9_col2, #T_649d3_row9_col4, #T_649d3_row9_col5, #T_649d3_row9_col6, #T_649d3_row9_col7, #T_649d3_row9_col8 {
#   background: white;
#   color: black;
#   color: black;
# }
# #T_649d3_row1_col3, #T_649d3_row4_col3, #T_649d3_row7_col3 {
#   background: #cbd5e8;
#   color: black;
#   color: black;
# }
# #T_649d3_row2_col3, #T_649d3_row5_col3, #T_649d3_row8_col3 {
#   background: nan;
#   color: black;
#   color: black;
# }
# </style>
# <table id="T_649d3_">
#   <caption>Model type: Neural Network</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model_5_Layer</th>
#       <th class="col_heading level0 col1" >Model_5_Shape</th>
#       <th class="col_heading level0 col2" >Model_5_Params</th>
#       <th class="col_heading level0 col3" >Model_6_Layer</th>
#       <th class="col_heading level0 col4" >Model_6_Shape</th>
#       <th class="col_heading level0 col5" >Model_6_Params</th>
#       <th class="col_heading level0 col6" >Model_7_Layer</th>
#       <th class="col_heading level0 col7" >Model_7_Shape</th>
#       <th class="col_heading level0 col8" >Model_7_Params</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_649d3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_649d3_row0_col0" class="data row0 col0" >Dense</td>
#       <td id="T_649d3_row0_col1" class="data row0 col1" >[None, 64]</td>
#       <td id="T_649d3_row0_col2" class="data row0 col2" >1728.000000</td>
#       <td id="T_649d3_row0_col3" class="data row0 col3" >Dense</td>
#       <td id="T_649d3_row0_col4" class="data row0 col4" >[None, 64]</td>
#       <td id="T_649d3_row0_col5" class="data row0 col5" >1728</td>
#       <td id="T_649d3_row0_col6" class="data row0 col6" >Dense</td>
#       <td id="T_649d3_row0_col7" class="data row0 col7" >[None, 64]</td>
#       <td id="T_649d3_row0_col8" class="data row0 col8" >1728.000000</td>
#     </tr>
#     <tr>
#       <th id="T_649d3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_649d3_row1_col0" class="data row1 col0" >Dense</td>
#       <td id="T_649d3_row1_col1" class="data row1 col1" >[None, 64]</td>
#       <td id="T_649d3_row1_col2" class="data row1 col2" >4160.000000</td>
#       <td id="T_649d3_row1_col3" class="data row1 col3" >BatchNormalization</td>
#       <td id="T_649d3_row1_col4" class="data row1 col4" >[None, 64]</td>
#       <td id="T_649d3_row1_col5" class="data row1 col5" >256</td>
#       <td id="T_649d3_row1_col6" class="data row1 col6" >Dense</td>
#       <td id="T_649d3_row1_col7" class="data row1 col7" >[None, 64]</td>
#       <td id="T_649d3_row1_col8" class="data row1 col8" >4160.000000</td>
#     </tr>
#     <tr>
#       <th id="T_649d3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_649d3_row2_col0" class="data row2 col0" >Dense</td>
#       <td id="T_649d3_row2_col1" class="data row2 col1" >[None, 64]</td>
#       <td id="T_649d3_row2_col2" class="data row2 col2" >4160.000000</td>
#       <td id="T_649d3_row2_col3" class="data row2 col3" >Activation</td>
#       <td id="T_649d3_row2_col4" class="data row2 col4" >[None, 64]</td>
#       <td id="T_649d3_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_649d3_row2_col6" class="data row2 col6" >Dense</td>
#       <td id="T_649d3_row2_col7" class="data row2 col7" >[None, 352]</td>
#       <td id="T_649d3_row2_col8" class="data row2 col8" >22880.000000</td>
#     </tr>
#     <tr>
#       <th id="T_649d3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_649d3_row3_col0" class="data row3 col0" >Dense</td>
#       <td id="T_649d3_row3_col1" class="data row3 col1" >[None, 1]</td>
#       <td id="T_649d3_row3_col2" class="data row3 col2" >65.000000</td>
#       <td id="T_649d3_row3_col3" class="data row3 col3" >Dense</td>
#       <td id="T_649d3_row3_col4" class="data row3 col4" >[None, 64]</td>
#       <td id="T_649d3_row3_col5" class="data row3 col5" >4160</td>
#       <td id="T_649d3_row3_col6" class="data row3 col6" >Dense</td>
#       <td id="T_649d3_row3_col7" class="data row3 col7" >[None, 1]</td>
#       <td id="T_649d3_row3_col8" class="data row3 col8" >353.000000</td>
#     </tr>
#     <tr>
#       <th id="T_649d3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_649d3_row4_col0" class="data row4 col0" >None</td>
#       <td id="T_649d3_row4_col1" class="data row4 col1" >None</td>
#       <td id="T_649d3_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_649d3_row4_col3" class="data row4 col3" >BatchNormalization</td>
#       <td id="T_649d3_row4_col4" class="data row4 col4" >[None, 64]</td>
#       <td id="T_649d3_row4_col5" class="data row4 col5" >256</td>
#       <td id="T_649d3_row4_col6" class="data row4 col6" >None</td>
#       <td id="T_649d3_row4_col7" class="data row4 col7" >None</td>
#       <td id="T_649d3_row4_col8" class="data row4 col8" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_649d3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_649d3_row5_col0" class="data row5 col0" >None</td>
#       <td id="T_649d3_row5_col1" class="data row5 col1" >None</td>
#       <td id="T_649d3_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_649d3_row5_col3" class="data row5 col3" >Activation</td>
#       <td id="T_649d3_row5_col4" class="data row5 col4" >[None, 64]</td>
#       <td id="T_649d3_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_649d3_row5_col6" class="data row5 col6" >None</td>
#       <td id="T_649d3_row5_col7" class="data row5 col7" >None</td>
#       <td id="T_649d3_row5_col8" class="data row5 col8" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_649d3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_649d3_row6_col0" class="data row6 col0" >None</td>
#       <td id="T_649d3_row6_col1" class="data row6 col1" >None</td>
#       <td id="T_649d3_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_649d3_row6_col3" class="data row6 col3" >Dense</td>
#       <td id="T_649d3_row6_col4" class="data row6 col4" >[None, 64]</td>
#       <td id="T_649d3_row6_col5" class="data row6 col5" >4160</td>
#       <td id="T_649d3_row6_col6" class="data row6 col6" >None</td>
#       <td id="T_649d3_row6_col7" class="data row6 col7" >None</td>
#       <td id="T_649d3_row6_col8" class="data row6 col8" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_649d3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_
