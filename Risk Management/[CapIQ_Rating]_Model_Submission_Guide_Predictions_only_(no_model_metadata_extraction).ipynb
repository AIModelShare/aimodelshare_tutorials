# %% [markdown]
# <p align="center"><img width="50%" src="https://aimodelsharecontent.s3.amazonaws.com/aimodshare_banner.jpg" /></p>
#
#
# ---

# %% [markdown]
# <p align="center"><h1 align="center">CapIQ Rating Classification Model Submission Guide - Predictions Only (No Model Metadata Extraction) </h1>
#
# ---
# Let's share our models to a centralized leaderboard, so that we can collaborate and learn from the model experimentation process...
#
# **Instructions:**
# 1.   Get data in and set up X_train / X_test / y_train
# 2.   Preprocess data
# 3. Fit model on preprocessed data
# 4. Generate predictions from X_test data and submit to competition
# 5. Repeat submission process to improve place on leaderboard

# %% [markdown]
# ## 1. Get data in and set up X_train, X_test, y_train objects

# %%
#install aimodelshare library
! pip install aimodelshare --upgrade

# %%
# Get competition data
from aimodelshare import download_data
download_data('public.ecr.aws/y2e2a1d6/capiq_rating_competition_data-repository:latest')
# Out:
# Downloading [======>                                          ]
#
# Data downloaded successfully.

# %%
# Separate data into X_train, y_train, and X_test
import pandas as pd
y_train_labels = pd.read_csv("capiq_rating_competition_data/y_train.csv", squeeze=True)
y_train = pd.get_dummies(y_train_labels)

X_train = pd.read_csv("capiq_rating_competition_data/X_train.csv")
X_test=pd.read_csv("capiq_rating_competition_data/X_test.csv")

X_train.head()
# Out:
#                              Name     Symbol                        Exchange  \
# 0           3M Company (NYSE:MMM)   NYSE:MMM  New York Stock Exchange (NYSE)
# 1            AAR Corp. (NYSE:AIR)   NYSE:AIR  New York Stock Exchange (NYSE)
# 2  Abbott Laboratories (NYSE:ABT)   NYSE:ABT  New York Stock Exchange (NYSE)
# 3         AbbVie Inc. (NYSE:ABBV)  NYSE:ABBV  New York Stock Exchange (NYSE)
# 4      Adecoagro S.A. (NYSE:AGRO)  NYSE:AGRO  New York Stock Exchange (NYSE)
#
#            Industry  MarketCap  EnterpriseValue   Revenue  GrossProfit  \
# 0       Industrials   99704.48        109611.58  31841.90     15447.60
# 1       Industrials    1131.61          1412.65   1816.20       272.93
# 2       Health Care  112198.80        121025.92  27682.23     15806.85
# 3       Health Care  135936.95        166341.05  31122.80     23163.60
# 4  Consumer Staples    1021.64          1760.08    817.16       260.81
#
#      EBITDA       EBIT  ...  CurrentAssets  ShortTermDebt  LTD_Cap_Leases  \
# 0   8734.60   7966.300  ...       13272.00       353.7000         1117.30
# 1    129.26    103.655  ...        1014.52         0.0600           37.37
# 2   6757.35   5505.365  ...       20018.30      1243.9000          608.10
# 3  13948.20  12604.850  ...       22157.20       678.8000         3891.50
# 4    255.28    193.000  ...         623.58         7.6627          178.79
#
#    Leases_LongTerm  LongTermDebt  Liabilities  Liabilities_N_Equity  \
# 0         253.1000      11248.20    31269.350              37798.60
# 1          13.0800        328.11     1303.615               1760.14
# 2         261.3000      15047.10    46540.700              60436.20
# 3         186.2000      37593.70    70162.000              71921.50
# 4          53.7321        595.08     1513.135               1949.59
#
#    Debt_Current  Debt_NonCurrent  Debt_Net
# 0      1471.000         11501.30   9166.30
# 1        37.430           341.19    276.71
# 2      1852.000         15308.40   8373.90
# 3      4570.300         37779.90  30633.70
# 4       186.449           648.81    606.12
#
# [5 rows x 28 columns]

# %%
#Check Shape
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
# Out:
# (406, 28)
# (100, 28)
# (406, 16)

# %% [markdown]
# ##2.   Preprocess data

# %%
# Write and execute code to preprocess data here

# %% [markdown]
# ##3. Fit model on preprocessed data

# %%
# Write and execute code to fit model on preprocessed data here.

# %%
#Set credentials using modelshare.org username/password

from aimodelshare.aws import set_credentials
    
apiurl='https://3hf4nd1e6b.execute-api.us-east-1.amazonaws.com/prod/m'
#This is the unique rest api that powers this specific Playground

set_credentials(apiurl=apiurl)
# Out:
# AI Modelshare Username:··········
# AI Modelshare Password:··········
# AI Model Share login credentials set successfully.

# %%
#Instantiate Competition
import aimodelshare as ai
mycompetition= ai.Competition(apiurl)

# %% [markdown]
# ## **4. Submit Model predictions to leaderboard (without extracting model architecture information):**
# - model metadata extraction allows you use compare_models() and instantiate_model() functions.

# %%
#Generate a list of predictions using X_test data

# This example uses randomly chosen values from y_train to generate a list of predictions
predicted_values = list(y_train_labels.sample(n=len(X_test.index)))

# %%
#Submit Model predictions to leaderboard (without extracting model architecture information): 

# Submit to Competition Leaderboard
mycompetition.submit_model(model_filepath = None,
                                 preprocessor_filepath=None,
                                 prediction_submission=predicted_values)
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 8
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:1756

# %%
# Get leaderboard to explore current best model architectures

# Get raw data in pandas data frame
data = mycompetition.get_leaderboard()

# Stylize leaderboard data
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_d9ffd_row0_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 32.0%, transparent 32.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d9ffd_row0_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 23.2%, transparent 23.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d9ffd_row0_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 28.6%, transparent 28.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d9ffd_row0_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 25.5%, transparent 25.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d9ffd_row0_col4, #T_d9ffd_row0_col5, #T_d9ffd_row0_col6, #T_d9ffd_row0_col7, #T_d9ffd_row0_col8, #T_d9ffd_row0_col9, #T_d9ffd_row0_col10, #T_d9ffd_row0_col11, #T_d9ffd_row0_col12, #T_d9ffd_row0_col13, #T_d9ffd_row0_col14, #T_d9ffd_row0_col15, #T_d9ffd_row0_col16, #T_d9ffd_row0_col17, #T_d9ffd_row1_col4, #T_d9ffd_row1_col5, #T_d9ffd_row1_col6, #T_d9ffd_row1_col7, #T_d9ffd_row1_col8, #T_d9ffd_row1_col9, #T_d9ffd_row1_col10, #T_d9ffd_row1_col11, #T_d9ffd_row1_col12, #T_d9ffd_row1_col13, #T_d9ffd_row1_col14, #T_d9ffd_row1_col15, #T_d9ffd_row1_col16, #T_d9ffd_row1_col17, #T_d9ffd_row2_col4, #T_d9ffd_row2_col5, #T_d9ffd_row2_col6, #T_d9ffd_row2_col7, #T_d9ffd_row2_col8, #T_d9ffd_row2_col9, #T_d9ffd_row2_col10, #T_d9ffd_row2_col11, #T_d9ffd_row2_col12, #T_d9ffd_row2_col13, #T_d9ffd_row2_col14, #T_d9ffd_row2_col15, #T_d9ffd_row2_col16, #T_d9ffd_row2_col17, #T_d9ffd_row3_col4, #T_d9ffd_row3_col5, #T_d9ffd_row3_col6, #T_d9ffd_row3_col7, #T_d9ffd_row3_col8, #T_d9ffd_row3_col9, #T_d9ffd_row3_col10, #T_d9ffd_row3_col11, #T_d9ffd_row3_col12, #T_d9ffd_row3_col13, #T_d9ffd_row3_col14, #T_d9ffd_row3_col15, #T_d9ffd_row3_col16, #T_d9ffd_row3_col17, #T_d9ffd_row4_col4, #T_d9ffd_row4_col5, #T_d9ffd_row4_col6, #T_d9ffd_row4_col7, #T_d9ffd_row4_col8, #T_d9ffd_row4_col9, #T_d9ffd_row4_col10, #T_d9ffd_row4_col11, #T_d9ffd_row4_col12, #T_d9ffd_row4_col13, #T_d9ffd_row4_col14, #T_d9ffd_row4_col15, #T_d9ffd_row4_col16, #T_d9ffd_row4_col17, #T_d9ffd_row5_col4, #T_d9ffd_row5_col5, #T_d9ffd_row5_col6, #T_d9ffd_row5_col7, #T_d9ffd_row5_col8, #T_d9ffd_row5_col9, #T_d9ffd_row5_col10, #T_d9ffd_row5_col11, #T_d9ffd_row5_col12, #T_d9ffd_row5_col13, #T_d9ffd_row5_col14, #T_d9ffd_row5_col15, #T_d9ffd_row5_col16, #T_d9ffd_row5_col17, #T_d9ffd_row6_col4, #T_d9ffd_row6_col5, #T_d9ffd_row6_col6, #T_d9ffd_row6_col7, #T_d9ffd_row6_col8, #T_d9ffd_row6_col9, #T_d9ffd_row6_col10, #T_d9ffd_row6_col11, #T_d9ffd_row6_col12, #T_d9ffd_row6_col13, #T_d9ffd_row6_col14, #T_d9ffd_row6_col15, #T_d9ffd_row6_col16, #T_d9ffd_row6_col17, #T_d9ffd_row7_col4, #T_d9ffd_row7_col5, #T_d9ffd_row7_col6, #T_d9ffd_row7_col7, #T_d9ffd_row7_col8, #T_d9ffd_row7_col9, #T_d9ffd_row7_col10, #T_d9ffd_row7_col11, #T_d9ffd_row7_col12, #T_d9ffd_row7_col13, #T_d9ffd_row7_col14, #T_d9ffd_row7_col15, #T_d9ffd_row7_col16, #T_d9ffd_row7_col17 {
#   text-align: center;
# }
# #T_d9ffd_row1_col0, #T_d9ffd_row2_col0, #T_d9ffd_row4_col0, #T_d9ffd_row7_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 24.0%, transparent 24.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d9ffd_row1_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 18.5%, transparent 18.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d9ffd_row1_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 22.2%, transparent 22.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d9ffd_row1_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 19.6%, transparent 19.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d9ffd_row2_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 18.3%, transparent 18.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d9ffd_row2_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 19.6%, transparent 19.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d9ffd_row2_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 24.0%, transparent 24.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d9ffd_row3_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 18.0%, transparent 18.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d9ffd_row3_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 13.6%, transparent 13.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d9ffd_row3_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 13.5%, transparent 13.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d9ffd_row3_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 15.8%, transparent 15.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d9ffd_row4_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 11.2%, transparent 11.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d9ffd_row4_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 9.6%, transparent 9.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d9ffd_row4_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 19.4%, transparent 19.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d9ffd_row5_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 22.0%, transparent 22.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d9ffd_row5_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 5.7%, transparent 5.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d9ffd_row5_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 4.6%, transparent 4.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d9ffd_row5_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 11.8%, transparent 11.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d9ffd_row6_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 10.0%, transparent 10.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d9ffd_row6_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 6.3%, transparent 6.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d9ffd_row6_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 12.4%, transparent 12.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d9ffd_row6_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 5.8%, transparent 5.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d9ffd_row7_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 3.2%, transparent 3.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d9ffd_row7_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 2.0%, transparent 2.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d9ffd_row7_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 8.3%, transparent 8.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# </style>
# <table id="T_d9ffd_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >accuracy</th>
#       <th class="col_heading level0 col1" >f1_score</th>
#       <th class="col_heading level0 col2" >precision</th>
#       <th cl

# %% [markdown]
# You can also compare two or more models for any models submitted to the leaderboard using example code for model metadata extraction (see code tab for this competition at www.modelshare.org for submission examples.)
# ```
# data=mycompetition.compare_models([1,2], verbose=1)
# mycompetition.stylize_compare(data)
# ```

# %% [markdown]
# #####  (Optional Extension) Submit Model With Custom Metadata:
# Can use to add team names or any other missing data you may wish to share on the leaderboard

# %%
# Custom metadata can be added by passing a dict to the custom_metadata argument of the submit_model() method
# This option can be used to fill in missing data points or add new columns to the leaderboard

custom_meta = {'team': 'team one',
               'model_type': 'your_model_type',
               'new_column': 'new metadata'}

mycompetition.submit_model(model_filepath = None,
                                 preprocessor_filepath=None,
                                 prediction_submission=predicted_values,
                                 custom_metadata = custom_meta)
