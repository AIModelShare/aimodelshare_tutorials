# %% [markdown]
# <p align="center"><img width="50%" src="https://aimodelsharecontent.s3.amazonaws.com/aimodshare_banner.jpg" /></p>
#
#
# ---

# %% [markdown]
# ## Model Submission Guide: CapIQ-Industry Classification Competition
# Let's share our models to a centralized leaderboard, so that we can collaborate and learn from the model experimentation process...
#
# **Instructions:**
# 1.   Get data in and set up X_train / X_test / y_train
# 2.   Preprocess data using Sklearn Column Transformer/ Write and Save Preprocessor function
# 3. Fit model on preprocessed data and save preprocessor function and model
# 4. Generate predictions from X_test data and submit model to competition
# 5. Repeat submission process to improve place on leaderboard

# %% [markdown]
# ## 1. Get data in and set up X_train, X_test, y_train objects

# %%
#install aimodelshare library
! pip install aimodelshare --upgrade

# %%
# Get competition data
from aimodelshare import download_data
download_data('public.ecr.aws/y2e2a1d6/capiq_industry_competition-repository:latest')
# Out:
# Downloading [======>                                          ]
#
# Data downloaded successfully.

# %%
# Separate data into X_train, y_train, and X_test
import pandas as pd
y_train_labels = pd.read_csv("capiq_industry_competition/y_train.csv", squeeze=True)
y_train = pd.get_dummies(y_train_labels)

X_train = pd.read_csv("capiq_industry_competition/X_train.csv")
X_test=pd.read_csv("capiq_industry_competition/X_test.csv")

X_train.head()
# Out:
#                              Name     Symbol                        Exchange  \
# 0           3M Company (NYSE:MMM)   NYSE:MMM  New York Stock Exchange (NYSE)
# 1            AAR Corp. (NYSE:AIR)   NYSE:AIR  New York Stock Exchange (NYSE)
# 2  Abbott Laboratories (NYSE:ABT)   NYSE:ABT  New York Stock Exchange (NYSE)
# 3         AbbVie Inc. (NYSE:ABBV)  NYSE:ABBV  New York Stock Exchange (NYSE)
# 4      Adecoagro S.A. (NYSE:AGRO)  NYSE:AGRO  New York Stock Exchange (NYSE)
#
#   Rating  MarketCap  EnterpriseValue   Revenue  GrossProfit    EBITDA  \
# 0     A+   99704.48        109611.58  31841.90     15447.60   8734.60
# 1     BB    1131.61          1412.65   1816.20       272.93    129.26
# 2    AA-  112198.80        121025.92  27682.23     15806.85   6757.35
# 3   BBB+  135936.95        166341.05  31122.80     23163.60  13948.20
# 4     BB    1021.64          1760.08    817.16       260.81    255.28
#
#         EBIT  ...  CurrentAssets  ShortTermDebt  LTD_Cap_Leases  \
# 0   7966.300  ...       13272.00       353.7000         1117.30
# 1    103.655  ...        1014.52         0.0600           37.37
# 2   5505.365  ...       20018.30      1243.9000          608.10
# 3  12604.850  ...       22157.20       678.8000         3891.50
# 4    193.000  ...         623.58         7.6627          178.79
#
#    Leases_LongTerm  LongTermDebt  Liabilities  Liabilities_N_Equity  \
# 0         253.1000      11248.20    31269.350              37798.60
# 1          13.0800        328.11     1303.615               1760.14
# 2         261.3000      15047.10    46540.700              60436.20
# 3         186.2000      37593.70    70162.000              71921.50
# 4          53.7321        595.08     1513.135               1949.59
#
#    Debt_Current  Debt_NonCurrent  Debt_Net
# 0      1471.000         11501.30   9166.30
# 1        37.430           341.19    276.71
# 2      1852.000         15308.40   8373.90
# 3      4570.300         37779.90  30633.70
# 4       186.449           648.81    606.12
#
# [5 rows x 28 columns]

# %% [markdown]
# ##2.   Preprocess data using Sklearn / Write and Save Preprocessor function

# %%
# Simple Preprocessor with sklearn 
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

numeric_features = ['MarketCap', 'EnterpriseValue', 'Revenue', 'GrossProfit', 'EBITDA', 
                    'EBIT', 'NetIncome', 'Cash', 'PPnE', 'Assets', 'Debt', 'Equity', 
                    'Receivables', 'Inventory', 'CurrentAssets', 'ShortTermDebt', 
                    'LTD_Cap_Leases', 'Leases_LongTerm', 'LongTermDebt', 'Liabilities', 
                    'Liabilities_N_Equity', 'Debt_Current', 'Debt_NonCurrent', 'Debt_Net']
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')), 
    ('scaler', StandardScaler())])

categorical_features = ['Rating']
## Replacing missing values with Modal value and then one-hot encoding.
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# Final preprocessor object set up with ColumnTransformer...

preprocess = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# fit preprocessor to your data
preprocess = preprocess.fit(X_train)

# %%
# Here is where we actually write the preprocessor function:
def preprocessor(data):
    preprocessed_data=preprocess.transform(data)
    return preprocessed_data

# %%
# check shape of X data after preprocessing it using our new function
preprocessor(X_train).shape
# Out:
# (405, 40)

# %% [markdown]
# ##3. Fit model on preprocessed data and save preprocessor function and model

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation

model = Sequential()
model.add(Dense(16, input_dim=40, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(32, activation='relu'))

model.add(Dense(10, activation='softmax')) 
                                            
# Compile model
model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# Fitting the NN to the Training set
model.fit(preprocessor(X_train), y_train, 
               epochs = 15, validation_split=0.25)
# Out:
# Epoch 1/15
# 10/10 [==============================] - 2s 53ms/step - loss: 2.3026 - accuracy: 0.1287 - val_loss: 2.3175 - val_accuracy: 0.1275
# Epoch 2/15
# 10/10 [==============================] - 0s 6ms/step - loss: 2.2891 - accuracy: 0.1518 - val_loss: 2.3060 - val_accuracy: 0.1471
# Epoch 3/15
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2761 - accuracy: 0.1914 - val_loss: 2.2950 - val_accuracy: 0.1765
# Epoch 4/15
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2636 - accuracy: 0.2178 - val_loss: 2.2854 - val_accuracy: 0.1863
# Epoch 5/15
# 10/10 [==============================] - 0s 6ms/step - loss: 2.2524 - accuracy: 0.2145 - val_loss: 2.2765 - val_accuracy: 0.2157
# Epoch 6/15
# 10/10 [==============================] - 0s 6ms/step - loss: 2.2418 - accuracy: 0.2310 - val_loss: 2.2682 - val_accuracy: 0.2059
# Epoch 7/15
# 10/10 [==============================] - 0s 5ms/step - loss: 2.2321 - accuracy: 0.2310 - val_loss: 2.2604 - val_accuracy: 0.2059
# Epoch 8/15
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2227 - accuracy: 0.2376 - val_loss: 2.2533 - val_accuracy: 0.2157
# Epoch 9/15
# 10/10 [==============================] - 0s 6ms/step - loss: 2.2141 - accuracy: 0.2409 - val_loss: 2.2466 - val_accuracy: 0.2157
# Epoch 10/15
# 10/10 [==============================] - 0s 5ms/step - loss: 2.2058 - accuracy: 0.2409 - val_loss: 2.2399 - val_accuracy: 0.2157
# Epoch 11/15
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1978 - accuracy: 0.2409 - val_loss: 2.2336 - val_accuracy: 0.2157
# Epoch 12/15
# 10/10 [==============================] - 0s 6ms/step - loss: 2.1900 - accuracy: 0.2409 - val_loss: 2.2279 - val_accuracy: 0.2255
# Epoch 13/15
# 10/10 [==============================] - 0s 5ms/step - loss: 2.1829 - accuracy: 0.2442 - val_loss: 2.2221 - val_accuracy: 0.2255
# Epoch 14/15
# 10/10 [==============================] - 0s 6ms/step - loss: 2.1757 - accuracy: 0.2442 - val_loss: 2.2168 - val_accuracy: 0.2255
# Epoch 15/15
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1690 - accuracy: 0.2475 - val_loss: 2.2117 - val_accuracy: 0.2255

# %% [markdown]
# #### Save preprocessor function to local "preprocessor.zip" file

# %%
import aimodelshare as ai
ai.export_preprocessor(preprocessor,"")
# Out:
# Your preprocessor is now saved to 'preprocessor.zip'

# %% [markdown]
# #### Save model to local ".onnx" file

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model = model_to_onnx(model, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %% [markdown]
# ## 4. Generate predictions from X_test data and submit model to competition

# %%
#Set credentials using modelshare.org username/password

from aimodelshare.aws import set_credentials

#This is the unique rest api that powers this Industry Classification Playground -- make sure to update the apiurl for new competition deployments
apiurl="https://o10cku0dzb.execute-api.us-east-1.amazonaws.com/prod/m"

set_credentials(apiurl=apiurl)
# Out:
# AI Modelshare Username:··········
# AI Modelshare Password:··········
# AI Model Share login credentials set successfully.

# %%
#Instantiate Competition
import aimodelshare as ai
mycompetition= ai.Competition(apiurl)

# %%
#Submit Model 1: 

#-- Generate predicted y values (Model 1)
#Note: Keras predict returns the predicted column index location for classification models
prediction_column_index=model.predict(preprocessor(X_test)).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

# Submit Model 1 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 5
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:1752

# %%
# Get leaderboard to explore current best model architectures

# Get raw data in pandas data frame
data = mycompetition.get_leaderboard()

# Stylize leaderboard data
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_88848_row0_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 43.1%, transparent 43.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_88848_row0_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 36.9%, transparent 36.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_88848_row0_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 39.7%, transparent 39.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_88848_row0_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 36.0%, transparent 36.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_88848_row0_col4, #T_88848_row0_col5, #T_88848_row0_col6, #T_88848_row0_col7, #T_88848_row0_col8, #T_88848_row0_col9, #T_88848_row0_col10, #T_88848_row0_col11, #T_88848_row0_col12, #T_88848_row0_col13, #T_88848_row0_col14, #T_88848_row0_col15, #T_88848_row0_col16, #T_88848_row0_col17, #T_88848_row1_col4, #T_88848_row1_col5, #T_88848_row1_col6, #T_88848_row1_col7, #T_88848_row1_col8, #T_88848_row1_col9, #T_88848_row1_col10, #T_88848_row1_col11, #T_88848_row1_col12, #T_88848_row1_col13, #T_88848_row1_col14, #T_88848_row1_col15, #T_88848_row1_col16, #T_88848_row1_col17, #T_88848_row2_col4, #T_88848_row2_col5, #T_88848_row2_col6, #T_88848_row2_col7, #T_88848_row2_col8, #T_88848_row2_col9, #T_88848_row2_col10, #T_88848_row2_col11, #T_88848_row2_col12, #T_88848_row2_col13, #T_88848_row2_col14, #T_88848_row2_col15, #T_88848_row2_col16, #T_88848_row2_col17, #T_88848_row3_col4, #T_88848_row3_col5, #T_88848_row3_col6, #T_88848_row3_col7, #T_88848_row3_col8, #T_88848_row3_col9, #T_88848_row3_col10, #T_88848_row3_col11, #T_88848_row3_col12, #T_88848_row3_col13, #T_88848_row3_col14, #T_88848_row3_col15, #T_88848_row3_col16, #T_88848_row3_col17, #T_88848_row4_col4, #T_88848_row4_col5, #T_88848_row4_col6, #T_88848_row4_col7, #T_88848_row4_col8, #T_88848_row4_col9, #T_88848_row4_col10, #T_88848_row4_col11, #T_88848_row4_col12, #T_88848_row4_col13, #T_88848_row4_col14, #T_88848_row4_col15, #T_88848_row4_col16, #T_88848_row4_col17 {
#   text-align: center;
# }
# #T_88848_row1_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 39.2%, transparent 39.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_88848_row1_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 34.5%, transparent 34.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_88848_row1_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 38.6%, transparent 38.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_88848_row1_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 33.2%, transparent 33.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_88848_row2_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 45.1%, transparent 45.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_88848_row2_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 29.2%, transparent 29.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_88848_row2_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 27.4%, transparent 27.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_88848_row2_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 32.5%, transparent 32.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_88848_row3_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 35.3%, transparent 35.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_88848_row3_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 21.5%, transparent 21.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_88848_row3_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 22.7%, transparent 22.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_88848_row3_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 24.7%, transparent 24.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_88848_row4_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 25.5%, transparent 25.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_88848_row4_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 5.0%, transparent 5.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_88848_row4_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 3.2%, transparent 3.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_88848_row4_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 11.1%, transparent 11.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# </style>
# <table id="T_88848_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >accuracy</th>
#       <th class="col_heading level0 col1" >f1_score</th>
#       <th class="col_heading level0 col2" >precision</th>
#       <th class="col_heading level0 col3" >recall</th>
#       <th class="col_heading level0 col4" >ml_framework</th>
#       <th class="col_heading level0 col5" >transfer_learning</th>
#       <th class="col_heading level0 col6" >deep_learning</th>
#       <th class="col_heading level0 col7" >model_type</th>
#       <th class="col_heading level0 col8" >depth</th>
#       <th class="col_heading level0 col9" >num_params</th>
#       <th class="col_heading level0 col10" >dense_layers</th>
#       <th class="col_heading level0 col11" >softmax_act</th>
#       <th class="col_heading level0 col12" >relu_act</th>
#       <th class="col_heading level0 col13" >loss</th>
#       <th class="col_heading level0 col14" >optimizer</th>
#       <th class="col_heading level0 col15" >memory_size</th>
#       <th class="col_heading level0 col16" >username</th>
#       <th class="col_heading level0 col17" >version</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88848_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_88848_row0_col0" class="data row0 col0" >43.14%</td>
#       <td id="T_88848_row0_col1" class="data row0 col1" >36.92%</td>
#       <td id="T_88848_row0_col2" class="data row0 col2" >39.65%</td>
#       <td id="T_88848_row0_col3" class="data row0 col3" >35.96%</td>
#       <td id="T_88848_row0_col4" class="data row0 col4" >sklearn</td>
#       <td id="T_88848_row0_col5" class="data row0 col5" >False</td>
#       <td id="T_88848_row0_col6" class="data row0 col6" >False</td>
#       <td id="T_88848_row0_col7" class="data row0 col7" >SVC</td>
#       <td id="T_88848_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_88848_row0_col9" class="data row0 col9" >1800.000000</td>
#       <td id="T_88848_row0_col10" class="data row0 col10" >nan</td>
#       <td id="T_88848_row0_col11" class="data row0 col11" >nan</td>
#       <td id="T_88848_row0_col12" class="data row0 col12" >nan</td>
#       <td id="T_88848_row0_col13" class="data row0 col13" >nan</td>
#       <td id="T_88848_row0_col14" class="data row0 col14" >nan</td>
#       <td id="T_88848_row0_col15" class="data row0 col15" >nan</td>
#       <td id="T_88848_row0_col16" class="data row0 col16" >ML_Risk_Mgmnt</td>
#       <td id="T_88848_row0_col17" class="data row0 col17" >2</td>
#     </tr>
#     <tr>
#       <th id="T_88848_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_88848_row1_col0" class="data row1 col0" >39.22%</td>
#       <td id="T_88848_row1_col1" class="data row1 col1" >34.51%</td>
#       <td id="T_88848_row1_col2" class="data row1 col2" >38.56%</td>
#       <td id="T_88848_row1_co

# %% [markdown]
# ## 5. Repeat submission process to improve place on leaderboard

# %%
# Train and submit model 2 using same preprocessor (note that you could save a new preprocessor, but we will use the same one for this example).
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation

model_2 = Sequential()
model_2.add(Dense(128, input_dim=40, activation='relu'))
model_2.add(Dropout(.3))
model_2.add(Dense(64, activation='relu'))
model_2.add(Dense(64, activation='relu'))
model_2.add(Dropout(.3))
model_2.add(Dense(64, activation='relu'))

model_2.add(Dense(10, activation='softmax')) 
                                            
# Compile model
model_2.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# Fitting the NN to the Training set
model_2.fit(preprocessor(X_train), y_train, 
               epochs = 50, validation_split=0.25)

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model = model_to_onnx(model_2, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("model2.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Submit Model 2: 

#-- Generate predicted y values (Model 2)
#Note: Keras predict returns the predicted column index location for classification models
prediction_column_index=model_2.predict(preprocessor(X_test)).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

# Submit Model 2 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model2.onnx",
                                 prediction_submission=prediction_labels,
                                 preprocessor_filepath="preprocessor.zip")
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 6
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:1752

# %%
# Compare two or more models
data=mycompetition.compare_models([5,6], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style type="text/css">
# #T_f7190_ caption {
#   color: black;
#   font-size: 18px;
# }
# #T_f7190_row0_col0, #T_f7190_row0_col3, #T_f7190_row1_col0, #T_f7190_row2_col0, #T_f7190_row2_col3, #T_f7190_row3_col0, #T_f7190_row3_col3, #T_f7190_row5_col3, #T_f7190_row6_col3 {
#   background: #fff2ae;
#   color: black;
#   color: black;
# }
# #T_f7190_row0_col1, #T_f7190_row0_col2, #T_f7190_row0_col4, #T_f7190_row0_col5, #T_f7190_row1_col1, #T_f7190_row1_col2, #T_f7190_row1_col4, #T_f7190_row1_col5, #T_f7190_row2_col1, #T_f7190_row2_col2, #T_f7190_row2_col4, #T_f7190_row2_col5, #T_f7190_row3_col1, #T_f7190_row3_col2, #T_f7190_row3_col4, #T_f7190_row3_col5, #T_f7190_row4_col0, #T_f7190_row4_col1, #T_f7190_row4_col2, #T_f7190_row4_col4, #T_f7190_row4_col5, #T_f7190_row5_col0, #T_f7190_row5_col1, #T_f7190_row5_col2, #T_f7190_row5_col4, #T_f7190_row5_col5, #T_f7190_row6_col0, #T_f7190_row6_col1, #T_f7190_row6_col2, #T_f7190_row6_col4, #T_f7190_row6_col5 {
#   background: white;
#   color: black;
#   color: black;
# }
# #T_f7190_row1_col3, #T_f7190_row4_col3 {
#   background: #cbd5e8;
#   color: black;
#   color: black;
# }
# </style>
# <table id="T_f7190_">
#   <caption>Model type: Neural Network</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model_5_Layer</th>
#       <th class="col_heading level0 col1" >Model_5_Shape</th>
#       <th class="col_heading level0 col2" >Model_5_Params</th>
#       <th class="col_heading level0 col3" >Model_6_Layer</th>
#       <th class="col_heading level0 col4" >Model_6_Shape</th>
#       <th class="col_heading level0 col5" >Model_6_Params</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f7190_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f7190_row0_col0" class="data row0 col0" >Dense</td>
#       <td id="T_f7190_row0_col1" class="data row0 col1" >[None, 16]</td>
#       <td id="T_f7190_row0_col2" class="data row0 col2" >656.000000</td>
#       <td id="T_f7190_row0_col3" class="data row0 col3" >Dense</td>
#       <td id="T_f7190_row0_col4" class="data row0 col4" >[None, 128]</td>
#       <td id="T_f7190_row0_col5" class="data row0 col5" >5248</td>
#     </tr>
#     <tr>
#       <th id="T_f7190_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f7190_row1_col0" class="data row1 col0" >Dense</td>
#       <td id="T_f7190_row1_col1" class="data row1 col1" >[None, 16]</td>
#       <td id="T_f7190_row1_col2" class="data row1 col2" >272.000000</td>
#       <td id="T_f7190_row1_col3" class="data row1 col3" >Dropout</td>
#       <td id="T_f7190_row1_col4" class="data row1 col4" >[None, 128]</td>
#       <td id="T_f7190_row1_col5" class="data row1 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f7190_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f7190_row2_col0" class="data row2 col0" >Dense</td>
#       <td id="T_f7190_row2_col1" class="data row2 col1" >[None, 32]</td>
#       <td id="T_f7190_row2_col2" class="data row2 col2" >544.000000</td>
#       <td id="T_f7190_row2_col3" class="data row2 col3" >Dense</td>
#       <td id="T_f7190_row2_col4" class="data row2 col4" >[None, 64]</td>
#       <td id="T_f7190_row2_col5" class="data row2 col5" >8256</td>
#     </tr>
#     <tr>
#       <th id="T_f7190_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f7190_row3_col0" class="data row3 col0" >Dense</td>
#       <td id="T_f7190_row3_col1" class="data row3 col1" >[None, 10]</td>
#       <td id="T_f7190_row3_col2" class="data row3 col2" >330.000000</td>
#       <td id="T_f7190_row3_col3" class="data row3 col3" >Dense</td>
#       <td id="T_f7190_row3_col4" class="data row3 col4" >[None, 64]</td>
#       <td id="T_f7190_row3_col5" class="data row3 col5" >4160</td>
#     </tr>
#     <tr>
#       <th id="T_f7190_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f7190_row4_col0" class="data row4 col0" >None</td>
#       <td id="T_f7190_row4_col1" class="data row4 col1" >None</td>
#       <td id="T_f7190_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_f7190_row4_col3" class="data row4 col3" >Dropout</td>
#       <td id="T_f7190_row4_col4" class="data row4 col4" >[None, 64]</td>
#       <td id="T_f7190_row4_col5" class="data row4 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f7190_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f7190_row5_col0" class="data row5 col0" >None</td>
#       <td id="T_f7190_row5_col1" class="data row5 col1" >None</td>
#       <td id="T_f7190_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_f7190_row5_col3" class="data row5 col3" >Dense</td>
#       <td id="T_f7190_row5_col4" class="data row5 col4" >[None, 64]</td>
#       <td id="T_f7190_row5_col5" class="data row5 col5" >4160</td>
#     </tr>
#     <tr>
#       <th id="T_f7190_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f7190_row6_col0" class="data row6 col0" >None</td>
#       <td id="T_f7190_row6_col1" class="data row6 col1" >None</td>
#       <td id="T_f7190_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_f7190_row6_col3" class="data row6 col3" >Dense</td>
#       <td id="T_f7190_row6_col4" class="data row6 col4" >[None, 10]</td>
#       <td id="T_f7190_row6_col5" class="data row6 col5" >650</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Optional: Tune model within range of hyperparameters with Keras Tuner
#
# *Simple example shown below. Consult [documentation](https://keras.io/guides/keras_tuner/getting_started/) to see full functionality.*

# %%
! pip install keras_tuner
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras_tuner
#   Downloading keras_tuner-1.1.3-py3-none-any.whl (135 kB)
#      |████████████████████████████████| 135 kB 7.5 MB/s
# Requirement already satisfied: ipython in /usr/local/lib/python3.7/dist-packages (from keras_tuner) (7.9.0)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.7/dist-packages (from keras_tuner) (2.8.0)
# Collecting kt-legacy
#   Downloading kt_legacy-1.0.4-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from keras_tuner) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from keras_tuner) (1.21.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from keras_tuner) (21.3)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython->keras_tuner) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython->keras_tuner) (0.2.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython->keras_tuner) (4.8.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython->keras_tuner) (5.1.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython->keras_tuner) (4.4.2)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.1-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 57.7 MB/s
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython->keras_tuner) (2.0.10)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython->keras_tuner) (2.6.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython->keras_tuner) (57.4.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.10->ipython->keras_tuner) (0.8.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->keras_tuner) (1.15.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->keras_tuner) (0.2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->keras_tuner) (3.0.9)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->ipython->keras_tuner) (0.7.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->keras_tuner) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->keras_tuner) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->keras_tuner) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->keras_tuner) (2022.6.15)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras_tuner) (1.48.1)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras_tuner) (3.17.3)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras_tuner) (1.2.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras_tuner) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras_tuner) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras_tuner) (1.35.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras_tuner) (1.8.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras_tuner) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras_tuner) (3.4.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras_tuner) (1.0.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras_tuner) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras_tuner) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras_tuner) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras_tuner) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard->keras_tuner) (4.12.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->keras_tuner) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->keras_tuner) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->keras_tuner) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras_tuner) (3.2.0)
# Installing collected packages: jedi, kt-legacy, keras-tuner
# Successfully installed jedi-0.18.1 keras-tuner-1.1.3 kt-legacy-1.0.4

# %%
#Separate validation data 
from sklearn.model_selection import train_test_split
x_train_split, x_val, y_train_split, y_val = train_test_split(
     X_train, y_train, test_size=0.2, random_state=42)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, BatchNormalization
from keras.regularizers import l1, l2, l1_l2
import keras_tuner as kt


#Define model structure & parameter search space with function
def build_model(hp):
    model = keras.Sequential()
    model.add(Dense(64, input_dim=40, activation='relu', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
    model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
    model.add(Dense(units=hp.Int("units", min_value=32, max_value=512, step=32), #range 32-512 inclusive, minimum step between tested values is 32
                    activation='relu', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
    model.add(Dense(10, activation='softmax')) 
    model.compile(
        optimizer="rmsprop", loss="binary_crossentropy", metrics=["accuracy"],
    )
    return model

#initialize the tuner (which will search through parameters)
tuner = kt.RandomSearch(
    hypermodel=build_model, 
    objective="val_accuracy", # objective to optimize
    max_trials=3, #max number of trials to run during search
    executions_per_trial=3, #higher number reduces variance of results; guages model performance more accurately 
    overwrite=True,
    directory="tuning_model",
    project_name="tuning_units",
)

tuner.search(preprocessor(x_train_split), y_train_split, epochs=1, validation_data=(preprocessor(x_val), y_val))
# Out:
# Trial 3 Complete [00h 00m 04s]
# val_accuracy: 0.13580246766408285
#
# Best val_accuracy So Far: 0.21810699502627054
# Total elapsed time: 00h 00m 13s

# %%
# Build model with best hyperparameters

# Get the top 2 hyperparameters.
best_hps = tuner.get_best_hyperparameters(5)
# Build the model with the best hp.
tuned_model = build_model(best_hps[0])
# Fit with the entire dataset.
tuned_model.fit(x=preprocessor(X_train), y=y_train, epochs=5)
# Out:
# Epoch 1/5
# 13/13 [==============================] - 1s 3ms/step - loss: 2.3745 - accuracy: 0.1654
# Epoch 2/5
# 13/13 [==============================] - 0s 4ms/step - loss: 1.7991 - accuracy: 0.2272
# Epoch 3/5
# 13/13 [==============================] - 0s 4ms/step - loss: 1.4714 - accuracy: 0.2247
# Epoch 4/5
# 13/13 [==============================] - 0s 6ms/step - loss: 1.2203 - accuracy: 0.2494
# Epoch 5/5
# 13/13 [==============================] - 0s 6ms/step - loss: 1.0143 - accuracy: 0.2593

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model = model_to_onnx(tuned_model, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("tuned_model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Submit Model 3: 

#-- Generate predicted y values (Model 3)
prediction_column_index=tuned_model.predict(preprocessor(X_test)).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

# Submit to Competition Leaderboard
mycompetition.submit_model(model_filepath = "tuned_model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 7
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:1752

# %%
# Get leaderboard

data = mycompetition.get_leaderboard()
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_ccf79_row0_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 43.1%, transparent 43.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ccf79_row0_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 36.9%, transparent 36.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ccf79_row0_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 39.7%, transparent 39.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ccf79_row0_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 36.0%, transparent 36.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ccf79_row0_col4, #T_ccf79_row0_col5, #T_ccf79_row0_col6, #T_ccf79_row0_col7, #T_ccf79_row0_col8, #T_ccf79_row0_col9, #T_ccf79_row0_col10, #T_ccf79_row0_col11, #T_ccf79_row0_col12, #T_ccf79_row0_col13, #T_ccf79_row0_col14, #T_ccf79_row0_col15, #T_ccf79_row0_col16, #T_ccf79_row0_col17, #T_ccf79_row0_col18, #T_ccf79_row1_col4, #T_ccf79_row1_col5, #T_ccf79_row1_col6, #T_ccf79_row1_col7, #T_ccf79_row1_col8, #T_ccf79_row1_col9, #T_ccf79_row1_col10, #T_ccf79_row1_col11, #T_ccf79_row1_col12, #T_ccf79_row1_col13, #T_ccf79_row1_col14, #T_ccf79_row1_col15, #T_ccf79_row1_col16, #T_ccf79_row1_col17, #T_ccf79_row1_col18, #T_ccf79_row2_col4, #T_ccf79_row2_col5, #T_ccf79_row2_col6, #T_ccf79_row2_col7, #T_ccf79_row2_col8, #T_ccf79_row2_col9, #T_ccf79_row2_col10, #T_ccf79_row2_col11, #T_ccf79_row2_col12, #T_ccf79_row2_col13, #T_ccf79_row2_col14, #T_ccf79_row2_col15, #T_ccf79_row2_col16, #T_ccf79_row2_col17, #T_ccf79_row2_col18, #T_ccf79_row3_col4, #T_ccf79_row3_col5, #T_ccf79_row3_col6, #T_ccf79_row3_col7, #T_ccf79_row3_col8, #T_ccf79_row3_col9, #T_ccf79_row3_col10, #T_ccf79_row3_col11, #T_ccf79_row3_col12, #T_ccf79_row3_col13, #T_ccf79_row3_col14, #T_ccf79_row3_col15, #T_ccf79_row3_col16, #T_ccf79_row3_col17, #T_ccf79_row3_col18, #T_ccf79_row4_col4, #T_ccf79_row4_col5, #T_ccf79_row4_col6, #T_ccf79_row4_col7, #T_ccf79_row4_col8, #T_ccf79_row4_col9, #T_ccf79_row4_col10, #T_ccf79_row4_col11, #T_ccf79_row4_col12, #T_ccf79_row4_col13, #T_ccf79_row4_col14, #T_ccf79_row4_col15, #T_ccf79_row4_col16, #T_ccf79_row4_col17, #T_ccf79_row4_col18, #T_ccf79_row5_col4, #T_ccf79_row5_col5, #T_ccf79_row5_col6, #T_ccf79_row5_col7, #T_ccf79_row5_col8, #T_ccf79_row5_col9, #T_ccf79_row5_col10, #T_ccf79_row5_col11, #T_ccf79_row5_col12, #T_ccf79_row5_col13, #T_ccf79_row5_col14, #T_ccf79_row5_col15, #T_ccf79_row5_col16, #T_ccf79_row5_col17, #T_ccf79_row5_col18, #T_ccf79_row6_col4, #T_ccf79_row6_col5, #T_ccf79_row6_col6, #T_ccf79_row6_col7, #T_ccf79_row6_col8, #T_ccf79_row6_col9, #T_ccf79_row6_col10, #T_ccf79_row6_col11, #T_ccf79_row6_col12, #T_ccf79_row6_col13, #T_ccf79_row6_col14, #T_ccf79_row6_col15, #T_ccf79_row6_col16, #T_ccf79_row6_col17, #T_ccf79_row6_col18 {
#   text-align: center;
# }
# #T_ccf79_row1_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 39.2%, transparent 39.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ccf79_row1_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 34.5%, transparent 34.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ccf79_row1_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 38.6%, transparent 38.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ccf79_row1_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 33.2%, transparent 33.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ccf79_row2_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 45.1%, transparent 45.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ccf79_row2_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 29.2%, transparent 29.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ccf79_row2_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 27.4%, transparent 27.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ccf79_row2_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 32.5%, transparent 32.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ccf79_row3_col0, #T_ccf79_row4_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 35.3%, transparent 35.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ccf79_row3_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 21.5%, transparent 21.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ccf79_row3_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 22.7%, transparent 22.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ccf79_row3_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 24.7%, transparent 24.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ccf79_row4_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 17.1%, transparent 17.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ccf79_row4_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 17.7%, transparent 17.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ccf79_row4_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 21.1%, transparent 21.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ccf79_row5_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 21.6%, transparent 21.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ccf79_row5_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 7.3%, transparent 7.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ccf79_row5_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 5.8%, transparent 5.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ccf79_row5_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 14.4%, transparent 14.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ccf79_row6_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 25.5%, transparent 25.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ccf79_row6_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 5.0%, transparent 5.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ccf79_row6_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 3.2%, transparent 3.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ccf79_row6_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 11.1%, transparent 11.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# </style>
# <table id="T_ccf79_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >accuracy</th>
#       <th class="col_heading level0 col1" >f1_score</th>
#       <th class="col_heading level0 col2" >precision</th>
#       <th class="col_heading level0 col3" >recall</th>
#       <th class="col_heading level0 col4" >ml_framework</th>
#       <th class="col_heading level0 col5" >transfer_learning</th>
#       <th class="col_heading level0 col6" >deep_learning</th>
#       <th class="col_heading level0 col7" >model_type</th>
#       <th class="col_heading level0 col8" >depth</th>
#       <th class="col_heading level0 col9" >num_params</th>
#       <th class="col_heading level0 col10" >dense_layers</th>
#       <th class="col_heading level0 col11" >dropout_layers</th>
#       <th

# %%
# Compare two or more models
data=mycompetition.compare_models([5, 6, 7], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style type="text/css">
# #T_bb8a0_ caption {
#   color: black;
#   font-size: 18px;
# }
# #T_bb8a0_row0_col0, #T_bb8a0_row0_col3, #T_bb8a0_row0_col6, #T_bb8a0_row1_col0, #T_bb8a0_row1_col6, #T_bb8a0_row2_col0, #T_bb8a0_row2_col3, #T_bb8a0_row2_col6, #T_bb8a0_row3_col0, #T_bb8a0_row3_col3, #T_bb8a0_row3_col6, #T_bb8a0_row5_col3, #T_bb8a0_row6_col3 {
#   background: #fff2ae;
#   color: black;
#   color: black;
# }
# #T_bb8a0_row0_col1, #T_bb8a0_row0_col2, #T_bb8a0_row0_col4, #T_bb8a0_row0_col5, #T_bb8a0_row0_col7, #T_bb8a0_row0_col8, #T_bb8a0_row1_col1, #T_bb8a0_row1_col2, #T_bb8a0_row1_col4, #T_bb8a0_row1_col5, #T_bb8a0_row1_col7, #T_bb8a0_row1_col8, #T_bb8a0_row2_col1, #T_bb8a0_row2_col2, #T_bb8a0_row2_col4, #T_bb8a0_row2_col5, #T_bb8a0_row2_col7, #T_bb8a0_row2_col8, #T_bb8a0_row3_col1, #T_bb8a0_row3_col2, #T_bb8a0_row3_col4, #T_bb8a0_row3_col5, #T_bb8a0_row3_col7, #T_bb8a0_row3_col8, #T_bb8a0_row4_col0, #T_bb8a0_row4_col1, #T_bb8a0_row4_col2, #T_bb8a0_row4_col4, #T_bb8a0_row4_col5, #T_bb8a0_row4_col6, #T_bb8a0_row4_col7, #T_bb8a0_row4_col8, #T_bb8a0_row5_col0, #T_bb8a0_row5_col1, #T_bb8a0_row5_col2, #T_bb8a0_row5_col4, #T_bb8a0_row5_col5, #T_bb8a0_row5_col6, #T_bb8a0_row5_col7, #T_bb8a0_row5_col8, #T_bb8a0_row6_col0, #T_bb8a0_row6_col1, #T_bb8a0_row6_col2, #T_bb8a0_row6_col4, #T_bb8a0_row6_col5, #T_bb8a0_row6_col6, #T_bb8a0_row6_col7, #T_bb8a0_row6_col8 {
#   background: white;
#   color: black;
#   color: black;
# }
# #T_bb8a0_row1_col3, #T_bb8a0_row4_col3 {
#   background: #cbd5e8;
#   color: black;
#   color: black;
# }
# </style>
# <table id="T_bb8a0_">
#   <caption>Model type: Neural Network</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model_5_Layer</th>
#       <th class="col_heading level0 col1" >Model_5_Shape</th>
#       <th class="col_heading level0 col2" >Model_5_Params</th>
#       <th class="col_heading level0 col3" >Model_6_Layer</th>
#       <th class="col_heading level0 col4" >Model_6_Shape</th>
#       <th class="col_heading level0 col5" >Model_6_Params</th>
#       <th class="col_heading level0 col6" >Model_7_Layer</th>
#       <th class="col_heading level0 col7" >Model_7_Shape</th>
#       <th class="col_heading level0 col8" >Model_7_Params</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb8a0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bb8a0_row0_col0" class="data row0 col0" >Dense</td>
#       <td id="T_bb8a0_row0_col1" class="data row0 col1" >[None, 16]</td>
#       <td id="T_bb8a0_row0_col2" class="data row0 col2" >656.000000</td>
#       <td id="T_bb8a0_row0_col3" class="data row0 col3" >Dense</td>
#       <td id="T_bb8a0_row0_col4" class="data row0 col4" >[None, 128]</td>
#       <td id="T_bb8a0_row0_col5" class="data row0 col5" >5248</td>
#       <td id="T_bb8a0_row0_col6" class="data row0 col6" >Dense</td>
#       <td id="T_bb8a0_row0_col7" class="data row0 col7" >[None, 64]</td>
#       <td id="T_bb8a0_row0_col8" class="data row0 col8" >2624.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bb8a0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bb8a0_row1_col0" class="data row1 col0" >Dense</td>
#       <td id="T_bb8a0_row1_col1" class="data row1 col1" >[None, 16]</td>
#       <td id="T_bb8a0_row1_col2" class="data row1 col2" >272.000000</td>
#       <td id="T_bb8a0_row1_col3" class="data row1 col3" >Dropout</td>
#       <td id="T_bb8a0_row1_col4" class="data row1 col4" >[None, 128]</td>
#       <td id="T_bb8a0_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_bb8a0_row1_col6" class="data row1 col6" >Dense</td>
#       <td id="T_bb8a0_row1_col7" class="data row1 col7" >[None, 64]</td>
#       <td id="T_bb8a0_row1_col8" class="data row1 col8" >4160.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bb8a0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bb8a0_row2_col0" class="data row2 col0" >Dense</td>
#       <td id="T_bb8a0_row2_col1" class="data row2 col1" >[None, 32]</td>
#       <td id="T_bb8a0_row2_col2" class="data row2 col2" >544.000000</td>
#       <td id="T_bb8a0_row2_col3" class="data row2 col3" >Dense</td>
#       <td id="T_bb8a0_row2_col4" class="data row2 col4" >[None, 64]</td>
#       <td id="T_bb8a0_row2_col5" class="data row2 col5" >8256</td>
#       <td id="T_bb8a0_row2_col6" class="data row2 col6" >Dense</td>
#       <td id="T_bb8a0_row2_col7" class="data row2 col7" >[None, 256]</td>
#       <td id="T_bb8a0_row2_col8" class="data row2 col8" >16640.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bb8a0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bb8a0_row3_col0" class="data row3 col0" >Dense</td>
#       <td id="T_bb8a0_row3_col1" class="data row3 col1" >[None, 10]</td>
#       <td id="T_bb8a0_row3_col2" class="data row3 col2" >330.000000</td>
#       <td id="T_bb8a0_row3_col3" class="data row3 col3" >Dense</td>
#       <td id="T_bb8a0_row3_col4" class="data row3 col4" >[None, 64]</td>
#       <td id="T_bb8a0_row3_col5" class="data row3 col5" >4160</td>
#       <td id="T_bb8a0_row3_col6" class="data row3 col6" >Dense</td>
#       <td id="T_bb8a0_row3_col7" class="data row3 col7" >[None, 10]</td>
#       <td id="T_bb8a0_row3_col8" class="data row3 col8" >2570.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bb8a0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bb8a0_row4_col0" class="data row4 col0" >None</td>
#       <td id="T_bb8a0_row4_col1" class="data row4 col1" >None</td>
#       <td id="T_bb8a0_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_bb8a0_row4_col3" class="data row4 col3" >Dropout</td>
#       <td id="T_bb8a0_row4_col4" class="data row4 col4" >[None, 64]</td>
#       <td id="T_bb8a0_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_bb8a0_row4_col6" class="data row4 col6" >None</td>
#       <td id="T_bb8a0_row4_col7" class="data row4 col7" >None</td>
#       <td id="T_bb8a0_row4_col8" class="data row4 col8" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_bb8a0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bb8a0_row5_col0" class="data row5 col0" >None</td>
#       <td id="T_bb8a0_row5_col1" class="data row5 col1" >None</td>
#       <td id="T_bb8a0_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_bb8a0_row5_col3" class="data row5 col3" >Dense</td>
#       <td id="T_bb8a0_row5_col4" class="data row5 col4" >[None, 64]</td>
#       <td id="T_bb8a0_row5_col5" class="data row5 col5" >4160</td>
#       <td id="T_bb8a0_row5_col6" class="data row5 col6" >None</td>
#       <td id="T_bb8a0_row5_col7" class="data row5 col7" >None</td>
#       <td id="T_bb8a0_row5_col8" class="data row5 col8" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_bb8a0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_bb8a0_row6_col0" class="data row6 col0" >None</td>
#       <td id="T_bb8a0_row6_col1" class="data row6 col1" >None</td>
#       <td id="T_bb8a0_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_bb8a0_row6_col3" class="data row6 col3" >Dense</td>
#       <td id="T_bb8a0_row6_col4" class="data row6 col4" >[None, 10]</td>
#       <td id="T_bb8a0_row6_col5" class="data row6 col5" >650</td>
#       <td id="T_bb8a0_row6_col6" class="data row6 col6" >None</td>
#       <td id="T_bb8a0_row6_col7" class="data row6 col7" >None</td>
#       <td id="T_bb8a0_row6_col8" class="data row6 col8" >nan</td>
#     </tr>
#   </tbody>
# </table>
