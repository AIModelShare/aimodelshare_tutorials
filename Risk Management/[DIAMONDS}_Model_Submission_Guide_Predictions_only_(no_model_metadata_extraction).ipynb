# %% [markdown]
# <p align="center"><img width="50%" src="https://aimodelsharecontent.s3.amazonaws.com/aimodshare_banner.jpg" /></p>
#
#
# ---

# %% [markdown]
# <p align="center"><h1 align="center">Diamond Price Prediction Model Submission Guide - Predictions Only (No Model Metadata Extraction)
#
# ---
# Let's share our models to a centralized leaderboard, so that we can collaborate and learn from the model experimentation process...
#
# **Instructions:**
# 1.   Get data in and set up X_train / X_test / y_train
# 2.   Preprocess data
# 3. Fit model on preprocessed data
# 4. Generate predictions from X_test data and submit to competition
# 5. Repeat submission process to improve place on leaderboard

# %% [markdown]
# # Objective: Predict the species of Iris ('Iris-setosa', 'Iris-versicolor', or  'Iris-virginica') based on it's characteristics (length and width of sepals and petals).
#
# ---

# %% [markdown]
# ## 1. Get data in and set up X_train, X_test, y_train objects

# %%
#install aimodelshare library
! pip install aimodelshare --upgrade

# %%
# Get competition data
from aimodelshare import download_data
download_data('public.ecr.aws/y2e2a1d6/diamonds_competition_data-repository:latest')
# Out:
# Downloading [=======================================>         ]
#
# Data downloaded successfully.

# %%
# Separate data into X_train, y_train, and X_test
import pandas as pd

X_train = pd.read_csv("diamonds_competition_data/X_train.csv")
y_train = pd.read_csv("diamonds_competition_data/y_train.csv", squeeze = True)

X_test=pd.read_csv("diamonds_competition_data/X_test.csv")

X_train.head()
# Out:
#    carat      cut color clarity  depth  table     x     y     z
# 0   0.90     Good     E     SI2   64.1   57.0  6.07  6.09  3.90
# 1   1.54  Premium     G     VS2   61.1   59.0  7.44  7.40  4.53
# 2   0.52    Ideal     D     SI1   62.4   56.0  5.17  5.12  3.21
# 3   0.85    Ideal     E     SI1   63.0   56.0  6.00  6.04  3.79
# 4   0.35    Ideal     D     VS2   60.9   57.0  4.55  4.51  2.76

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
# Out:
# (43152, 9)
# (10788, 9)
# (43152,)

# %% [markdown]
# ##2.   Preprocess data

# %%
# Write and execute code to preprocess data here

# %% [markdown]
# ##3. Fit model on preprocessed data

# %%
# Write and execute code to fit model on preprocessed data here.

# %%
#Set credentials using modelshare.org username/password

from aimodelshare.aws import set_credentials
    
apiurl="https://csyks5i22a.execute-api.us-east-1.amazonaws.com/prod/m" 
#This is the unique rest api that powers this Diamond Price Prediction  Playground

set_credentials(apiurl=apiurl)
# Out:
# AI Modelshare Username:··········
# AI Modelshare Password:··········
# AI Model Share login credentials set successfully.

# %%
#Instantiate Competition
import aimodelshare as ai
mycompetition= ai.Competition(apiurl)

# %% [markdown]
# ## **4. Submit Model predictions to leaderboard (without extracting model architecture information):**
# - model metadata extraction allows you use compare_models() and instantiate_model() functions.

# %%
#Generate a list of predictions using X_test data

# This example uses randomly chosen values from y_train to generate a list of predictions
predicted_values = list(y_train.sample(n=len(X_test.index)))

# %%
#Submit Model predictions to leaderboard (without extracting model architecture information): 

# Submit to Competition Leaderboard
mycompetition.submit_model(model_filepath = None,
                                 preprocessor_filepath=None,
                                 prediction_submission=predicted_values)
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 8
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:1747

# %%
# Get leaderboard to explore current best model architectures

# Get raw data in pandas data frame
data = mycompetition.get_leaderboard()

# Stylize leaderboard data
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_53ccb_row0_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 1.3%, transparent 1.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_53ccb_row0_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 11.4%, transparent 11.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_53ccb_row0_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 8.6%, transparent 8.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_53ccb_row0_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 100.0%, transparent 100.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_53ccb_row0_col4, #T_53ccb_row0_col5, #T_53ccb_row0_col6, #T_53ccb_row0_col7, #T_53ccb_row0_col8, #T_53ccb_row0_col9, #T_53ccb_row0_col10, #T_53ccb_row0_col11, #T_53ccb_row0_col12, #T_53ccb_row0_col13, #T_53ccb_row0_col14, #T_53ccb_row0_col15, #T_53ccb_row0_col16, #T_53ccb_row1_col4, #T_53ccb_row1_col5, #T_53ccb_row1_col6, #T_53ccb_row1_col7, #T_53ccb_row1_col8, #T_53ccb_row1_col9, #T_53ccb_row1_col10, #T_53ccb_row1_col11, #T_53ccb_row1_col12, #T_53ccb_row1_col13, #T_53ccb_row1_col14, #T_53ccb_row1_col15, #T_53ccb_row1_col16, #T_53ccb_row2_col4, #T_53ccb_row2_col5, #T_53ccb_row2_col6, #T_53ccb_row2_col7, #T_53ccb_row2_col8, #T_53ccb_row2_col9, #T_53ccb_row2_col10, #T_53ccb_row2_col11, #T_53ccb_row2_col12, #T_53ccb_row2_col13, #T_53ccb_row2_col14, #T_53ccb_row2_col15, #T_53ccb_row2_col16, #T_53ccb_row3_col4, #T_53ccb_row3_col5, #T_53ccb_row3_col6, #T_53ccb_row3_col7, #T_53ccb_row3_col8, #T_53ccb_row3_col9, #T_53ccb_row3_col10, #T_53ccb_row3_col11, #T_53ccb_row3_col12, #T_53ccb_row3_col13, #T_53ccb_row3_col14, #T_53ccb_row3_col15, #T_53ccb_row3_col16, #T_53ccb_row4_col4, #T_53ccb_row4_col5, #T_53ccb_row4_col6, #T_53ccb_row4_col7, #T_53ccb_row4_col8, #T_53ccb_row4_col9, #T_53ccb_row4_col10, #T_53ccb_row4_col11, #T_53ccb_row4_col12, #T_53ccb_row4_col13, #T_53ccb_row4_col14, #T_53ccb_row4_col15, #T_53ccb_row4_col16, #T_53ccb_row5_col4, #T_53ccb_row5_col5, #T_53ccb_row5_col6, #T_53ccb_row5_col7, #T_53ccb_row5_col8, #T_53ccb_row5_col9, #T_53ccb_row5_col10, #T_53ccb_row5_col11, #T_53ccb_row5_col12, #T_53ccb_row5_col13, #T_53ccb_row5_col14, #T_53ccb_row5_col15, #T_53ccb_row5_col16, #T_53ccb_row6_col4, #T_53ccb_row6_col5, #T_53ccb_row6_col6, #T_53ccb_row6_col7, #T_53ccb_row6_col8, #T_53ccb_row6_col9, #T_53ccb_row6_col10, #T_53ccb_row6_col11, #T_53ccb_row6_col12, #T_53ccb_row6_col13, #T_53ccb_row6_col14, #T_53ccb_row6_col15, #T_53ccb_row6_col16, #T_53ccb_row7_col4, #T_53ccb_row7_col5, #T_53ccb_row7_col6, #T_53ccb_row7_col7, #T_53ccb_row7_col8, #T_53ccb_row7_col9, #T_53ccb_row7_col10, #T_53ccb_row7_col11, #T_53ccb_row7_col12, #T_53ccb_row7_col13, #T_53ccb_row7_col14, #T_53ccb_row7_col15, #T_53ccb_row7_col16 {
#   text-align: center;
# }
# #T_53ccb_row1_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 1.7%, transparent 1.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_53ccb_row1_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 12.9%, transparent 12.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_53ccb_row1_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 9.5%, transparent 9.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_53ccb_row1_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 99.2%, transparent 99.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_53ccb_row2_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 5.9%, transparent 5.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_53ccb_row2_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 24.2%, transparent 24.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_53ccb_row2_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 19.4%, transparent 19.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_53ccb_row2_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 90.6%, transparent 90.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_53ccb_row3_col0, #T_53ccb_row4_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 6.0%, transparent 6.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_53ccb_row3_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 24.4%, transparent 24.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_53ccb_row3_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 19.5%, transparent 19.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_53ccb_row3_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 90.4%, transparent 90.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_53ccb_row4_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 24.6%, transparent 24.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_53ccb_row4_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 20.9%, transparent 20.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_53ccb_row4_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 90.2%, transparent 90.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_53ccb_row5_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 8.1%, transparent 8.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_53ccb_row5_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 28.5%, transparent 28.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_53ccb_row5_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 25.2%, transparent 25.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_53ccb_row5_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 85.9%, transparent 85.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_53ccb_row6_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 62.9%, transparent 62.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_53ccb_row6_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 79.3%, transparent 79.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_53ccb_row6_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 79.8%, transparent 79.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_53ccb_row6_col3, #T_53ccb_row7_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_53ccb_row7_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 100.0%, transparent 100.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_53ccb_row7_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 100.0%, transparent 100.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_53ccb_row7_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 100.0%, transparent 100.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# </style>
# <table id="T_53ccb_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >mse</th>
#       <th class="col_heading level0 col1" >rmse</th>
#       <th class="col_heading level0 col2" >mae</th>
#       <th class="col_heading level0 col3" >r2</th>
#       <th class="col_heading level0 col4"

# %% [markdown]
# You can also compare two or more models for any models submitted to the leaderboard using example code for model metadata extraction (see code tab for this competition at www.modelshare.org for submission examples.)
# ```
# data=mycompetition.compare_models([1,2], verbose=1)
# mycompetition.stylize_compare(data)
# ```

# %% [markdown]
# #####  (Optional Extension) Submit Model With Custom Metadata:
# Can use to add team names or any other missing data you may wish to share on the leaderboard

# %%
# Custom metadata can be added by passing a dict to the custom_metadata argument of the submit_model() method
# This option can be used to fill in missing data points or add new columns to the leaderboard

custom_meta = {'team': 'team one',
               'model_type': 'your_model_type',
               'new_column': 'new metadata'}

mycompetition.submit_model(model_filepath = None,
                                 preprocessor_filepath=None,
                                 prediction_submission=predicted_values,
                                 custom_metadata = custom_meta)
