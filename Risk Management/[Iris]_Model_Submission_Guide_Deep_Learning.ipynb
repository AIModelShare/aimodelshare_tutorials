# %% [markdown]
# <p align="center"><img width="50%" src="https://aimodelsharecontent.s3.amazonaws.com/aimodshare_banner.jpg" /></p>
#
#
# ---

# %% [markdown]
# ## Model Submission Guide: Iris Classification Competition
# Let's share our models to a centralized leaderboard, so that we can collaborate and learn from the model experimentation process...
#
# **Instructions:**
# 1.   Get data in and set up X_train / X_test / y_train
# 2.   Preprocess data using Sklearn Column Transformer/ Write and Save Preprocessor function
# 3. Fit model on preprocessed data and save preprocessor function and model
# 4. Generate predictions from X_test data and submit model to competition
# 5. Repeat submission process to improve place on leaderboard

# %% [markdown]
# ## 1. Get data in and set up X_train, X_test, y_train objects

# %%
#install aimodelshare library
! pip install aimodelshare --upgrade

# %%
# Get competition data
from aimodelshare import download_data
download_data('public.ecr.aws/y2e2a1d6/iris_competition_data-repository:latest')
# Out:
# Downloading [>                                                ]
#
# Data downloaded successfully.

# %%
# Separate data into X_train, y_train, and X_test
import pandas as pd
y_train = pd.read_csv("iris_competition_data/y_train.csv")
y_train_labels = y_train.idxmax(axis=1)

X_train = pd.read_csv("iris_competition_data/X_train.csv")
X_test=pd.read_csv("iris_competition_data/X_test.csv")

X_train.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# 0           5.1          3.5           1.4          0.2
# 1           4.7          3.2           1.3          0.2
# 2           5.0          3.6           1.4          0.2
# 3           4.6          3.4           1.4          0.3
# 4           4.4          2.9           1.4          0.2

# %% [markdown]
# ##2.   Preprocess data using Sklearn / Write and Save Preprocessor function

# %%
# Simple Preprocessor with sklearn 

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
# Here is where we actually write the preprocessor function:
def preprocessor(data):
    preprocessed_data=scaler.transform(data)
    return preprocessed_data

# %%
# check shape of X data after preprocessing it using our new function
preprocessor(X_train).shape
# Out:
# (75, 4)

# %% [markdown]
# ##3. Fit model on preprocessed data and save preprocessor function and model

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation

model = Sequential()
model.add(Dense(16, input_dim=4, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(32, activation='relu'))

model.add(Dense(3, activation='softmax')) 
                                            
# Compile model
model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# Fitting the NN to the Training set
model.fit(preprocessor(X_train), y_train, 
               epochs = 15, validation_split=0.25)

# %% [markdown]
# #### Save preprocessor function to local "preprocessor.zip" file

# %%
import aimodelshare as ai
ai.export_preprocessor(preprocessor,"")
# Out:
# Your preprocessor is now saved to 'preprocessor.zip'

# %% [markdown]
# #### Save model to local ".onnx" file

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model = model_to_onnx(model, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %% [markdown]
# ## 4. Generate predictions from X_test data and submit model to competition

# %%
#Set credentials using modelshare.org username/password

from aimodelshare.aws import set_credentials

#This is the unique rest api that powers this Iris Classification Playground -- make sure to update the apiurl for new competition deployments
apiurl="https://h1t33c5s23.execute-api.us-east-1.amazonaws.com/prod/m"

set_credentials(apiurl=apiurl)
# Out:
# AI Modelshare Username:··········
# AI Modelshare Password:··········
# AI Model Share login credentials set successfully.

# %%
#Instantiate Competition
import aimodelshare as ai
mycompetition= ai.Competition(apiurl)

# %%
#Submit Model 1: 

#-- Generate predicted y values (Model 1)
#Note: Keras predict returns the predicted column index location for classification models
prediction_column_index=model.predict(preprocessor(X_test)).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

# Submit Model 1 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 5
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:1742

# %%
# Get leaderboard to explore current best model architectures

# Get raw data in pandas data frame
data = mycompetition.get_leaderboard()

# Stylize leaderboard data
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_d640c_row0_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 92.1%, transparent 92.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d640c_row0_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 91.9%, transparent 91.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d640c_row0_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 92.9%, transparent 92.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d640c_row0_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 92.3%, transparent 92.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d640c_row0_col4, #T_d640c_row0_col5, #T_d640c_row0_col6, #T_d640c_row0_col7, #T_d640c_row0_col8, #T_d640c_row0_col9, #T_d640c_row0_col10, #T_d640c_row0_col11, #T_d640c_row0_col12, #T_d640c_row0_col13, #T_d640c_row0_col14, #T_d640c_row0_col15, #T_d640c_row0_col16, #T_d640c_row0_col17, #T_d640c_row1_col4, #T_d640c_row1_col5, #T_d640c_row1_col6, #T_d640c_row1_col7, #T_d640c_row1_col8, #T_d640c_row1_col9, #T_d640c_row1_col10, #T_d640c_row1_col11, #T_d640c_row1_col12, #T_d640c_row1_col13, #T_d640c_row1_col14, #T_d640c_row1_col15, #T_d640c_row1_col16, #T_d640c_row1_col17, #T_d640c_row2_col4, #T_d640c_row2_col5, #T_d640c_row2_col6, #T_d640c_row2_col7, #T_d640c_row2_col8, #T_d640c_row2_col9, #T_d640c_row2_col10, #T_d640c_row2_col11, #T_d640c_row2_col12, #T_d640c_row2_col13, #T_d640c_row2_col14, #T_d640c_row2_col15, #T_d640c_row2_col16, #T_d640c_row2_col17, #T_d640c_row3_col4, #T_d640c_row3_col5, #T_d640c_row3_col6, #T_d640c_row3_col7, #T_d640c_row3_col8, #T_d640c_row3_col9, #T_d640c_row3_col10, #T_d640c_row3_col11, #T_d640c_row3_col12, #T_d640c_row3_col13, #T_d640c_row3_col14, #T_d640c_row3_col15, #T_d640c_row3_col16, #T_d640c_row3_col17, #T_d640c_row4_col4, #T_d640c_row4_col5, #T_d640c_row4_col6, #T_d640c_row4_col7, #T_d640c_row4_col8, #T_d640c_row4_col9, #T_d640c_row4_col10, #T_d640c_row4_col11, #T_d640c_row4_col12, #T_d640c_row4_col13, #T_d640c_row4_col14, #T_d640c_row4_col15, #T_d640c_row4_col16, #T_d640c_row4_col17 {
#   text-align: center;
# }
# #T_d640c_row1_col0, #T_d640c_row2_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 86.8%, transparent 86.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d640c_row1_col1, #T_d640c_row2_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 87.0%, transparent 87.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d640c_row1_col2, #T_d640c_row2_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 88.3%, transparent 88.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d640c_row1_col3, #T_d640c_row2_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 87.2%, transparent 87.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d640c_row3_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 65.8%, transparent 65.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d640c_row3_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 55.6%, transparent 55.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d640c_row3_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 50.0%, transparent 50.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d640c_row3_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 66.7%, transparent 66.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d640c_row4_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 57.9%, transparent 57.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d640c_row4_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 49.0%, transparent 49.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d640c_row4_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 45.1%, transparent 45.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_d640c_row4_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 58.5%, transparent 58.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# </style>
# <table id="T_d640c_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >accuracy</th>
#       <th class="col_heading level0 col1" >f1_score</th>
#       <th class="col_heading level0 col2" >precision</th>
#       <th class="col_heading level0 col3" >recall</th>
#       <th class="col_heading level0 col4" >ml_framework</th>
#       <th class="col_heading level0 col5" >transfer_learning</th>
#       <th class="col_heading level0 col6" >deep_learning</th>
#       <th class="col_heading level0 col7" >model_type</th>
#       <th class="col_heading level0 col8" >depth</th>
#       <th class="col_heading level0 col9" >num_params</th>
#       <th class="col_heading level0 col10" >dense_layers</th>
#       <th class="col_heading level0 col11" >relu_act</th>
#       <th class="col_heading level0 col12" >softmax_act</th>
#       <th class="col_heading level0 col13" >loss</th>
#       <th class="col_heading level0 col14" >optimizer</th>
#       <th class="col_heading level0 col15" >memory_size</th>
#       <th class="col_heading level0 col16" >username</th>
#       <th class="col_heading level0 col17" >version</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d640c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d640c_row0_col0" class="data row0 col0" >92.11%</td>
#       <td id="T_d640c_row0_col1" class="data row0 col1" >91.85%</td>
#       <td id="T_d640c_row0_col2" class="data row0 col2" >92.86%</td>
#       <td id="T_d640c_row0_col3" class="data row0 col3" >92.31%</td>
#       <td id="T_d640c_row0_col4" class="data row0 col4" >sklearn</td>
#       <td id="T_d640c_row0_col5" class="data row0 col5" >False</td>
#       <td id="T_d640c_row0_col6" class="data row0 col6" >False</td>
#       <td id="T_d640c_row0_col7" class="data row0 col7" >RandomForestClassifier</td>
#       <td id="T_d640c_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_d640c_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_d640c_row0_col10" class="data row0 col10" >nan</td>
#       <td id="T_d640c_row0_col11" class="data row0 col11" >nan</td>
#       <td id="T_d640c_row0_col12" class="data row0 col12" >nan</td>
#       <td id="T_d640c_row0_col13" class="data row0 col13" >nan</td>
#       <td id="T_d640c_row0_col14" class="data row0 col14" >nan</td>
#       <td id="T_d640c_row0_col15" class="data row0 col15" >nan</td>
#       <td id="T_d640c_row0_col16" class="data row0 col16" >ML_Risk_Mgmnt</td>
#       <td id="T_d640c_row0_col17" class="data row0 col17" >3</td>
#     </tr>
#     <tr>
#       <th id="T_d640c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d640c_row1_col0" class="data row1 col0" >86.84%</td>
#       <td id="T_d640c_row1_col1" class="data row1 col1" >87.01%</td>
#       <td id="T_d640c_row1_col2" class="data row1 col2" >88.33%</td>
#       <td id="T_d640c_row1_col3" class="data row1 col3" >87.18%</td>
#       <td id="T_d640c_row1_col4" class="data row1 col4" >sklearn</td>
#       <td id="T_d640c_row1_col5" class="data row1 col5" >False</td>
#       <td id="T_d640c_row1_col6" class="data row1 col6" >False</td>
#       <td id="T_d640c_row1_col7" class="data row1 col7" >SVC</td>
#       <td id="T_d640c_row1_col8" class="data row1 col8" >nan</td>
#       <td id="T_d640c_row1_col9" class="data row1 col9" >12.000000</td>
#       <td id="T_d640c_row1_col10" class="data row1 col10" >nan</td>
#       <td id="T_d640c_row1_col11" class="data row1 col11" >nan</td>
#       <td id="T_d640c_row1_col12" class="data row1

# %% [markdown]
# ## 5. Repeat submission process to improve place on leaderboard

# %%
# Train and submit model 2 using same preprocessor (note that you could save a new preprocessor, but we will use the same one for this example).
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation

model_2 = Sequential()
model_2.add(Dense(128, input_dim=4, activation='relu'))
model_2.add(Dropout(.3))
model_2.add(Dense(64, activation='relu'))
model_2.add(Dense(64, activation='relu'))
model_2.add(Dropout(.3))
model_2.add(Dense(64, activation='relu'))

model_2.add(Dense(3, activation='softmax')) 
                                            
# Compile model
model_2.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# Fitting the NN to the Training set
model_2.fit(preprocessor(X_train), y_train, 
               epochs = 10, validation_split=0.25)

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model = model_to_onnx(model_2, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("model2.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Submit Model 2: 

#-- Generate predicted y values (Model 2)
#Note: Keras predict returns the predicted column index location for classification models
prediction_column_index=model_2.predict(preprocessor(X_test)).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

# Submit Model 2 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model2.onnx",
                                 prediction_submission=prediction_labels,
                                 preprocessor_filepath="preprocessor.zip")
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 6
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:1742

# %%
# Compare two or more models
data=mycompetition.compare_models([5,6], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style type="text/css">
# #T_3f497_ caption {
#   color: black;
#   font-size: 18px;
# }
# #T_3f497_row0_col0, #T_3f497_row0_col3, #T_3f497_row1_col0, #T_3f497_row2_col0, #T_3f497_row2_col3, #T_3f497_row3_col0, #T_3f497_row3_col3, #T_3f497_row5_col3, #T_3f497_row6_col3 {
#   background: #fff2ae;
#   color: black;
#   color: black;
# }
# #T_3f497_row0_col1, #T_3f497_row0_col2, #T_3f497_row0_col4, #T_3f497_row0_col5, #T_3f497_row1_col1, #T_3f497_row1_col2, #T_3f497_row1_col4, #T_3f497_row1_col5, #T_3f497_row2_col1, #T_3f497_row2_col2, #T_3f497_row2_col4, #T_3f497_row2_col5, #T_3f497_row3_col1, #T_3f497_row3_col2, #T_3f497_row3_col4, #T_3f497_row3_col5, #T_3f497_row4_col0, #T_3f497_row4_col1, #T_3f497_row4_col2, #T_3f497_row4_col4, #T_3f497_row4_col5, #T_3f497_row5_col0, #T_3f497_row5_col1, #T_3f497_row5_col2, #T_3f497_row5_col4, #T_3f497_row5_col5, #T_3f497_row6_col0, #T_3f497_row6_col1, #T_3f497_row6_col2, #T_3f497_row6_col4, #T_3f497_row6_col5 {
#   background: white;
#   color: black;
#   color: black;
# }
# #T_3f497_row1_col3, #T_3f497_row4_col3 {
#   background: #cbd5e8;
#   color: black;
#   color: black;
# }
# </style>
# <table id="T_3f497_">
#   <caption>Model type: Neural Network</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model_5_Layer</th>
#       <th class="col_heading level0 col1" >Model_5_Shape</th>
#       <th class="col_heading level0 col2" >Model_5_Params</th>
#       <th class="col_heading level0 col3" >Model_6_Layer</th>
#       <th class="col_heading level0 col4" >Model_6_Shape</th>
#       <th class="col_heading level0 col5" >Model_6_Params</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3f497_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3f497_row0_col0" class="data row0 col0" >Dense</td>
#       <td id="T_3f497_row0_col1" class="data row0 col1" >[None, 16]</td>
#       <td id="T_3f497_row0_col2" class="data row0 col2" >80.000000</td>
#       <td id="T_3f497_row0_col3" class="data row0 col3" >Dense</td>
#       <td id="T_3f497_row0_col4" class="data row0 col4" >[None, 128]</td>
#       <td id="T_3f497_row0_col5" class="data row0 col5" >640</td>
#     </tr>
#     <tr>
#       <th id="T_3f497_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3f497_row1_col0" class="data row1 col0" >Dense</td>
#       <td id="T_3f497_row1_col1" class="data row1 col1" >[None, 16]</td>
#       <td id="T_3f497_row1_col2" class="data row1 col2" >272.000000</td>
#       <td id="T_3f497_row1_col3" class="data row1 col3" >Dropout</td>
#       <td id="T_3f497_row1_col4" class="data row1 col4" >[None, 128]</td>
#       <td id="T_3f497_row1_col5" class="data row1 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_3f497_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3f497_row2_col0" class="data row2 col0" >Dense</td>
#       <td id="T_3f497_row2_col1" class="data row2 col1" >[None, 32]</td>
#       <td id="T_3f497_row2_col2" class="data row2 col2" >544.000000</td>
#       <td id="T_3f497_row2_col3" class="data row2 col3" >Dense</td>
#       <td id="T_3f497_row2_col4" class="data row2 col4" >[None, 64]</td>
#       <td id="T_3f497_row2_col5" class="data row2 col5" >8256</td>
#     </tr>
#     <tr>
#       <th id="T_3f497_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3f497_row3_col0" class="data row3 col0" >Dense</td>
#       <td id="T_3f497_row3_col1" class="data row3 col1" >[None, 3]</td>
#       <td id="T_3f497_row3_col2" class="data row3 col2" >99.000000</td>
#       <td id="T_3f497_row3_col3" class="data row3 col3" >Dense</td>
#       <td id="T_3f497_row3_col4" class="data row3 col4" >[None, 64]</td>
#       <td id="T_3f497_row3_col5" class="data row3 col5" >4160</td>
#     </tr>
#     <tr>
#       <th id="T_3f497_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3f497_row4_col0" class="data row4 col0" >None</td>
#       <td id="T_3f497_row4_col1" class="data row4 col1" >None</td>
#       <td id="T_3f497_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_3f497_row4_col3" class="data row4 col3" >Dropout</td>
#       <td id="T_3f497_row4_col4" class="data row4 col4" >[None, 64]</td>
#       <td id="T_3f497_row4_col5" class="data row4 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_3f497_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3f497_row5_col0" class="data row5 col0" >None</td>
#       <td id="T_3f497_row5_col1" class="data row5 col1" >None</td>
#       <td id="T_3f497_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_3f497_row5_col3" class="data row5 col3" >Dense</td>
#       <td id="T_3f497_row5_col4" class="data row5 col4" >[None, 64]</td>
#       <td id="T_3f497_row5_col5" class="data row5 col5" >4160</td>
#     </tr>
#     <tr>
#       <th id="T_3f497_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3f497_row6_col0" class="data row6 col0" >None</td>
#       <td id="T_3f497_row6_col1" class="data row6 col1" >None</td>
#       <td id="T_3f497_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_3f497_row6_col3" class="data row6 col3" >Dense</td>
#       <td id="T_3f497_row6_col4" class="data row6 col4" >[None, 3]</td>
#       <td id="T_3f497_row6_col5" class="data row6 col5" >195</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Optional: Tune model within range of hyperparameters with Keras Tuner
#
# *Simple example shown below. Consult [documentation](https://keras.io/guides/keras_tuner/getting_started/) to see full functionality.*

# %%
! pip install keras_tuner

# %%
#Separate validation data 
from sklearn.model_selection import train_test_split
x_train_split, x_val, y_train_split, y_val = train_test_split(
     X_train, y_train, test_size=0.2, random_state=42)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, BatchNormalization
from keras.regularizers import l1, l2, l1_l2
import keras_tuner as kt


#Define model structure & parameter search space with function
def build_model(hp):
    model = keras.Sequential()
    model.add(Dense(64, input_dim=4, activation='relu', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
    model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
    model.add(Dense(units=hp.Int("units", min_value=32, max_value=512, step=32), #range 32-512 inclusive, minimum step between tested values is 32
                    activation='relu', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
    model.add(Dense(3, activation='softmax')) 
    model.compile(
        optimizer="rmsprop", loss="binary_crossentropy", metrics=["accuracy"],
    )
    return model

#initialize the tuner (which will search through parameters)
tuner = kt.RandomSearch(
    hypermodel=build_model, 
    objective="val_accuracy", # objective to optimize
    max_trials=3, #max number of trials to run during search
    executions_per_trial=3, #higher number reduces variance of results; guages model performance more accurately 
    overwrite=True,
    directory="tuning_model",
    project_name="tuning_units",
)

tuner.search(preprocessor(x_train_split), y_train_split, epochs=1, validation_data=(preprocessor(x_val), y_val))
# Out:
# Trial 3 Complete [00h 00m 05s]
# val_accuracy: 0.5777777930100759
#
# Best val_accuracy So Far: 0.7111111283302307
# Total elapsed time: 00h 00m 15s

# %%
# Build model with best hyperparameters

# Get the top 2 hyperparameters.
best_hps = tuner.get_best_hyperparameters(5)
# Build the model with the best hp.
tuned_model = build_model(best_hps[0])
# Fit with the entire dataset.
tuned_model.fit(x=preprocessor(X_train), y=y_train, epochs=5)

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model = model_to_onnx(tuned_model, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("tuned_model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Submit Model 3: 

#-- Generate predicted y values (Model 3)
prediction_column_index=tuned_model.predict(preprocessor(X_test)).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

# Submit to Competition Leaderboard
mycompetition.submit_model(model_filepath = "tuned_model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 7
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:1742

# %%
# Get leaderboard

data = mycompetition.get_leaderboard()
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_ab8a7_row0_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 92.1%, transparent 92.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ab8a7_row0_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 91.9%, transparent 91.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ab8a7_row0_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 92.9%, transparent 92.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ab8a7_row0_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 92.3%, transparent 92.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ab8a7_row0_col4, #T_ab8a7_row0_col5, #T_ab8a7_row0_col6, #T_ab8a7_row0_col7, #T_ab8a7_row0_col8, #T_ab8a7_row0_col9, #T_ab8a7_row0_col10, #T_ab8a7_row0_col11, #T_ab8a7_row0_col12, #T_ab8a7_row0_col13, #T_ab8a7_row0_col14, #T_ab8a7_row0_col15, #T_ab8a7_row0_col16, #T_ab8a7_row0_col17, #T_ab8a7_row0_col18, #T_ab8a7_row1_col4, #T_ab8a7_row1_col5, #T_ab8a7_row1_col6, #T_ab8a7_row1_col7, #T_ab8a7_row1_col8, #T_ab8a7_row1_col9, #T_ab8a7_row1_col10, #T_ab8a7_row1_col11, #T_ab8a7_row1_col12, #T_ab8a7_row1_col13, #T_ab8a7_row1_col14, #T_ab8a7_row1_col15, #T_ab8a7_row1_col16, #T_ab8a7_row1_col17, #T_ab8a7_row1_col18, #T_ab8a7_row2_col4, #T_ab8a7_row2_col5, #T_ab8a7_row2_col6, #T_ab8a7_row2_col7, #T_ab8a7_row2_col8, #T_ab8a7_row2_col9, #T_ab8a7_row2_col10, #T_ab8a7_row2_col11, #T_ab8a7_row2_col12, #T_ab8a7_row2_col13, #T_ab8a7_row2_col14, #T_ab8a7_row2_col15, #T_ab8a7_row2_col16, #T_ab8a7_row2_col17, #T_ab8a7_row2_col18, #T_ab8a7_row3_col4, #T_ab8a7_row3_col5, #T_ab8a7_row3_col6, #T_ab8a7_row3_col7, #T_ab8a7_row3_col8, #T_ab8a7_row3_col9, #T_ab8a7_row3_col10, #T_ab8a7_row3_col11, #T_ab8a7_row3_col12, #T_ab8a7_row3_col13, #T_ab8a7_row3_col14, #T_ab8a7_row3_col15, #T_ab8a7_row3_col16, #T_ab8a7_row3_col17, #T_ab8a7_row3_col18, #T_ab8a7_row4_col4, #T_ab8a7_row4_col5, #T_ab8a7_row4_col6, #T_ab8a7_row4_col7, #T_ab8a7_row4_col8, #T_ab8a7_row4_col9, #T_ab8a7_row4_col10, #T_ab8a7_row4_col11, #T_ab8a7_row4_col12, #T_ab8a7_row4_col13, #T_ab8a7_row4_col14, #T_ab8a7_row4_col15, #T_ab8a7_row4_col16, #T_ab8a7_row4_col17, #T_ab8a7_row4_col18, #T_ab8a7_row5_col4, #T_ab8a7_row5_col5, #T_ab8a7_row5_col6, #T_ab8a7_row5_col7, #T_ab8a7_row5_col8, #T_ab8a7_row5_col9, #T_ab8a7_row5_col10, #T_ab8a7_row5_col11, #T_ab8a7_row5_col12, #T_ab8a7_row5_col13, #T_ab8a7_row5_col14, #T_ab8a7_row5_col15, #T_ab8a7_row5_col16, #T_ab8a7_row5_col17, #T_ab8a7_row5_col18, #T_ab8a7_row6_col4, #T_ab8a7_row6_col5, #T_ab8a7_row6_col6, #T_ab8a7_row6_col7, #T_ab8a7_row6_col8, #T_ab8a7_row6_col9, #T_ab8a7_row6_col10, #T_ab8a7_row6_col11, #T_ab8a7_row6_col12, #T_ab8a7_row6_col13, #T_ab8a7_row6_col14, #T_ab8a7_row6_col15, #T_ab8a7_row6_col16, #T_ab8a7_row6_col17, #T_ab8a7_row6_col18 {
#   text-align: center;
# }
# #T_ab8a7_row1_col0, #T_ab8a7_row2_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 86.8%, transparent 86.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ab8a7_row1_col1, #T_ab8a7_row2_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 87.0%, transparent 87.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ab8a7_row1_col2, #T_ab8a7_row2_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 88.3%, transparent 88.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ab8a7_row1_col3, #T_ab8a7_row2_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 87.2%, transparent 87.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ab8a7_row3_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 76.3%, transparent 76.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ab8a7_row3_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 73.8%, transparent 73.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ab8a7_row3_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 86.4%, transparent 86.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ab8a7_row3_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 76.9%, transparent 76.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ab8a7_row4_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 65.8%, transparent 65.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ab8a7_row4_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 55.6%, transparent 55.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ab8a7_row4_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 50.0%, transparent 50.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ab8a7_row4_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 66.7%, transparent 66.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ab8a7_row5_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 57.9%, transparent 57.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ab8a7_row5_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 49.0%, transparent 49.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ab8a7_row5_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 45.1%, transparent 45.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ab8a7_row5_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 58.5%, transparent 58.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ab8a7_row6_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 34.2%, transparent 34.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ab8a7_row6_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 17.0%, transparent 17.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ab8a7_row6_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 11.4%, transparent 11.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ab8a7_row6_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 33.3%, transparent 33.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# </style>
# <table id="T_ab8a7_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >accuracy</th>
#       <th class="col_heading level0 col1" >f1_score</th>
#       <th class="col_heading level0 col2" >precision</th>
#       <th class="col_heading level0 col3" >recall</th>
#       <th class="col_heading level0 col4" >ml_framework</th>
#       <th class="col_heading level0 col5" >transfer_learning</th>
#       <th class="col_heading level0 col6" >deep_learning</th>
#       <th class="col_heading level0 col7" >model_type</th>
#       <th class="col_heading level0 col8" >depth</th>
#       <th class="col_heading level0 col9" >num_params</th>
#       <th class="col_heading level0 col10" >dropout_layers</th>
#       <th class="col_heading level0 col11" >dense_layers</th>
#       <th class="col_heading level0 col12" >relu_act</th>
#       <th class="col_heading level0 col13" >softmax_act</th>
#       <th class="col_heading level0 col14" >loss</th>
#       <th class="col_heading level0 col15" >optimizer</th>
#       <th class="col_heading level0 col16" >memory_size</th>
#       <th class="col_heading level0 col17" >username</th>
#       <th class="col_heading level0 col18" >version</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab8a7_level0_row0" class="

# %%
# Compare two or more models
data=mycompetition.compare_models([5, 6, 7], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style type="text/css">
# #T_87eb0_ caption {
#   color: black;
#   font-size: 18px;
# }
# #T_87eb0_row0_col0, #T_87eb0_row0_col3, #T_87eb0_row0_col6, #T_87eb0_row1_col0, #T_87eb0_row1_col6, #T_87eb0_row2_col0, #T_87eb0_row2_col3, #T_87eb0_row2_col6, #T_87eb0_row3_col0, #T_87eb0_row3_col3, #T_87eb0_row3_col6, #T_87eb0_row5_col3, #T_87eb0_row6_col3 {
#   background: #fff2ae;
#   color: black;
#   color: black;
# }
# #T_87eb0_row0_col1, #T_87eb0_row0_col2, #T_87eb0_row0_col4, #T_87eb0_row0_col5, #T_87eb0_row0_col7, #T_87eb0_row0_col8, #T_87eb0_row1_col1, #T_87eb0_row1_col2, #T_87eb0_row1_col4, #T_87eb0_row1_col5, #T_87eb0_row1_col7, #T_87eb0_row1_col8, #T_87eb0_row2_col1, #T_87eb0_row2_col2, #T_87eb0_row2_col4, #T_87eb0_row2_col5, #T_87eb0_row2_col7, #T_87eb0_row2_col8, #T_87eb0_row3_col1, #T_87eb0_row3_col2, #T_87eb0_row3_col4, #T_87eb0_row3_col5, #T_87eb0_row3_col7, #T_87eb0_row3_col8, #T_87eb0_row4_col0, #T_87eb0_row4_col1, #T_87eb0_row4_col2, #T_87eb0_row4_col4, #T_87eb0_row4_col5, #T_87eb0_row4_col6, #T_87eb0_row4_col7, #T_87eb0_row4_col8, #T_87eb0_row5_col0, #T_87eb0_row5_col1, #T_87eb0_row5_col2, #T_87eb0_row5_col4, #T_87eb0_row5_col5, #T_87eb0_row5_col6, #T_87eb0_row5_col7, #T_87eb0_row5_col8, #T_87eb0_row6_col0, #T_87eb0_row6_col1, #T_87eb0_row6_col2, #T_87eb0_row6_col4, #T_87eb0_row6_col5, #T_87eb0_row6_col6, #T_87eb0_row6_col7, #T_87eb0_row6_col8 {
#   background: white;
#   color: black;
#   color: black;
# }
# #T_87eb0_row1_col3, #T_87eb0_row4_col3 {
#   background: #cbd5e8;
#   color: black;
#   color: black;
# }
# </style>
# <table id="T_87eb0_">
#   <caption>Model type: Neural Network</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model_5_Layer</th>
#       <th class="col_heading level0 col1" >Model_5_Shape</th>
#       <th class="col_heading level0 col2" >Model_5_Params</th>
#       <th class="col_heading level0 col3" >Model_6_Layer</th>
#       <th class="col_heading level0 col4" >Model_6_Shape</th>
#       <th class="col_heading level0 col5" >Model_6_Params</th>
#       <th class="col_heading level0 col6" >Model_7_Layer</th>
#       <th class="col_heading level0 col7" >Model_7_Shape</th>
#       <th class="col_heading level0 col8" >Model_7_Params</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87eb0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_87eb0_row0_col0" class="data row0 col0" >Dense</td>
#       <td id="T_87eb0_row0_col1" class="data row0 col1" >[None, 16]</td>
#       <td id="T_87eb0_row0_col2" class="data row0 col2" >80.000000</td>
#       <td id="T_87eb0_row0_col3" class="data row0 col3" >Dense</td>
#       <td id="T_87eb0_row0_col4" class="data row0 col4" >[None, 128]</td>
#       <td id="T_87eb0_row0_col5" class="data row0 col5" >640</td>
#       <td id="T_87eb0_row0_col6" class="data row0 col6" >Dense</td>
#       <td id="T_87eb0_row0_col7" class="data row0 col7" >[None, 64]</td>
#       <td id="T_87eb0_row0_col8" class="data row0 col8" >320.000000</td>
#     </tr>
#     <tr>
#       <th id="T_87eb0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_87eb0_row1_col0" class="data row1 col0" >Dense</td>
#       <td id="T_87eb0_row1_col1" class="data row1 col1" >[None, 16]</td>
#       <td id="T_87eb0_row1_col2" class="data row1 col2" >272.000000</td>
#       <td id="T_87eb0_row1_col3" class="data row1 col3" >Dropout</td>
#       <td id="T_87eb0_row1_col4" class="data row1 col4" >[None, 128]</td>
#       <td id="T_87eb0_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_87eb0_row1_col6" class="data row1 col6" >Dense</td>
#       <td id="T_87eb0_row1_col7" class="data row1 col7" >[None, 64]</td>
#       <td id="T_87eb0_row1_col8" class="data row1 col8" >4160.000000</td>
#     </tr>
#     <tr>
#       <th id="T_87eb0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_87eb0_row2_col0" class="data row2 col0" >Dense</td>
#       <td id="T_87eb0_row2_col1" class="data row2 col1" >[None, 32]</td>
#       <td id="T_87eb0_row2_col2" class="data row2 col2" >544.000000</td>
#       <td id="T_87eb0_row2_col3" class="data row2 col3" >Dense</td>
#       <td id="T_87eb0_row2_col4" class="data row2 col4" >[None, 64]</td>
#       <td id="T_87eb0_row2_col5" class="data row2 col5" >8256</td>
#       <td id="T_87eb0_row2_col6" class="data row2 col6" >Dense</td>
#       <td id="T_87eb0_row2_col7" class="data row2 col7" >[None, 384]</td>
#       <td id="T_87eb0_row2_col8" class="data row2 col8" >24960.000000</td>
#     </tr>
#     <tr>
#       <th id="T_87eb0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_87eb0_row3_col0" class="data row3 col0" >Dense</td>
#       <td id="T_87eb0_row3_col1" class="data row3 col1" >[None, 3]</td>
#       <td id="T_87eb0_row3_col2" class="data row3 col2" >99.000000</td>
#       <td id="T_87eb0_row3_col3" class="data row3 col3" >Dense</td>
#       <td id="T_87eb0_row3_col4" class="data row3 col4" >[None, 64]</td>
#       <td id="T_87eb0_row3_col5" class="data row3 col5" >4160</td>
#       <td id="T_87eb0_row3_col6" class="data row3 col6" >Dense</td>
#       <td id="T_87eb0_row3_col7" class="data row3 col7" >[None, 3]</td>
#       <td id="T_87eb0_row3_col8" class="data row3 col8" >1155.000000</td>
#     </tr>
#     <tr>
#       <th id="T_87eb0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_87eb0_row4_col0" class="data row4 col0" >None</td>
#       <td id="T_87eb0_row4_col1" class="data row4 col1" >None</td>
#       <td id="T_87eb0_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_87eb0_row4_col3" class="data row4 col3" >Dropout</td>
#       <td id="T_87eb0_row4_col4" class="data row4 col4" >[None, 64]</td>
#       <td id="T_87eb0_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_87eb0_row4_col6" class="data row4 col6" >None</td>
#       <td id="T_87eb0_row4_col7" class="data row4 col7" >None</td>
#       <td id="T_87eb0_row4_col8" class="data row4 col8" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_87eb0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_87eb0_row5_col0" class="data row5 col0" >None</td>
#       <td id="T_87eb0_row5_col1" class="data row5 col1" >None</td>
#       <td id="T_87eb0_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_87eb0_row5_col3" class="data row5 col3" >Dense</td>
#       <td id="T_87eb0_row5_col4" class="data row5 col4" >[None, 64]</td>
#       <td id="T_87eb0_row5_col5" class="data row5 col5" >4160</td>
#       <td id="T_87eb0_row5_col6" class="data row5 col6" >None</td>
#       <td id="T_87eb0_row5_col7" class="data row5 col7" >None</td>
#       <td id="T_87eb0_row5_col8" class="data row5 col8" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_87eb0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_87eb0_row6_col0" class="data row6 col0" >None</td>
#       <td id="T_87eb0_row6_col1" class="data row6 col1" >None</td>
#       <td id="T_87eb0_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_87eb0_row6_col3" class="data row6 col3" >Dense</td>
#       <td id="T_87eb0_row6_col4" class="data row6 col4" >[None, 3]</td>
#       <td id="T_87eb0_row6_col5" class="data row6 col5" >195</td>
#       <td id="T_87eb0_row6_col6" class="data row6 col6" >None</td>
#       <td id="T_87eb0_row6_col7" class="data row6 col7" >None</td>
#       <td id="T_87eb0_row6_col8" class="data row6 col8" >nan</td>
#     </tr>
#   </tbody>
# </table>
