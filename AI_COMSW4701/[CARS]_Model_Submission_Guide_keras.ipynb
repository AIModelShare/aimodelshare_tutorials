# %% [markdown]
# <p align="center"><img width="50%" src="https://aimodelsharecontent.s3.amazonaws.com/aimodshare_banner.jpg" /></p>
#
#
# ---

# %% [markdown]
# <p align="center"><h1 align="center">Used Car Sales Price Prediction Competition
#
# ##### <p align="center">*Note: Dataset adapted from N. Birla's public dataset ['Vehicle Dataset'](https://www.kaggle.com/nehalbirla/vehicle-dataset-from-cardekho)*
# ---
# Let's share our models to a centralized leaderboard, so that we can collaborate and learn from the model experimentation process...
#
# **Instructions:**
# 1.   Get data in and set up X_train / X_test / y_train
# 2.   Preprocess data  with Sklearn Column Transformer/ Write and Save Preprocessor function
# 3. Fit model on preprocessed data and save preprocessor function and model
# 4. Generate predictions from X_test data and submit model to competition
# 5. Repeat submission process to improve place on leaderboard

# %% [markdown]
# ## 1. Get data in and set up X_train, X_test, y_train objects

# %%
#install aimodelshare library
! pip install aimodelshare --upgrade

# %%
# Get competition data
from aimodelshare import download_data
download_data('public.ecr.aws/y2e2a1d6/used_car_competition_data-repository:latest')
# Out:
# Downloading [=========>                                       ]
#
# Data downloaded successfully.

# %%
# Separate data into X_train, y_train, and X_test
import pandas as pd

X_train = pd.read_csv("/content/used_car_competition_data/training_data.csv")
y_train = X_train['selling_price']
X_train.drop(['selling_price'], axis=1, inplace=True)

X_test=pd.read_csv("/content/used_car_competition_data/test_data.csv")

X_train.head()
# Out:
#    year  km_driven    fuel       seller_type  ... mileage  engine  max_power  seats
# 0  2019       7032  Petrol  Trustmark Dealer  ...   19.00  1199.0      88.76    5.0
# 1  2013      60000  Petrol        Individual  ...   14.09  1596.0      99.60    5.0
# 2  2019      20000  Petrol            Dealer  ...   22.37  2487.0     214.56    5.0
# 3  2016      11500  Petrol        Individual  ...   25.17   799.0      53.30    5.0
# 4  2012      35000  Petrol        Individual  ...   14.00   796.0      35.00    5.0
#
# [5 rows x 10 columns]

# %% [markdown]
# ##2.   Preprocess data using Sklearn Column Transformer / Write and Save Preprocessor function

# %%
# In this case we use Sklearn's Column transformer in our preprocessor function

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

#Preprocess data using sklearn's Column Transformer approach

# We create the preprocessing pipelines for both numeric and categorical data.
numeric_features = ['km_driven', 'mileage', 'engine', 'max_power', 'year']
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')), #'imputer' names the step
    ('scaler', StandardScaler())])

categorical_features = ['fuel', 'seller_type', 'transmission', 'owner', 'seats']

# Replacing missing values with Modal value and then one-hot encoding.
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# Final preprocessor object set up with ColumnTransformer...

preprocess = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# fit preprocessor to your data
preprocess = preprocess.fit(X_train)

# %%
# Write function to transform data with preprocessor 
# In this case we use sklearn's Column transformer in our preprocessor function

def preprocessor(data):
    preprocessed_data=preprocess.transform(data)
    return preprocessed_data

# %%
# check shape of X data 
preprocessor(X_train).shape
# Out:
# (6502, 28)

# %% [markdown]
# ##3. Fit model on preprocessed data and save preprocessor function and model

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
import keras

feature_count=preprocessor(X_train).shape[1] #count features in input data

model = Sequential()
model.add(Dense(64, input_dim=feature_count, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))

model.add(Dense(1, kernel_initializer='normal')) 
                                            
# Compile model
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])

# Fitting the NN to the Training set
model.fit(preprocessor(X_train), y_train, 
               batch_size = 60, 
               epochs = 50, validation_split=0.35)

# %% [markdown]
# #### Save preprocessor function to local "preprocessor.zip" file

# %%
import aimodelshare as ai
ai.export_preprocessor(preprocessor,"")
# Out:
# Your preprocessor is now saved to 'preprocessor.zip'

# %% [markdown]
# #### Save model to local ".onnx" file

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

# Check how many preprocessed input features there are
from skl2onnx.common.data_types import FloatTensorType

onnx_model = model_to_onnx(model, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %% [markdown]
# ## 4. Generate predictions from X_test data and submit model to competition

# %%
#Set credentials using modelshare.org username/password

from aimodelshare.aws import set_credentials
    
apiurl="https://0ubc2lk3ie.execute-api.us-east-1.amazonaws.com/prod/m" #This is the unique rest api that powers this Used Car Sales Prediction Playground

set_credentials(apiurl=apiurl)
# Out:
# AI Modelshare Username:··········
# AI Modelshare Password:··········
# AI Model Share login credentials set successfully.

# %%
#Instantiate Competition
import aimodelshare as ai
mycompetition= ai.Competition(apiurl)

# %%
#Submit Model 1: 

#-- Generate predicted values (a list of predicted car prices) (Model 1)
predicted_values = model.predict(preprocessor(X_test))

# Submit Model 1 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=predicted_values)
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 7
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:1360

# %%
# Get leaderboard to explore current best model architectures

# Get raw data in pandas data frame
data = mycompetition.get_leaderboard()

# Stylize leaderboard data
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_0cd90_row0_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 29.5%, transparent 29.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_0cd90_row0_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 54.3%, transparent 54.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_0cd90_row0_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 48.9%, transparent 48.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_0cd90_row0_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 100.0%, transparent 100.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_0cd90_row0_col4, #T_0cd90_row0_col5, #T_0cd90_row0_col6, #T_0cd90_row0_col7, #T_0cd90_row0_col8, #T_0cd90_row0_col9, #T_0cd90_row0_col10, #T_0cd90_row0_col11, #T_0cd90_row0_col12, #T_0cd90_row0_col13, #T_0cd90_row0_col14, #T_0cd90_row0_col15, #T_0cd90_row0_col16, #T_0cd90_row0_col17, #T_0cd90_row1_col4, #T_0cd90_row1_col5, #T_0cd90_row1_col6, #T_0cd90_row1_col7, #T_0cd90_row1_col8, #T_0cd90_row1_col9, #T_0cd90_row1_col10, #T_0cd90_row1_col11, #T_0cd90_row1_col12, #T_0cd90_row1_col13, #T_0cd90_row1_col14, #T_0cd90_row1_col15, #T_0cd90_row1_col16, #T_0cd90_row1_col17, #T_0cd90_row2_col4, #T_0cd90_row2_col5, #T_0cd90_row2_col6, #T_0cd90_row2_col7, #T_0cd90_row2_col8, #T_0cd90_row2_col9, #T_0cd90_row2_col10, #T_0cd90_row2_col11, #T_0cd90_row2_col12, #T_0cd90_row2_col13, #T_0cd90_row2_col14, #T_0cd90_row2_col15, #T_0cd90_row2_col16, #T_0cd90_row2_col17, #T_0cd90_row3_col4, #T_0cd90_row3_col5, #T_0cd90_row3_col6, #T_0cd90_row3_col7, #T_0cd90_row3_col8, #T_0cd90_row3_col9, #T_0cd90_row3_col10, #T_0cd90_row3_col11, #T_0cd90_row3_col12, #T_0cd90_row3_col13, #T_0cd90_row3_col14, #T_0cd90_row3_col15, #T_0cd90_row3_col16, #T_0cd90_row3_col17, #T_0cd90_row4_col4, #T_0cd90_row4_col5, #T_0cd90_row4_col6, #T_0cd90_row4_col7, #T_0cd90_row4_col8, #T_0cd90_row4_col9, #T_0cd90_row4_col10, #T_0cd90_row4_col11, #T_0cd90_row4_col12, #T_0cd90_row4_col13, #T_0cd90_row4_col14, #T_0cd90_row4_col15, #T_0cd90_row4_col16, #T_0cd90_row4_col17, #T_0cd90_row5_col4, #T_0cd90_row5_col5, #T_0cd90_row5_col6, #T_0cd90_row5_col7, #T_0cd90_row5_col8, #T_0cd90_row5_col9, #T_0cd90_row5_col10, #T_0cd90_row5_col11, #T_0cd90_row5_col12, #T_0cd90_row5_col13, #T_0cd90_row5_col14, #T_0cd90_row5_col15, #T_0cd90_row5_col16, #T_0cd90_row5_col17, #T_0cd90_row6_col4, #T_0cd90_row6_col5, #T_0cd90_row6_col6, #T_0cd90_row6_col7, #T_0cd90_row6_col8, #T_0cd90_row6_col9, #T_0cd90_row6_col10, #T_0cd90_row6_col11, #T_0cd90_row6_col12, #T_0cd90_row6_col13, #T_0cd90_row6_col14, #T_0cd90_row6_col15, #T_0cd90_row6_col16, #T_0cd90_row6_col17 {
#   text-align: center;
# }
# #T_0cd90_row1_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 42.2%, transparent 42.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_0cd90_row1_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 65.0%, transparent 65.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_0cd90_row1_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 52.2%, transparent 52.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_0cd90_row1_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 97.7%, transparent 97.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_0cd90_row2_col0, #T_0cd90_row3_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 61.7%, transparent 61.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_0cd90_row2_col1, #T_0cd90_row3_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 78.5%, transparent 78.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_0cd90_row2_col2, #T_0cd90_row3_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 75.8%, transparent 75.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_0cd90_row2_col3, #T_0cd90_row3_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 94.1%, transparent 94.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_0cd90_row4_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 72.4%, transparent 72.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_0cd90_row4_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 85.1%, transparent 85.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_0cd90_row4_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 72.6%, transparent 72.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_0cd90_row4_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 92.1%, transparent 92.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_0cd90_row5_col0, #T_0cd90_row6_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 100.0%, transparent 100.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_0cd90_row5_col1, #T_0cd90_row6_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 100.0%, transparent 100.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_0cd90_row5_col2, #T_0cd90_row6_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 100.0%, transparent 100.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_0cd90_row5_col3, #T_0cd90_row6_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 87.0%, transparent 87.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# </style>
# <table id="T_0cd90_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >mse</th>
#       <th class="col_heading level0 col1" >rmse</th>
#       <th class="col_heading level0 col2" >mae</th>
#       <th class="col_heading level0 col3" >r2</th>
#       <th class="col_heading level0 col4" >ml_framework</th>
#       <th class="col_heading level0 col5" >transfer_learning</th>
#       <th class="col_heading level0 col6" >deep_learning</th>
#       <th class="col_heading level0 col7" >model_type</th>
#       <th class="col_heading level0 col8" >depth</th>
#       <th class="col_heading level0 col9" >num_params</th>
#       <th class="col_heading level0 col10" >dense_layers</th>
#       <th class="col_heading level0 col11" >relu_act</th>
#       <th class="col_heading level0 col12" >loss</th>
#       <th class="col_heading level0 col13" >optimizer</th>
#       <th class="col_heading level0 col14" >model_config</th>
#       <th class="col_heading level0 col15" >memory_size</th>
#       <th class="col_heading level0 col16" >username</th>
#       <th class="col_heading level0 col17" >version</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0cd90_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0cd90_row0_col0" class="data row0 col0" >6878604.12</td>
#       <td id="T_0cd90_row0_col1" class="data row0 col1" >2622.71</td>
#       <td id="T_0cd90_row0_col2" class="data row0 col2" >1617.79</td>
#       <td id="T_0cd90_row0_col3" class="data row0 col3" >0.95</td>
#       <td id="T_0cd90_row0_col4" class="data row0 col4" >sklearn</td>
#       <td id="T_0cd90_row0_col5" class="data row0 col5" >False</td>
#       <td id="T_0cd90_row0_col6" class="data row0 col6" >False</td>
#       <td id="T_0cd90_row0_col7" class="data row0 col7" >RandomForestRegressor</td>
#       <td id="T_0cd90_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_0cd90_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_0cd90_row0_col10" class="data row0 col10" >nan</td>
#       <td id="T_0cd90_row0_col11" class="data row0 col11" >nan</td>

# %% [markdown]
# ## 5. Repeat submission process to improve place on leaderboard

# %%
# Create model 2  -- Model with Dropout regularization
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout,BatchNormalization

feature_count=preprocessor(X_train).shape[1] #count features in input data

model_2 = Sequential()
model_2.add(Dense(64, input_dim=feature_count))
model_2.add(BatchNormalization())
model_2.add(Activation('relu'))
model_2.add(Dense(64))
model_2.add(BatchNormalization())
model_2.add(Activation('relu'))
model_2.add(Dense(64))
model_2.add(BatchNormalization())
model_2.add(Activation('relu'))
model_2.add(Dense(1, kernel_initializer='normal')) 
                                            
# Compile model
model_2.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])

# Fitting the NN to the Training set
model_2.fit(preprocessor(X_train), y_train, 
               batch_size = 60, 
               epochs = 60, validation_split=0.35)

# %%
# Save Model 2 to .onnx file

onnx_model = model_to_onnx(model_2, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

# Save model to local .onnx file
with open("model_2.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
# Submit Model 2

#-- Generate predicted y values (Model 2)
prediction_labels = model_2.predict(preprocessor(X_test))

# Submit Model 2 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model_2.onnx",
                                 prediction_submission=prediction_labels,
                                 preprocessor_filepath="preprocessor.zip")
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 8
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:1360

# %%
# Compare two or more models
data=mycompetition.compare_models([7, 8], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style type="text/css">
# #T_edaee_ caption {
#   color: black;
#   font-size: 18px;
# }
# #T_edaee_row0_col0, #T_edaee_row0_col3, #T_edaee_row1_col0, #T_edaee_row2_col0, #T_edaee_row3_col0, #T_edaee_row3_col3, #T_edaee_row6_col3, #T_edaee_row9_col3 {
#   background: #fff2ae;
#   color: black;
#   color: black;
# }
# #T_edaee_row0_col1, #T_edaee_row0_col2, #T_edaee_row0_col4, #T_edaee_row0_col5, #T_edaee_row1_col1, #T_edaee_row1_col2, #T_edaee_row1_col4, #T_edaee_row1_col5, #T_edaee_row2_col1, #T_edaee_row2_col2, #T_edaee_row2_col4, #T_edaee_row2_col5, #T_edaee_row3_col1, #T_edaee_row3_col2, #T_edaee_row3_col4, #T_edaee_row3_col5, #T_edaee_row4_col0, #T_edaee_row4_col1, #T_edaee_row4_col2, #T_edaee_row4_col4, #T_edaee_row4_col5, #T_edaee_row5_col0, #T_edaee_row5_col1, #T_edaee_row5_col2, #T_edaee_row5_col4, #T_edaee_row5_col5, #T_edaee_row6_col0, #T_edaee_row6_col1, #T_edaee_row6_col2, #T_edaee_row6_col4, #T_edaee_row6_col5, #T_edaee_row7_col0, #T_edaee_row7_col1, #T_edaee_row7_col2, #T_edaee_row7_col4, #T_edaee_row7_col5, #T_edaee_row8_col0, #T_edaee_row8_col1, #T_edaee_row8_col2, #T_edaee_row8_col4, #T_edaee_row8_col5, #T_edaee_row9_col0, #T_edaee_row9_col1, #T_edaee_row9_col2, #T_edaee_row9_col4, #T_edaee_row9_col5 {
#   background: white;
#   color: black;
#   color: black;
# }
# #T_edaee_row1_col3, #T_edaee_row4_col3, #T_edaee_row7_col3 {
#   background: #f1e2cc;
#   color: black;
#   color: black;
# }
# #T_edaee_row2_col3, #T_edaee_row5_col3, #T_edaee_row8_col3 {
#   background: #fdcdac;
#   color: black;
#   color: black;
# }
# </style>
# <table id="T_edaee_">
#   <caption>Model type: Neural Network</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model_7_Layer</th>
#       <th class="col_heading level0 col1" >Model_7_Shape</th>
#       <th class="col_heading level0 col2" >Model_7_Params</th>
#       <th class="col_heading level0 col3" >Model_8_Layer</th>
#       <th class="col_heading level0 col4" >Model_8_Shape</th>
#       <th class="col_heading level0 col5" >Model_8_Params</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_edaee_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_edaee_row0_col0" class="data row0 col0" >Dense</td>
#       <td id="T_edaee_row0_col1" class="data row0 col1" >[None, 64]</td>
#       <td id="T_edaee_row0_col2" class="data row0 col2" >1856.000000</td>
#       <td id="T_edaee_row0_col3" class="data row0 col3" >Dense</td>
#       <td id="T_edaee_row0_col4" class="data row0 col4" >[None, 64]</td>
#       <td id="T_edaee_row0_col5" class="data row0 col5" >1856</td>
#     </tr>
#     <tr>
#       <th id="T_edaee_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_edaee_row1_col0" class="data row1 col0" >Dense</td>
#       <td id="T_edaee_row1_col1" class="data row1 col1" >[None, 64]</td>
#       <td id="T_edaee_row1_col2" class="data row1 col2" >4160.000000</td>
#       <td id="T_edaee_row1_col3" class="data row1 col3" >BatchNormalization</td>
#       <td id="T_edaee_row1_col4" class="data row1 col4" >[None, 64]</td>
#       <td id="T_edaee_row1_col5" class="data row1 col5" >256</td>
#     </tr>
#     <tr>
#       <th id="T_edaee_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_edaee_row2_col0" class="data row2 col0" >Dense</td>
#       <td id="T_edaee_row2_col1" class="data row2 col1" >[None, 64]</td>
#       <td id="T_edaee_row2_col2" class="data row2 col2" >4160.000000</td>
#       <td id="T_edaee_row2_col3" class="data row2 col3" >Activation</td>
#       <td id="T_edaee_row2_col4" class="data row2 col4" >[None, 64]</td>
#       <td id="T_edaee_row2_col5" class="data row2 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_edaee_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_edaee_row3_col0" class="data row3 col0" >Dense</td>
#       <td id="T_edaee_row3_col1" class="data row3 col1" >[None, 1]</td>
#       <td id="T_edaee_row3_col2" class="data row3 col2" >65.000000</td>
#       <td id="T_edaee_row3_col3" class="data row3 col3" >Dense</td>
#       <td id="T_edaee_row3_col4" class="data row3 col4" >[None, 64]</td>
#       <td id="T_edaee_row3_col5" class="data row3 col5" >4160</td>
#     </tr>
#     <tr>
#       <th id="T_edaee_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_edaee_row4_col0" class="data row4 col0" >None</td>
#       <td id="T_edaee_row4_col1" class="data row4 col1" >None</td>
#       <td id="T_edaee_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_edaee_row4_col3" class="data row4 col3" >BatchNormalization</td>
#       <td id="T_edaee_row4_col4" class="data row4 col4" >[None, 64]</td>
#       <td id="T_edaee_row4_col5" class="data row4 col5" >256</td>
#     </tr>
#     <tr>
#       <th id="T_edaee_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_edaee_row5_col0" class="data row5 col0" >None</td>
#       <td id="T_edaee_row5_col1" class="data row5 col1" >None</td>
#       <td id="T_edaee_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_edaee_row5_col3" class="data row5 col3" >Activation</td>
#       <td id="T_edaee_row5_col4" class="data row5 col4" >[None, 64]</td>
#       <td id="T_edaee_row5_col5" class="data row5 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_edaee_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_edaee_row6_col0" class="data row6 col0" >None</td>
#       <td id="T_edaee_row6_col1" class="data row6 col1" >None</td>
#       <td id="T_edaee_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_edaee_row6_col3" class="data row6 col3" >Dense</td>
#       <td id="T_edaee_row6_col4" class="data row6 col4" >[None, 64]</td>
#       <td id="T_edaee_row6_col5" class="data row6 col5" >4160</td>
#     </tr>
#     <tr>
#       <th id="T_edaee_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_edaee_row7_col0" class="data row7 col0" >None</td>
#       <td id="T_edaee_row7_col1" class="data row7 col1" >None</td>
#       <td id="T_edaee_row7_col2" class="data row7 col2" >nan</td>
#       <td id="T_edaee_row7_col3" class="data row7 col3" >BatchNormalization</td>
#       <td id="T_edaee_row7_col4" class="data row7 col4" >[None, 64]</td>
#       <td id="T_edaee_row7_col5" class="data row7 col5" >256</td>
#     </tr>
#     <tr>
#       <th id="T_edaee_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_edaee_row8_col0" class="data row8 col0" >None</td>
#       <td id="T_edaee_row8_col1" class="data row8 col1" >None</td>
#       <td id="T_edaee_row8_col2" class="data row8 col2" >nan</td>
#       <td id="T_edaee_row8_col3" class="data row8 col3" >Activation</td>
#       <td id="T_edaee_row8_col4" class="data row8 col4" >[None, 64]</td>
#       <td id="T_edaee_row8_col5" class="data row8 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_edaee_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_edaee_row9_col0" class="data row9 col0" >None</td>
#       <td id="T_edaee_row9_col1" class="data row9 col1" >None</td>
#       <td id="T_edaee_row9_col2" class="data row9 col2" >nan</td>
#       <td id="T_edaee_row9_col3" class="data row9 col3" >Dense</td>
#       <td id="T_edaee_row9_col4" class="data row9 col4" >[None, 1]</td>
#       <td id="T_edaee_row9_col5" class="data row9 col5" >65</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Optional: Tune model within range of hyperparameters with Keras Tuner
#
# *Simple example shown below. Consult [documentation](https://keras.io/guides/keras_tuner/getting_started/) to see full functionality.*

# %%
! pip install keras_tuner

# %%
#Separate validation data 
from sklearn.model_selection import train_test_split
x_train_split, x_val, y_train_split, y_val = train_test_split(
     X_train, y_train, test_size=0.2, random_state=42)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, BatchNormalization
from keras.regularizers import l1, l2, l1_l2
import keras_tuner as kt

feature_count=preprocessor(X_train).shape[1] #count features in input data

#Define model structure & parameter search space with function
def build_model(hp):
    model = keras.Sequential()
    model.add(Dense(64, input_dim=feature_count, activation='relu', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
    model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
    model.add(Dense(units=hp.Int("units", min_value=32, max_value=512, step=32), #range 32-512 inclusive, minimum step between tested values is 32
                    activation='relu', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
    model.add(Dense(1, kernel_initializer='normal')) 
    model.compile(
        loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])
    return model                                          

#initialize the tuner (which will search through parameters)
tuner = kt.RandomSearch(
    hypermodel=build_model, 
    objective="mean_squared_error", # objective to optimize
    max_trials=3, #max number of trials to run during search
    executions_per_trial=3, #higher number reduces variance of results; guages model performance more accurately 
    overwrite=True,
    directory="tuning_model",
    project_name="tuning_units",
)

tuner.search(preprocessor(x_train_split), y_train_split, epochs=2, validation_data=(preprocessor(x_val), y_val))
# Out:
# Trial 3 Complete [00h 00m 10s]
# mean_squared_error: 50156012.0
#
# Best mean_squared_error So Far: 47213058.666666664
# Total elapsed time: 00h 00m 35s

# %%
# Build model with best hyperparameters

# Get the top 2 hyperparameters.
best_hps = tuner.get_best_hyperparameters(5)
# Build the model with the best hp.
tuned_model = build_model(best_hps[0])
# Fit with the entire dataset.
tuned_model.fit(x=preprocessor(X_train), y=y_train, epochs=5)
# Out:
# Epoch 1/5
# 204/204 [==============================] - 1s 2ms/step - loss: 141262976.0000 - mean_squared_error: 141262976.0000
# Epoch 2/5
# 204/204 [==============================] - 0s 2ms/step - loss: 38316324.0000 - mean_squared_error: 38316320.0000
# Epoch 3/5
# 204/204 [==============================] - 0s 2ms/step - loss: 25242888.0000 - mean_squared_error: 25242874.0000
# Epoch 4/5
# 204/204 [==============================] - 0s 2ms/step - loss: 19444980.0000 - mean_squared_error: 19444970.0000
# Epoch 5/5
# 204/204 [==============================] - 0s 2ms/step - loss: 16062467.0000 - mean_squared_error: 16062448.0000

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model = model_to_onnx(tuned_model, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("tuned_model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Submit Model 3: 

#-- Generate predicted values
prediction_labels = tuned_model.predict(preprocessor(X_test))

# Submit Model 3 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "tuned_model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 9
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:1360

# %%
# Get leaderboard

data = mycompetition.get_leaderboard()
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_8a9e5_row0_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 5.0%, transparent 5.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8a9e5_row0_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 22.3%, transparent 22.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8a9e5_row0_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 22.7%, transparent 22.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8a9e5_row0_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 100.0%, transparent 100.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8a9e5_row0_col4, #T_8a9e5_row0_col5, #T_8a9e5_row0_col6, #T_8a9e5_row0_col7, #T_8a9e5_row0_col8, #T_8a9e5_row0_col9, #T_8a9e5_row0_col10, #T_8a9e5_row0_col11, #T_8a9e5_row0_col12, #T_8a9e5_row0_col13, #T_8a9e5_row0_col14, #T_8a9e5_row0_col15, #T_8a9e5_row0_col16, #T_8a9e5_row0_col17, #T_8a9e5_row0_col18, #T_8a9e5_row1_col4, #T_8a9e5_row1_col5, #T_8a9e5_row1_col6, #T_8a9e5_row1_col7, #T_8a9e5_row1_col8, #T_8a9e5_row1_col9, #T_8a9e5_row1_col10, #T_8a9e5_row1_col11, #T_8a9e5_row1_col12, #T_8a9e5_row1_col13, #T_8a9e5_row1_col14, #T_8a9e5_row1_col15, #T_8a9e5_row1_col16, #T_8a9e5_row1_col17, #T_8a9e5_row1_col18, #T_8a9e5_row2_col4, #T_8a9e5_row2_col5, #T_8a9e5_row2_col6, #T_8a9e5_row2_col7, #T_8a9e5_row2_col8, #T_8a9e5_row2_col9, #T_8a9e5_row2_col10, #T_8a9e5_row2_col11, #T_8a9e5_row2_col12, #T_8a9e5_row2_col13, #T_8a9e5_row2_col14, #T_8a9e5_row2_col15, #T_8a9e5_row2_col16, #T_8a9e5_row2_col17, #T_8a9e5_row2_col18, #T_8a9e5_row3_col4, #T_8a9e5_row3_col5, #T_8a9e5_row3_col6, #T_8a9e5_row3_col7, #T_8a9e5_row3_col8, #T_8a9e5_row3_col9, #T_8a9e5_row3_col10, #T_8a9e5_row3_col11, #T_8a9e5_row3_col12, #T_8a9e5_row3_col13, #T_8a9e5_row3_col14, #T_8a9e5_row3_col15, #T_8a9e5_row3_col16, #T_8a9e5_row3_col17, #T_8a9e5_row3_col18, #T_8a9e5_row4_col4, #T_8a9e5_row4_col5, #T_8a9e5_row4_col6, #T_8a9e5_row4_col7, #T_8a9e5_row4_col8, #T_8a9e5_row4_col9, #T_8a9e5_row4_col10, #T_8a9e5_row4_col11, #T_8a9e5_row4_col12, #T_8a9e5_row4_col13, #T_8a9e5_row4_col14, #T_8a9e5_row4_col15, #T_8a9e5_row4_col16, #T_8a9e5_row4_col17, #T_8a9e5_row4_col18, #T_8a9e5_row5_col4, #T_8a9e5_row5_col5, #T_8a9e5_row5_col6, #T_8a9e5_row5_col7, #T_8a9e5_row5_col8, #T_8a9e5_row5_col9, #T_8a9e5_row5_col10, #T_8a9e5_row5_col11, #T_8a9e5_row5_col12, #T_8a9e5_row5_col13, #T_8a9e5_row5_col14, #T_8a9e5_row5_col15, #T_8a9e5_row5_col16, #T_8a9e5_row5_col17, #T_8a9e5_row5_col18, #T_8a9e5_row6_col4, #T_8a9e5_row6_col5, #T_8a9e5_row6_col6, #T_8a9e5_row6_col7, #T_8a9e5_row6_col8, #T_8a9e5_row6_col9, #T_8a9e5_row6_col10, #T_8a9e5_row6_col11, #T_8a9e5_row6_col12, #T_8a9e5_row6_col13, #T_8a9e5_row6_col14, #T_8a9e5_row6_col15, #T_8a9e5_row6_col16, #T_8a9e5_row6_col17, #T_8a9e5_row6_col18, #T_8a9e5_row7_col4, #T_8a9e5_row7_col5, #T_8a9e5_row7_col6, #T_8a9e5_row7_col7, #T_8a9e5_row7_col8, #T_8a9e5_row7_col9, #T_8a9e5_row7_col10, #T_8a9e5_row7_col11, #T_8a9e5_row7_col12, #T_8a9e5_row7_col13, #T_8a9e5_row7_col14, #T_8a9e5_row7_col15, #T_8a9e5_row7_col16, #T_8a9e5_row7_col17, #T_8a9e5_row7_col18, #T_8a9e5_row8_col4, #T_8a9e5_row8_col5, #T_8a9e5_row8_col6, #T_8a9e5_row8_col7, #T_8a9e5_row8_col8, #T_8a9e5_row8_col9, #T_8a9e5_row8_col10, #T_8a9e5_row8_col11, #T_8a9e5_row8_col12, #T_8a9e5_row8_col13, #T_8a9e5_row8_col14, #T_8a9e5_row8_col15, #T_8a9e5_row8_col16, #T_8a9e5_row8_col17, #T_8a9e5_row8_col18 {
#   text-align: center;
# }
# #T_8a9e5_row1_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 7.1%, transparent 7.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8a9e5_row1_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 26.7%, transparent 26.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8a9e5_row1_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 24.3%, transparent 24.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8a9e5_row1_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 97.7%, transparent 97.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8a9e5_row2_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 11.7%, transparent 11.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8a9e5_row2_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 34.2%, transparent 34.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8a9e5_row2_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 29.8%, transparent 29.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8a9e5_row2_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 92.6%, transparent 92.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8a9e5_row3_col0, #T_8a9e5_row4_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 10.4%, transparent 10.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8a9e5_row3_col1, #T_8a9e5_row4_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 32.3%, transparent 32.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8a9e5_row3_col2, #T_8a9e5_row4_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 35.2%, transparent 35.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8a9e5_row3_col3, #T_8a9e5_row4_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 94.1%, transparent 94.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8a9e5_row5_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 12.2%, transparent 12.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8a9e5_row5_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 35.0%, transparent 35.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8a9e5_row5_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 33.7%, transparent 33.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8a9e5_row5_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 92.1%, transparent 92.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8a9e5_row6_col0, #T_8a9e5_row7_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 16.9%, transparent 16.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8a9e5_row6_col1, #T_8a9e5_row7_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 41.1%, transparent 41.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8a9e5_row6_col2, #T_8a9e5_row7_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 46.5%, transparent 46.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8a9e5_row6_col3, #T_8a9e5_row7_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 87.0%, transparent 87.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8a9e5_row8_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 100.0%, transparent 100.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8a9e5_row8_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 100.0%, transparent 100.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8a9e5_row8_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 100.0%, transparent 100.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_8a9e5_row8_col3 {
#   text-align: center;
#   width: 10em;
#   heigh

# %%
# Compare two or more models
data=mycompetition.compare_models([7, 8, 9], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style type="text/css">
# #T_2e03d_ caption {
#   color: black;
#   font-size: 18px;
# }
# #T_2e03d_row0_col0, #T_2e03d_row0_col3, #T_2e03d_row0_col6, #T_2e03d_row1_col0, #T_2e03d_row1_col6, #T_2e03d_row2_col0, #T_2e03d_row2_col6, #T_2e03d_row3_col0, #T_2e03d_row3_col3, #T_2e03d_row3_col6, #T_2e03d_row6_col3, #T_2e03d_row9_col3 {
#   background: #fff2ae;
#   color: black;
#   color: black;
# }
# #T_2e03d_row0_col1, #T_2e03d_row0_col2, #T_2e03d_row0_col4, #T_2e03d_row0_col5, #T_2e03d_row0_col7, #T_2e03d_row0_col8, #T_2e03d_row1_col1, #T_2e03d_row1_col2, #T_2e03d_row1_col4, #T_2e03d_row1_col5, #T_2e03d_row1_col7, #T_2e03d_row1_col8, #T_2e03d_row2_col1, #T_2e03d_row2_col2, #T_2e03d_row2_col4, #T_2e03d_row2_col5, #T_2e03d_row2_col7, #T_2e03d_row2_col8, #T_2e03d_row3_col1, #T_2e03d_row3_col2, #T_2e03d_row3_col4, #T_2e03d_row3_col5, #T_2e03d_row3_col7, #T_2e03d_row3_col8, #T_2e03d_row4_col0, #T_2e03d_row4_col1, #T_2e03d_row4_col2, #T_2e03d_row4_col4, #T_2e03d_row4_col5, #T_2e03d_row4_col6, #T_2e03d_row4_col7, #T_2e03d_row4_col8, #T_2e03d_row5_col0, #T_2e03d_row5_col1, #T_2e03d_row5_col2, #T_2e03d_row5_col4, #T_2e03d_row5_col5, #T_2e03d_row5_col6, #T_2e03d_row5_col7, #T_2e03d_row5_col8, #T_2e03d_row6_col0, #T_2e03d_row6_col1, #T_2e03d_row6_col2, #T_2e03d_row6_col4, #T_2e03d_row6_col5, #T_2e03d_row6_col6, #T_2e03d_row6_col7, #T_2e03d_row6_col8, #T_2e03d_row7_col0, #T_2e03d_row7_col1, #T_2e03d_row7_col2, #T_2e03d_row7_col4, #T_2e03d_row7_col5, #T_2e03d_row7_col6, #T_2e03d_row7_col7, #T_2e03d_row7_col8, #T_2e03d_row8_col0, #T_2e03d_row8_col1, #T_2e03d_row8_col2, #T_2e03d_row8_col4, #T_2e03d_row8_col5, #T_2e03d_row8_col6, #T_2e03d_row8_col7, #T_2e03d_row8_col8, #T_2e03d_row9_col0, #T_2e03d_row9_col1, #T_2e03d_row9_col2, #T_2e03d_row9_col4, #T_2e03d_row9_col5, #T_2e03d_row9_col6, #T_2e03d_row9_col7, #T_2e03d_row9_col8 {
#   background: white;
#   color: black;
#   color: black;
# }
# #T_2e03d_row1_col3, #T_2e03d_row4_col3, #T_2e03d_row7_col3 {
#   background: #f1e2cc;
#   color: black;
#   color: black;
# }
# #T_2e03d_row2_col3, #T_2e03d_row5_col3, #T_2e03d_row8_col3 {
#   background: #fdcdac;
#   color: black;
#   color: black;
# }
# </style>
# <table id="T_2e03d_">
#   <caption>Model type: Neural Network</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model_7_Layer</th>
#       <th class="col_heading level0 col1" >Model_7_Shape</th>
#       <th class="col_heading level0 col2" >Model_7_Params</th>
#       <th class="col_heading level0 col3" >Model_8_Layer</th>
#       <th class="col_heading level0 col4" >Model_8_Shape</th>
#       <th class="col_heading level0 col5" >Model_8_Params</th>
#       <th class="col_heading level0 col6" >Model_9_Layer</th>
#       <th class="col_heading level0 col7" >Model_9_Shape</th>
#       <th class="col_heading level0 col8" >Model_9_Params</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e03d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2e03d_row0_col0" class="data row0 col0" >Dense</td>
#       <td id="T_2e03d_row0_col1" class="data row0 col1" >[None, 64]</td>
#       <td id="T_2e03d_row0_col2" class="data row0 col2" >1856.000000</td>
#       <td id="T_2e03d_row0_col3" class="data row0 col3" >Dense</td>
#       <td id="T_2e03d_row0_col4" class="data row0 col4" >[None, 64]</td>
#       <td id="T_2e03d_row0_col5" class="data row0 col5" >1856</td>
#       <td id="T_2e03d_row0_col6" class="data row0 col6" >Dense</td>
#       <td id="T_2e03d_row0_col7" class="data row0 col7" >[None, 64]</td>
#       <td id="T_2e03d_row0_col8" class="data row0 col8" >1856.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2e03d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2e03d_row1_col0" class="data row1 col0" >Dense</td>
#       <td id="T_2e03d_row1_col1" class="data row1 col1" >[None, 64]</td>
#       <td id="T_2e03d_row1_col2" class="data row1 col2" >4160.000000</td>
#       <td id="T_2e03d_row1_col3" class="data row1 col3" >BatchNormalization</td>
#       <td id="T_2e03d_row1_col4" class="data row1 col4" >[None, 64]</td>
#       <td id="T_2e03d_row1_col5" class="data row1 col5" >256</td>
#       <td id="T_2e03d_row1_col6" class="data row1 col6" >Dense</td>
#       <td id="T_2e03d_row1_col7" class="data row1 col7" >[None, 64]</td>
#       <td id="T_2e03d_row1_col8" class="data row1 col8" >4160.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2e03d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2e03d_row2_col0" class="data row2 col0" >Dense</td>
#       <td id="T_2e03d_row2_col1" class="data row2 col1" >[None, 64]</td>
#       <td id="T_2e03d_row2_col2" class="data row2 col2" >4160.000000</td>
#       <td id="T_2e03d_row2_col3" class="data row2 col3" >Activation</td>
#       <td id="T_2e03d_row2_col4" class="data row2 col4" >[None, 64]</td>
#       <td id="T_2e03d_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_2e03d_row2_col6" class="data row2 col6" >Dense</td>
#       <td id="T_2e03d_row2_col7" class="data row2 col7" >[None, 320]</td>
#       <td id="T_2e03d_row2_col8" class="data row2 col8" >20800.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2e03d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2e03d_row3_col0" class="data row3 col0" >Dense</td>
#       <td id="T_2e03d_row3_col1" class="data row3 col1" >[None, 1]</td>
#       <td id="T_2e03d_row3_col2" class="data row3 col2" >65.000000</td>
#       <td id="T_2e03d_row3_col3" class="data row3 col3" >Dense</td>
#       <td id="T_2e03d_row3_col4" class="data row3 col4" >[None, 64]</td>
#       <td id="T_2e03d_row3_col5" class="data row3 col5" >4160</td>
#       <td id="T_2e03d_row3_col6" class="data row3 col6" >Dense</td>
#       <td id="T_2e03d_row3_col7" class="data row3 col7" >[None, 1]</td>
#       <td id="T_2e03d_row3_col8" class="data row3 col8" >321.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2e03d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2e03d_row4_col0" class="data row4 col0" >None</td>
#       <td id="T_2e03d_row4_col1" class="data row4 col1" >None</td>
#       <td id="T_2e03d_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_2e03d_row4_col3" class="data row4 col3" >BatchNormalization</td>
#       <td id="T_2e03d_row4_col4" class="data row4 col4" >[None, 64]</td>
#       <td id="T_2e03d_row4_col5" class="data row4 col5" >256</td>
#       <td id="T_2e03d_row4_col6" class="data row4 col6" >None</td>
#       <td id="T_2e03d_row4_col7" class="data row4 col7" >None</td>
#       <td id="T_2e03d_row4_col8" class="data row4 col8" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2e03d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2e03d_row5_col0" class="data row5 col0" >None</td>
#       <td id="T_2e03d_row5_col1" class="data row5 col1" >None</td>
#       <td id="T_2e03d_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_2e03d_row5_col3" class="data row5 col3" >Activation</td>
#       <td id="T_2e03d_row5_col4" class="data row5 col4" >[None, 64]</td>
#       <td id="T_2e03d_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_2e03d_row5_col6" class="data row5 col6" >None</td>
#       <td id="T_2e03d_row5_col7" class="data row5 col7" >None</td>
#       <td id="T_2e03d_row5_col8" class="data row5 col8" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2e03d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2e03d_row6_col0" class="data row6 col0" >None</td>
#       <td id="T_2e03d_row6_col1" class="data row6 col1" >None</td>
#       <td id="T_2e03d_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_2e03d_row6_col3" class="data row6 col3" >Dense</td>
#       <td id="T_2e03d_row6_col4" class="data row6 col4" >[None, 64]</td>
#       <td id="T_2e03d_row6_col5" class="data row6 col5" >4160</td>
#       <td id="T_2e03d_row6_col6" class="data row6 col6" >None</td>
#       <td id="T_2e03d_row6_col7" class="data row6 col7" >None</td>
#       <td id="T_2e03d_row6_col8" class="data row6 col8" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2e03d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id
