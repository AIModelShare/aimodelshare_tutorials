# %% [markdown]
# <p align="center"><img width="50%" src="https://aimodelsharecontent.s3.amazonaws.com/aimodshare_banner.jpg" /></p>
#
#
# ---

# %% [markdown]
# <p align="center"><h1 align="center">Social Mobility Competition Model Submission Guide - Predictions Only (No Model Metadata Extraction) </h1>
#
# ---
# Let's share our models to a centralized leaderboard, so that we can collaborate and learn from the model experimentation process...
#
# **Instructions:**
# 1.   Get data in and set up X_train / X_test / y_train
# 2.   Preprocess data
# 3. Fit model on preprocessed data
# 4. Generate predictions from X_test data and submit to competition
# 5. Repeat submission process to improve place on leaderboard

# %% [markdown]
# ## 1. Get data in and set up X_train, X_test, y_train objects

# %%
#install aimodelshare library
! pip install aimodelshare --upgrade

# %%
# Get competition data
from aimodelshare import download_data
download_data('public.ecr.aws/y2e2a1d6/social_mobility_competition_data-repository:latest')
# Out:
# Downloading [===========================================>     ]
#
# Data downloaded successfully.

# %%
# Separate data into X_train, y_train, and X_test
import pandas as pd

X_train = pd.read_csv("/content/social_mobility_competition_data/X_train.csv")
y_train = pd.read_csv("/content/social_mobility_competition_data/y_train.csv", squeeze=True)

X_test=pd.read_csv("/content/social_mobility_competition_data/X_test.csv")

X_train.head()
# Out:
#     geoid           place     pop  housing        P_1         P_2        P_3  \
# 0  1003.0  Baldwin County  187114   104061  82.847946   98.593450  101.77671
# 1  1005.0  Barbour County   27321    11829  76.313896   93.878720   90.70294
# 2  1007.0     Bibb County   22754     8981  73.765620  104.868470   82.12955
# 3  1013.0   Butler County   20624     9964  92.096670  121.073296  117.82320
# 4  1015.0  Calhoun County  117714    53289  76.938210   95.478250   98.32662
#
#           P_4        P_5         P_6  ...  P_112  P_113  P_114  P_115  P_116  \
# 0   82.477325   62.60906   65.417640  ...    0.0  19.10   0.00   2.01   0.00
# 1   91.192700  101.84381  102.085240  ...    0.0  45.16   0.00   4.84   0.00
# 2   68.382010   71.17644   69.621730  ...    0.0  30.91   0.00   7.27   0.00
# 3  143.117360  131.00436  134.067840  ...    0.0  41.07   0.00   5.36   0.00
# 4   87.650314   64.08210   60.688488  ...    0.0  18.79   0.61   3.03   0.61
#
#    P_117  P_118  P_119  P_120  P_121
# 0   3.52    0.0   0.00    0.0    0.0
# 1   1.61    0.0   3.23    0.0    0.0
# 2   1.82    0.0   0.00    0.0    0.0
# 3   1.79    0.0   0.00    0.0    0.0
# 4   2.42    0.0   0.00    0.0    0.0
#
# [5 rows x 125 columns]

# %%
# Check Data Shape
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
# Out:
# (1259, 125)
# (1259, 125)
# (1259,)

# %% [markdown]
# ##2.   Preprocess data

# %%
# Write and execute code to preprocess data here

# %% [markdown]
# ##3. Fit model on preprocessed data

# %%
# Write and execute code to fit model on preprocessed data here.

# %%
#Set credentials using modelshare.org username/password

from aimodelshare.aws import set_credentials
    
apiurl="https://89lu7cpgh1.execute-api.us-east-1.amazonaws.com/prod/m"
#This is the unique rest api that powers this Playground -- make sure to update the apiurl for new competition deployments

set_credentials(apiurl=apiurl)
# Out:
# AI Modelshare Username:··········
# AI Modelshare Password:··········
# AI Model Share login credentials set successfully.

# %%
#Instantiate Competition
import aimodelshare as ai
mycompetition= ai.Competition(apiurl)

# %% [markdown]
# ## **4. Submit Model predictions to leaderboard (without extracting model architecture information):**
# - model metadata extraction allows you use compare_models() and instantiate_model() functions.

# %%
#Generate a list of predictions between .2 and .6
import numpy as np
predicted_values = np.random.uniform(.2, .6, size=len(X_test))
predicted_values = predicted_values.tolist()

# %%
#Submit Model predictions to leaderboard (without extracting model architecture information): 

# Submit to Competition Leaderboard
mycompetition.submit_model(model_filepath = None,
                                 preprocessor_filepath=None,
                                 prediction_submission=predicted_values)
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 8
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:2821

# %%
# Get leaderboard to explore current best model architectures

# Get raw data in pandas data frame
data = mycompetition.get_leaderboard()

# Stylize leaderboard data
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_b0ebb_row0_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 3.6%, transparent 3.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_b0ebb_row0_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 19.0%, transparent 19.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_b0ebb_row0_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 17.0%, transparent 17.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_b0ebb_row0_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 100.0%, transparent 100.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_b0ebb_row0_col4, #T_b0ebb_row0_col5, #T_b0ebb_row0_col6, #T_b0ebb_row0_col7, #T_b0ebb_row0_col8, #T_b0ebb_row0_col9, #T_b0ebb_row0_col10, #T_b0ebb_row0_col11, #T_b0ebb_row0_col12, #T_b0ebb_row0_col13, #T_b0ebb_row0_col14, #T_b0ebb_row0_col15, #T_b0ebb_row0_col16, #T_b0ebb_row1_col4, #T_b0ebb_row1_col5, #T_b0ebb_row1_col6, #T_b0ebb_row1_col7, #T_b0ebb_row1_col8, #T_b0ebb_row1_col9, #T_b0ebb_row1_col10, #T_b0ebb_row1_col11, #T_b0ebb_row1_col12, #T_b0ebb_row1_col13, #T_b0ebb_row1_col14, #T_b0ebb_row1_col15, #T_b0ebb_row1_col16, #T_b0ebb_row2_col4, #T_b0ebb_row2_col5, #T_b0ebb_row2_col6, #T_b0ebb_row2_col7, #T_b0ebb_row2_col8, #T_b0ebb_row2_col9, #T_b0ebb_row2_col10, #T_b0ebb_row2_col11, #T_b0ebb_row2_col12, #T_b0ebb_row2_col13, #T_b0ebb_row2_col14, #T_b0ebb_row2_col15, #T_b0ebb_row2_col16, #T_b0ebb_row3_col4, #T_b0ebb_row3_col5, #T_b0ebb_row3_col6, #T_b0ebb_row3_col7, #T_b0ebb_row3_col8, #T_b0ebb_row3_col9, #T_b0ebb_row3_col10, #T_b0ebb_row3_col11, #T_b0ebb_row3_col12, #T_b0ebb_row3_col13, #T_b0ebb_row3_col14, #T_b0ebb_row3_col15, #T_b0ebb_row3_col16, #T_b0ebb_row4_col4, #T_b0ebb_row4_col5, #T_b0ebb_row4_col6, #T_b0ebb_row4_col7, #T_b0ebb_row4_col8, #T_b0ebb_row4_col9, #T_b0ebb_row4_col10, #T_b0ebb_row4_col11, #T_b0ebb_row4_col12, #T_b0ebb_row4_col13, #T_b0ebb_row4_col14, #T_b0ebb_row4_col15, #T_b0ebb_row4_col16, #T_b0ebb_row5_col4, #T_b0ebb_row5_col5, #T_b0ebb_row5_col6, #T_b0ebb_row5_col7, #T_b0ebb_row5_col8, #T_b0ebb_row5_col9, #T_b0ebb_row5_col10, #T_b0ebb_row5_col11, #T_b0ebb_row5_col12, #T_b0ebb_row5_col13, #T_b0ebb_row5_col14, #T_b0ebb_row5_col15, #T_b0ebb_row5_col16, #T_b0ebb_row6_col4, #T_b0ebb_row6_col5, #T_b0ebb_row6_col6, #T_b0ebb_row6_col7, #T_b0ebb_row6_col8, #T_b0ebb_row6_col9, #T_b0ebb_row6_col10, #T_b0ebb_row6_col11, #T_b0ebb_row6_col12, #T_b0ebb_row6_col13, #T_b0ebb_row6_col14, #T_b0ebb_row6_col15, #T_b0ebb_row6_col16, #T_b0ebb_row7_col4, #T_b0ebb_row7_col5, #T_b0ebb_row7_col6, #T_b0ebb_row7_col7, #T_b0ebb_row7_col8, #T_b0ebb_row7_col9, #T_b0ebb_row7_col10, #T_b0ebb_row7_col11, #T_b0ebb_row7_col12, #T_b0ebb_row7_col13, #T_b0ebb_row7_col14, #T_b0ebb_row7_col15, #T_b0ebb_row7_col16 {
#   text-align: center;
# }
# #T_b0ebb_row1_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 3.7%, transparent 3.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_b0ebb_row1_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 19.1%, transparent 19.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_b0ebb_row1_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 17.1%, transparent 17.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_b0ebb_row1_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 99.6%, transparent 99.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_b0ebb_row2_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 4.8%, transparent 4.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_b0ebb_row2_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 21.8%, transparent 21.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_b0ebb_row2_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 19.9%, transparent 19.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_b0ebb_row2_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 91.3%, transparent 91.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_b0ebb_row3_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 5.6%, transparent 5.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_b0ebb_row3_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 23.7%, transparent 23.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_b0ebb_row3_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 21.7%, transparent 21.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_b0ebb_row3_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 84.9%, transparent 84.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_b0ebb_row4_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 7.6%, transparent 7.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_b0ebb_row4_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 27.6%, transparent 27.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_b0ebb_row4_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 24.3%, transparent 24.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_b0ebb_row4_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 70.1%, transparent 70.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_b0ebb_row5_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 9.1%, transparent 9.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_b0ebb_row5_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 30.2%, transparent 30.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_b0ebb_row5_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 27.1%, transparent 27.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_b0ebb_row5_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 59.1%, transparent 59.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_b0ebb_row6_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 31.3%, transparent 31.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_b0ebb_row6_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 56.0%, transparent 56.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_b0ebb_row6_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 46.5%, transparent 46.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_b0ebb_row6_col3, #T_b0ebb_row7_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_b0ebb_row7_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 100.0%, transparent 100.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_b0ebb_row7_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 100.0%, transparent 100.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_b0ebb_row7_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 100.0%, transparent 100.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# </style>
# <table id="T_b0ebb_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >mse</th>
#       <th class="col_heading leve

# %% [markdown]
# You can also compare two or more models for any models submitted to the leaderboard using example code for model metadata extraction (see code tab for this competition at www.modelshare.org for submission examples.)
# ```
# data=mycompetition.compare_models([1,2], verbose=1)
# mycompetition.stylize_compare(data)
# ```

# %% [markdown]
# #####  (Optional Extension) Submit Model With Custom Metadata:
# Can use to add team names or any other missing data you may wish to share on the leaderboard

# %%
# Custom metadata can be added by passing a dict to the custom_metadata argument of the submit_model() method
# This option can be used to fill in missing data points or add new columns to the leaderboard

custom_meta = {'team': 'team one',
               'model_type': 'your_model_type',
               'new_column': 'new metadata'}

mycompetition.submit_model(model_filepath = None,
                                 preprocessor_filepath=None,
                                 prediction_submission=predicted_values,
                                 custom_metadata = custom_meta)
