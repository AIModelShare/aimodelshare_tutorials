# %% [markdown]
# <p align="center"><img width="50%" src="https://aimodelsharecontent.s3.amazonaws.com/aimodshare_banner.jpg" /></p>
#
#
# ---

# %% [markdown]
# <p align="center"><h1 align="center">Social Mobility Prediction Competition
#
# ---
#
# </h1>Let's share our models to a centralized leaderboard, so that we can collaborate and learn from the model experimentation process...
#
# **Instructions:**
# 1.   Get data in and set up X_train / X_test / y_train
# 2.   Preprocess data  with Sklearn Column Transformer/ Write and Save Preprocessor function
# 3. Fit model on preprocessed data and save preprocessor function and model
# 4. Generate predictions from X_test data and submit model to competition
# 5. Repeat submission process to improve place on leaderboard

# %% [markdown]
# ## 1. Get data in and set up X_train, X_test, y_train objects

# %%
#install aimodelshare library
! pip install aimodelshare --upgrade

# %%
# Get competition data
from aimodelshare import download_data
download_data('public.ecr.aws/y2e2a1d6/social_mobility_competition_data-repository:latest')
# Out:
# Downloading [===========================================>     ]
#
# Data downloaded successfully.

# %%
# Separate data into X_train, y_train, and X_test
import pandas as pd

X_train = pd.read_csv("/content/social_mobility_competition_data/X_train.csv")
y_train = pd.read_csv("/content/social_mobility_competition_data/y_train.csv", squeeze=True)

X_test=pd.read_csv("/content/social_mobility_competition_data/X_test.csv")

X_train.head()
# Out:
#     geoid           place     pop  housing        P_1         P_2        P_3  \
# 0  1003.0  Baldwin County  187114   104061  82.847946   98.593450  101.77671
# 1  1005.0  Barbour County   27321    11829  76.313896   93.878720   90.70294
# 2  1007.0     Bibb County   22754     8981  73.765620  104.868470   82.12955
# 3  1013.0   Butler County   20624     9964  92.096670  121.073296  117.82320
# 4  1015.0  Calhoun County  117714    53289  76.938210   95.478250   98.32662
#
#           P_4        P_5         P_6  ...  P_112  P_113  P_114  P_115  P_116  \
# 0   82.477325   62.60906   65.417640  ...    0.0  19.10   0.00   2.01   0.00
# 1   91.192700  101.84381  102.085240  ...    0.0  45.16   0.00   4.84   0.00
# 2   68.382010   71.17644   69.621730  ...    0.0  30.91   0.00   7.27   0.00
# 3  143.117360  131.00436  134.067840  ...    0.0  41.07   0.00   5.36   0.00
# 4   87.650314   64.08210   60.688488  ...    0.0  18.79   0.61   3.03   0.61
#
#    P_117  P_118  P_119  P_120  P_121
# 0   3.52    0.0   0.00    0.0    0.0
# 1   1.61    0.0   3.23    0.0    0.0
# 2   1.82    0.0   0.00    0.0    0.0
# 3   1.79    0.0   0.00    0.0    0.0
# 4   2.42    0.0   0.00    0.0    0.0
#
# [5 rows x 125 columns]

# %% [markdown]
# ##2.   Preprocess data using Sklearn Column Transformer / Write and Save Preprocessor function

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# Create the preprocessing pipeline for both numeric data.
numeric_features=X_train.columns.tolist()
numeric_features.remove('geoid')
numeric_features.remove('place')

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

# final preprocessor object set up with ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[('num', numeric_transformer, numeric_features)])

#Fit your preprocessor object
preprocess=preprocessor.fit(X_train)

# %%
# Write function to transform data with preprocessor

def preprocessor(data):
    preprocessed_data=preprocess.transform(data)
    return preprocessed_data

# %%
# check shape of X data 
preprocessor(X_train).shape
# Out:
# (1259, 123)

# %% [markdown]
# ##3. Fit model on preprocessed data and save preprocessor function and model

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
import keras

feature_count=preprocessor(X_train).shape[1] #count features in input data

model = Sequential()
model.add(Dense(64, input_dim=feature_count, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))

model.add(Dense(1, kernel_initializer='normal')) 
                                            
# Compile model
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])

# Fitting the NN to the Training set
model.fit(preprocessor(X_train), y_train, 
               batch_size = 60, 
               epochs = 50, validation_split=0.35)

# %% [markdown]
# #### Save preprocessor function to local "preprocessor.zip" file

# %%
import aimodelshare as ai
ai.export_preprocessor(preprocessor,"")
# Out:
# Your preprocessor is now saved to 'preprocessor.zip'

# %% [markdown]
# #### Save model to local ".onnx" file

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

# Check how many preprocessed input features there are
from skl2onnx.common.data_types import FloatTensorType

onnx_model = model_to_onnx(model, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %% [markdown]
# ## 4. Generate predictions from X_test data and submit model to competition

# %%
#Set credentials using modelshare.org username/password

from aimodelshare.aws import set_credentials

apiurl="https://89lu7cpgh1.execute-api.us-east-1.amazonaws.com/prod/m" #This is the unique rest api that powers this Social Mobility Prediction Playground

set_credentials(apiurl=apiurl)
# Out:
# AI Modelshare Username:··········
# AI Modelshare Password:··········
# AI Model Share login credentials set successfully.

# %%
#Instantiate Competition
import aimodelshare as ai
mycompetition= ai.Competition(apiurl)

# %%
#Submit Model 1: 

#-- Generate predicted values (a list of predicted car prices) (Model 1)
predicted_values = model.predict(preprocessor(X_test))

# Submit Model 1 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=predicted_values)
# Out:
# 40/40 [==============================] - 0s 1ms/step
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 5
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:2821

# %%
# Get leaderboard to explore current best model architectures

# Get raw data in pandas data frame
data = mycompetition.get_leaderboard()

# Stylize leaderboard data
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_41717_row0_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 11.5%, transparent 11.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_41717_row0_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 33.9%, transparent 33.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_41717_row0_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 36.5%, transparent 36.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_41717_row0_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 100.0%, transparent 100.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_41717_row0_col4, #T_41717_row0_col5, #T_41717_row0_col6, #T_41717_row0_col7, #T_41717_row0_col8, #T_41717_row0_col9, #T_41717_row0_col10, #T_41717_row0_col11, #T_41717_row0_col12, #T_41717_row0_col13, #T_41717_row0_col14, #T_41717_row0_col15, #T_41717_row0_col16, #T_41717_row1_col4, #T_41717_row1_col5, #T_41717_row1_col6, #T_41717_row1_col7, #T_41717_row1_col8, #T_41717_row1_col9, #T_41717_row1_col10, #T_41717_row1_col11, #T_41717_row1_col12, #T_41717_row1_col13, #T_41717_row1_col14, #T_41717_row1_col15, #T_41717_row1_col16, #T_41717_row2_col4, #T_41717_row2_col5, #T_41717_row2_col6, #T_41717_row2_col7, #T_41717_row2_col8, #T_41717_row2_col9, #T_41717_row2_col10, #T_41717_row2_col11, #T_41717_row2_col12, #T_41717_row2_col13, #T_41717_row2_col14, #T_41717_row2_col15, #T_41717_row2_col16, #T_41717_row3_col4, #T_41717_row3_col5, #T_41717_row3_col6, #T_41717_row3_col7, #T_41717_row3_col8, #T_41717_row3_col9, #T_41717_row3_col10, #T_41717_row3_col11, #T_41717_row3_col12, #T_41717_row3_col13, #T_41717_row3_col14, #T_41717_row3_col15, #T_41717_row3_col16, #T_41717_row4_col4, #T_41717_row4_col5, #T_41717_row4_col6, #T_41717_row4_col7, #T_41717_row4_col8, #T_41717_row4_col9, #T_41717_row4_col10, #T_41717_row4_col11, #T_41717_row4_col12, #T_41717_row4_col13, #T_41717_row4_col14, #T_41717_row4_col15, #T_41717_row4_col16 {
#   text-align: center;
# }
# #T_41717_row1_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 11.6%, transparent 11.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_41717_row1_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 34.1%, transparent 34.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_41717_row1_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 36.7%, transparent 36.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_41717_row1_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 99.6%, transparent 99.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_41717_row2_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 15.2%, transparent 15.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_41717_row2_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 39.0%, transparent 39.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_41717_row2_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 42.7%, transparent 42.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_41717_row2_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 91.3%, transparent 91.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_41717_row3_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 24.4%, transparent 24.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_41717_row3_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 49.4%, transparent 49.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_41717_row3_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 52.2%, transparent 52.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_41717_row3_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 70.1%, transparent 70.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_41717_row4_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 100.0%, transparent 100.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_41717_row4_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 100.0%, transparent 100.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_41717_row4_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 100.0%, transparent 100.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_41717_row4_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   color: #251e1b;
#   font-size: 12px;
# }
# </style>
# <table id="T_41717_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >mse</th>
#       <th class="col_heading level0 col1" >rmse</th>
#       <th class="col_heading level0 col2" >mae</th>
#       <th class="col_heading level0 col3" >r2</th>
#       <th class="col_heading level0 col4" >ml_framework</th>
#       <th class="col_heading level0 col5" >transfer_learning</th>
#       <th class="col_heading level0 col6" >deep_learning</th>
#       <th class="col_heading level0 col7" >model_type</th>
#       <th class="col_heading level0 col8" >depth</th>
#       <th class="col_heading level0 col9" >num_params</th>
#       <th class="col_heading level0 col10" >dense_layers</th>
#       <th class="col_heading level0 col11" >relu_act</th>
#       <th class="col_heading level0 col12" >loss</th>
#       <th class="col_heading level0 col13" >optimizer</th>
#       <th class="col_heading level0 col14" >memory_size</th>
#       <th class="col_heading level0 col15" >username</th>
#       <th class="col_heading level0 col16" >version</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41717_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_41717_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_41717_row0_col1" class="data row0 col1" >0.02</td>
#       <td id="T_41717_row0_col2" class="data row0 col2" >0.02</td>
#       <td id="T_41717_row0_col3" class="data row0 col3" >0.79</td>
#       <td id="T_41717_row0_col4" class="data row0 col4" >sklearn</td>
#       <td id="T_41717_row0_col5" class="data row0 col5" >False</td>
#       <td id="T_41717_row0_col6" class="data row0 col6" >False</td>
#       <td id="T_41717_row0_col7" class="data row0 col7" >RandomForestRegressor</td>
#       <td id="T_41717_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_41717_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_41717_row0_col10" class="data row0 col10" >nan</td>
#       <td id="T_41717_row0_col11" class="data row0 col11" >nan</td>
#       <td id="T_41717_row0_col12" class="data row0 col12" >nan</td>
#       <td id="T_41717_row0_col13" class="data row0 col13" >nan</td>
#       <td id="T_41717_row0_col14" class="data row0 col14" >nan</td>
#       <td id="T_41717_row0_col15" class="data row0 col15" >econ50_bigdata</td>
#       <td id="T_41717_row0_col16" class="data row0 col16" >2</td>
#     </tr>
#     <tr>
#       <th id="T_41717_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_41717_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_41717_row1_col1" class="data row1 col1" >0.02</td>
#       <td id="T_41717_row1_col2" class="data row1 col2" >0.02</td>
#       <td id="T_41717_row1_col3" class="data row1 col3" >0.79</td>
#       <td id="T_41717_row1_col4" class="data row1 col4" >sklearn</td>
#       <td id="T_41717_row1_col5" class="data row1 col5" >False</td>
#       <td id="T_41717_row1_col6" class="data row1 col6" >False</td>
#       <td id="T_41717_row1_col7" class="data row1 col7" >RandomForestRe

# %% [markdown]
# ## 5. Repeat submission process to improve place on leaderboard

# %%
# Create model 2  -- Model with Dropout regularization
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout,BatchNormalization

feature_count=preprocessor(X_train).shape[1] #count features in input data

model_2 = Sequential()
model_2.add(Dense(64, input_dim=feature_count))
model_2.add(BatchNormalization())
model_2.add(Activation('relu'))
model_2.add(Dense(64))
model_2.add(BatchNormalization())
model_2.add(Activation('relu'))
model_2.add(Dense(64))
model_2.add(BatchNormalization())
model_2.add(Activation('relu'))
model_2.add(Dense(1, kernel_initializer='normal')) 
                                            
# Compile model
model_2.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])

# Fitting the NN to the Training set
model_2.fit(preprocessor(X_train), y_train, 
               batch_size = 60, 
               epochs = 80, validation_split=0.35)

# %%
# Save Model 2 to .onnx file

onnx_model = model_to_onnx(model_2, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

# Save model to local .onnx file
with open("model_2.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
# Submit Model 2

#-- Generate predicted y values (Model 2)
prediction_labels = model_2.predict(preprocessor(X_test))

# Submit Model 2 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model_2.onnx",
                                 prediction_submission=prediction_labels,
                                 preprocessor_filepath="preprocessor.zip")
# Out:
# 40/40 [==============================] - 0s 2ms/step
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 6
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:2821

# %%
# Compare two or more models
data=mycompetition.compare_models([5, 6], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style type="text/css">
# #T_a964b_ caption {
#   color: black;
#   font-size: 18px;
# }
# #T_a964b_row0_col0, #T_a964b_row0_col3, #T_a964b_row1_col0, #T_a964b_row2_col0, #T_a964b_row3_col0, #T_a964b_row3_col3, #T_a964b_row6_col3, #T_a964b_row9_col3 {
#   background: #fff2ae;
#   color: black;
#   color: black;
# }
# #T_a964b_row0_col1, #T_a964b_row0_col2, #T_a964b_row0_col4, #T_a964b_row0_col5, #T_a964b_row1_col1, #T_a964b_row1_col2, #T_a964b_row1_col4, #T_a964b_row1_col5, #T_a964b_row2_col1, #T_a964b_row2_col2, #T_a964b_row2_col4, #T_a964b_row2_col5, #T_a964b_row3_col1, #T_a964b_row3_col2, #T_a964b_row3_col4, #T_a964b_row3_col5, #T_a964b_row4_col0, #T_a964b_row4_col1, #T_a964b_row4_col2, #T_a964b_row4_col4, #T_a964b_row4_col5, #T_a964b_row5_col0, #T_a964b_row5_col1, #T_a964b_row5_col2, #T_a964b_row5_col4, #T_a964b_row5_col5, #T_a964b_row6_col0, #T_a964b_row6_col1, #T_a964b_row6_col2, #T_a964b_row6_col4, #T_a964b_row6_col5, #T_a964b_row7_col0, #T_a964b_row7_col1, #T_a964b_row7_col2, #T_a964b_row7_col4, #T_a964b_row7_col5, #T_a964b_row8_col0, #T_a964b_row8_col1, #T_a964b_row8_col2, #T_a964b_row8_col4, #T_a964b_row8_col5, #T_a964b_row9_col0, #T_a964b_row9_col1, #T_a964b_row9_col2, #T_a964b_row9_col4, #T_a964b_row9_col5 {
#   background: white;
#   color: black;
#   color: black;
# }
# #T_a964b_row1_col3, #T_a964b_row4_col3, #T_a964b_row7_col3 {
#   background: #cbd5e8;
#   color: black;
#   color: black;
# }
# #T_a964b_row2_col3, #T_a964b_row5_col3, #T_a964b_row8_col3 {
#   background: nan;
#   color: black;
#   color: black;
# }
# </style>
# <table id="T_a964b_">
#   <caption>Model type: Neural Network</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model_5_Layer</th>
#       <th class="col_heading level0 col1" >Model_5_Shape</th>
#       <th class="col_heading level0 col2" >Model_5_Params</th>
#       <th class="col_heading level0 col3" >Model_6_Layer</th>
#       <th class="col_heading level0 col4" >Model_6_Shape</th>
#       <th class="col_heading level0 col5" >Model_6_Params</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a964b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a964b_row0_col0" class="data row0 col0" >Dense</td>
#       <td id="T_a964b_row0_col1" class="data row0 col1" >[None, 64]</td>
#       <td id="T_a964b_row0_col2" class="data row0 col2" >7936.000000</td>
#       <td id="T_a964b_row0_col3" class="data row0 col3" >Dense</td>
#       <td id="T_a964b_row0_col4" class="data row0 col4" >[None, 64]</td>
#       <td id="T_a964b_row0_col5" class="data row0 col5" >7936</td>
#     </tr>
#     <tr>
#       <th id="T_a964b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a964b_row1_col0" class="data row1 col0" >Dense</td>
#       <td id="T_a964b_row1_col1" class="data row1 col1" >[None, 64]</td>
#       <td id="T_a964b_row1_col2" class="data row1 col2" >4160.000000</td>
#       <td id="T_a964b_row1_col3" class="data row1 col3" >BatchNormalization</td>
#       <td id="T_a964b_row1_col4" class="data row1 col4" >[None, 64]</td>
#       <td id="T_a964b_row1_col5" class="data row1 col5" >256</td>
#     </tr>
#     <tr>
#       <th id="T_a964b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a964b_row2_col0" class="data row2 col0" >Dense</td>
#       <td id="T_a964b_row2_col1" class="data row2 col1" >[None, 64]</td>
#       <td id="T_a964b_row2_col2" class="data row2 col2" >4160.000000</td>
#       <td id="T_a964b_row2_col3" class="data row2 col3" >Activation</td>
#       <td id="T_a964b_row2_col4" class="data row2 col4" >[None, 64]</td>
#       <td id="T_a964b_row2_col5" class="data row2 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a964b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a964b_row3_col0" class="data row3 col0" >Dense</td>
#       <td id="T_a964b_row3_col1" class="data row3 col1" >[None, 1]</td>
#       <td id="T_a964b_row3_col2" class="data row3 col2" >65.000000</td>
#       <td id="T_a964b_row3_col3" class="data row3 col3" >Dense</td>
#       <td id="T_a964b_row3_col4" class="data row3 col4" >[None, 64]</td>
#       <td id="T_a964b_row3_col5" class="data row3 col5" >4160</td>
#     </tr>
#     <tr>
#       <th id="T_a964b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a964b_row4_col0" class="data row4 col0" >None</td>
#       <td id="T_a964b_row4_col1" class="data row4 col1" >None</td>
#       <td id="T_a964b_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_a964b_row4_col3" class="data row4 col3" >BatchNormalization</td>
#       <td id="T_a964b_row4_col4" class="data row4 col4" >[None, 64]</td>
#       <td id="T_a964b_row4_col5" class="data row4 col5" >256</td>
#     </tr>
#     <tr>
#       <th id="T_a964b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a964b_row5_col0" class="data row5 col0" >None</td>
#       <td id="T_a964b_row5_col1" class="data row5 col1" >None</td>
#       <td id="T_a964b_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_a964b_row5_col3" class="data row5 col3" >Activation</td>
#       <td id="T_a964b_row5_col4" class="data row5 col4" >[None, 64]</td>
#       <td id="T_a964b_row5_col5" class="data row5 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a964b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a964b_row6_col0" class="data row6 col0" >None</td>
#       <td id="T_a964b_row6_col1" class="data row6 col1" >None</td>
#       <td id="T_a964b_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_a964b_row6_col3" class="data row6 col3" >Dense</td>
#       <td id="T_a964b_row6_col4" class="data row6 col4" >[None, 64]</td>
#       <td id="T_a964b_row6_col5" class="data row6 col5" >4160</td>
#     </tr>
#     <tr>
#       <th id="T_a964b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a964b_row7_col0" class="data row7 col0" >None</td>
#       <td id="T_a964b_row7_col1" class="data row7 col1" >None</td>
#       <td id="T_a964b_row7_col2" class="data row7 col2" >nan</td>
#       <td id="T_a964b_row7_col3" class="data row7 col3" >BatchNormalization</td>
#       <td id="T_a964b_row7_col4" class="data row7 col4" >[None, 64]</td>
#       <td id="T_a964b_row7_col5" class="data row7 col5" >256</td>
#     </tr>
#     <tr>
#       <th id="T_a964b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a964b_row8_col0" class="data row8 col0" >None</td>
#       <td id="T_a964b_row8_col1" class="data row8 col1" >None</td>
#       <td id="T_a964b_row8_col2" class="data row8 col2" >nan</td>
#       <td id="T_a964b_row8_col3" class="data row8 col3" >Activation</td>
#       <td id="T_a964b_row8_col4" class="data row8 col4" >[None, 64]</td>
#       <td id="T_a964b_row8_col5" class="data row8 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a964b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a964b_row9_col0" class="data row9 col0" >None</td>
#       <td id="T_a964b_row9_col1" class="data row9 col1" >None</td>
#       <td id="T_a964b_row9_col2" class="data row9 col2" >nan</td>
#       <td id="T_a964b_row9_col3" class="data row9 col3" >Dense</td>
#       <td id="T_a964b_row9_col4" class="data row9 col4" >[None, 1]</td>
#       <td id="T_a964b_row9_col5" class="data row9 col5" >65</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Optional: Tune model within range of hyperparameters with Keras Tuner
#
# *Simple example shown below. Consult [documentation](https://keras.io/guides/keras_tuner/getting_started/) to see full functionality.*

# %%
! pip install keras_tuner

# %%
#Separate validation data 
from sklearn.model_selection import train_test_split
x_train_split, x_val, y_train_split, y_val = train_test_split(
     X_train, y_train, test_size=0.2, random_state=42)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, BatchNormalization
from keras.regularizers import l1, l2, l1_l2
import keras_tuner as kt

feature_count=preprocessor(X_train).shape[1] #count features in input data

#Define model structure & parameter search space with function
def build_model(hp):
    model = keras.Sequential()
    model.add(Dense(64, input_dim=feature_count, activation='relu', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
    model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
    model.add(Dense(units=hp.Int("units", min_value=32, max_value=512, step=32), #range 32-512 inclusive, minimum step between tested values is 32
                    activation='relu', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
    model.add(Dense(1, kernel_initializer='normal')) 
    model.compile(
        loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])
    return model                                          

#initialize the tuner (which will search through parameters)
tuner = kt.RandomSearch(
    hypermodel=build_model, 
    objective="mean_squared_error", # objective to optimize
    max_trials=3, #max number of trials to run during search
    executions_per_trial=3, #higher number reduces variance of results; guages model performance more accurately 
    overwrite=True,
    directory="tuning_model",
    project_name="tuning_units",
)

tuner.search(preprocessor(x_train_split), y_train_split, epochs=2, validation_data=(preprocessor(x_val), y_val))
# Out:
# Trial 3 Complete [00h 00m 09s]
# mean_squared_error: 0.0061927807206908865
#
# Best mean_squared_error So Far: 0.0060390629805624485
# Total elapsed time: 00h 00m 30s

# %%
# Build model with best hyperparameters

# Get the top 2 hyperparameters.
best_hps = tuner.get_best_hyperparameters(5)
# Build the model with the best hp.
tuned_model = build_model(best_hps[0])
# Fit with the entire dataset.
tuned_model.fit(x=preprocessor(X_train), y=y_train, epochs=50)

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model = model_to_onnx(tuned_model, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("tuned_model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Submit Model 3: 

#-- Generate predicted values
prediction_labels = tuned_model.predict(preprocessor(X_test))

# Submit Model 3 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "tuned_model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# 40/40 [==============================] - 0s 6ms/step
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 7
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:2821

# %%
# Get leaderboard

data = mycompetition.get_leaderboard()
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_827b3_row0_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 11.5%, transparent 11.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_827b3_row0_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 33.9%, transparent 33.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_827b3_row0_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 36.5%, transparent 36.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_827b3_row0_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 100.0%, transparent 100.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_827b3_row0_col4, #T_827b3_row0_col5, #T_827b3_row0_col6, #T_827b3_row0_col7, #T_827b3_row0_col8, #T_827b3_row0_col9, #T_827b3_row0_col10, #T_827b3_row0_col11, #T_827b3_row0_col12, #T_827b3_row0_col13, #T_827b3_row0_col14, #T_827b3_row0_col15, #T_827b3_row0_col16, #T_827b3_row0_col17, #T_827b3_row1_col4, #T_827b3_row1_col5, #T_827b3_row1_col6, #T_827b3_row1_col7, #T_827b3_row1_col8, #T_827b3_row1_col9, #T_827b3_row1_col10, #T_827b3_row1_col11, #T_827b3_row1_col12, #T_827b3_row1_col13, #T_827b3_row1_col14, #T_827b3_row1_col15, #T_827b3_row1_col16, #T_827b3_row1_col17, #T_827b3_row2_col4, #T_827b3_row2_col5, #T_827b3_row2_col6, #T_827b3_row2_col7, #T_827b3_row2_col8, #T_827b3_row2_col9, #T_827b3_row2_col10, #T_827b3_row2_col11, #T_827b3_row2_col12, #T_827b3_row2_col13, #T_827b3_row2_col14, #T_827b3_row2_col15, #T_827b3_row2_col16, #T_827b3_row2_col17, #T_827b3_row3_col4, #T_827b3_row3_col5, #T_827b3_row3_col6, #T_827b3_row3_col7, #T_827b3_row3_col8, #T_827b3_row3_col9, #T_827b3_row3_col10, #T_827b3_row3_col11, #T_827b3_row3_col12, #T_827b3_row3_col13, #T_827b3_row3_col14, #T_827b3_row3_col15, #T_827b3_row3_col16, #T_827b3_row3_col17, #T_827b3_row4_col4, #T_827b3_row4_col5, #T_827b3_row4_col6, #T_827b3_row4_col7, #T_827b3_row4_col8, #T_827b3_row4_col9, #T_827b3_row4_col10, #T_827b3_row4_col11, #T_827b3_row4_col12, #T_827b3_row4_col13, #T_827b3_row4_col14, #T_827b3_row4_col15, #T_827b3_row4_col16, #T_827b3_row4_col17, #T_827b3_row5_col4, #T_827b3_row5_col5, #T_827b3_row5_col6, #T_827b3_row5_col7, #T_827b3_row5_col8, #T_827b3_row5_col9, #T_827b3_row5_col10, #T_827b3_row5_col11, #T_827b3_row5_col12, #T_827b3_row5_col13, #T_827b3_row5_col14, #T_827b3_row5_col15, #T_827b3_row5_col16, #T_827b3_row5_col17, #T_827b3_row6_col4, #T_827b3_row6_col5, #T_827b3_row6_col6, #T_827b3_row6_col7, #T_827b3_row6_col8, #T_827b3_row6_col9, #T_827b3_row6_col10, #T_827b3_row6_col11, #T_827b3_row6_col12, #T_827b3_row6_col13, #T_827b3_row6_col14, #T_827b3_row6_col15, #T_827b3_row6_col16, #T_827b3_row6_col17 {
#   text-align: center;
# }
# #T_827b3_row1_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 11.6%, transparent 11.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_827b3_row1_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 34.1%, transparent 34.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_827b3_row1_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 36.7%, transparent 36.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_827b3_row1_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 99.6%, transparent 99.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_827b3_row2_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 15.2%, transparent 15.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_827b3_row2_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 39.0%, transparent 39.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_827b3_row2_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 42.7%, transparent 42.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_827b3_row2_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 91.3%, transparent 91.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_827b3_row3_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 18.0%, transparent 18.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_827b3_row3_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 42.4%, transparent 42.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_827b3_row3_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 46.6%, transparent 46.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_827b3_row3_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 84.9%, transparent 84.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_827b3_row4_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 24.4%, transparent 24.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_827b3_row4_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 49.4%, transparent 49.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_827b3_row4_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 52.2%, transparent 52.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_827b3_row4_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 70.1%, transparent 70.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_827b3_row5_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 29.1%, transparent 29.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_827b3_row5_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 53.9%, transparent 53.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_827b3_row5_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 58.1%, transparent 58.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_827b3_row5_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 59.1%, transparent 59.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_827b3_row6_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 100.0%, transparent 100.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_827b3_row6_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 100.0%, transparent 100.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_827b3_row6_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 100.0%, transparent 100.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_827b3_row6_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   color: #251e1b;
#   font-size: 12px;
# }
# </style>
# <table id="T_827b3_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >mse</th>
#       <th class="col_heading level0 col1" >rmse</th>
#       <th class="col_heading level0 col2" >mae</th>
#       <th class="col_heading level0 col3" >r2</th>
#       <th class="col_heading level0 col4" >ml_framework</th>
#       <th class="col_heading level0 col5" >transfer_learning</th>
#       <th class="col_heading level0 col6" >deep_learning</th>
#       <th class="col_heading level0 col7" >model_type</th>
#       <th class="col_heading level0 col8" >depth</th>
#       <th class="col_heading level0 col9" >num_params</th>
#       <th class="col_heading level0 col10" >batchnormalization_layers</th>
#       <th class="col_heading level0 col11" >dense_layers</th>
#       <th class="col_heading level0 col12" >relu_act</th

# %%
# Compare two or more models
data=mycompetition.compare_models([5, 6, 7], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style type="text/css">
# #T_63f58_ caption {
#   color: black;
#   font-size: 18px;
# }
# #T_63f58_row0_col0, #T_63f58_row0_col3, #T_63f58_row0_col6, #T_63f58_row1_col0, #T_63f58_row1_col6, #T_63f58_row2_col0, #T_63f58_row2_col6, #T_63f58_row3_col0, #T_63f58_row3_col3, #T_63f58_row3_col6, #T_63f58_row6_col3, #T_63f58_row9_col3 {
#   background: #fff2ae;
#   color: black;
#   color: black;
# }
# #T_63f58_row0_col1, #T_63f58_row0_col2, #T_63f58_row0_col4, #T_63f58_row0_col5, #T_63f58_row0_col7, #T_63f58_row0_col8, #T_63f58_row1_col1, #T_63f58_row1_col2, #T_63f58_row1_col4, #T_63f58_row1_col5, #T_63f58_row1_col7, #T_63f58_row1_col8, #T_63f58_row2_col1, #T_63f58_row2_col2, #T_63f58_row2_col4, #T_63f58_row2_col5, #T_63f58_row2_col7, #T_63f58_row2_col8, #T_63f58_row3_col1, #T_63f58_row3_col2, #T_63f58_row3_col4, #T_63f58_row3_col5, #T_63f58_row3_col7, #T_63f58_row3_col8, #T_63f58_row4_col0, #T_63f58_row4_col1, #T_63f58_row4_col2, #T_63f58_row4_col4, #T_63f58_row4_col5, #T_63f58_row4_col6, #T_63f58_row4_col7, #T_63f58_row4_col8, #T_63f58_row5_col0, #T_63f58_row5_col1, #T_63f58_row5_col2, #T_63f58_row5_col4, #T_63f58_row5_col5, #T_63f58_row5_col6, #T_63f58_row5_col7, #T_63f58_row5_col8, #T_63f58_row6_col0, #T_63f58_row6_col1, #T_63f58_row6_col2, #T_63f58_row6_col4, #T_63f58_row6_col5, #T_63f58_row6_col6, #T_63f58_row6_col7, #T_63f58_row6_col8, #T_63f58_row7_col0, #T_63f58_row7_col1, #T_63f58_row7_col2, #T_63f58_row7_col4, #T_63f58_row7_col5, #T_63f58_row7_col6, #T_63f58_row7_col7, #T_63f58_row7_col8, #T_63f58_row8_col0, #T_63f58_row8_col1, #T_63f58_row8_col2, #T_63f58_row8_col4, #T_63f58_row8_col5, #T_63f58_row8_col6, #T_63f58_row8_col7, #T_63f58_row8_col8, #T_63f58_row9_col0, #T_63f58_row9_col1, #T_63f58_row9_col2, #T_63f58_row9_col4, #T_63f58_row9_col5, #T_63f58_row9_col6, #T_63f58_row9_col7, #T_63f58_row9_col8 {
#   background: white;
#   color: black;
#   color: black;
# }
# #T_63f58_row1_col3, #T_63f58_row4_col3, #T_63f58_row7_col3 {
#   background: #cbd5e8;
#   color: black;
#   color: black;
# }
# #T_63f58_row2_col3, #T_63f58_row5_col3, #T_63f58_row8_col3 {
#   background: nan;
#   color: black;
#   color: black;
# }
# </style>
# <table id="T_63f58_">
#   <caption>Model type: Neural Network</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model_5_Layer</th>
#       <th class="col_heading level0 col1" >Model_5_Shape</th>
#       <th class="col_heading level0 col2" >Model_5_Params</th>
#       <th class="col_heading level0 col3" >Model_6_Layer</th>
#       <th class="col_heading level0 col4" >Model_6_Shape</th>
#       <th class="col_heading level0 col5" >Model_6_Params</th>
#       <th class="col_heading level0 col6" >Model_7_Layer</th>
#       <th class="col_heading level0 col7" >Model_7_Shape</th>
#       <th class="col_heading level0 col8" >Model_7_Params</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63f58_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_63f58_row0_col0" class="data row0 col0" >Dense</td>
#       <td id="T_63f58_row0_col1" class="data row0 col1" >[None, 64]</td>
#       <td id="T_63f58_row0_col2" class="data row0 col2" >7936.000000</td>
#       <td id="T_63f58_row0_col3" class="data row0 col3" >Dense</td>
#       <td id="T_63f58_row0_col4" class="data row0 col4" >[None, 64]</td>
#       <td id="T_63f58_row0_col5" class="data row0 col5" >7936</td>
#       <td id="T_63f58_row0_col6" class="data row0 col6" >Dense</td>
#       <td id="T_63f58_row0_col7" class="data row0 col7" >[None, 64]</td>
#       <td id="T_63f58_row0_col8" class="data row0 col8" >7936.000000</td>
#     </tr>
#     <tr>
#       <th id="T_63f58_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_63f58_row1_col0" class="data row1 col0" >Dense</td>
#       <td id="T_63f58_row1_col1" class="data row1 col1" >[None, 64]</td>
#       <td id="T_63f58_row1_col2" class="data row1 col2" >4160.000000</td>
#       <td id="T_63f58_row1_col3" class="data row1 col3" >BatchNormalization</td>
#       <td id="T_63f58_row1_col4" class="data row1 col4" >[None, 64]</td>
#       <td id="T_63f58_row1_col5" class="data row1 col5" >256</td>
#       <td id="T_63f58_row1_col6" class="data row1 col6" >Dense</td>
#       <td id="T_63f58_row1_col7" class="data row1 col7" >[None, 64]</td>
#       <td id="T_63f58_row1_col8" class="data row1 col8" >4160.000000</td>
#     </tr>
#     <tr>
#       <th id="T_63f58_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_63f58_row2_col0" class="data row2 col0" >Dense</td>
#       <td id="T_63f58_row2_col1" class="data row2 col1" >[None, 64]</td>
#       <td id="T_63f58_row2_col2" class="data row2 col2" >4160.000000</td>
#       <td id="T_63f58_row2_col3" class="data row2 col3" >Activation</td>
#       <td id="T_63f58_row2_col4" class="data row2 col4" >[None, 64]</td>
#       <td id="T_63f58_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_63f58_row2_col6" class="data row2 col6" >Dense</td>
#       <td id="T_63f58_row2_col7" class="data row2 col7" >[None, 448]</td>
#       <td id="T_63f58_row2_col8" class="data row2 col8" >29120.000000</td>
#     </tr>
#     <tr>
#       <th id="T_63f58_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_63f58_row3_col0" class="data row3 col0" >Dense</td>
#       <td id="T_63f58_row3_col1" class="data row3 col1" >[None, 1]</td>
#       <td id="T_63f58_row3_col2" class="data row3 col2" >65.000000</td>
#       <td id="T_63f58_row3_col3" class="data row3 col3" >Dense</td>
#       <td id="T_63f58_row3_col4" class="data row3 col4" >[None, 64]</td>
#       <td id="T_63f58_row3_col5" class="data row3 col5" >4160</td>
#       <td id="T_63f58_row3_col6" class="data row3 col6" >Dense</td>
#       <td id="T_63f58_row3_col7" class="data row3 col7" >[None, 1]</td>
#       <td id="T_63f58_row3_col8" class="data row3 col8" >449.000000</td>
#     </tr>
#     <tr>
#       <th id="T_63f58_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_63f58_row4_col0" class="data row4 col0" >None</td>
#       <td id="T_63f58_row4_col1" class="data row4 col1" >None</td>
#       <td id="T_63f58_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_63f58_row4_col3" class="data row4 col3" >BatchNormalization</td>
#       <td id="T_63f58_row4_col4" class="data row4 col4" >[None, 64]</td>
#       <td id="T_63f58_row4_col5" class="data row4 col5" >256</td>
#       <td id="T_63f58_row4_col6" class="data row4 col6" >None</td>
#       <td id="T_63f58_row4_col7" class="data row4 col7" >None</td>
#       <td id="T_63f58_row4_col8" class="data row4 col8" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_63f58_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_63f58_row5_col0" class="data row5 col0" >None</td>
#       <td id="T_63f58_row5_col1" class="data row5 col1" >None</td>
#       <td id="T_63f58_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_63f58_row5_col3" class="data row5 col3" >Activation</td>
#       <td id="T_63f58_row5_col4" class="data row5 col4" >[None, 64]</td>
#       <td id="T_63f58_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_63f58_row5_col6" class="data row5 col6" >None</td>
#       <td id="T_63f58_row5_col7" class="data row5 col7" >None</td>
#       <td id="T_63f58_row5_col8" class="data row5 col8" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_63f58_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_63f58_row6_col0" class="data row6 col0" >None</td>
#       <td id="T_63f58_row6_col1" class="data row6 col1" >None</td>
#       <td id="T_63f58_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_63f58_row6_col3" class="data row6 col3" >Dense</td>
#       <td id="T_63f58_row6_col4" class="data row6 col4" >[None, 64]</td>
#       <td id="T_63f58_row6_col5" class="data row6 col5" >4160</td>
#       <td id="T_63f58_row6_col6" class="data row6 col6" >None</td>
#       <td id="T_63f58_row6_col7" class="data row6 col7" >None</td>
#       <td id="T_63f58_row6_col8" class="data row6 col8" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_63f58_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_
