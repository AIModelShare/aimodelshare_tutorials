# %% [markdown]
# <p align="center"><img width="50%" src="https://aimodelsharecontent.s3.amazonaws.com/aimodshare_banner.jpg" /></p>
#
#
# ---

# %% [markdown]
# ## Covid Tweet Misinformation Prediction Competition
# Let's share our models to a centralized leaderboard, so that we can collaborate and learn from the model experimentation process...
#
# **Instructions:**
# 1.   Get data in and set up X_train / X_test / y_train
# 2.   Preprocess data using keras Tokenizer/ Write and Save Preprocessor function
# 3. Fit model on preprocessed data and save preprocessor function and model
# 4. Generate predictions from X_test data and submit model to competition
# 5. Repeat submission process to improve place on leaderboard

# %% [markdown]
# ## 1. Get data in and set up X_train, X_test, y_train objects

# %%
#install aimodelshare library
! pip install aimodelshare --upgrade

# %%
# Get competition data
from aimodelshare import download_data
download_data('public.ecr.aws/y2e2a1d6/covid_tweet_competition_data-repository:latest')
# Out:
# Downloading [======================================>          ]
#
# Data downloaded successfully.

# %%
# Set up X_train, X_test, and y_train_labels objects
import pandas as pd
X_train=pd.read_csv("covid_tweet_competition_data/X_train.csv", squeeze=True)
X_test=pd.read_csv("covid_tweet_competition_data/X_test.csv", squeeze=True)

y_train_labels=pd.read_csv("covid_tweet_competition_data/y_train_labels.csv", squeeze=True)

# ohe encode Y data
y_train = pd.get_dummies(y_train_labels)

X_train.head()
# Out:
# 0    "[T]he label of the popular Lysol already show...
# 1    There were more deaths on the roads of France ...
# 2    250 new cases of #COVID19Nigeria; Plateau-69 F...
# 3    @XanderArmstrong Why was chloroquine described...
# 4    Our new Can Compare 'College' tags make it eas...
# Name: tweet, dtype: object

# %% [markdown]
# ##2.   Preprocess data using keras tokenizer / Write and Save Preprocessor function

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# Build vocabulary from training text data
tokenizer = Tokenizer(num_words=10000)
tokenizer.fit_on_texts(X_train)

# preprocessor tokenizes words and makes sure all documents have the same length
def preprocessor(data, maxlen=40, max_words=10000):

    sequences = tokenizer.texts_to_sequences(data)

    word_index = tokenizer.word_index
    X = pad_sequences(sequences, maxlen=maxlen)

    return X

print(preprocessor(X_train).shape)
print(preprocessor(X_test).shape)
# Out:
# (6505, 40)
# (2055, 40)

# %% [markdown]
# ##3. Fit model on preprocessed data and save preprocessor function and model

# %%
from tensorflow.keras.layers import Dense, Embedding,Flatten
from tensorflow.keras.models import Sequential

model = Sequential()
model.add(Embedding(10000, 16, input_length=40))
model.add(Flatten())
model.add(Dense(2, activation='softmax'))
model.summary()

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['acc'])

history = model.fit(preprocessor(X_train), y_train,
                    epochs=1,
                    batch_size=32,
                    validation_split=0.2)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 40, 16)            160000
#
#  flatten (Flatten)           (None, 640)               0
#
#  dense (Dense)               (None, 2)                 1282
#
# =================================================================
# Total params: 161,282
# Trainable params: 161,282
# Non-trainable params: 0
# _________________________________________________________________
# 163/163 [==============================] - 2s 6ms/step - loss: 0.5016 - acc: 0.7544 - val_loss: 0.3725 - val_acc: 0.8317

# %% [markdown]
# #### Save preprocessor function to local "preprocessor.zip" file

# %%
import aimodelshare as ai
ai.export_preprocessor(preprocessor,"")
# Out:
# Your preprocessor is now saved to 'preprocessor.zip'

# %% [markdown]
# #### Save model to local ".onnx" file

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model = model_to_onnx(model, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %% [markdown]
# ## 4. Generate predictions from X_test data and submit model to competition

# %%
#Set credentials using modelshare.org username/password

from aimodelshare.aws import set_credentials
    
apiurl="https://oxm5jqr4k6.execute-api.us-east-1.amazonaws.com/prod/m" #This is the unique rest api that powers this Covid Tweet Playground

set_credentials(apiurl=apiurl)
# Out:
# AI Modelshare Username:··········
# AI Modelshare Password:··········
# AI Model Share login credentials set successfully.

# %%
#Instantiate Competition

mycompetition= ai.Competition(apiurl)

# %%
#Submit Model 1: 

#-- Generate predicted y values (Model 1)
#Note: Keras predict returns the predicted column index location for classification models
prediction_column_index=model.predict(preprocessor(X_test)).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

# Submit Model 1 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 7
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:1311

# %%
# Get leaderboard to explore current best model architectures

# Get raw data in pandas data frame
data = mycompetition.get_leaderboard()

# Stylize leaderboard data
mycompetition.stylize_leaderboard(data)
# Out:
# <style  type="text/css" >
# #T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row0_col0{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f8d6 88.4%, transparent 88.4%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row0_col1{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#c778c8 88.3%, transparent 88.3%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row0_col2{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff4971 88.4%, transparent 88.4%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row0_col3{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#aadbaa 88.3%, transparent 88.3%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row0_col4,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row0_col5,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row0_col6,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row0_col7,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row0_col8,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row0_col9,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row0_col10,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row0_col11,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row0_col12,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row0_col13,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row0_col14,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row0_col15,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row0_col16,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row0_col17,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row0_col18,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row0_col19,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row1_col4,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row1_col5,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row1_col6,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row1_col7,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row1_col8,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row1_col9,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row1_col10,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row1_col11,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row1_col12,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row1_col13,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row1_col14,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row1_col15,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row1_col16,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row1_col17,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row1_col18,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row1_col19,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row2_col4,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row2_col5,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row2_col6,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row2_col7,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row2_col8,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row2_col9,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row2_col10,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row2_col11,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row2_col12,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row2_col13,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row2_col14,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row2_col15,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row2_col16,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row2_col17,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row2_col18,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row2_col19,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row3_col4,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row3_col5,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row3_col6,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row3_col7,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row3_col8,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row3_col9,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row3_col10,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row3_col11,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row3_col12,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row3_col13,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row3_col14,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row3_col15,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row3_col16,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row3_col17,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row3_col18,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row3_col19,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row4_col4,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row4_col5,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row4_col6,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row4_col7,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row4_col8,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row4_col9,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row4_col10,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row4_col11,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row4_col12,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row4_col13,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row4_col14,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row4_col15,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row4_col16,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row4_col17,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row4_col18,#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row4_col19,#T_4ba492f2_7fa9_11ec ...
#             text-align:  center;
#         }#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row1_col0{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f8d6 85.5%, transparent 85.5%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row1_col1{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#c778c8 85.4%, transparent 85.4%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row1_col2{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff4971 86.4%, transparent 86.4%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row1_col3{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#aadbaa 85.3%, transparent 85.3%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_4ba492f2_7fa9_11ec_a3fb_0242ac1c0002row2_col0{
#             text-align:  center;

# %% [markdown]
# ## 5. Repeat submission process to improve place on leaderboard

# %%
# Train and submit model 2 using same preprocessor (note that you could save a new preprocessor, but we will use the same one for this example).
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, LSTM, Flatten

model2 = Sequential()
model2.add(Embedding(10000, 16, input_length=40))
model2.add(LSTM(32, return_sequences=True, dropout=0.2))
model2.add(LSTM(32, dropout=0.2))
model2.add(Flatten())
model2.add(Dense(2, activation='softmax'))

model2.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history = model2.fit(preprocessor(X_train), y_train,
                    epochs=1,
                    batch_size=32,
                    validation_split=0.2)
# Out:
# 163/163 [==============================] - 11s 45ms/step - loss: 0.4166 - acc: 0.8105 - val_loss: 0.2486 - val_acc: 0.9070

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model = model_to_onnx(model2, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("model2.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Submit Model 2: 

#-- Generate predicted y values (Model 2)
prediction_column_index=model2.predict(preprocessor(X_test)).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

# Submit Model 2 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model2.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 8
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:1311

# %%
# Compare two or more models 
data=mycompetition.compare_models([7, 8], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style  type="text/css" >
#     #T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002 caption {
#           color: black;
#           font-size: 18px;
#     }#T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row0_col0,#T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row0_col3{
#             background:  #f4cae4;
#             color:  black;
#             color:  black;
#         }#T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row0_col1,#T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row0_col2,#T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row0_col4,#T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row0_col5,#T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row1_col1,#T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row1_col2,#T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row1_col4,#T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row1_col5,#T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row2_col1,#T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row2_col2,#T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row2_col4,#T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row2_col5,#T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row3_col0,#T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row3_col1,#T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row3_col2,#T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row3_col4,#T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row3_col5,#T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row4_col0,#T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row4_col1,#T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row4_col2,#T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row4_col4,#T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row4_col5{
#             background:  white;
#             color:  black;
#             color:  black;
#         }#T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row1_col0,#T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row3_col3{
#             background:  #e6f5c9;
#             color:  black;
#             color:  black;
#         }#T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row1_col3,#T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row2_col3{
#             background:  #cbd5e8;
#             color:  black;
#             color:  black;
#         }#T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row2_col0,#T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row4_col3{
#             background:  #fff2ae;
#             color:  black;
#             color:  black;
#         }</style><table id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002" ><caption>Model type: Neural Network</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model_7_Layer</th>        <th class="col_heading level0 col1" >Model_7_Shape</th>        <th class="col_heading level0 col2" >Model_7_Params</th>        <th class="col_heading level0 col3" >Model_8_Layer</th>        <th class="col_heading level0 col4" >Model_8_Shape</th>        <th class="col_heading level0 col5" >Model_8_Params</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row0_col0" class="data row0 col0" >Embedding</td>
#                         <td id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row0_col1" class="data row0 col1" >[None, 40, 16]</td>
#                         <td id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row0_col2" class="data row0 col2" >160000.000000</td>
#                         <td id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row0_col3" class="data row0 col3" >Embedding</td>
#                         <td id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row0_col4" class="data row0 col4" >[None, 40, 16]</td>
#                         <td id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row0_col5" class="data row0 col5" >160000</td>
#             </tr>
#             <tr>
#                         <th id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row1_col0" class="data row1 col0" >Flatten</td>
#                         <td id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row1_col1" class="data row1 col1" >[None, 640]</td>
#                         <td id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row1_col2" class="data row1 col2" >0.000000</td>
#                         <td id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row1_col3" class="data row1 col3" >LSTM</td>
#                         <td id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row1_col4" class="data row1 col4" >[None, 40, 32]</td>
#                         <td id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row1_col5" class="data row1 col5" >6272</td>
#             </tr>
#             <tr>
#                         <th id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row2_col0" class="data row2 col0" >Dense</td>
#                         <td id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row2_col1" class="data row2 col1" >[None, 2]</td>
#                         <td id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row2_col2" class="data row2 col2" >1282.000000</td>
#                         <td id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row2_col3" class="data row2 col3" >LSTM</td>
#                         <td id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row2_col4" class="data row2 col4" >[None, 32]</td>
#                         <td id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row2_col5" class="data row2 col5" >8320</td>
#             </tr>
#             <tr>
#                         <th id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row3_col0" class="data row3 col0" >None</td>
#                         <td id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row3_col1" class="data row3 col1" >None</td>
#                         <td id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row3_col2" class="data row3 col2" >nan</td>
#                         <td id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row3_col3" class="data row3 col3" >Flatten</td>
#                         <td id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row3_col4" class="data row3 col4" >[None, 32]</td>
#                         <td id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row3_col5" class="data row3 col5" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row4_col0" class="data row4 col0" >None</td>
#                         <td id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row4_col1" class="data row4 col1" >None</td>
#                         <td id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row4_col2" class="data row4 col2" >nan</td>
#                         <td id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row4_col3" class="data row4 col3" >Dense</td>
#                         <td id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row4_col4" class="data row4 col4" >[None, 2]</td>
#                         <td id="T_95100ebc_7fa9_11ec_a3fb_0242ac1c0002row4_col5" class="data row4 col5" >66</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Optional: Tune model within range of hyperparameters with Keras Tuner
#
# *Simple example shown below. Consult [documentation](https://keras.io/guides/keras_tuner/getting_started/) to see full functionality.*

# %%
! pip install keras_tuner

# %%
#Separate validation data 
from sklearn.model_selection import train_test_split
x_train_split, x_val, y_train_split, y_val = train_test_split(
     X_train, y_train, test_size=0.2, random_state=42)

# %%
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, LSTM, Flatten
import keras_tuner as kt

#Define model structure & parameter search space with function
def build_model(hp):
    model = keras.Sequential()
    model.add(Embedding(10000, 16, input_length=40))
    model.add(LSTM(units=hp.Int("units", min_value=32, max_value=512, step=32), #range 32-512 inclusive, minimum step between tested values is 32
                   return_sequences=True, dropout=0.2, recurrent_dropout=0.2))
    model.add(Flatten())
    model.add(Dense(2, activation='softmax'))
    model.compile(
        optimizer="rmsprop", loss="binary_crossentropy", metrics=["accuracy"],
    )
    return model

#initialize the tuner (which will search through parameters)
tuner = kt.RandomSearch(
    hypermodel=build_model, 
    objective="val_accuracy", # objective to optimize
    max_trials=3, #max number of trials to run during search
    executions_per_trial=1, #higher number reduces variance of results; guages model performance more accurately 
    overwrite=True,
    directory="tuning_model",
    project_name="tuning_units",
)

tuner.search(preprocessor(x_train_split), y_train_split, epochs=1, validation_data=(preprocessor(x_val), y_val))
# Out:
# Trial 3 Complete [00h 02m 25s]
# val_accuracy: 0.8916218280792236
#
# Best val_accuracy So Far: 0.8946964144706726
# Total elapsed time: 00h 05m 10s

# %%
# Build model with best hyperparameters

# Get the top 2 hyperparameters.
best_hps = tuner.get_best_hyperparameters(5)
# Build the model with the best hp.
tuned_model = build_model(best_hps[0])
# Fit with the entire dataset.
tuned_model.fit(x=preprocessor(X_train), y=y_train, epochs=1)
# Out:
# 204/204 [==============================] - 14s 56ms/step - loss: 0.3621 - accuracy: 0.8403

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model = model_to_onnx(tuned_model, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("tuned_model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Submit Model 3: 

#-- Generate predicted y values (Model 3)
prediction_column_index=tuned_model.predict(preprocessor(X_test)).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

# Submit Model 1 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "tuned_model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 9
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:1311

# %%
# Get leaderboard

data = mycompetition.get_leaderboard()
mycompetition.stylize_leaderboard(data)
# Out:
# <style  type="text/css" >
# #T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row0_col0{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f8d6 90.2%, transparent 90.2%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row0_col1{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#c778c8 90.2%, transparent 90.2%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row0_col2{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff4971 90.2%, transparent 90.2%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row0_col3{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#aadbaa 90.2%, transparent 90.2%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row0_col4,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row0_col5,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row0_col6,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row0_col7,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row0_col8,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row0_col9,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row0_col10,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row0_col11,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row0_col12,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row0_col13,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row0_col14,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row0_col15,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row0_col16,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row0_col17,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row0_col18,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row0_col19,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row0_col20,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row0_col21,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row1_col4,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row1_col5,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row1_col6,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row1_col7,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row1_col8,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row1_col9,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row1_col10,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row1_col11,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row1_col12,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row1_col13,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row1_col14,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row1_col15,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row1_col16,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row1_col17,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row1_col18,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row1_col19,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row1_col20,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row1_col21,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row2_col4,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row2_col5,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row2_col6,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row2_col7,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row2_col8,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row2_col9,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row2_col10,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row2_col11,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row2_col12,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row2_col13,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row2_col14,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row2_col15,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row2_col16,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row2_col17,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row2_col18,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row2_col19,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row2_col20,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row2_col21,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row3_col4,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row3_col5,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row3_col6,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row3_col7,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row3_col8,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row3_col9,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row3_col10,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row3_col11,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row3_col12,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row3_col13,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row3_col14,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row3_col15,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row3_col16,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row3_col17,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row3_col18,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row3_col19,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row3_col20,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row3_col21,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row4_col4,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row4_col5,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row4_col6,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row4_col7,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row4_col8,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row4_col9,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row4_col10,#T_98ad9d90_7faa_11ec_a3fb_0242ac1c0002row4_col11,#T_98ad9d90_7faa_11ec ...

# %%
# Compare two or more models
data=mycompetition.compare_models([7, 8, 9], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style  type="text/css" >
#     #T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002 caption {
#           color: black;
#           font-size: 18px;
#     }#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row0_col0,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row0_col3,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row0_col6{
#             background:  #f4cae4;
#             color:  black;
#             color:  black;
#         }#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row0_col1,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row0_col2,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row0_col4,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row0_col5,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row0_col7,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row0_col8,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row1_col1,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row1_col2,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row1_col4,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row1_col5,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row1_col7,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row1_col8,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row2_col1,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row2_col2,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row2_col4,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row2_col5,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row2_col7,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row2_col8,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row3_col0,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row3_col1,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row3_col2,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row3_col4,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row3_col5,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row3_col7,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row3_col8,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row4_col0,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row4_col1,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row4_col2,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row4_col4,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row4_col5,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row4_col6,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row4_col7,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row4_col8{
#             background:  white;
#             color:  black;
#             color:  black;
#         }#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row1_col0,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row2_col6,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row3_col3{
#             background:  #e6f5c9;
#             color:  black;
#             color:  black;
#         }#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row1_col3,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row1_col6,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row2_col3{
#             background:  #cbd5e8;
#             color:  black;
#             color:  black;
#         }#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row2_col0,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row3_col6,#T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row4_col3{
#             background:  #fff2ae;
#             color:  black;
#             color:  black;
#         }</style><table id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002" ><caption>Model type: Neural Network</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model_7_Layer</th>        <th class="col_heading level0 col1" >Model_7_Shape</th>        <th class="col_heading level0 col2" >Model_7_Params</th>        <th class="col_heading level0 col3" >Model_8_Layer</th>        <th class="col_heading level0 col4" >Model_8_Shape</th>        <th class="col_heading level0 col5" >Model_8_Params</th>        <th class="col_heading level0 col6" >Model_9_Layer</th>        <th class="col_heading level0 col7" >Model_9_Shape</th>        <th class="col_heading level0 col8" >Model_9_Params</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row0_col0" class="data row0 col0" >Embedding</td>
#                         <td id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row0_col1" class="data row0 col1" >[None, 40, 16]</td>
#                         <td id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row0_col2" class="data row0 col2" >160000.000000</td>
#                         <td id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row0_col3" class="data row0 col3" >Embedding</td>
#                         <td id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row0_col4" class="data row0 col4" >[None, 40, 16]</td>
#                         <td id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row0_col5" class="data row0 col5" >160000</td>
#                         <td id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row0_col6" class="data row0 col6" >Embedding</td>
#                         <td id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row0_col7" class="data row0 col7" >[None, 40, 16]</td>
#                         <td id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row0_col8" class="data row0 col8" >160000.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row1_col0" class="data row1 col0" >Flatten</td>
#                         <td id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row1_col1" class="data row1 col1" >[None, 640]</td>
#                         <td id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row1_col2" class="data row1 col2" >0.000000</td>
#                         <td id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row1_col3" class="data row1 col3" >LSTM</td>
#                         <td id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row1_col4" class="data row1 col4" >[None, 40, 32]</td>
#                         <td id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row1_col5" class="data row1 col5" >6272</td>
#                         <td id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row1_col6" class="data row1 col6" >LSTM</td>
#                         <td id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row1_col7" class="data row1 col7" >[None, 40, 64]</td>
#                         <td id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row1_col8" class="data row1 col8" >20736.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row2_col0" class="data row2 col0" >Dense</td>
#                         <td id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row2_col1" class="data row2 col1" >[None, 2]</td>
#                         <td id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row2_col2" class="data row2 col2" >1282.000000</td>
#                         <td id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row2_col3" class="data row2 col3" >LSTM</td>
#                         <td id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row2_col4" class="data row2 col4" >[None, 32]</td>
#                         <td id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row2_col5" class="data row2 col5" >8320</td>
#                         <td id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row2_col6" class="data row2 col6" >Flatten</td>
#                         <td id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row2_col7" class="data row2 col7" >[None, 2560]</td>
#                         <td id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row2_col8" class="data row2 col8" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row3_col0" class="data row3 col0" >None</td>
#                         <td id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row3_col1" class="data row3 col1" >None</td>
#                         <td id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row3_col2" class="data row3 col2" >nan</td>
#                         <td id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row3_col3" class="data row3 col3" >Flatten</td>
#                         <td id="T_b11a7f42_7faa_11ec_a3fb_0242ac1c0002row3_col4" class="dat
