# %% [markdown]
# <p align="center"><img width="50%" src="https://aimodelsharecontent.s3.amazonaws.com/aimodshare_banner.jpg" /></p>
#
#
# ---

# %% [markdown]
# ## Model Submission Guide: Dates Classification Competition
# Let's share our models to a centralized leaderboard, so that we can collaborate and learn from the model experimentation process...
#
# **Instructions:**
# 1.   Get data in and set up X_train / X_test / y_train
# 2.   Preprocess data using Sklearn Column Transformer/ Write and Save Preprocessor function
# 3. Fit model on preprocessed data and save preprocessor function and model
# 4. Generate predictions from X_test data and submit model to competition
# 5. Repeat submission process to improve place on leaderboard

# %% [markdown]
# ## 1. Get data in and set up X_train, X_test, y_train objects

# %%
#install aimodelshare library
! pip install aimodelshare==0.0.189

# %%
# Get competition data
from aimodelshare import download_data
download_data('public.ecr.aws/i7c1w0k3/date_competition_data-repository:latest')
# Out:
# Downloading [=============>                                   ]
#
# Data downloaded successfully.

# %%
# Separate data into X_train, y_train, and X_test
import pandas as pd
y_train = pd.read_csv("date_competition_data/y_train.csv")
y_train_labels = y_train.idxmax(axis=1)

X_train = pd.read_csv("date_competition_data/X_train.csv")
X_test=pd.read_csv("date_competition_data/X_test.csv")

X_train.head()
# Out:
#    PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  SOLIDITY  \
# 0  2385.5110    849.6287    548.4377        0.7638  681.0944    0.9874
# 1  2360.4670    919.1130    479.2314        0.8533  661.2138    0.9657
# 2  1059.0460    378.1419    270.6614        0.6983  319.2416    0.9883
# 3  2279.7581    770.8477    654.0494        0.5292  708.2852    0.9945
# 4  1843.9160    647.9982    479.8817        0.6720  556.0906    0.9906
#
#    CONVEX_AREA  EXTENT  ASPECT_RATIO  ROUNDNESS  ...  SkewRB  KurtosisRR  \
# 0       368969  0.7596        1.5492     0.8045  ...  0.3835      2.5413
# 1       355591  0.6926        1.9179     0.7744  ...  0.8084     13.2536
# 2        80990  0.7521        1.3971     0.8968  ... -0.1599      2.2247
# 3       396190  0.7632        1.1786     0.9527  ...  1.6654      5.7796
# 4       245181  0.7818        1.3503     0.8977  ... -0.3694      2.4534
#
#    KurtosisRG  KurtosisRB     EntropyRR    EntropyRG    EntropyRB  ALLdaub4RR  \
# 0      2.7010      4.7956 -4.570224e+10 -31309285376 -31791349760     54.5422
# 1     10.8915      5.0327 -6.173153e+09 -10177111040 -13946608640     20.5354
# 2      2.4509      2.2165 -9.834114e+09  -9082079232  -8377428480     54.3915
# 3      9.1424      7.8056 -1.841185e+10 -23242752000 -23591233536     34.5177
# 4      2.2759      2.5079 -4.665024e+10 -40748339200 -32199612416     66.5225
#
#    ALLdaub4RG  ALLdaub4RB
# 0     46.1706     47.5687
# 1     27.7553     33.2095
# 2     53.0591     50.5000
# 3     38.9835     38.4695
# 4     62.6833     56.9092
#
# [5 rows x 33 columns]

# %% [markdown]
# ##2.   Preprocess data using Sklearn / Write and Save Preprocessor function

# %%
# Simple Preprocessor with sklearn 

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)

# %%
# Here is where we actually write the preprocessor function:
def preprocessor(data):
    preprocessed_data=scaler.transform(data)
    return preprocessed_data

# %%
# check shape of X data after preprocessing it using our new function
preprocessor(X_train).shape
# Out:
# (718, 33)

# %% [markdown]
# ##3. Fit model on preprocessed data and save preprocessor function and model

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation

model = Sequential()
model.add(Dense(16, input_dim=33, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(32, activation='relu'))

model.add(Dense(7, activation='softmax')) 
                                            
# Compile model
model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# Fitting the NN to the Training set
model.fit(preprocessor(X_train), y_train, 
               epochs = 15, validation_split=0.25)

# %% [markdown]
# #### Save preprocessor function to local "preprocessor.zip" file

# %%
import aimodelshare as ai
ai.export_preprocessor(preprocessor,"")
# Out:
# Your preprocessor is now saved to 'preprocessor.zip'

# %% [markdown]
# #### Save model to local ".onnx" file

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model = model_to_onnx(model, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %% [markdown]
# ## 4. Generate predictions from X_test data and submit model to competition

# %%
#Set credentials using modelshare.org username/password

from aimodelshare.aws import set_credentials

#This is the unique rest api that powers this specific Date Classification Playground -- make sure to update the apiurl for new competition deployments
apiurl="https://gkurq4ko89.execute-api.us-east-1.amazonaws.com/prod/m"

set_credentials(apiurl=apiurl)
# Out:
# AI Modelshare Username:··········
# AI Modelshare Password:··········
# AI Model Share login credentials set successfully.

# %%
#Instantiate Competition
import aimodelshare as ai
mycompetition= ai.Competition(apiurl)

# %%
#Submit Model 1: 

#-- Generate predicted y values (Model 1)
#Note: Keras predict returns the predicted column index location for classification models
prediction_column_index=model.predict(preprocessor(X_test)).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

# Submit Model 1 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)

# %%
# Get leaderboard to explore current best model architectures

# Get raw data in pandas data frame
data = mycompetition.get_leaderboard()

# Stylize leaderboard data
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_f2eac_row0_col0, #T_f2eac_row1_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 87.8%, transparent 87.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_f2eac_row0_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 82.3%, transparent 82.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_f2eac_row0_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 84.7%, transparent 84.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_f2eac_row0_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 83.7%, transparent 83.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_f2eac_row0_col4, #T_f2eac_row0_col5, #T_f2eac_row0_col6, #T_f2eac_row0_col7, #T_f2eac_row0_col8, #T_f2eac_row0_col9, #T_f2eac_row0_col10, #T_f2eac_row0_col11, #T_f2eac_row0_col12, #T_f2eac_row0_col13, #T_f2eac_row0_col14, #T_f2eac_row0_col15, #T_f2eac_row0_col16, #T_f2eac_row0_col17, #T_f2eac_row1_col4, #T_f2eac_row1_col5, #T_f2eac_row1_col6, #T_f2eac_row1_col7, #T_f2eac_row1_col8, #T_f2eac_row1_col9, #T_f2eac_row1_col10, #T_f2eac_row1_col11, #T_f2eac_row1_col12, #T_f2eac_row1_col13, #T_f2eac_row1_col14, #T_f2eac_row1_col15, #T_f2eac_row1_col16, #T_f2eac_row1_col17, #T_f2eac_row2_col4, #T_f2eac_row2_col5, #T_f2eac_row2_col6, #T_f2eac_row2_col7, #T_f2eac_row2_col8, #T_f2eac_row2_col9, #T_f2eac_row2_col10, #T_f2eac_row2_col11, #T_f2eac_row2_col12, #T_f2eac_row2_col13, #T_f2eac_row2_col14, #T_f2eac_row2_col15, #T_f2eac_row2_col16, #T_f2eac_row2_col17, #T_f2eac_row3_col4, #T_f2eac_row3_col5, #T_f2eac_row3_col6, #T_f2eac_row3_col7, #T_f2eac_row3_col8, #T_f2eac_row3_col9, #T_f2eac_row3_col10, #T_f2eac_row3_col11, #T_f2eac_row3_col12, #T_f2eac_row3_col13, #T_f2eac_row3_col14, #T_f2eac_row3_col15, #T_f2eac_row3_col16, #T_f2eac_row3_col17, #T_f2eac_row4_col4, #T_f2eac_row4_col5, #T_f2eac_row4_col6, #T_f2eac_row4_col7, #T_f2eac_row4_col8, #T_f2eac_row4_col9, #T_f2eac_row4_col10, #T_f2eac_row4_col11, #T_f2eac_row4_col12, #T_f2eac_row4_col13, #T_f2eac_row4_col14, #T_f2eac_row4_col15, #T_f2eac_row4_col16, #T_f2eac_row4_col17, #T_f2eac_row5_col4, #T_f2eac_row5_col5, #T_f2eac_row5_col6, #T_f2eac_row5_col7, #T_f2eac_row5_col8, #T_f2eac_row5_col9, #T_f2eac_row5_col10, #T_f2eac_row5_col11, #T_f2eac_row5_col12, #T_f2eac_row5_col13, #T_f2eac_row5_col14, #T_f2eac_row5_col15, #T_f2eac_row5_col16, #T_f2eac_row5_col17 {
#   text-align: center;
# }
# #T_f2eac_row1_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 80.0%, transparent 80.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_f2eac_row1_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 84.8%, transparent 84.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_f2eac_row1_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 81.3%, transparent 81.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_f2eac_row2_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 84.4%, transparent 84.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_f2eac_row2_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 70.9%, transparent 70.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_f2eac_row2_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 69.1%, transparent 69.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_f2eac_row2_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 76.0%, transparent 76.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_f2eac_row3_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 81.1%, transparent 81.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_f2eac_row3_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 74.9%, transparent 74.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_f2eac_row3_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 76.9%, transparent 76.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_f2eac_row3_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 74.8%, transparent 74.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_f2eac_row4_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 72.2%, transparent 72.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_f2eac_row4_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 50.6%, transparent 50.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_f2eac_row4_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 56.4%, transparent 56.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_f2eac_row4_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 58.6%, transparent 58.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_f2eac_row5_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 75.6%, transparent 75.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_f2eac_row5_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 50.0%, transparent 50.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_f2eac_row5_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 46.3%, transparent 46.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_f2eac_row5_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 55.7%, transparent 55.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# </style>
# <table id="T_f2eac" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f2eac_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_f2eac_level0_col1" class="col_heading level0 col1" >f1_score</th>
#       <th id="T_f2eac_level0_col2" class="col_heading level0 col2" >precision</th>
#       <th id="T_f2eac_level0_col3" class="col_heading level0 col3" >recall</th>
#       <th id="T_f2eac_level0_col4" class="col_heading level0 col4" >ml_framework</th>
#       <th id="T_f2eac_level0_col5" class="col_heading level0 col5" >transfer_learning</th>
#       <th id="T_f2eac_level0_col6" class="col_heading level0 col6" >deep_learning</th>
#       <th id="T_f2eac_level0_col7" class="col_heading level0 col7" >model_type</th>
#       <th id="T_f2eac_level0_col8" class="col_heading level0 col8" >depth</th>
#       <th id="T_f2eac_level0_col9" class="col_heading level0 col9" >num_params</th>
#       <th id="T_f2eac_level0_col10" class="col_heading level0 col10" >dense_layers</th>
#       <th id="T_f2eac_level0_col11" class="col_heading level0 col11" >softmax_act</th>
#       <th id="T_f2eac_level0_col12" class="col_heading level0 col12" >relu_act</th>
#       <th id="T_f2eac_level0_col13" class="col_heading level0 col13" >loss</th>
#       <th id="T_f2eac_level0_col14" class="col_heading level0 col14" >optimizer</th>
#       <th id="T_f2eac_level0_col15" class="col_heading level0 col15" >memory_size</th>
#       <th id="T_f2eac_level0_col16" class="col_heading level0 col16" >username</th>
#       <th id="T_f2eac_level0_col17" class="col_heading level0 col17" >version</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2eac_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f2eac_row0_col0" class="data row0 col0" >87.78%</td>
#       <td id="T_f2eac_row0_col1" class="data row0 col1" >82.26%</td>
#       <td id="T_f2eac_row0_col2" class="data row0 col2" >84.69%</td>
#       <td id="T_f2eac_row0_col3" class="data row0 col3" >83.73%</td>
#       <td id="T_f2eac_row0_col4" class="data row0 col4" >sklearn</td>
#       <td id="T_f2eac_row0_col5" class="data row0 col5" >False</td>
#       <td id="T_f2eac_row0_col6" class="data row0 col6" >False</td>
#       <td id="T_f2eac_row0_col7" class="data row0 col7" >RandomForestClassifier</td>
#       <

# %% [markdown]
# ## 5. Repeat submission process to improve place on leaderboard

# %%
# Train and submit model 2 using same preprocessor (note that you could save a new preprocessor, but we will use the same one for this example).
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation

model_2 = Sequential()
model_2.add(Dense(128, input_dim=33, activation='relu'))
model_2.add(Dropout(.3))
model_2.add(Dense(64, activation='relu'))
model_2.add(Dense(64, activation='relu'))
model_2.add(Dropout(.3))
model_2.add(Dense(64, activation='relu'))

model_2.add(Dense(7, activation='softmax')) 
                                            
# Compile model
model_2.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# Fitting the NN to the Training set
model_2.fit(preprocessor(X_train), y_train, 
               epochs = 10, validation_split=0.25)

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model = model_to_onnx(model_2, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("model2.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Submit Model 2: 

#-- Generate predicted y values (Model 2)
#Note: Keras predict returns the predicted column index location for classification models
prediction_column_index=model_2.predict(preprocessor(X_test)).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

# Submit Model 2 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model2.onnx",
                                 prediction_submission=prediction_labels,
                                 preprocessor_filepath="preprocessor.zip")

# %%
# Compare two or more models
data=mycompetition.compare_models([6,7], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# /usr/local/lib/python3.9/dist-packages/aimodelshare/aimsonnx.py:1242: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   display(HTML(df_styled.render()))
# <style type="text/css">
# #T_dc3d4 caption {
#   color: black;
#   font-size: 18px;
# }
# #T_dc3d4_row0_col0, #T_dc3d4_row0_col3, #T_dc3d4_row1_col0, #T_dc3d4_row2_col0, #T_dc3d4_row2_col3, #T_dc3d4_row3_col0, #T_dc3d4_row3_col3, #T_dc3d4_row5_col3, #T_dc3d4_row6_col3 {
#   background: #fff2ae;
#   color: black;
#   color: black;
# }
# #T_dc3d4_row0_col1, #T_dc3d4_row0_col2, #T_dc3d4_row0_col4, #T_dc3d4_row0_col5, #T_dc3d4_row1_col1, #T_dc3d4_row1_col2, #T_dc3d4_row1_col4, #T_dc3d4_row1_col5, #T_dc3d4_row2_col1, #T_dc3d4_row2_col2, #T_dc3d4_row2_col4, #T_dc3d4_row2_col5, #T_dc3d4_row3_col1, #T_dc3d4_row3_col2, #T_dc3d4_row3_col4, #T_dc3d4_row3_col5, #T_dc3d4_row4_col0, #T_dc3d4_row4_col1, #T_dc3d4_row4_col2, #T_dc3d4_row4_col4, #T_dc3d4_row4_col5, #T_dc3d4_row5_col0, #T_dc3d4_row5_col1, #T_dc3d4_row5_col2, #T_dc3d4_row5_col4, #T_dc3d4_row5_col5, #T_dc3d4_row6_col0, #T_dc3d4_row6_col1, #T_dc3d4_row6_col2, #T_dc3d4_row6_col4, #T_dc3d4_row6_col5 {
#   background: white;
#   color: black;
#   color: black;
# }
# #T_dc3d4_row1_col3, #T_dc3d4_row4_col3 {
#   background: #cbd5e8;
#   color: black;
#   color: black;
# }
# </style>
# <table id="T_dc3d4">
#   <caption>Model type: Neural Network</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dc3d4_level0_col0" class="col_heading level0 col0" >Model_6_Layer</th>
#       <th id="T_dc3d4_level0_col1" class="col_heading level0 col1" >Model_6_Shape</th>
#       <th id="T_dc3d4_level0_col2" class="col_heading level0 col2" >Model_6_Params</th>
#       <th id="T_dc3d4_level0_col3" class="col_heading level0 col3" >Model_7_Layer</th>
#       <th id="T_dc3d4_level0_col4" class="col_heading level0 col4" >Model_7_Shape</th>
#       <th id="T_dc3d4_level0_col5" class="col_heading level0 col5" >Model_7_Params</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc3d4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dc3d4_row0_col0" class="data row0 col0" >Dense</td>
#       <td id="T_dc3d4_row0_col1" class="data row0 col1" >[None, 16]</td>
#       <td id="T_dc3d4_row0_col2" class="data row0 col2" >544.000000</td>
#       <td id="T_dc3d4_row0_col3" class="data row0 col3" >Dense</td>
#       <td id="T_dc3d4_row0_col4" class="data row0 col4" >[None, 128]</td>
#       <td id="T_dc3d4_row0_col5" class="data row0 col5" >4352</td>
#     </tr>
#     <tr>
#       <th id="T_dc3d4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dc3d4_row1_col0" class="data row1 col0" >Dense</td>
#       <td id="T_dc3d4_row1_col1" class="data row1 col1" >[None, 16]</td>
#       <td id="T_dc3d4_row1_col2" class="data row1 col2" >272.000000</td>
#       <td id="T_dc3d4_row1_col3" class="data row1 col3" >Dropout</td>
#       <td id="T_dc3d4_row1_col4" class="data row1 col4" >[None, 128]</td>
#       <td id="T_dc3d4_row1_col5" class="data row1 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_dc3d4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dc3d4_row2_col0" class="data row2 col0" >Dense</td>
#       <td id="T_dc3d4_row2_col1" class="data row2 col1" >[None, 32]</td>
#       <td id="T_dc3d4_row2_col2" class="data row2 col2" >544.000000</td>
#       <td id="T_dc3d4_row2_col3" class="data row2 col3" >Dense</td>
#       <td id="T_dc3d4_row2_col4" class="data row2 col4" >[None, 64]</td>
#       <td id="T_dc3d4_row2_col5" class="data row2 col5" >8256</td>
#     </tr>
#     <tr>
#       <th id="T_dc3d4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dc3d4_row3_col0" class="data row3 col0" >Dense</td>
#       <td id="T_dc3d4_row3_col1" class="data row3 col1" >[None, 7]</td>
#       <td id="T_dc3d4_row3_col2" class="data row3 col2" >231.000000</td>
#       <td id="T_dc3d4_row3_col3" class="data row3 col3" >Dense</td>
#       <td id="T_dc3d4_row3_col4" class="data row3 col4" >[None, 64]</td>
#       <td id="T_dc3d4_row3_col5" class="data row3 col5" >4160</td>
#     </tr>
#     <tr>
#       <th id="T_dc3d4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dc3d4_row4_col0" class="data row4 col0" >None</td>
#       <td id="T_dc3d4_row4_col1" class="data row4 col1" >None</td>
#       <td id="T_dc3d4_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_dc3d4_row4_col3" class="data row4 col3" >Dropout</td>
#       <td id="T_dc3d4_row4_col4" class="data row4 col4" >[None, 64]</td>
#       <td id="T_dc3d4_row4_col5" class="data row4 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_dc3d4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dc3d4_row5_col0" class="data row5 col0" >None</td>
#       <td id="T_dc3d4_row5_col1" class="data row5 col1" >None</td>
#       <td id="T_dc3d4_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_dc3d4_row5_col3" class="data row5 col3" >Dense</td>
#       <td id="T_dc3d4_row5_col4" class="data row5 col4" >[None, 64]</td>
#       <td id="T_dc3d4_row5_col5" class="data row5 col5" >4160</td>
#     </tr>
#     <tr>
#       <th id="T_dc3d4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dc3d4_row6_col0" class="data row6 col0" >None</td>
#       <td id="T_dc3d4_row6_col1" class="data row6 col1" >None</td>
#       <td id="T_dc3d4_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_dc3d4_row6_col3" class="data row6 col3" >Dense</td>
#       <td id="T_dc3d4_row6_col4" class="data row6 col4" >[None, 7]</td>
#       <td id="T_dc3d4_row6_col5" class="data row6 col5" >455</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Optional: Tune model within range of hyperparameters with Keras Tuner
#
# *Simple example shown below. Consult [documentation](https://keras.io/guides/keras_tuner/getting_started/) to see full functionality.*

# %%
! pip install keras_tuner

# %%
#Separate validation data 
from sklearn.model_selection import train_test_split
x_train_split, x_val, y_train_split, y_val = train_test_split(
     X_train, y_train, test_size=0.2, random_state=42)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, BatchNormalization
from keras.regularizers import l1, l2, l1_l2
import keras_tuner as kt


#Define model structure & parameter search space with function
def build_model(hp):
    model = keras.Sequential()
    model.add(Dense(64, input_dim=33, activation='relu', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
    model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
    model.add(Dense(units=hp.Int("units", min_value=32, max_value=512, step=32), #range 32-512 inclusive, minimum step between tested values is 32
                    activation='relu', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
    model.add(Dense(7, activation='softmax')) 
    model.compile(
        optimizer="rmsprop", loss="binary_crossentropy", metrics=["accuracy"],
    )
    return model

#initialize the tuner (which will search through parameters)
tuner = kt.RandomSearch(
    hypermodel=build_model, 
    objective="val_accuracy", # objective to optimize
    max_trials=3, #max number of trials to run during search
    executions_per_trial=3, #higher number reduces variance of results; guages model performance more accurately 
    overwrite=True,
    directory="tuning_model",
    project_name="tuning_units",
)

tuner.search(preprocessor(x_train_split), y_train_split, epochs=1, validation_data=(preprocessor(x_val), y_val))
# Out:
# Trial 3 Complete [00h 00m 19s]
# val_accuracy: 0.6597222288449606
#
# Best val_accuracy So Far: 0.6736111243565878
# Total elapsed time: 00h 00m 57s

# %%
# Build model with best hyperparameters

# Get the top 2 hyperparameters.
best_hps = tuner.get_best_hyperparameters(5)
# Build the model with the best hp.
tuned_model = build_model(best_hps[0])
# Fit with the entire dataset.
tuned_model.fit(x=preprocessor(X_train), y=y_train, epochs=5)

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model = model_to_onnx(tuned_model, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("tuned_model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Submit Model 3: 

#-- Generate predicted y values (Model 3)
prediction_column_index=tuned_model.predict(preprocessor(X_test)).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

# Submit to Competition Leaderboard
mycompetition.submit_model(model_filepath = "tuned_model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)

# %%
# Get leaderboard

data = mycompetition.get_leaderboard()
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_c636e_row0_col0, #T_c636e_row1_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 87.8%, transparent 87.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c636e_row0_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 82.3%, transparent 82.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c636e_row0_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 84.7%, transparent 84.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c636e_row0_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 83.7%, transparent 83.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c636e_row0_col4, #T_c636e_row0_col5, #T_c636e_row0_col6, #T_c636e_row0_col7, #T_c636e_row0_col8, #T_c636e_row0_col9, #T_c636e_row0_col10, #T_c636e_row0_col11, #T_c636e_row0_col12, #T_c636e_row0_col13, #T_c636e_row0_col14, #T_c636e_row0_col15, #T_c636e_row0_col16, #T_c636e_row0_col17, #T_c636e_row0_col18, #T_c636e_row1_col4, #T_c636e_row1_col5, #T_c636e_row1_col6, #T_c636e_row1_col7, #T_c636e_row1_col8, #T_c636e_row1_col9, #T_c636e_row1_col10, #T_c636e_row1_col11, #T_c636e_row1_col12, #T_c636e_row1_col13, #T_c636e_row1_col14, #T_c636e_row1_col15, #T_c636e_row1_col16, #T_c636e_row1_col17, #T_c636e_row1_col18, #T_c636e_row2_col4, #T_c636e_row2_col5, #T_c636e_row2_col6, #T_c636e_row2_col7, #T_c636e_row2_col8, #T_c636e_row2_col9, #T_c636e_row2_col10, #T_c636e_row2_col11, #T_c636e_row2_col12, #T_c636e_row2_col13, #T_c636e_row2_col14, #T_c636e_row2_col15, #T_c636e_row2_col16, #T_c636e_row2_col17, #T_c636e_row2_col18, #T_c636e_row3_col4, #T_c636e_row3_col5, #T_c636e_row3_col6, #T_c636e_row3_col7, #T_c636e_row3_col8, #T_c636e_row3_col9, #T_c636e_row3_col10, #T_c636e_row3_col11, #T_c636e_row3_col12, #T_c636e_row3_col13, #T_c636e_row3_col14, #T_c636e_row3_col15, #T_c636e_row3_col16, #T_c636e_row3_col17, #T_c636e_row3_col18, #T_c636e_row4_col4, #T_c636e_row4_col5, #T_c636e_row4_col6, #T_c636e_row4_col7, #T_c636e_row4_col8, #T_c636e_row4_col9, #T_c636e_row4_col10, #T_c636e_row4_col11, #T_c636e_row4_col12, #T_c636e_row4_col13, #T_c636e_row4_col14, #T_c636e_row4_col15, #T_c636e_row4_col16, #T_c636e_row4_col17, #T_c636e_row4_col18, #T_c636e_row5_col4, #T_c636e_row5_col5, #T_c636e_row5_col6, #T_c636e_row5_col7, #T_c636e_row5_col8, #T_c636e_row5_col9, #T_c636e_row5_col10, #T_c636e_row5_col11, #T_c636e_row5_col12, #T_c636e_row5_col13, #T_c636e_row5_col14, #T_c636e_row5_col15, #T_c636e_row5_col16, #T_c636e_row5_col17, #T_c636e_row5_col18, #T_c636e_row6_col4, #T_c636e_row6_col5, #T_c636e_row6_col6, #T_c636e_row6_col7, #T_c636e_row6_col8, #T_c636e_row6_col9, #T_c636e_row6_col10, #T_c636e_row6_col11, #T_c636e_row6_col12, #T_c636e_row6_col13, #T_c636e_row6_col14, #T_c636e_row6_col15, #T_c636e_row6_col16, #T_c636e_row6_col17, #T_c636e_row6_col18, #T_c636e_row7_col4, #T_c636e_row7_col5, #T_c636e_row7_col6, #T_c636e_row7_col7, #T_c636e_row7_col8, #T_c636e_row7_col9, #T_c636e_row7_col10, #T_c636e_row7_col11, #T_c636e_row7_col12, #T_c636e_row7_col13, #T_c636e_row7_col14, #T_c636e_row7_col15, #T_c636e_row7_col16, #T_c636e_row7_col17, #T_c636e_row7_col18 {
#   text-align: center;
# }
# #T_c636e_row1_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 80.0%, transparent 80.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c636e_row1_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 84.8%, transparent 84.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c636e_row1_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 81.3%, transparent 81.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c636e_row2_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 84.4%, transparent 84.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c636e_row2_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 70.9%, transparent 70.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c636e_row2_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 69.1%, transparent 69.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c636e_row2_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 76.0%, transparent 76.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c636e_row3_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 81.1%, transparent 81.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c636e_row3_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 74.9%, transparent 74.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c636e_row3_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 76.9%, transparent 76.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c636e_row3_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 74.8%, transparent 74.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c636e_row4_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 72.2%, transparent 72.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c636e_row4_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 50.6%, transparent 50.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c636e_row4_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 56.4%, transparent 56.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c636e_row4_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 58.6%, transparent 58.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c636e_row5_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 75.6%, transparent 75.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c636e_row5_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 50.0%, transparent 50.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c636e_row5_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 46.3%, transparent 46.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c636e_row5_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 55.7%, transparent 55.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c636e_row6_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 71.1%, transparent 71.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c636e_row6_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 48.1%, transparent 48.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c636e_row6_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 44.8%, transparent 44.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c636e_row6_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 54.3%, transparent 54.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c636e_row7_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 70.0%, transparent 70.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c636e_row7_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 46.3%, transparent 46.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c636e_row7_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 53.8%, transparent 53.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c636e_row7_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 51.4%, transparent 51.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# </style>
# <table id="T_c636e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c636e_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_c636e_level

# %%
# Compare two or more models
data=mycompetition.compare_models([6, 7, 8], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# /usr/local/lib/python3.9/dist-packages/aimodelshare/aimsonnx.py:1242: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   display(HTML(df_styled.render()))
# <style type="text/css">
# #T_34ccc caption {
#   color: black;
#   font-size: 18px;
# }
# #T_34ccc_row0_col0, #T_34ccc_row0_col3, #T_34ccc_row0_col6, #T_34ccc_row1_col0, #T_34ccc_row1_col6, #T_34ccc_row2_col0, #T_34ccc_row2_col3, #T_34ccc_row2_col6, #T_34ccc_row3_col0, #T_34ccc_row3_col3, #T_34ccc_row3_col6, #T_34ccc_row5_col3, #T_34ccc_row6_col3 {
#   background: #fff2ae;
#   color: black;
#   color: black;
# }
# #T_34ccc_row0_col1, #T_34ccc_row0_col2, #T_34ccc_row0_col4, #T_34ccc_row0_col5, #T_34ccc_row0_col7, #T_34ccc_row0_col8, #T_34ccc_row1_col1, #T_34ccc_row1_col2, #T_34ccc_row1_col4, #T_34ccc_row1_col5, #T_34ccc_row1_col7, #T_34ccc_row1_col8, #T_34ccc_row2_col1, #T_34ccc_row2_col2, #T_34ccc_row2_col4, #T_34ccc_row2_col5, #T_34ccc_row2_col7, #T_34ccc_row2_col8, #T_34ccc_row3_col1, #T_34ccc_row3_col2, #T_34ccc_row3_col4, #T_34ccc_row3_col5, #T_34ccc_row3_col7, #T_34ccc_row3_col8, #T_34ccc_row4_col0, #T_34ccc_row4_col1, #T_34ccc_row4_col2, #T_34ccc_row4_col4, #T_34ccc_row4_col5, #T_34ccc_row4_col6, #T_34ccc_row4_col7, #T_34ccc_row4_col8, #T_34ccc_row5_col0, #T_34ccc_row5_col1, #T_34ccc_row5_col2, #T_34ccc_row5_col4, #T_34ccc_row5_col5, #T_34ccc_row5_col6, #T_34ccc_row5_col7, #T_34ccc_row5_col8, #T_34ccc_row6_col0, #T_34ccc_row6_col1, #T_34ccc_row6_col2, #T_34ccc_row6_col4, #T_34ccc_row6_col5, #T_34ccc_row6_col6, #T_34ccc_row6_col7, #T_34ccc_row6_col8 {
#   background: white;
#   color: black;
#   color: black;
# }
# #T_34ccc_row1_col3, #T_34ccc_row4_col3 {
#   background: #cbd5e8;
#   color: black;
#   color: black;
# }
# </style>
# <table id="T_34ccc">
#   <caption>Model type: Neural Network</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34ccc_level0_col0" class="col_heading level0 col0" >Model_6_Layer</th>
#       <th id="T_34ccc_level0_col1" class="col_heading level0 col1" >Model_6_Shape</th>
#       <th id="T_34ccc_level0_col2" class="col_heading level0 col2" >Model_6_Params</th>
#       <th id="T_34ccc_level0_col3" class="col_heading level0 col3" >Model_7_Layer</th>
#       <th id="T_34ccc_level0_col4" class="col_heading level0 col4" >Model_7_Shape</th>
#       <th id="T_34ccc_level0_col5" class="col_heading level0 col5" >Model_7_Params</th>
#       <th id="T_34ccc_level0_col6" class="col_heading level0 col6" >Model_8_Layer</th>
#       <th id="T_34ccc_level0_col7" class="col_heading level0 col7" >Model_8_Shape</th>
#       <th id="T_34ccc_level0_col8" class="col_heading level0 col8" >Model_8_Params</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34ccc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_34ccc_row0_col0" class="data row0 col0" >Dense</td>
#       <td id="T_34ccc_row0_col1" class="data row0 col1" >[None, 16]</td>
#       <td id="T_34ccc_row0_col2" class="data row0 col2" >544.000000</td>
#       <td id="T_34ccc_row0_col3" class="data row0 col3" >Dense</td>
#       <td id="T_34ccc_row0_col4" class="data row0 col4" >[None, 128]</td>
#       <td id="T_34ccc_row0_col5" class="data row0 col5" >4352</td>
#       <td id="T_34ccc_row0_col6" class="data row0 col6" >Dense</td>
#       <td id="T_34ccc_row0_col7" class="data row0 col7" >[None, 64]</td>
#       <td id="T_34ccc_row0_col8" class="data row0 col8" >2176.000000</td>
#     </tr>
#     <tr>
#       <th id="T_34ccc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_34ccc_row1_col0" class="data row1 col0" >Dense</td>
#       <td id="T_34ccc_row1_col1" class="data row1 col1" >[None, 16]</td>
#       <td id="T_34ccc_row1_col2" class="data row1 col2" >272.000000</td>
#       <td id="T_34ccc_row1_col3" class="data row1 col3" >Dropout</td>
#       <td id="T_34ccc_row1_col4" class="data row1 col4" >[None, 128]</td>
#       <td id="T_34ccc_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_34ccc_row1_col6" class="data row1 col6" >Dense</td>
#       <td id="T_34ccc_row1_col7" class="data row1 col7" >[None, 64]</td>
#       <td id="T_34ccc_row1_col8" class="data row1 col8" >4160.000000</td>
#     </tr>
#     <tr>
#       <th id="T_34ccc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_34ccc_row2_col0" class="data row2 col0" >Dense</td>
#       <td id="T_34ccc_row2_col1" class="data row2 col1" >[None, 32]</td>
#       <td id="T_34ccc_row2_col2" class="data row2 col2" >544.000000</td>
#       <td id="T_34ccc_row2_col3" class="data row2 col3" >Dense</td>
#       <td id="T_34ccc_row2_col4" class="data row2 col4" >[None, 64]</td>
#       <td id="T_34ccc_row2_col5" class="data row2 col5" >8256</td>
#       <td id="T_34ccc_row2_col6" class="data row2 col6" >Dense</td>
#       <td id="T_34ccc_row2_col7" class="data row2 col7" >[None, 192]</td>
#       <td id="T_34ccc_row2_col8" class="data row2 col8" >12480.000000</td>
#     </tr>
#     <tr>
#       <th id="T_34ccc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_34ccc_row3_col0" class="data row3 col0" >Dense</td>
#       <td id="T_34ccc_row3_col1" class="data row3 col1" >[None, 7]</td>
#       <td id="T_34ccc_row3_col2" class="data row3 col2" >231.000000</td>
#       <td id="T_34ccc_row3_col3" class="data row3 col3" >Dense</td>
#       <td id="T_34ccc_row3_col4" class="data row3 col4" >[None, 64]</td>
#       <td id="T_34ccc_row3_col5" class="data row3 col5" >4160</td>
#       <td id="T_34ccc_row3_col6" class="data row3 col6" >Dense</td>
#       <td id="T_34ccc_row3_col7" class="data row3 col7" >[None, 7]</td>
#       <td id="T_34ccc_row3_col8" class="data row3 col8" >1351.000000</td>
#     </tr>
#     <tr>
#       <th id="T_34ccc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_34ccc_row4_col0" class="data row4 col0" >None</td>
#       <td id="T_34ccc_row4_col1" class="data row4 col1" >None</td>
#       <td id="T_34ccc_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_34ccc_row4_col3" class="data row4 col3" >Dropout</td>
#       <td id="T_34ccc_row4_col4" class="data row4 col4" >[None, 64]</td>
#       <td id="T_34ccc_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_34ccc_row4_col6" class="data row4 col6" >None</td>
#       <td id="T_34ccc_row4_col7" class="data row4 col7" >None</td>
#       <td id="T_34ccc_row4_col8" class="data row4 col8" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_34ccc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_34ccc_row5_col0" class="data row5 col0" >None</td>
#       <td id="T_34ccc_row5_col1" class="data row5 col1" >None</td>
#       <td id="T_34ccc_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_34ccc_row5_col3" class="data row5 col3" >Dense</td>
#       <td id="T_34ccc_row5_col4" class="data row5 col4" >[None, 64]</td>
#       <td id="T_34ccc_row5_col5" class="data row5 col5" >4160</td>
#       <td id="T_34ccc_row5_col6" class="data row5 col6" >None</td>
#       <td id="T_34ccc_row5_col7" class="data row5 col7" >None</td>
#       <td id="T_34ccc_row5_col8" class="data row5 col8" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_34ccc_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_34ccc_row6_col0" class="data row6 col0" >None</td>
#       <td id="T_34ccc_row6_col1" class="data row6 col1" >None</td>
#       <td id="T_34ccc_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_34ccc_row6_col3" class="data row6 col3" >Dense</td>
#       <td id="T_34ccc_row6_col4" class="data row6 col4" >[None, 7]</td>
#       <td id="T_34ccc_row6_col5" class="data row6 col5" >455</td>
#       <td id="T_34ccc_row6_col6" class="data row6 col6" >None</td>
#       <td id="T_34ccc_row6_col7" class="data row6 col7" >None</td>
#       <td id="T_34ccc_row6_col8" class="data row6 col8" >nan</td>
#     </tr>
#   </tbody>
# </table>
