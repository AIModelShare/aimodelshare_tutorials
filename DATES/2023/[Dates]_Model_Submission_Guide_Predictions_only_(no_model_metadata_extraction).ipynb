# %% [markdown]
# <p align="center"><img width="50%" src="https://aimodelsharecontent.s3.amazonaws.com/aimodshare_banner.jpg" /></p>
#
#
# ---

# %% [markdown]
# <p align="center"><h1 align="center">Dates Classification Prediction Model Submission Guide - Predictions Only (No Model Metadata Extraction) </h1>
#
# ---
# Let's share our models to a centralized leaderboard, so that we can collaborate and learn from the model experimentation process...
#
# **Instructions:**
# 1.   Get data in and set up X_train / X_test / y_train
# 2.   Preprocess data
# 3. Fit model on preprocessed data
# 4. Generate predictions from X_test data and submit to competition
# 5. Repeat submission process to improve place on leaderboard

# %% [markdown]
# ## 1. Get data in and set up X_train, X_test, y_train objects

# %%
#install aimodelshare library
! pip install aimodelshare --upgrade

# %%
# Get competition data
from aimodelshare import download_data
download_data('public.ecr.aws/i7c1w0k3/date_competition_data-repository:latest')
# Out:
# Downloading [=============>                                   ]
#
# Data downloaded successfully.

# %%
# Separate data into X_train, y_train, and X_test
import pandas as pd
y_train = pd.read_csv("date_competition_data/y_train.csv")
y_train_labels = y_train.idxmax(axis=1)

X_train = pd.read_csv("date_competition_data/X_train.csv")
X_test=pd.read_csv("date_competition_data/X_test.csv")

X_train.head()
# Out:
#    PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  SOLIDITY  \
# 0  2385.5110    849.6287    548.4377        0.7638  681.0944    0.9874
# 1  2360.4670    919.1130    479.2314        0.8533  661.2138    0.9657
# 2  1059.0460    378.1419    270.6614        0.6983  319.2416    0.9883
# 3  2279.7581    770.8477    654.0494        0.5292  708.2852    0.9945
# 4  1843.9160    647.9982    479.8817        0.6720  556.0906    0.9906
#
#    CONVEX_AREA  EXTENT  ASPECT_RATIO  ROUNDNESS  ...  SkewRB  KurtosisRR  \
# 0       368969  0.7596        1.5492     0.8045  ...  0.3835      2.5413
# 1       355591  0.6926        1.9179     0.7744  ...  0.8084     13.2536
# 2        80990  0.7521        1.3971     0.8968  ... -0.1599      2.2247
# 3       396190  0.7632        1.1786     0.9527  ...  1.6654      5.7796
# 4       245181  0.7818        1.3503     0.8977  ... -0.3694      2.4534
#
#    KurtosisRG  KurtosisRB     EntropyRR    EntropyRG    EntropyRB  ALLdaub4RR  \
# 0      2.7010      4.7956 -4.570224e+10 -31309285376 -31791349760     54.5422
# 1     10.8915      5.0327 -6.173153e+09 -10177111040 -13946608640     20.5354
# 2      2.4509      2.2165 -9.834114e+09  -9082079232  -8377428480     54.3915
# 3      9.1424      7.8056 -1.841185e+10 -23242752000 -23591233536     34.5177
# 4      2.2759      2.5079 -4.665024e+10 -40748339200 -32199612416     66.5225
#
#    ALLdaub4RG  ALLdaub4RB
# 0     46.1706     47.5687
# 1     27.7553     33.2095
# 2     53.0591     50.5000
# 3     38.9835     38.4695
# 4     62.6833     56.9092
#
# [5 rows x 33 columns]

# %%
# Check Data Shape
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
# Out:
# (718, 33)
# (180, 33)
# (718, 7)

# %% [markdown]
# ##2.   Preprocess data

# %%
# Write and execute code to preprocess data here

# %% [markdown]
# ##3. Fit model on preprocessed data

# %%
# Write and execute code to fit model on preprocessed data here.

# %%
#Set credentials using modelshare.org username/password

from aimodelshare.aws import set_credentials
    
apiurl="https://gkurq4ko89.execute-api.us-east-1.amazonaws.com/prod/m"
#This is the unique rest api that powers this specific Date Classification Playground -- make sure to update the apiurl for new competition deployments

set_credentials(apiurl=apiurl)
# Out:
# AI Modelshare Username:··········
# AI Modelshare Password:··········
# AI Model Share login credentials set successfully.

# %%
#Instantiate Competition
import aimodelshare as ai
mycompetition= ai.Competition(apiurl)

# %% [markdown]
# ## **4. Submit Model predictions to leaderboard (without extracting model architecture information):**
# - model metadata extraction allows you use compare_models() and instantiate_model() functions.

# %%
#Generate a list of predictions using X_test data

# This example uses randomly chosen values from y_train to generate a list of predictions
predicted_values = list(y_train_labels.sample(n=len(X_test.index)))

# %%
#Submit Model predictions to leaderboard (without extracting model architecture information): 

# Submit to Competition Leaderboard
mycompetition.submit_model(model_filepath = None,
                                 preprocessor_filepath=None,
                                 prediction_submission=predicted_values)

# %%
# Get leaderboard to explore current best model architectures

# Get raw data in pandas data frame
data = mycompetition.get_leaderboard()

# Stylize leaderboard data
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_bb0ea_row0_col0, #T_bb0ea_row1_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 87.8%, transparent 87.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb0ea_row0_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 82.3%, transparent 82.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb0ea_row0_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 84.7%, transparent 84.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb0ea_row0_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 83.7%, transparent 83.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb0ea_row0_col4, #T_bb0ea_row0_col5, #T_bb0ea_row0_col6, #T_bb0ea_row0_col7, #T_bb0ea_row0_col8, #T_bb0ea_row0_col9, #T_bb0ea_row0_col10, #T_bb0ea_row0_col11, #T_bb0ea_row0_col12, #T_bb0ea_row0_col13, #T_bb0ea_row0_col14, #T_bb0ea_row0_col15, #T_bb0ea_row0_col16, #T_bb0ea_row0_col17, #T_bb0ea_row1_col4, #T_bb0ea_row1_col5, #T_bb0ea_row1_col6, #T_bb0ea_row1_col7, #T_bb0ea_row1_col8, #T_bb0ea_row1_col9, #T_bb0ea_row1_col10, #T_bb0ea_row1_col11, #T_bb0ea_row1_col12, #T_bb0ea_row1_col13, #T_bb0ea_row1_col14, #T_bb0ea_row1_col15, #T_bb0ea_row1_col16, #T_bb0ea_row1_col17, #T_bb0ea_row2_col4, #T_bb0ea_row2_col5, #T_bb0ea_row2_col6, #T_bb0ea_row2_col7, #T_bb0ea_row2_col8, #T_bb0ea_row2_col9, #T_bb0ea_row2_col10, #T_bb0ea_row2_col11, #T_bb0ea_row2_col12, #T_bb0ea_row2_col13, #T_bb0ea_row2_col14, #T_bb0ea_row2_col15, #T_bb0ea_row2_col16, #T_bb0ea_row2_col17, #T_bb0ea_row3_col4, #T_bb0ea_row3_col5, #T_bb0ea_row3_col6, #T_bb0ea_row3_col7, #T_bb0ea_row3_col8, #T_bb0ea_row3_col9, #T_bb0ea_row3_col10, #T_bb0ea_row3_col11, #T_bb0ea_row3_col12, #T_bb0ea_row3_col13, #T_bb0ea_row3_col14, #T_bb0ea_row3_col15, #T_bb0ea_row3_col16, #T_bb0ea_row3_col17, #T_bb0ea_row4_col4, #T_bb0ea_row4_col5, #T_bb0ea_row4_col6, #T_bb0ea_row4_col7, #T_bb0ea_row4_col8, #T_bb0ea_row4_col9, #T_bb0ea_row4_col10, #T_bb0ea_row4_col11, #T_bb0ea_row4_col12, #T_bb0ea_row4_col13, #T_bb0ea_row4_col14, #T_bb0ea_row4_col15, #T_bb0ea_row4_col16, #T_bb0ea_row4_col17, #T_bb0ea_row5_col4, #T_bb0ea_row5_col5, #T_bb0ea_row5_col6, #T_bb0ea_row5_col7, #T_bb0ea_row5_col8, #T_bb0ea_row5_col9, #T_bb0ea_row5_col10, #T_bb0ea_row5_col11, #T_bb0ea_row5_col12, #T_bb0ea_row5_col13, #T_bb0ea_row5_col14, #T_bb0ea_row5_col15, #T_bb0ea_row5_col16, #T_bb0ea_row5_col17, #T_bb0ea_row6_col4, #T_bb0ea_row6_col5, #T_bb0ea_row6_col6, #T_bb0ea_row6_col7, #T_bb0ea_row6_col8, #T_bb0ea_row6_col9, #T_bb0ea_row6_col10, #T_bb0ea_row6_col11, #T_bb0ea_row6_col12, #T_bb0ea_row6_col13, #T_bb0ea_row6_col14, #T_bb0ea_row6_col15, #T_bb0ea_row6_col16, #T_bb0ea_row6_col17, #T_bb0ea_row7_col4, #T_bb0ea_row7_col5, #T_bb0ea_row7_col6, #T_bb0ea_row7_col7, #T_bb0ea_row7_col8, #T_bb0ea_row7_col9, #T_bb0ea_row7_col10, #T_bb0ea_row7_col11, #T_bb0ea_row7_col12, #T_bb0ea_row7_col13, #T_bb0ea_row7_col14, #T_bb0ea_row7_col15, #T_bb0ea_row7_col16, #T_bb0ea_row7_col17, #T_bb0ea_row8_col4, #T_bb0ea_row8_col5, #T_bb0ea_row8_col6, #T_bb0ea_row8_col7, #T_bb0ea_row8_col8, #T_bb0ea_row8_col9, #T_bb0ea_row8_col10, #T_bb0ea_row8_col11, #T_bb0ea_row8_col12, #T_bb0ea_row8_col13, #T_bb0ea_row8_col14, #T_bb0ea_row8_col15, #T_bb0ea_row8_col16, #T_bb0ea_row8_col17 {
#   text-align: center;
# }
# #T_bb0ea_row1_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 80.0%, transparent 80.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb0ea_row1_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 84.8%, transparent 84.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb0ea_row1_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 81.3%, transparent 81.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb0ea_row2_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 84.4%, transparent 84.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb0ea_row2_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 70.9%, transparent 70.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb0ea_row2_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 69.1%, transparent 69.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb0ea_row2_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 76.0%, transparent 76.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb0ea_row3_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 81.1%, transparent 81.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb0ea_row3_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 74.9%, transparent 74.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb0ea_row3_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 76.9%, transparent 76.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb0ea_row3_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 74.8%, transparent 74.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb0ea_row4_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 72.2%, transparent 72.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb0ea_row4_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 50.6%, transparent 50.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb0ea_row4_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 56.4%, transparent 56.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb0ea_row4_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 58.6%, transparent 58.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb0ea_row5_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 75.6%, transparent 75.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb0ea_row5_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 50.0%, transparent 50.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb0ea_row5_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 46.3%, transparent 46.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb0ea_row5_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 55.7%, transparent 55.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb0ea_row6_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 71.1%, transparent 71.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb0ea_row6_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 48.1%, transparent 48.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb0ea_row6_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 44.8%, transparent 44.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb0ea_row6_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 54.3%, transparent 54.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb0ea_row7_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 70.0%, transparent 70.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb0ea_row7_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 46.3%, transparent 46.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb0ea_row7_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 53.8%, transparent 53.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb0ea_row7_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 51.4%, transparent 51.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb0ea_row8_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8

# %% [markdown]
# You can also compare two or more models for any models submitted to the leaderboard using example code for model metadata extraction (see code tab for this competition at www.modelshare.org for submission examples.)
# ```
# data=mycompetition.compare_models([1,2], verbose=1)
# mycompetition.stylize_compare(data)
# ```

# %% [markdown]
# #####  (Optional Extension) Submit Model With Custom Metadata:
# Can use to add team names or any other missing data you may wish to share on the leaderboard

# %%
# Custom metadata can be added by passing a dict to the custom_metadata argument of the submit_model() method
# This option can be used to fill in missing data points or add new columns to the leaderboard

custom_meta = {'team': 'team one',
               'model_type': 'your_model_type',
               'new_column': 'new metadata'}

mycompetition.submit_model(model_filepath = None,
                                 preprocessor_filepath=None,
                                 prediction_submission=predicted_values,
                                 custom_metadata = custom_meta)
