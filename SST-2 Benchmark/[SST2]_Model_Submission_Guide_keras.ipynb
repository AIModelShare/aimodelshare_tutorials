# %% [markdown]
# <p align="center"><img width="50%" src="https://aimodelsharecontent.s3.amazonaws.com/aimodshare_banner.jpg" /></p>
#
#
# ---

# %% [markdown]
# ## Stanford Sentiment Treebank - Movie Review Classification Competition
# Let's share our models to a centralized leaderboard, so that we can collaborate and learn from the model experimentation process...
#
# **Instructions:**
# 1.   Get data in and set up X_train / X_test / y_train
# 2.   Preprocess data using keras Tokenizer/ Write and Save Preprocessor function
# 3. Fit model on preprocessed data and save preprocessor function and model
# 4. Generate predictions from X_test data and submit model to competition
# 5. Repeat submission process to improve place on leaderboard

# %% [markdown]
# ## 1. Get data in and set up X_train, X_test, y_train objects

# %%
#install aimodelshare library
! pip install aimodelshare==0.0.189

# %%
# Get competition data
from aimodelshare import download_data
download_data('public.ecr.aws/y2e2a1d6/sst2_competition_data-repository:latest')
# Out:
# Downloading [=============================================>   ]
#
# Data downloaded successfully.

# %%
# Set up X_train, X_test, and y_train_labels objects
import pandas as pd
import warnings
warnings.simplefilter(action='ignore', category=Warning)

X_train=pd.read_csv("sst2_competition_data/X_train.csv", squeeze=True)
X_test=pd.read_csv("sst2_competition_data/X_test.csv", squeeze=True)

y_train_labels=pd.read_csv("sst2_competition_data/y_train_labels.csv", squeeze=True)

# ohe encode Y data
y_train = pd.get_dummies(y_train_labels)

X_train.head()
# Out:
# 0    The Rock is destined to be the 21st Century 's...
# 1    The gorgeously elaborate continuation of `` Th...
# 2    Singer/composer Bryan Adams contributes a slew...
# 3                 Yet the act is still charming here .
# 4    Whether or not you 're enlightened by any of D...
# Name: text, dtype: object

# %% [markdown]
# ##2.   Preprocess data using keras tokenizer / Write and Save Preprocessor function

# %%
# This preprocessor function makes use of the tf.keras tokenizer

from tensorflow import keras
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import pad_sequences
import numpy as np

# Build vocabulary from training text data
tokenizer = Tokenizer(num_words=10000)
tokenizer.fit_on_texts(X_train)

# preprocessor tokenizes words and makes sure all documents have the same length
def preprocessor(data, maxlen=40, max_words=10000):

    sequences = tokenizer.texts_to_sequences(data)

    word_index = tokenizer.word_index
    X = pad_sequences(sequences, maxlen=maxlen)

    return X

print(preprocessor(X_train).shape)
print(preprocessor(X_test).shape)
# Out:
# (6920, 40)
# (1821, 40)

# %% [markdown]
# ##3. Fit model on preprocessed data and save preprocessor function and model

# %%
from tensorflow.keras.layers import Dense, Embedding,Flatten
from tensorflow.keras.models import Sequential

model = Sequential()
model.add(Embedding(10000, 16, input_length=40))
model.add(Flatten())
model.add(Dense(2, activation='softmax'))
model.summary()

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['acc'])

history = model.fit(preprocessor(X_train), y_train,
                    epochs=10,
                    batch_size=32,
                    validation_split=0.2)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 40, 16)            160000
#
#  flatten (Flatten)           (None, 640)               0
#
#  dense (Dense)               (None, 2)                 1282
#
# =================================================================
# Total params: 161,282
# Trainable params: 161,282
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 173/173 [==============================] - 4s 8ms/step - loss: 0.6675 - acc: 0.6120 - val_loss: 0.9088 - val_acc: 0.1488
# Epoch 2/10
# 173/173 [==============================] - 1s 6ms/step - loss: 0.6232 - acc: 0.6329 - val_loss: 0.7764 - val_acc: 0.3049
# Epoch 3/10
# 173/173 [==============================] - 1s 6ms/step - loss: 0.5348 - acc: 0.7484 - val_loss: 0.7301 - val_acc: 0.4986
# Epoch 4/10
# 173/173 [==============================] - 1s 5ms/step - loss: 0.4278 - acc: 0.8438 - val_loss: 0.6703 - val_acc: 0.6178
# Epoch 5/10
# 173/173 [==============================] - 1s 5ms/step - loss: 0.3296 - acc: 0.9019 - val_loss: 0.7201 - val_acc: 0.5614
# Epoch 6/10
# 173/173 [==============================] - 1s 5ms/step - loss: 0.2501 - acc: 0.9305 - val_loss: 0.6576 - val_acc: 0.6257
# Epoch 7/10
# 173/173 [==============================] - 1s 5ms/step - loss: 0.1905 - acc: 0.9534 - val_loss: 0.6442 - val_acc: 0.6669
# Epoch 8/10
# 173/173 [==============================] - 1s 7ms/step - loss: 0.1450 - acc: 0.9655 - val_loss: 0.6441 - val_acc: 0.6756
# Epoch 9/10
# 173/173 [==============================] - 1s 6ms/step - loss: 0.1100 - acc: 0.9756 - val_loss: 0.6515 - val_acc: 0.6806
# Epoch 10/10
# 173/173 [==============================] - 1s 6ms/step - loss: 0.0846 - acc: 0.9818 - val_loss: 0.7129 - val_acc: 0.6604

# %% [markdown]
# #### Save preprocessor function to local "preprocessor.zip" file

# %%
import aimodelshare as ai
ai.export_preprocessor(preprocessor,"")
# Out:
# Your preprocessor is now saved to 'preprocessor.zip'

# %% [markdown]
# #### Save model to local ".onnx" file

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model = model_to_onnx(model, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %% [markdown]
# ## 4. Generate predictions from X_test data and submit model to competition

# %%
#Set credentials using modelshare.org username/password

from aimodelshare.aws import set_credentials
    
apiurl="https://rlxjxnoql9.execute-api.us-east-1.amazonaws.com/prod/m" #This is the unique rest api that powers this specific Playground

set_credentials(apiurl=apiurl)
# Out:
# AI Modelshare Username:··········
# AI Modelshare Password:··········
# AI Model Share login credentials set successfully.

# %%
#Instantiate Competition

mycompetition= ai.Competition(apiurl)

# %%
#Submit Model 1: 

#-- Generate predicted y values (Model 1)
#Note: Keras predict returns the predicted column index location for classification models
prediction_column_index=model.predict(preprocessor(X_test)).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

# Submit Model 1 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# 57/57 [==============================] - 0s 1ms/step
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 12
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:2763

# %%
# Get leaderboard to explore current best model architectures

# Get raw data in pandas data frame
data = mycompetition.get_leaderboard()

# Stylize leaderboard data
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_32f02_row0_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 76.7%, transparent 76.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_32f02_row0_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 76.5%, transparent 76.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_32f02_row0_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 77.9%, transparent 77.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_32f02_row0_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 76.7%, transparent 76.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_32f02_row0_col4, #T_32f02_row0_col5, #T_32f02_row0_col6, #T_32f02_row0_col7, #T_32f02_row0_col8, #T_32f02_row0_col9, #T_32f02_row0_col10, #T_32f02_row0_col11, #T_32f02_row0_col12, #T_32f02_row0_col13, #T_32f02_row0_col14, #T_32f02_row0_col15, #T_32f02_row0_col16, #T_32f02_row0_col17, #T_32f02_row0_col18, #T_32f02_row0_col19, #T_32f02_row1_col4, #T_32f02_row1_col5, #T_32f02_row1_col6, #T_32f02_row1_col7, #T_32f02_row1_col8, #T_32f02_row1_col9, #T_32f02_row1_col10, #T_32f02_row1_col11, #T_32f02_row1_col12, #T_32f02_row1_col13, #T_32f02_row1_col14, #T_32f02_row1_col15, #T_32f02_row1_col16, #T_32f02_row1_col17, #T_32f02_row1_col18, #T_32f02_row1_col19, #T_32f02_row2_col4, #T_32f02_row2_col5, #T_32f02_row2_col6, #T_32f02_row2_col7, #T_32f02_row2_col8, #T_32f02_row2_col9, #T_32f02_row2_col10, #T_32f02_row2_col11, #T_32f02_row2_col12, #T_32f02_row2_col13, #T_32f02_row2_col14, #T_32f02_row2_col15, #T_32f02_row2_col16, #T_32f02_row2_col17, #T_32f02_row2_col18, #T_32f02_row2_col19, #T_32f02_row3_col4, #T_32f02_row3_col5, #T_32f02_row3_col6, #T_32f02_row3_col7, #T_32f02_row3_col8, #T_32f02_row3_col9, #T_32f02_row3_col10, #T_32f02_row3_col11, #T_32f02_row3_col12, #T_32f02_row3_col13, #T_32f02_row3_col14, #T_32f02_row3_col15, #T_32f02_row3_col16, #T_32f02_row3_col17, #T_32f02_row3_col18, #T_32f02_row3_col19, #T_32f02_row4_col4, #T_32f02_row4_col5, #T_32f02_row4_col6, #T_32f02_row4_col7, #T_32f02_row4_col8, #T_32f02_row4_col9, #T_32f02_row4_col10, #T_32f02_row4_col11, #T_32f02_row4_col12, #T_32f02_row4_col13, #T_32f02_row4_col14, #T_32f02_row4_col15, #T_32f02_row4_col16, #T_32f02_row4_col17, #T_32f02_row4_col18, #T_32f02_row4_col19, #T_32f02_row5_col4, #T_32f02_row5_col5, #T_32f02_row5_col6, #T_32f02_row5_col7, #T_32f02_row5_col8, #T_32f02_row5_col9, #T_32f02_row5_col10, #T_32f02_row5_col11, #T_32f02_row5_col12, #T_32f02_row5_col13, #T_32f02_row5_col14, #T_32f02_row5_col15, #T_32f02_row5_col16, #T_32f02_row5_col17, #T_32f02_row5_col18, #T_32f02_row5_col19, #T_32f02_row6_col4, #T_32f02_row6_col5, #T_32f02_row6_col6, #T_32f02_row6_col7, #T_32f02_row6_col8, #T_32f02_row6_col9, #T_32f02_row6_col10, #T_32f02_row6_col11, #T_32f02_row6_col12, #T_32f02_row6_col13, #T_32f02_row6_col14, #T_32f02_row6_col15, #T_32f02_row6_col16, #T_32f02_row6_col17, #T_32f02_row6_col18, #T_32f02_row6_col19, #T_32f02_row7_col4, #T_32f02_row7_col5, #T_32f02_row7_col6, #T_32f02_row7_col7, #T_32f02_row7_col8, #T_32f02_row7_col9, #T_32f02_row7_col10, #T_32f02_row7_col11, #T_32f02_row7_col12, #T_32f02_row7_col13, #T_32f02_row7_col14, #T_32f02_row7_col15, #T_32f02_row7_col16, #T_32f02_row7_col17, #T_32f02_row7_col18, #T_32f02_row7_col19, #T_32f02_row8_col4, #T_32f02_row8_col5, #T_32f02_row8_col6, #T_32f02_row8_col7, #T_32f02_row8_col8, #T_32f02_row8_col9, #T_32f02_row8_col10, #T_32f02_row8_col11, #T_32f02_row8_col12, #T_32f02_row8_col13, #T_32f02_row8_col14, #T_32f02_row8_col15, #T_32f02_row8_col16, #T_32f02_row8_col17, #T_32f02_row8_col18, #T_32f02_row8_col19, #T_32f02_row9_col4, #T_32f02_row9_col5, #T_32f02_row9_col6, #T_32f02_row9_col7, #T_32f02_row9_col8, #T_32f02_row9_col9, #T_32f02_row9_col10, #T_32f02_row9_col11, #T_32f02_row9_col12, #T_32f02_row9_col13, #T_32f02_row9_col14, #T_32f02_row9_col15, #T_32f02_row9_col16, #T_32f02_row9_col17, #T_32f02_row9_col18, #T_32f02_row9_col19, #T_32f02_row10_col4, #T_32f02_row10_col5, #T_32f02_row10_col6, #T_32f02_row10_col7, #T_32f02_row10_col8, #T_32f02_row10_col9, #T_32f02_row10_col10, #T_32f02_row10_col11, #T_32f02_row10_col12, #T_32f02_row10_col13, #T_32f02_row10_col14, #T_32f02_row10_col15, #T_32f02_row10_col16, #T_32f02_row10_col17, #T_32f02_row10_col18, #T_32f02_row10_col19, #T_32f02_row11_col4, #T_32f02_row11_col5, #T_32f02_row11_col6, #T_32f02_row11_col7, #T_32f02_row11_col8, #T_32f02_row11_col9, #T_32f02_row11_col10, #T_32f02_row11_col11, #T_32f02_row11_col12, #T_32f02_row11_col13, #T_32f02_row11_col14, #T_32f02_row11_col15, #T_32f02_row11_col16, #T_32f02_row11_col17, #T_32f02_row11_col18, #T_32f02_row11_col19 {
#   text-align: center;
# }
# #T_32f02_row1_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 75.7%, transparent 75.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_32f02_row1_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 75.3%, transparent 75.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_32f02_row1_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 77.8%, transparent 77.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_32f02_row1_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 75.8%, transparent 75.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_32f02_row2_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 71.0%, transparent 71.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_32f02_row2_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 71.0%, transparent 71.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_32f02_row2_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 71.0%, transparent 71.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_32f02_row2_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 71.0%, transparent 71.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_32f02_row3_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 68.8%, transparent 68.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_32f02_row3_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 68.6%, transparent 68.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_32f02_row3_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 69.5%, transparent 69.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_32f02_row3_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 68.8%, transparent 68.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_32f02_row4_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 61.9%, transparent 61.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_32f02_row4_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 59.3%, transparent 59.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_32f02_row4_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 66.1%, transparent 66.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_32f02_row4_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 61.9%, transparent 61.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_32f02_row5_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 53.7%, transparent 53.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_32f02_row5_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 41.2%, transparent 41.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_32f02_row5_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 74.6%, transparent 74.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_32f02_row5_col3 {
#   text-align: center;
#   width: 10em;
#   background:

# %% [markdown]
# ## 5. Repeat submission process to improve place on leaderboard

# %%
# Train and submit model 2 using same preprocessor (note that you could save a new preprocessor, but we will use the same one for this example).
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, LSTM, Flatten

model2 = Sequential()
model2.add(Embedding(10000, 16, input_length=40))
model2.add(LSTM(32, return_sequences=True, dropout=0.2))
model2.add(LSTM(32, dropout=0.2))
model2.add(Flatten())
model2.add(Dense(2, activation='softmax'))

model2.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history = model2.fit(preprocessor(X_train), y_train,
                    epochs=1,
                    batch_size=32,
                    validation_split=0.2)
# Out:
# 173/173 [==============================] - 8s 26ms/step - loss: 0.6538 - acc: 0.6198 - val_loss: 0.7307 - val_acc: 0.5462

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model = model_to_onnx(model2, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("model2.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Submit Model 2: 

#-- Generate predicted y values (Model 2)
prediction_column_index=model2.predict(preprocessor(X_test)).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

# Submit Model 2 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model2.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# 57/57 [==============================] - 1s 7ms/step
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 2
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:2763

# %%
# Compare two or more models 
data=mycompetition.compare_models([1, 2], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style type="text/css">
# #T_e079e caption {
#   color: black;
#   font-size: 18px;
# }
# #T_e079e_row0_col0, #T_e079e_row0_col3 {
#   background: #b3e2cd;
#   color: black;
#   color: black;
# }
# #T_e079e_row0_col1, #T_e079e_row0_col2, #T_e079e_row0_col4, #T_e079e_row0_col5, #T_e079e_row1_col1, #T_e079e_row1_col2, #T_e079e_row1_col4, #T_e079e_row1_col5, #T_e079e_row2_col1, #T_e079e_row2_col2, #T_e079e_row2_col4, #T_e079e_row2_col5, #T_e079e_row3_col0, #T_e079e_row3_col1, #T_e079e_row3_col2, #T_e079e_row3_col4, #T_e079e_row3_col5, #T_e079e_row4_col0, #T_e079e_row4_col1, #T_e079e_row4_col2, #T_e079e_row4_col4, #T_e079e_row4_col5 {
#   background: white;
#   color: black;
#   color: black;
# }
# #T_e079e_row1_col0, #T_e079e_row3_col3 {
#   background: nan;
#   color: black;
#   color: black;
# }
# #T_e079e_row1_col3, #T_e079e_row2_col3 {
#   background: #f1e2cc;
#   color: black;
#   color: black;
# }
# #T_e079e_row2_col0, #T_e079e_row4_col3 {
#   background: #fff2ae;
#   color: black;
#   color: black;
# }
# </style>
# <table id="T_e079e">
#   <caption>Model type: Neural Network</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e079e_level0_col0" class="col_heading level0 col0" >Model_1_Layer</th>
#       <th id="T_e079e_level0_col1" class="col_heading level0 col1" >Model_1_Shape</th>
#       <th id="T_e079e_level0_col2" class="col_heading level0 col2" >Model_1_Params</th>
#       <th id="T_e079e_level0_col3" class="col_heading level0 col3" >Model_2_Layer</th>
#       <th id="T_e079e_level0_col4" class="col_heading level0 col4" >Model_2_Shape</th>
#       <th id="T_e079e_level0_col5" class="col_heading level0 col5" >Model_2_Params</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e079e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e079e_row0_col0" class="data row0 col0" >Embedding</td>
#       <td id="T_e079e_row0_col1" class="data row0 col1" >[None, 40, 16]</td>
#       <td id="T_e079e_row0_col2" class="data row0 col2" >160000.000000</td>
#       <td id="T_e079e_row0_col3" class="data row0 col3" >Embedding</td>
#       <td id="T_e079e_row0_col4" class="data row0 col4" >[None, 40, 16]</td>
#       <td id="T_e079e_row0_col5" class="data row0 col5" >160000</td>
#     </tr>
#     <tr>
#       <th id="T_e079e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e079e_row1_col0" class="data row1 col0" >Flatten</td>
#       <td id="T_e079e_row1_col1" class="data row1 col1" >[None, 640]</td>
#       <td id="T_e079e_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_e079e_row1_col3" class="data row1 col3" >LSTM</td>
#       <td id="T_e079e_row1_col4" class="data row1 col4" >[None, 40, 32]</td>
#       <td id="T_e079e_row1_col5" class="data row1 col5" >6272</td>
#     </tr>
#     <tr>
#       <th id="T_e079e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e079e_row2_col0" class="data row2 col0" >Dense</td>
#       <td id="T_e079e_row2_col1" class="data row2 col1" >[None, 2]</td>
#       <td id="T_e079e_row2_col2" class="data row2 col2" >1282.000000</td>
#       <td id="T_e079e_row2_col3" class="data row2 col3" >LSTM</td>
#       <td id="T_e079e_row2_col4" class="data row2 col4" >[None, 32]</td>
#       <td id="T_e079e_row2_col5" class="data row2 col5" >8320</td>
#     </tr>
#     <tr>
#       <th id="T_e079e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e079e_row3_col0" class="data row3 col0" >None</td>
#       <td id="T_e079e_row3_col1" class="data row3 col1" >None</td>
#       <td id="T_e079e_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_e079e_row3_col3" class="data row3 col3" >Flatten</td>
#       <td id="T_e079e_row3_col4" class="data row3 col4" >[None, 32]</td>
#       <td id="T_e079e_row3_col5" class="data row3 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e079e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e079e_row4_col0" class="data row4 col0" >None</td>
#       <td id="T_e079e_row4_col1" class="data row4 col1" >None</td>
#       <td id="T_e079e_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_e079e_row4_col3" class="data row4 col3" >Dense</td>
#       <td id="T_e079e_row4_col4" class="data row4 col4" >[None, 2]</td>
#       <td id="T_e079e_row4_col5" class="data row4 col5" >66</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Optional: Tune model within range of hyperparameters with Keras Tuner
#
# *Simple example shown below. Consult [documentation](https://keras.io/guides/keras_tuner/getting_started/) to see full functionality.*

# %%
! pip install keras_tuner

# %%
#Separate validation data 
from sklearn.model_selection import train_test_split
x_train_split, x_val, y_train_split, y_val = train_test_split(
     X_train, y_train, test_size=0.2, random_state=42)

# %%
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, LSTM, Flatten
import keras_tuner as kt

#Define model structure & parameter search space with function
def build_model(hp):
    model = keras.Sequential()
    model.add(Embedding(10000, 16, input_length=40))
    model.add(LSTM(units=hp.Int("units", min_value=32, max_value=512, step=32), #range 32-512 inclusive, minimum step between tested values is 32
                   return_sequences=True, dropout=0.2, recurrent_dropout=0.2))
    model.add(Flatten())
    model.add(Dense(2, activation='softmax'))
    model.compile(
        optimizer="rmsprop", loss="binary_crossentropy", metrics=["accuracy"],
    )
    return model

#initialize the tuner (which will search through parameters)
tuner = kt.RandomSearch(
    hypermodel=build_model, 
    objective="val_accuracy", # objective to optimize
    max_trials=3, #max number of trials to run during search
    executions_per_trial=1, #higher number reduces variance of results; guages model performance more accurately 
    overwrite=True,
    directory="tuning_model",
    project_name="tuning_units",
)

tuner.search(preprocessor(x_train_split), y_train_split, epochs=1, validation_data=(preprocessor(x_val), y_val))
# Out:
# Trial 3 Complete [00h 00m 08s]
# val_accuracy: 0.6748554706573486
#
# Best val_accuracy So Far: 0.6849710941314697
# Total elapsed time: 00h 01m 45s

# %%
# Build model with best hyperparameters

# Get the top 2 hyperparameters.
best_hps = tuner.get_best_hyperparameters(5)
# Build the model with the best hp.
tuned_model = build_model(best_hps[0])
# Fit with the entire dataset.
tuned_model.fit(x=preprocessor(X_train), y=y_train, epochs=1)
# Out:
# 217/217 [==============================] - 67s 298ms/step - loss: 0.6752 - accuracy: 0.5908

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model = model_to_onnx(tuned_model, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("tuned_model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Submit Model 3: 

#-- Generate predicted y values (Model 3)
prediction_column_index=tuned_model.predict(preprocessor(X_test)).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

# Submit Model 1 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "tuned_model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# 57/57 [==============================] - 3s 46ms/step
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 3
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:2763

# %%
# Get leaderboard

data = mycompetition.get_leaderboard()
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_bb6b6_row0_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 76.7%, transparent 76.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb6b6_row0_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 76.5%, transparent 76.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb6b6_row0_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 77.9%, transparent 77.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb6b6_row0_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 76.7%, transparent 76.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb6b6_row0_col4, #T_bb6b6_row0_col5, #T_bb6b6_row0_col6, #T_bb6b6_row0_col7, #T_bb6b6_row0_col8, #T_bb6b6_row0_col9, #T_bb6b6_row0_col10, #T_bb6b6_row0_col11, #T_bb6b6_row0_col12, #T_bb6b6_row0_col13, #T_bb6b6_row0_col14, #T_bb6b6_row0_col15, #T_bb6b6_row0_col16, #T_bb6b6_row0_col17, #T_bb6b6_row0_col18, #T_bb6b6_row0_col19, #T_bb6b6_row0_col20, #T_bb6b6_row1_col4, #T_bb6b6_row1_col5, #T_bb6b6_row1_col6, #T_bb6b6_row1_col7, #T_bb6b6_row1_col8, #T_bb6b6_row1_col9, #T_bb6b6_row1_col10, #T_bb6b6_row1_col11, #T_bb6b6_row1_col12, #T_bb6b6_row1_col13, #T_bb6b6_row1_col14, #T_bb6b6_row1_col15, #T_bb6b6_row1_col16, #T_bb6b6_row1_col17, #T_bb6b6_row1_col18, #T_bb6b6_row1_col19, #T_bb6b6_row1_col20, #T_bb6b6_row2_col4, #T_bb6b6_row2_col5, #T_bb6b6_row2_col6, #T_bb6b6_row2_col7, #T_bb6b6_row2_col8, #T_bb6b6_row2_col9, #T_bb6b6_row2_col10, #T_bb6b6_row2_col11, #T_bb6b6_row2_col12, #T_bb6b6_row2_col13, #T_bb6b6_row2_col14, #T_bb6b6_row2_col15, #T_bb6b6_row2_col16, #T_bb6b6_row2_col17, #T_bb6b6_row2_col18, #T_bb6b6_row2_col19, #T_bb6b6_row2_col20 {
#   text-align: center;
# }
# #T_bb6b6_row1_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 71.0%, transparent 71.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb6b6_row1_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 71.0%, transparent 71.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb6b6_row1_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 71.0%, transparent 71.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb6b6_row1_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 71.0%, transparent 71.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb6b6_row2_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 68.8%, transparent 68.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb6b6_row2_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 68.6%, transparent 68.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb6b6_row2_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 69.5%, transparent 69.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_bb6b6_row2_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 68.8%, transparent 68.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# </style>
# <table id="T_bb6b6_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >accuracy</th>
#       <th class="col_heading level0 col1" >f1_score</th>
#       <th class="col_heading level0 col2" >precision</th>
#       <th class="col_heading level0 col3" >recall</th>
#       <th class="col_heading level0 col4" >ml_framework</th>
#       <th class="col_heading level0 col5" >transfer_learning</th>
#       <th class="col_heading level0 col6" >deep_learning</th>
#       <th class="col_heading level0 col7" >model_type</th>
#       <th class="col_heading level0 col8" >depth</th>
#       <th class="col_heading level0 col9" >num_params</th>
#       <th class="col_heading level0 col10" >embedding_layers</th>
#       <th class="col_heading level0 col11" >flatten_layers</th>
#       <th class="col_heading level0 col12" >lstm_layers</th>
#       <th class="col_heading level0 col13" >dense_layers</th>
#       <th class="col_heading level0 col14" >softmax_act</th>
#       <th class="col_heading level0 col15" >tanh_act</th>
#       <th class="col_heading level0 col16" >loss</th>
#       <th class="col_heading level0 col17" >optimizer</th>
#       <th class="col_heading level0 col18" >memory_size</th>
#       <th class="col_heading level0 col19" >username</th>
#       <th class="col_heading level0 col20" >version</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb6b6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bb6b6_row0_col0" class="data row0 col0" >76.73%</td>
#       <td id="T_bb6b6_row0_col1" class="data row0 col1" >76.48%</td>
#       <td id="T_bb6b6_row0_col2" class="data row0 col2" >77.92%</td>
#       <td id="T_bb6b6_row0_col3" class="data row0 col3" >76.74%</td>
#       <td id="T_bb6b6_row0_col4" class="data row0 col4" >keras</td>
#       <td id="T_bb6b6_row0_col5" class="data row0 col5" >False</td>
#       <td id="T_bb6b6_row0_col6" class="data row0 col6" >True</td>
#       <td id="T_bb6b6_row0_col7" class="data row0 col7" >Sequential</td>
#       <td id="T_bb6b6_row0_col8" class="data row0 col8" >3</td>
#       <td id="T_bb6b6_row0_col9" class="data row0 col9" >161282</td>
#       <td id="T_bb6b6_row0_col10" class="data row0 col10" >1</td>
#       <td id="T_bb6b6_row0_col11" class="data row0 col11" >1</td>
#       <td id="T_bb6b6_row0_col12" class="data row0 col12" >nan</td>
#       <td id="T_bb6b6_row0_col13" class="data row0 col13" >1</td>
#       <td id="T_bb6b6_row0_col14" class="data row0 col14" >1</td>
#       <td id="T_bb6b6_row0_col15" class="data row0 col15" >nan</td>
#       <td id="T_bb6b6_row0_col16" class="data row0 col16" >str</td>
#       <td id="T_bb6b6_row0_col17" class="data row0 col17" >RMSprop</td>
#       <td id="T_bb6b6_row0_col18" class="data row0 col18" >645576</td>
#       <td id="T_bb6b6_row0_col19" class="data row0 col19" >AIModelShare</td>
#       <td id="T_bb6b6_row0_col20" class="data row0 col20" >1</td>
#     </tr>
#     <tr>
#       <th id="T_bb6b6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bb6b6_row1_col0" class="data row1 col0" >71.02%</td>
#       <td id="T_bb6b6_row1_col1" class="data row1 col1" >71.02%</td>
#       <td id="T_bb6b6_row1_col2" class="data row1 col2" >71.03%</td>
#       <td id="T_bb6b6_row1_col3" class="data row1 col3" >71.02%</td>
#       <td id="T_bb6b6_row1_col4" class="data row1 col4" >keras</td>
#       <td id="T_bb6b6_row1_col5" class="data row1 col5" >False</td>
#       <td id="T_bb6b6_row1_col6" class="data row1 col6" >True</td>
#       <td id="T_bb6b6_row1_col7" class="data row1 col7" >Sequential</td>
#       <td id="T_bb6b6_row1_col8" class="data row1 col8" >4</td>
#       <td id="T_bb6b6_row1_col9" class="data row1 col9" >460034</td>
#       <td id="T_bb6b6_row1_col10" class="data row1 col10" >1</td>
#       <td id="T_bb6b6_row1_col11" class="data row1 col11" >1</td>
#       <td id="T_bb6b6_row1_col12" class="data row1 col12" >1.000000</td>
#       <td id="T_bb6b6_row1_col13" class="data row1 col13" >1</td>
#       <td id="T_bb6b6_row1_col14" class="data row1 col14" >1</td>
#       <td id="T_bb6b6_row1_col15" class="data row1 col15" >1.000000</td>
#       <td id="T_bb6b6_row1_col16" class="data row1 col16" >str</td>
#       <td id="T_bb6b6_row1_col17" class="data row1 col17" >RMSprop</td>
#       <td id="T_bb6b6_row1_col18" class="data row1 col18" >1840960</td>
#       <td id="T_bb6b6_row1_col19" class="data row1 col19" >AIModelShare</td>
#       <td id="T_bb6b6_row1_col20" class="data row1 col20" >3</td>
#     </tr>
#     <tr>
#       <th id="T_bb6b6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bb6b6_row2_col0" class="data row2 col0" >68.83%</td>
#       <td id="T_bb6b6_row2_col1" class="data row2 col1" >68.55%</td>
#       <td i

# %%
# Compare two or more models
data=mycompetition.compare_models([1, 2, 3], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style type="text/css">
# #T_0d508_ caption {
#   color: black;
#   font-size: 18px;
# }
# #T_0d508_row0_col0, #T_0d508_row0_col3, #T_0d508_row0_col6 {
#   background: #b3e2cd;
#   color: black;
#   color: black;
# }
# #T_0d508_row0_col1, #T_0d508_row0_col2, #T_0d508_row0_col4, #T_0d508_row0_col5, #T_0d508_row0_col7, #T_0d508_row0_col8, #T_0d508_row1_col1, #T_0d508_row1_col2, #T_0d508_row1_col4, #T_0d508_row1_col5, #T_0d508_row1_col7, #T_0d508_row1_col8, #T_0d508_row2_col1, #T_0d508_row2_col2, #T_0d508_row2_col4, #T_0d508_row2_col5, #T_0d508_row2_col7, #T_0d508_row2_col8, #T_0d508_row3_col0, #T_0d508_row3_col1, #T_0d508_row3_col2, #T_0d508_row3_col4, #T_0d508_row3_col5, #T_0d508_row3_col7, #T_0d508_row3_col8, #T_0d508_row4_col0, #T_0d508_row4_col1, #T_0d508_row4_col2, #T_0d508_row4_col4, #T_0d508_row4_col5, #T_0d508_row4_col6, #T_0d508_row4_col7, #T_0d508_row4_col8 {
#   background: white;
#   color: black;
#   color: black;
# }
# #T_0d508_row1_col0, #T_0d508_row2_col6, #T_0d508_row3_col3 {
#   background: nan;
#   color: black;
#   color: black;
# }
# #T_0d508_row1_col3, #T_0d508_row1_col6, #T_0d508_row2_col3 {
#   background: #f1e2cc;
#   color: black;
#   color: black;
# }
# #T_0d508_row2_col0, #T_0d508_row3_col6, #T_0d508_row4_col3 {
#   background: #fff2ae;
#   color: black;
#   color: black;
# }
# </style>
# <table id="T_0d508_">
#   <caption>Model type: Neural Network</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model_1_Layer</th>
#       <th class="col_heading level0 col1" >Model_1_Shape</th>
#       <th class="col_heading level0 col2" >Model_1_Params</th>
#       <th class="col_heading level0 col3" >Model_2_Layer</th>
#       <th class="col_heading level0 col4" >Model_2_Shape</th>
#       <th class="col_heading level0 col5" >Model_2_Params</th>
#       <th class="col_heading level0 col6" >Model_3_Layer</th>
#       <th class="col_heading level0 col7" >Model_3_Shape</th>
#       <th class="col_heading level0 col8" >Model_3_Params</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d508_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0d508_row0_col0" class="data row0 col0" >Embedding</td>
#       <td id="T_0d508_row0_col1" class="data row0 col1" >[None, 40, 16]</td>
#       <td id="T_0d508_row0_col2" class="data row0 col2" >160000.000000</td>
#       <td id="T_0d508_row0_col3" class="data row0 col3" >Embedding</td>
#       <td id="T_0d508_row0_col4" class="data row0 col4" >[None, 40, 16]</td>
#       <td id="T_0d508_row0_col5" class="data row0 col5" >160000</td>
#       <td id="T_0d508_row0_col6" class="data row0 col6" >Embedding</td>
#       <td id="T_0d508_row0_col7" class="data row0 col7" >[None, 40, 16]</td>
#       <td id="T_0d508_row0_col8" class="data row0 col8" >160000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0d508_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0d508_row1_col0" class="data row1 col0" >Flatten</td>
#       <td id="T_0d508_row1_col1" class="data row1 col1" >[None, 640]</td>
#       <td id="T_0d508_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_0d508_row1_col3" class="data row1 col3" >LSTM</td>
#       <td id="T_0d508_row1_col4" class="data row1 col4" >[None, 40, 32]</td>
#       <td id="T_0d508_row1_col5" class="data row1 col5" >6272</td>
#       <td id="T_0d508_row1_col6" class="data row1 col6" >LSTM</td>
#       <td id="T_0d508_row1_col7" class="data row1 col7" >[None, 40, 256]</td>
#       <td id="T_0d508_row1_col8" class="data row1 col8" >279552.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0d508_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0d508_row2_col0" class="data row2 col0" >Dense</td>
#       <td id="T_0d508_row2_col1" class="data row2 col1" >[None, 2]</td>
#       <td id="T_0d508_row2_col2" class="data row2 col2" >1282.000000</td>
#       <td id="T_0d508_row2_col3" class="data row2 col3" >LSTM</td>
#       <td id="T_0d508_row2_col4" class="data row2 col4" >[None, 32]</td>
#       <td id="T_0d508_row2_col5" class="data row2 col5" >8320</td>
#       <td id="T_0d508_row2_col6" class="data row2 col6" >Flatten</td>
#       <td id="T_0d508_row2_col7" class="data row2 col7" >[None, 10240]</td>
#       <td id="T_0d508_row2_col8" class="data row2 col8" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0d508_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0d508_row3_col0" class="data row3 col0" >None</td>
#       <td id="T_0d508_row3_col1" class="data row3 col1" >None</td>
#       <td id="T_0d508_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_0d508_row3_col3" class="data row3 col3" >Flatten</td>
#       <td id="T_0d508_row3_col4" class="data row3 col4" >[None, 32]</td>
#       <td id="T_0d508_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_0d508_row3_col6" class="data row3 col6" >Dense</td>
#       <td id="T_0d508_row3_col7" class="data row3 col7" >[None, 2]</td>
#       <td id="T_0d508_row3_col8" class="data row3 col8" >20482.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0d508_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0d508_row4_col0" class="data row4 col0" >None</td>
#       <td id="T_0d508_row4_col1" class="data row4 col1" >None</td>
#       <td id="T_0d508_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_0d508_row4_col3" class="data row4 col3" >Dense</td>
#       <td id="T_0d508_row4_col4" class="data row4 col4" >[None, 2]</td>
#       <td id="T_0d508_row4_col5" class="data row4 col5" >66</td>
#       <td id="T_0d508_row4_col6" class="data row4 col6" >None</td>
#       <td id="T_0d508_row4_col7" class="data row4 col7" >None</td>
#       <td id="T_0d508_row4_col8" class="data row4 col8" >nan</td>
#     </tr>
#   </tbody>
# </table>
