# %% [markdown]
# <p align="center"><img width="50%" src="https://aimodelsharecontent.s3.amazonaws.com/aimodshare_banner.jpg" /></p>
#
#
# ---

# %% [markdown]
# ## Stanford Sentiment Treebank - Movie Review Classification Competition
# Let's share our models to a centralized leaderboard, so that we can collaborate and learn from the model experimentation process...
#
# **Instructions:**
# 1.   Get data in and set up X_train / X_test / y_train
# 2.   Preprocess data using Sklearn TFIDF Vectorizer/ Write and Save Preprocessor function
# 3. Fit model on preprocessed data and save preprocessor function and model
# 4. Generate predictions from X_test data and submit model to competition
# 5. Repeat submission process to improve place on leaderboard

# %% [markdown]
# ## 1. Get data in and set up X_train, X_test, y_train objects

# %%
#install aimodelshare library
! pip install aimodelshare==0.0.189

# %%
# Get competition data
from aimodelshare import download_data
download_data('public.ecr.aws/y2e2a1d6/sst2_competition_data-repository:latest')
# Out:
# Downloading [=============================================>   ]
#
# Data downloaded successfully.

# %%
# Set up X_train, X_test, and y_train_labels objects
import pandas as pd
import warnings
warnings.simplefilter(action='ignore', category=Warning)

X_train=pd.read_csv("sst2_competition_data/X_train.csv", squeeze=True)
X_test=pd.read_csv("sst2_competition_data/X_test.csv", squeeze=True)

y_train_labels=pd.read_csv("sst2_competition_data/y_train_labels.csv", squeeze=True)

X_train.head()
# Out:
# 0    The Rock is destined to be the 21st Century 's...
# 1    The gorgeously elaborate continuation of `` Th...
# 2    Singer/composer Bryan Adams contributes a slew...
# 3                 Yet the act is still charming here .
# 4    Whether or not you 're enlightened by any of D...
# Name: text, dtype: object

# %% [markdown]
# ##2.   Preprocess data using Sklearn Tfidf Vectorizer / Write and Save Preprocessor function

# %%
# Build a Document-Term Matrix (DTM) out of words in the training set 
# Remove stop words that occur too frequently to be useful, and 
# Use Term Frequency - Inverse Document Frequency (TF-IDF) formula to weight by how common words are generally

from sklearn.feature_extraction.text import TfidfVectorizer
tf_idf_vectorizer = TfidfVectorizer(stop_words='english')
tfidf_simple = tf_idf_vectorizer.fit(X_train)

# %%
# Write function to transform data with preprocessor 
# New samples will be put into a DTM based on vocabularly from training set

def preprocessor(data):
  from sklearn.feature_extraction.text import TfidfVectorizer
  import numpy as np
  new_tfidf_df = tfidf_simple.transform(data)
  new_tfidf_df = new_tfidf_df.todense()
  return np.array(new_tfidf_df)

print(preprocessor(X_train).shape)
print(preprocessor(X_test).shape)
# Out:
# (6920, 13504)
# (1821, 13504)

# %% [markdown]
# ##3. Fit model on preprocessed data and save preprocessor function and model

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, max_depth=3, random_state=0)
model.fit(preprocessor(X_train), y_train_labels) # Fitting to the training set.
model.score(preprocessor(X_train), y_train_labels) # Fit score, 0-1 scale.
# Out:
# 0.5393063583815029

# %% [markdown]
# #### Save preprocessor function to local "preprocessor.zip" file

# %%
import aimodelshare as ai
ai.export_preprocessor(preprocessor,"")
# Out:
# Your preprocessor is now saved to 'preprocessor.zip'

# %% [markdown]
# #### Save model to local ".onnx" file

# %%
# Save sklearn model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

# Check how many preprocessed input features are there?
from skl2onnx.common.data_types import FloatTensorType

feature_count=preprocessor(X_test).shape[1] #Get count of preprocessed features
initial_type = [('float_input', FloatTensorType([None, feature_count]))]  # Insert correct number of preprocessed features

onnx_model = model_to_onnx(model, framework='sklearn',
                          initial_types=initial_type,
                          transfer_learning=False,
                          deep_learning=False)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %% [markdown]
# ## 4. Generate predictions from X_test data and submit model to competition

# %%
#Set credentials using modelshare.org username/password

from aimodelshare.aws import set_credentials
    
apiurl="https://rlxjxnoql9.execute-api.us-east-1.amazonaws.com/prod/m" #This is the unique rest api that powers this Movie Review Playground

set_credentials(apiurl=apiurl)
# Out:
# AI Modelshare Username:··········
# AI Modelshare Password:··········
# AI Model Share login credentials set successfully.

# %%
#Instantiate Competition
import aimodelshare as ai
mycompetition= ai.Competition(apiurl)

# %%
#Submit Model 1: 

#-- Generate predicted values (a list of predicted labels "positive" or "negative") (Model 1)
prediction_labels = model.predict(preprocessor(X_test))

# Submit Model 1 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 11
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:2763

# %%
# Get leaderboard to explore current best model architectures

# Get raw data in pandas data frame
data = mycompetition.get_leaderboard()

# Stylize leaderboard data
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_152f8_row0_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 76.7%, transparent 76.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_152f8_row0_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 76.5%, transparent 76.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_152f8_row0_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 77.9%, transparent 77.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_152f8_row0_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 76.7%, transparent 76.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_152f8_row0_col4, #T_152f8_row0_col5, #T_152f8_row0_col6, #T_152f8_row0_col7, #T_152f8_row0_col8, #T_152f8_row0_col9, #T_152f8_row0_col10, #T_152f8_row0_col11, #T_152f8_row0_col12, #T_152f8_row0_col13, #T_152f8_row0_col14, #T_152f8_row0_col15, #T_152f8_row0_col16, #T_152f8_row0_col17, #T_152f8_row0_col18, #T_152f8_row0_col19, #T_152f8_row1_col4, #T_152f8_row1_col5, #T_152f8_row1_col6, #T_152f8_row1_col7, #T_152f8_row1_col8, #T_152f8_row1_col9, #T_152f8_row1_col10, #T_152f8_row1_col11, #T_152f8_row1_col12, #T_152f8_row1_col13, #T_152f8_row1_col14, #T_152f8_row1_col15, #T_152f8_row1_col16, #T_152f8_row1_col17, #T_152f8_row1_col18, #T_152f8_row1_col19, #T_152f8_row2_col4, #T_152f8_row2_col5, #T_152f8_row2_col6, #T_152f8_row2_col7, #T_152f8_row2_col8, #T_152f8_row2_col9, #T_152f8_row2_col10, #T_152f8_row2_col11, #T_152f8_row2_col12, #T_152f8_row2_col13, #T_152f8_row2_col14, #T_152f8_row2_col15, #T_152f8_row2_col16, #T_152f8_row2_col17, #T_152f8_row2_col18, #T_152f8_row2_col19, #T_152f8_row3_col4, #T_152f8_row3_col5, #T_152f8_row3_col6, #T_152f8_row3_col7, #T_152f8_row3_col8, #T_152f8_row3_col9, #T_152f8_row3_col10, #T_152f8_row3_col11, #T_152f8_row3_col12, #T_152f8_row3_col13, #T_152f8_row3_col14, #T_152f8_row3_col15, #T_152f8_row3_col16, #T_152f8_row3_col17, #T_152f8_row3_col18, #T_152f8_row3_col19, #T_152f8_row4_col4, #T_152f8_row4_col5, #T_152f8_row4_col6, #T_152f8_row4_col7, #T_152f8_row4_col8, #T_152f8_row4_col9, #T_152f8_row4_col10, #T_152f8_row4_col11, #T_152f8_row4_col12, #T_152f8_row4_col13, #T_152f8_row4_col14, #T_152f8_row4_col15, #T_152f8_row4_col16, #T_152f8_row4_col17, #T_152f8_row4_col18, #T_152f8_row4_col19, #T_152f8_row5_col4, #T_152f8_row5_col5, #T_152f8_row5_col6, #T_152f8_row5_col7, #T_152f8_row5_col8, #T_152f8_row5_col9, #T_152f8_row5_col10, #T_152f8_row5_col11, #T_152f8_row5_col12, #T_152f8_row5_col13, #T_152f8_row5_col14, #T_152f8_row5_col15, #T_152f8_row5_col16, #T_152f8_row5_col17, #T_152f8_row5_col18, #T_152f8_row5_col19, #T_152f8_row6_col4, #T_152f8_row6_col5, #T_152f8_row6_col6, #T_152f8_row6_col7, #T_152f8_row6_col8, #T_152f8_row6_col9, #T_152f8_row6_col10, #T_152f8_row6_col11, #T_152f8_row6_col12, #T_152f8_row6_col13, #T_152f8_row6_col14, #T_152f8_row6_col15, #T_152f8_row6_col16, #T_152f8_row6_col17, #T_152f8_row6_col18, #T_152f8_row6_col19, #T_152f8_row7_col4, #T_152f8_row7_col5, #T_152f8_row7_col6, #T_152f8_row7_col7, #T_152f8_row7_col8, #T_152f8_row7_col9, #T_152f8_row7_col10, #T_152f8_row7_col11, #T_152f8_row7_col12, #T_152f8_row7_col13, #T_152f8_row7_col14, #T_152f8_row7_col15, #T_152f8_row7_col16, #T_152f8_row7_col17, #T_152f8_row7_col18, #T_152f8_row7_col19, #T_152f8_row8_col4, #T_152f8_row8_col5, #T_152f8_row8_col6, #T_152f8_row8_col7, #T_152f8_row8_col8, #T_152f8_row8_col9, #T_152f8_row8_col10, #T_152f8_row8_col11, #T_152f8_row8_col12, #T_152f8_row8_col13, #T_152f8_row8_col14, #T_152f8_row8_col15, #T_152f8_row8_col16, #T_152f8_row8_col17, #T_152f8_row8_col18, #T_152f8_row8_col19, #T_152f8_row9_col4, #T_152f8_row9_col5, #T_152f8_row9_col6, #T_152f8_row9_col7, #T_152f8_row9_col8, #T_152f8_row9_col9, #T_152f8_row9_col10, #T_152f8_row9_col11, #T_152f8_row9_col12, #T_152f8_row9_col13, #T_152f8_row9_col14, #T_152f8_row9_col15, #T_152f8_row9_col16, #T_152f8_row9_col17, #T_152f8_row9_col18, #T_152f8_row9_col19, #T_152f8_row10_col4, #T_152f8_row10_col5, #T_152f8_row10_col6, #T_152f8_row10_col7, #T_152f8_row10_col8, #T_152f8_row10_col9, #T_152f8_row10_col10, #T_152f8_row10_col11, #T_152f8_row10_col12, #T_152f8_row10_col13, #T_152f8_row10_col14, #T_152f8_row10_col15, #T_152f8_row10_col16, #T_152f8_row10_col17, #T_152f8_row10_col18, #T_152f8_row10_col19 {
#   text-align: center;
# }
# #T_152f8_row1_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 71.0%, transparent 71.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_152f8_row1_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 71.0%, transparent 71.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_152f8_row1_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 71.0%, transparent 71.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_152f8_row1_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 71.0%, transparent 71.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_152f8_row2_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 68.8%, transparent 68.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_152f8_row2_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 68.6%, transparent 68.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_152f8_row2_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 69.5%, transparent 69.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_152f8_row2_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 68.8%, transparent 68.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_152f8_row3_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 61.9%, transparent 61.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_152f8_row3_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 59.3%, transparent 59.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_152f8_row3_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 66.1%, transparent 66.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_152f8_row3_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 61.9%, transparent 61.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_152f8_row4_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 53.7%, transparent 53.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_152f8_row4_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 41.2%, transparent 41.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_152f8_row4_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 74.6%, transparent 74.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_152f8_row4_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 53.7%, transparent 53.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_152f8_row5_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 54.7%, transparent 54.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_152f8_row5_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 44.0%, transparent 44.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_152f8_row5_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 70.1%, transparent 70.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_152f8_row5_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 54.7%, transparent 54.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_152f8_row6_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 51.6%, transparent 51.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_152f8_row6_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-g

# %% [markdown]
# ## 5. Repeat submission process to improve place on leaderboard

# %%
# Train and submit model 2 using same preprocessor (note that you could save a new preprocessor, but we will use the same one for this example).
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=500, max_depth=5, random_state=0)
model.fit(preprocessor(X_train), y_train_labels) # Fitting to the training set.
model.score(preprocessor(X_train), y_train_labels) # Fit score, 0-1 scale.
# Out:
# 0.5570809248554913

# %%
# Save sklearn model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

feature_count=preprocessor(X_test).shape[1] #Get count of preprocessed features
initial_type = [('float_input', FloatTensorType([None, feature_count]))]  # Insert correct number of preprocessed features

onnx_model = model_to_onnx(model, framework='sklearn',
                          initial_types=initial_type,
                          transfer_learning=False,
                          deep_learning=False)

with open("model2.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Submit Model 2: 

#-- Generate predicted values (a list of predicted labels "positive" or "negative") (Model 2)
prediction_labels = model.predict(preprocessor(X_test))

# Submit Model 2 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model2.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 5
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:2763

# %%
# Compare two or more models
data=mycompetition.compare_models([4, 5], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style type="text/css">
# #T_9a2db caption {
#   color: black;
#   font-size: 18px;
# }
# #T_9a2db_row4_col2, #T_9a2db_row4_col3, #T_9a2db_row13_col3, #T_9a2db_row16_col2, #T_9a2db_row16_col3 {
#   background: tomato;
# }
# </style>
# <table id="T_9a2db">
#   <caption>Model type: RandomForestClassifier</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9a2db_level0_col0" class="col_heading level0 col0" >param_name</th>
#       <th id="T_9a2db_level0_col1" class="col_heading level0 col1" >default_value</th>
#       <th id="T_9a2db_level0_col2" class="col_heading level0 col2" >model_version_4</th>
#       <th id="T_9a2db_level0_col3" class="col_heading level0 col3" >model_version_5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a2db_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9a2db_row0_col0" class="data row0 col0" >bootstrap</td>
#       <td id="T_9a2db_row0_col1" class="data row0 col1" >True</td>
#       <td id="T_9a2db_row0_col2" class="data row0 col2" >True</td>
#       <td id="T_9a2db_row0_col3" class="data row0 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9a2db_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9a2db_row1_col0" class="data row1 col0" >ccp_alpha</td>
#       <td id="T_9a2db_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_9a2db_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_9a2db_row1_col3" class="data row1 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9a2db_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9a2db_row2_col0" class="data row2 col0" >class_weight</td>
#       <td id="T_9a2db_row2_col1" class="data row2 col1" >None</td>
#       <td id="T_9a2db_row2_col2" class="data row2 col2" >None</td>
#       <td id="T_9a2db_row2_col3" class="data row2 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9a2db_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9a2db_row3_col0" class="data row3 col0" >criterion</td>
#       <td id="T_9a2db_row3_col1" class="data row3 col1" >gini</td>
#       <td id="T_9a2db_row3_col2" class="data row3 col2" >gini</td>
#       <td id="T_9a2db_row3_col3" class="data row3 col3" >gini</td>
#     </tr>
#     <tr>
#       <th id="T_9a2db_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9a2db_row4_col0" class="data row4 col0" >max_depth</td>
#       <td id="T_9a2db_row4_col1" class="data row4 col1" >None</td>
#       <td id="T_9a2db_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_9a2db_row4_col3" class="data row4 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_9a2db_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9a2db_row5_col0" class="data row5 col0" >max_features</td>
#       <td id="T_9a2db_row5_col1" class="data row5 col1" >auto</td>
#       <td id="T_9a2db_row5_col2" class="data row5 col2" >auto</td>
#       <td id="T_9a2db_row5_col3" class="data row5 col3" >auto</td>
#     </tr>
#     <tr>
#       <th id="T_9a2db_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9a2db_row6_col0" class="data row6 col0" >max_leaf_nodes</td>
#       <td id="T_9a2db_row6_col1" class="data row6 col1" >None</td>
#       <td id="T_9a2db_row6_col2" class="data row6 col2" >None</td>
#       <td id="T_9a2db_row6_col3" class="data row6 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9a2db_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9a2db_row7_col0" class="data row7 col0" >max_samples</td>
#       <td id="T_9a2db_row7_col1" class="data row7 col1" >None</td>
#       <td id="T_9a2db_row7_col2" class="data row7 col2" >None</td>
#       <td id="T_9a2db_row7_col3" class="data row7 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9a2db_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9a2db_row8_col0" class="data row8 col0" >min_impurity_decrease</td>
#       <td id="T_9a2db_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_9a2db_row8_col2" class="data row8 col2" >0.000000</td>
#       <td id="T_9a2db_row8_col3" class="data row8 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9a2db_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9a2db_row9_col0" class="data row9 col0" >min_impurity_split</td>
#       <td id="T_9a2db_row9_col1" class="data row9 col1" >None</td>
#       <td id="T_9a2db_row9_col2" class="data row9 col2" >None</td>
#       <td id="T_9a2db_row9_col3" class="data row9 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9a2db_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9a2db_row10_col0" class="data row10 col0" >min_samples_leaf</td>
#       <td id="T_9a2db_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_9a2db_row10_col2" class="data row10 col2" >1</td>
#       <td id="T_9a2db_row10_col3" class="data row10 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_9a2db_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9a2db_row11_col0" class="data row11 col0" >min_samples_split</td>
#       <td id="T_9a2db_row11_col1" class="data row11 col1" >2</td>
#       <td id="T_9a2db_row11_col2" class="data row11 col2" >2</td>
#       <td id="T_9a2db_row11_col3" class="data row11 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_9a2db_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9a2db_row12_col0" class="data row12 col0" >min_weight_fraction_leaf</td>
#       <td id="T_9a2db_row12_col1" class="data row12 col1" >0.000000</td>
#       <td id="T_9a2db_row12_col2" class="data row12 col2" >0.000000</td>
#       <td id="T_9a2db_row12_col3" class="data row12 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9a2db_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9a2db_row13_col0" class="data row13 col0" >n_estimators</td>
#       <td id="T_9a2db_row13_col1" class="data row13 col1" >100</td>
#       <td id="T_9a2db_row13_col2" class="data row13 col2" >100</td>
#       <td id="T_9a2db_row13_col3" class="data row13 col3" >500</td>
#     </tr>
#     <tr>
#       <th id="T_9a2db_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9a2db_row14_col0" class="data row14 col0" >n_jobs</td>
#       <td id="T_9a2db_row14_col1" class="data row14 col1" >None</td>
#       <td id="T_9a2db_row14_col2" class="data row14 col2" >None</td>
#       <td id="T_9a2db_row14_col3" class="data row14 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9a2db_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_9a2db_row15_col0" class="data row15 col0" >oob_score</td>
#       <td id="T_9a2db_row15_col1" class="data row15 col1" >False</td>
#       <td id="T_9a2db_row15_col2" class="data row15 col2" >False</td>
#       <td id="T_9a2db_row15_col3" class="data row15 col3" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9a2db_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_9a2db_row16_col0" class="data row16 col0" >random_state</td>
#       <td id="T_9a2db_row16_col1" class="data row16 col1" >None</td>
#       <td id="T_9a2db_row16_col2" class="data row16 col2" >0</td>
#       <td id="T_9a2db_row16_col3" class="data row16 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9a2db_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_9a2db_row17_col0" class="data row17 col0" >verbose</td>
#       <td id="T_9a2db_row17_col1" class="data row17 col1" >0</td>
#       <td id="T_9a2db_row17_col2" class="data row17 col2" >0</td>
#       <td id="T_9a2db_row17_col3" class="data row17 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9a2db_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_9a2db_row18_col0" class="data row18 col0" >warm_start</td>
#       <td id="T_9a2db_row18_col1" class="data row18 col1" >False</td>
#       <td id="T_9a2db_row18_col2" class="data row18 col2" >False</td>
#       <td id="T_9a2db_row18_col3" class="data row18 col3" >False</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Submit a third model using GridSearchCV

from sklearn.model_selection import GridSearchCV
import numpy as np

param_grid = {'n_estimators': np.arange(100, 300, 500),'max_depth':[1, 3, 5]} #np.arange creates sequence of numbers for each k value

gridmodel = GridSearchCV(RandomForestClassifier(), param_grid=param_grid, cv=10)

#use meta model methods to fit score and predict model:
gridmodel.fit(preprocessor(X_train), y_train_labels)

#extract best score and parameter by calling objects "best_score_" and "best_params_"
print("best mean cross-validation score: {:.3f}".format(gridmodel.best_score_))
print("best parameters: {}".format(gridmodel.best_params_))
# Out:
# best mean cross-validation score: 0.549
# best parameters: {'max_depth': 5, 'n_estimators': 100}

# %%
# Save sklearn model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx


feature_count=preprocessor(X_test).shape[1] #Get count of preprocessed features
initial_type = [('float_input', FloatTensorType([None, feature_count]))]  # Insert correct number of preprocessed features

onnx_model = model_to_onnx(gridmodel, framework='sklearn',
                          initial_types=initial_type,
                          transfer_learning=False,
                          deep_learning=False)

with open("gridmodel.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Submit Model 3: 

#-- Generate predicted values (a list of predicted labels "real" or "fake")
prediction_labels = gridmodel.predict(preprocessor(X_test))

# Submit Model 3 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "gridmodel.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 6
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:2763

# %%
# Get leaderboard

data = mycompetition.get_leaderboard()
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_89ee2_row0_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 76.7%, transparent 76.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_89ee2_row0_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 76.5%, transparent 76.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_89ee2_row0_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 77.9%, transparent 77.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_89ee2_row0_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 76.7%, transparent 76.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_89ee2_row0_col4, #T_89ee2_row0_col5, #T_89ee2_row0_col6, #T_89ee2_row0_col7, #T_89ee2_row0_col8, #T_89ee2_row0_col9, #T_89ee2_row0_col10, #T_89ee2_row0_col11, #T_89ee2_row0_col12, #T_89ee2_row0_col13, #T_89ee2_row0_col14, #T_89ee2_row0_col15, #T_89ee2_row0_col16, #T_89ee2_row0_col17, #T_89ee2_row0_col18, #T_89ee2_row0_col19, #T_89ee2_row0_col20, #T_89ee2_row1_col4, #T_89ee2_row1_col5, #T_89ee2_row1_col6, #T_89ee2_row1_col7, #T_89ee2_row1_col8, #T_89ee2_row1_col9, #T_89ee2_row1_col10, #T_89ee2_row1_col11, #T_89ee2_row1_col12, #T_89ee2_row1_col13, #T_89ee2_row1_col14, #T_89ee2_row1_col15, #T_89ee2_row1_col16, #T_89ee2_row1_col17, #T_89ee2_row1_col18, #T_89ee2_row1_col19, #T_89ee2_row1_col20, #T_89ee2_row2_col4, #T_89ee2_row2_col5, #T_89ee2_row2_col6, #T_89ee2_row2_col7, #T_89ee2_row2_col8, #T_89ee2_row2_col9, #T_89ee2_row2_col10, #T_89ee2_row2_col11, #T_89ee2_row2_col12, #T_89ee2_row2_col13, #T_89ee2_row2_col14, #T_89ee2_row2_col15, #T_89ee2_row2_col16, #T_89ee2_row2_col17, #T_89ee2_row2_col18, #T_89ee2_row2_col19, #T_89ee2_row2_col20, #T_89ee2_row3_col4, #T_89ee2_row3_col5, #T_89ee2_row3_col6, #T_89ee2_row3_col7, #T_89ee2_row3_col8, #T_89ee2_row3_col9, #T_89ee2_row3_col10, #T_89ee2_row3_col11, #T_89ee2_row3_col12, #T_89ee2_row3_col13, #T_89ee2_row3_col14, #T_89ee2_row3_col15, #T_89ee2_row3_col16, #T_89ee2_row3_col17, #T_89ee2_row3_col18, #T_89ee2_row3_col19, #T_89ee2_row3_col20, #T_89ee2_row4_col4, #T_89ee2_row4_col5, #T_89ee2_row4_col6, #T_89ee2_row4_col7, #T_89ee2_row4_col8, #T_89ee2_row4_col9, #T_89ee2_row4_col10, #T_89ee2_row4_col11, #T_89ee2_row4_col12, #T_89ee2_row4_col13, #T_89ee2_row4_col14, #T_89ee2_row4_col15, #T_89ee2_row4_col16, #T_89ee2_row4_col17, #T_89ee2_row4_col18, #T_89ee2_row4_col19, #T_89ee2_row4_col20, #T_89ee2_row5_col4, #T_89ee2_row5_col5, #T_89ee2_row5_col6, #T_89ee2_row5_col7, #T_89ee2_row5_col8, #T_89ee2_row5_col9, #T_89ee2_row5_col10, #T_89ee2_row5_col11, #T_89ee2_row5_col12, #T_89ee2_row5_col13, #T_89ee2_row5_col14, #T_89ee2_row5_col15, #T_89ee2_row5_col16, #T_89ee2_row5_col17, #T_89ee2_row5_col18, #T_89ee2_row5_col19, #T_89ee2_row5_col20 {
#   text-align: center;
# }
# #T_89ee2_row1_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 71.0%, transparent 71.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_89ee2_row1_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 71.0%, transparent 71.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_89ee2_row1_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 71.0%, transparent 71.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_89ee2_row1_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 71.0%, transparent 71.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_89ee2_row2_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 68.8%, transparent 68.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_89ee2_row2_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 68.6%, transparent 68.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_89ee2_row2_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 69.5%, transparent 69.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_89ee2_row2_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 68.8%, transparent 68.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_89ee2_row3_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 53.7%, transparent 53.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_89ee2_row3_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 41.2%, transparent 41.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_89ee2_row3_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 74.6%, transparent 74.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_89ee2_row3_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 53.7%, transparent 53.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_89ee2_row4_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 54.7%, transparent 54.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_89ee2_row4_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 44.0%, transparent 44.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_89ee2_row4_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 70.1%, transparent 70.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_89ee2_row4_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 54.7%, transparent 54.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_89ee2_row5_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 51.6%, transparent 51.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_89ee2_row5_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 37.0%, transparent 37.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_89ee2_row5_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 72.5%, transparent 72.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_89ee2_row5_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 51.6%, transparent 51.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# </style>
# <table id="T_89ee2_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >accuracy</th>
#       <th class="col_heading level0 col1" >f1_score</th>
#       <th class="col_heading level0 col2" >precision</th>
#       <th class="col_heading level0 col3" >recall</th>
#       <th class="col_heading level0 col4" >ml_framework</th>
#       <th class="col_heading level0 col5" >transfer_learning</th>
#       <th class="col_heading level0 col6" >deep_learning</th>
#       <th class="col_heading level0 col7" >model_type</th>
#       <th class="col_heading level0 col8" >depth</th>
#       <th class="col_heading level0 col9" >num_params</th>
#       <th class="col_heading level0 col10" >embedding_layers</th>
#       <th class="col_heading level0 col11" >flatten_layers</th>
#       <th class="col_heading level0 col12" >lstm_layers</th>
#       <th class="col_heading level0 col13" >dense_layers</th>
#       <th class="col_heading level0 col14" >softmax_act</th>
#       <th class="col_heading level0 col15" >tanh_act</th>
#       <th class="col_heading level0 col16" >loss</th>
#       <th class="col_heading level0 col17" >optimizer</th>
#       <th class="col_heading level0 col18" >memory_size</th>
#       <th class="col_heading level0 col19" >username</th>
#       <th class="col_heading level0 col20" >version</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89ee2_level0_row0" class="row_headin

# %%
# Compare two or more models
data=mycompetition.compare_models([4, 5, 6], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style type="text/css">
# #T_5dc09_ caption {
#   color: black;
#   font-size: 18px;
# }
# #T_5dc09_row4_col2, #T_5dc09_row4_col3, #T_5dc09_row4_col4, #T_5dc09_row13_col3, #T_5dc09_row16_col2, #T_5dc09_row16_col3 {
#   background: tomato;
# }
# </style>
# <table id="T_5dc09_">
#   <caption>Model type: RandomForestClassifier</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >param_name</th>
#       <th class="col_heading level0 col1" >default_value</th>
#       <th class="col_heading level0 col2" >model_version_4</th>
#       <th class="col_heading level0 col3" >model_version_5</th>
#       <th class="col_heading level0 col4" >model_version_6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5dc09_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5dc09_row0_col0" class="data row0 col0" >bootstrap</td>
#       <td id="T_5dc09_row0_col1" class="data row0 col1" >True</td>
#       <td id="T_5dc09_row0_col2" class="data row0 col2" >True</td>
#       <td id="T_5dc09_row0_col3" class="data row0 col3" >True</td>
#       <td id="T_5dc09_row0_col4" class="data row0 col4" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5dc09_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5dc09_row1_col0" class="data row1 col0" >ccp_alpha</td>
#       <td id="T_5dc09_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_5dc09_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_5dc09_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_5dc09_row1_col4" class="data row1 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5dc09_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5dc09_row2_col0" class="data row2 col0" >class_weight</td>
#       <td id="T_5dc09_row2_col1" class="data row2 col1" >None</td>
#       <td id="T_5dc09_row2_col2" class="data row2 col2" >None</td>
#       <td id="T_5dc09_row2_col3" class="data row2 col3" >None</td>
#       <td id="T_5dc09_row2_col4" class="data row2 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_5dc09_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5dc09_row3_col0" class="data row3 col0" >criterion</td>
#       <td id="T_5dc09_row3_col1" class="data row3 col1" >gini</td>
#       <td id="T_5dc09_row3_col2" class="data row3 col2" >gini</td>
#       <td id="T_5dc09_row3_col3" class="data row3 col3" >gini</td>
#       <td id="T_5dc09_row3_col4" class="data row3 col4" >gini</td>
#     </tr>
#     <tr>
#       <th id="T_5dc09_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5dc09_row4_col0" class="data row4 col0" >max_depth</td>
#       <td id="T_5dc09_row4_col1" class="data row4 col1" >None</td>
#       <td id="T_5dc09_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_5dc09_row4_col3" class="data row4 col3" >5</td>
#       <td id="T_5dc09_row4_col4" class="data row4 col4" >5</td>
#     </tr>
#     <tr>
#       <th id="T_5dc09_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5dc09_row5_col0" class="data row5 col0" >max_features</td>
#       <td id="T_5dc09_row5_col1" class="data row5 col1" >auto</td>
#       <td id="T_5dc09_row5_col2" class="data row5 col2" >auto</td>
#       <td id="T_5dc09_row5_col3" class="data row5 col3" >auto</td>
#       <td id="T_5dc09_row5_col4" class="data row5 col4" >auto</td>
#     </tr>
#     <tr>
#       <th id="T_5dc09_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5dc09_row6_col0" class="data row6 col0" >max_leaf_nodes</td>
#       <td id="T_5dc09_row6_col1" class="data row6 col1" >None</td>
#       <td id="T_5dc09_row6_col2" class="data row6 col2" >None</td>
#       <td id="T_5dc09_row6_col3" class="data row6 col3" >None</td>
#       <td id="T_5dc09_row6_col4" class="data row6 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_5dc09_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5dc09_row7_col0" class="data row7 col0" >max_samples</td>
#       <td id="T_5dc09_row7_col1" class="data row7 col1" >None</td>
#       <td id="T_5dc09_row7_col2" class="data row7 col2" >None</td>
#       <td id="T_5dc09_row7_col3" class="data row7 col3" >None</td>
#       <td id="T_5dc09_row7_col4" class="data row7 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_5dc09_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5dc09_row8_col0" class="data row8 col0" >min_impurity_decrease</td>
#       <td id="T_5dc09_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_5dc09_row8_col2" class="data row8 col2" >0.000000</td>
#       <td id="T_5dc09_row8_col3" class="data row8 col3" >0.000000</td>
#       <td id="T_5dc09_row8_col4" class="data row8 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5dc09_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5dc09_row9_col0" class="data row9 col0" >min_impurity_split</td>
#       <td id="T_5dc09_row9_col1" class="data row9 col1" >None</td>
#       <td id="T_5dc09_row9_col2" class="data row9 col2" >None</td>
#       <td id="T_5dc09_row9_col3" class="data row9 col3" >None</td>
#       <td id="T_5dc09_row9_col4" class="data row9 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_5dc09_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5dc09_row10_col0" class="data row10 col0" >min_samples_leaf</td>
#       <td id="T_5dc09_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_5dc09_row10_col2" class="data row10 col2" >1</td>
#       <td id="T_5dc09_row10_col3" class="data row10 col3" >1</td>
#       <td id="T_5dc09_row10_col4" class="data row10 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5dc09_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5dc09_row11_col0" class="data row11 col0" >min_samples_split</td>
#       <td id="T_5dc09_row11_col1" class="data row11 col1" >2</td>
#       <td id="T_5dc09_row11_col2" class="data row11 col2" >2</td>
#       <td id="T_5dc09_row11_col3" class="data row11 col3" >2</td>
#       <td id="T_5dc09_row11_col4" class="data row11 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_5dc09_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5dc09_row12_col0" class="data row12 col0" >min_weight_fraction_leaf</td>
#       <td id="T_5dc09_row12_col1" class="data row12 col1" >0.000000</td>
#       <td id="T_5dc09_row12_col2" class="data row12 col2" >0.000000</td>
#       <td id="T_5dc09_row12_col3" class="data row12 col3" >0.000000</td>
#       <td id="T_5dc09_row12_col4" class="data row12 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5dc09_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5dc09_row13_col0" class="data row13 col0" >n_estimators</td>
#       <td id="T_5dc09_row13_col1" class="data row13 col1" >100</td>
#       <td id="T_5dc09_row13_col2" class="data row13 col2" >100</td>
#       <td id="T_5dc09_row13_col3" class="data row13 col3" >500</td>
#       <td id="T_5dc09_row13_col4" class="data row13 col4" >100</td>
#     </tr>
#     <tr>
#       <th id="T_5dc09_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_5dc09_row14_col0" class="data row14 col0" >n_jobs</td>
#       <td id="T_5dc09_row14_col1" class="data row14 col1" >None</td>
#       <td id="T_5dc09_row14_col2" class="data row14 col2" >None</td>
#       <td id="T_5dc09_row14_col3" class="data row14 col3" >None</td>
#       <td id="T_5dc09_row14_col4" class="data row14 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_5dc09_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_5dc09_row15_col0" class="data row15 col0" >oob_score</td>
#       <td id="T_5dc09_row15_col1" class="data row15 col1" >False</td>
#       <td id="T_5dc09_row15_col2" class="data row15 col2" >False</td>
#       <td id="T_5dc09_row15_col3" class="data row15 col3" >False</td>
#       <td id="T_5dc09_row15_col4" class="data row15 col4" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5dc09_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_5dc09_row16_col0" class="data row16 col0" >random_state</td>
#       <td id

# %%
# Here are several classic ML architectures you can choose from to experiment with next:
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier


#Example code to fit model:
model = GradientBoostingClassifier(n_estimators=50, learning_rate=1.0,
    max_depth=1, random_state=0).fit(preprocessor(X_train), y_train_labels)
model.score(preprocessor(X_train), y_train_labels)

# Save sklearn model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx


feature_count=preprocessor(X_test).shape[1] #Get count of preprocessed features
initial_type = [('float_input', FloatTensorType([None, feature_count]))]  # Insert correct number of preprocessed features

onnx_model = model_to_onnx(model, framework='sklearn',
                          initial_types=initial_type,
                          transfer_learning=False,
                          deep_learning=False)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

#-- Generate predicted values (a list of predicted labels "real" or "fake")
prediction_labels = model.predict(preprocessor(X_test))

# Submit model to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 7
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:2763
