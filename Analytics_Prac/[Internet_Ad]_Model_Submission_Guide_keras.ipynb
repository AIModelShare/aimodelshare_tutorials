# %% [markdown]
# <p align="center"><img width="50%" src="https://aimodelsharecontent.s3.amazonaws.com/aimodshare_banner.jpg" /></p>
#
#
# ---

# %% [markdown]
# <p align="center"><h1 align="center">Internet Ad Model Submission Guide - Deep Learning
#
# ##### <p align="center">*Data Source: Lichman, M. (2013). [UCI Machine Learning Repository](http://archive.ics.uci.edu/ml) . Irvine, CA: University of California, School of Information and Computer Science.*
#
# ---
# Let's share our models to a centralized leaderboard, so that we can collaborate and learn from the model experimentation process...
#
# **Instructions:**
# 1.   Get data in and set up X_train / X_test / y_train
# 2.   Preprocess data  with Sklearn Column Transformer/ Write and Save Preprocessor function
# 3. Fit model on preprocessed data and save preprocessor function and model
# 4. Generate predictions from X_test data and submit model to competition
# 5. Repeat submission process to improve place on leaderboard

# %% [markdown]
# # Objective: Predict whether an image is an advertisement (ad.) or not (nonad.)
#
# ---
#
# **Data**: This dataset represents a set of possible advertisements on Internet pages. The features encode the geometry of the image (if available) as well as phrases occuring in the URL, the image's URL and alt text, the anchor text, and words occuring near the anchor text.
#
# **Features (1558 features)**
# * **height** height of image
# * **width** width of image
# * **aratio** aspect ratio of image
# * **URL Terms** 457 features of page urls
# * **orig URL Terms** 495 features from original image urls
# * **anc URL Terms** 472 features from anchor urls
# * **alt Terms** 111 features from image alt text
# * **caption Terms** 19 features from image captions
#
# **Target**
# *   Binary variable (ad./nonad)

# %% [markdown]
# ## 1. Get data in and set up X_train, X_test, y_train objects

# %%
#install aimodelshare library
! pip install aimodelshare --upgrade

# %%
# Get competition data
from aimodelshare import download_data
download_data('public.ecr.aws/y2e2a1d6/internet_ads_competition_data-repository:latest')
# Out:
# Downloading [==================>                              ]
#
# Data downloaded successfully.

# %%
# Load data into X_train, y_train, and X_test
import pandas as pd
X_train = pd.read_csv("internet_ads_competition_data/X_train.csv")
y_train = pd.read_csv("internet_ads_competition_data/y_train.csv", squeeze=True)
y_train = pd.get_dummies(y_train)

X_test=pd.read_csv("internet_ads_competition_data/X_test.csv")

X_train.head()
# Out:
#    height  width  aratio  ...  caption*click  caption*for  caption*you
# 0    60.0  468.0  7.8000  ...              0            0            0
# 1   120.0  120.0  1.0000  ...              0            0            0
# 2    90.0  128.0  1.4222  ...              0            0            0
# 3    24.0  120.0  5.0000  ...              0            0            0
# 4    77.0  108.0  1.4025  ...              0            0            0
#
# [5 rows x 1558 columns]

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
# Out:
# (2623, 1558)
# (656, 1558)
# (2623, 2)

# %% [markdown]
# ##2.   Preprocess data using Sklearn Column Transformer / Write and Save Preprocessor function

# %%
# In this case we use Sklearn's Column transformer in our preprocessor function

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

#Preprocess data using sklearn's Column Transformer approach

# We create the preprocessing pipelines for both numeric and categorical data.
numeric_features = ['height', 'width', 'aratio']
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')), #'imputer' names the step
    ('scaler', StandardScaler())])

binary_features = X_train.columns.tolist()
binary_features = [colname for colname in binary_features if colname not in numeric_features]

# Replacing missing values with Modal value 
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent'))])

# Final preprocessor object set up with ColumnTransformer...

preprocess = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, binary_features)])

# fit preprocessor to your data
preprocess = preprocess.fit(X_train)

# %%
# Write function to transform data with preprocessor

def preprocessor(data):
    preprocessed_data=preprocess.transform(data)
    return preprocessed_data

# %%
# check shape of X data 
preprocessor(X_train).shape
# Out:
# (2623, 1558)

# %% [markdown]
# ##3. Fit model on preprocessed data and save preprocessor function and model

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
import keras

feature_count=preprocessor(X_train).shape[1] #count features in input data

model = Sequential()
model.add(Dense(64, input_dim=feature_count, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))

model.add(Dense(2, activation='softmax')) 
                                            
# Compile model
model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# Fitting the NN to the Training set
model.fit(preprocessor(X_train), y_train, 
               batch_size = 20, 
               epochs = 3, validation_split=0.25)
# Out:
# Epoch 1/3
# 99/99 [==============================] - 1s 5ms/step - loss: 0.5071 - accuracy: 0.8622 - val_loss: 0.3703 - val_accuracy: 0.8872
# Epoch 2/3
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3613 - accuracy: 0.8622 - val_loss: 0.2921 - val_accuracy: 0.8872
# Epoch 3/3
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3058 - accuracy: 0.8622 - val_loss: 0.2458 - val_accuracy: 0.8872

# %% [markdown]
# #### Save preprocessor function to local "preprocessor.zip" file

# %%
import aimodelshare as ai
ai.export_preprocessor(preprocessor,"")
# Out:
# Your preprocessor is now saved to 'preprocessor.zip'

# %% [markdown]
# #### Save model to local ".onnx" file

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model = model_to_onnx(model, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %% [markdown]
# ## 4. Generate predictions from X_test data and submit model to competition

# %%
#Set credentials using modelshare.org username/password

from aimodelshare.aws import set_credentials
    
apiurl="https://vy08zh602l.execute-api.us-east-1.amazonaws.com/prod/m"
#This is the unique rest api that powers this Internet Ad Prediction Playground

set_credentials(apiurl=apiurl)
# Out:
# AI Modelshare Username:··········
# AI Modelshare Password:··········
# AI Model Share login credentials set successfully.

# %%
#Instantiate Competition
import aimodelshare as ai
mycompetition= ai.Competition(apiurl)

# %%
#Submit Model 1: 

#-- Generate predicted y values (Model 1)
#Note: Keras predict returns the predicted column index location for classification models
prediction_column_index=model.predict(preprocessor(X_test)).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

# Submit Model 1 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 8
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:1462

# %%
# Get leaderboard to explore current best model architectures

# Get raw data in pandas data frame
data = mycompetition.get_leaderboard()

# Stylize leaderboard data
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_092ff_row0_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 96.6%, transparent 96.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_092ff_row0_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 94.2%, transparent 94.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_092ff_row0_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 94.2%, transparent 94.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_092ff_row0_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 94.2%, transparent 94.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_092ff_row0_col4, #T_092ff_row0_col5, #T_092ff_row0_col6, #T_092ff_row0_col7, #T_092ff_row0_col8, #T_092ff_row0_col9, #T_092ff_row0_col10, #T_092ff_row0_col11, #T_092ff_row0_col12, #T_092ff_row0_col13, #T_092ff_row0_col14, #T_092ff_row0_col15, #T_092ff_row0_col16, #T_092ff_row0_col17, #T_092ff_row1_col4, #T_092ff_row1_col5, #T_092ff_row1_col6, #T_092ff_row1_col7, #T_092ff_row1_col8, #T_092ff_row1_col9, #T_092ff_row1_col10, #T_092ff_row1_col11, #T_092ff_row1_col12, #T_092ff_row1_col13, #T_092ff_row1_col14, #T_092ff_row1_col15, #T_092ff_row1_col16, #T_092ff_row1_col17, #T_092ff_row2_col4, #T_092ff_row2_col5, #T_092ff_row2_col6, #T_092ff_row2_col7, #T_092ff_row2_col8, #T_092ff_row2_col9, #T_092ff_row2_col10, #T_092ff_row2_col11, #T_092ff_row2_col12, #T_092ff_row2_col13, #T_092ff_row2_col14, #T_092ff_row2_col15, #T_092ff_row2_col16, #T_092ff_row2_col17, #T_092ff_row3_col4, #T_092ff_row3_col5, #T_092ff_row3_col6, #T_092ff_row3_col7, #T_092ff_row3_col8, #T_092ff_row3_col9, #T_092ff_row3_col10, #T_092ff_row3_col11, #T_092ff_row3_col12, #T_092ff_row3_col13, #T_092ff_row3_col14, #T_092ff_row3_col15, #T_092ff_row3_col16, #T_092ff_row3_col17, #T_092ff_row4_col4, #T_092ff_row4_col5, #T_092ff_row4_col6, #T_092ff_row4_col7, #T_092ff_row4_col8, #T_092ff_row4_col9, #T_092ff_row4_col10, #T_092ff_row4_col11, #T_092ff_row4_col12, #T_092ff_row4_col13, #T_092ff_row4_col14, #T_092ff_row4_col15, #T_092ff_row4_col16, #T_092ff_row4_col17, #T_092ff_row5_col4, #T_092ff_row5_col5, #T_092ff_row5_col6, #T_092ff_row5_col7, #T_092ff_row5_col8, #T_092ff_row5_col9, #T_092ff_row5_col10, #T_092ff_row5_col11, #T_092ff_row5_col12, #T_092ff_row5_col13, #T_092ff_row5_col14, #T_092ff_row5_col15, #T_092ff_row5_col16, #T_092ff_row5_col17, #T_092ff_row6_col4, #T_092ff_row6_col5, #T_092ff_row6_col6, #T_092ff_row6_col7, #T_092ff_row6_col8, #T_092ff_row6_col9, #T_092ff_row6_col10, #T_092ff_row6_col11, #T_092ff_row6_col12, #T_092ff_row6_col13, #T_092ff_row6_col14, #T_092ff_row6_col15, #T_092ff_row6_col16, #T_092ff_row6_col17, #T_092ff_row7_col4, #T_092ff_row7_col5, #T_092ff_row7_col6, #T_092ff_row7_col7, #T_092ff_row7_col8, #T_092ff_row7_col9, #T_092ff_row7_col10, #T_092ff_row7_col11, #T_092ff_row7_col12, #T_092ff_row7_col13, #T_092ff_row7_col14, #T_092ff_row7_col15, #T_092ff_row7_col16, #T_092ff_row7_col17 {
#   text-align: center;
# }
# #T_092ff_row1_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 95.3%, transparent 95.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_092ff_row1_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 91.1%, transparent 91.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_092ff_row1_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 95.0%, transparent 95.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_092ff_row1_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 88.1%, transparent 88.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_092ff_row2_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 91.3%, transparent 91.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_092ff_row2_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 81.4%, transparent 81.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_092ff_row2_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 93.1%, transparent 93.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_092ff_row2_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 76.0%, transparent 76.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_092ff_row3_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 90.2%, transparent 90.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_092ff_row3_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 77.9%, transparent 77.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_092ff_row3_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 93.8%, transparent 93.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_092ff_row3_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 72.3%, transparent 72.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_092ff_row4_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 72.9%, transparent 72.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_092ff_row4_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 48.7%, transparent 48.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_092ff_row4_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 48.7%, transparent 48.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_092ff_row4_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 48.9%, transparent 48.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_092ff_row5_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 82.6%, transparent 82.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_092ff_row5_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 45.2%, transparent 45.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_092ff_row5_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 41.3%, transparent 41.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_092ff_row5_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 50.0%, transparent 50.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_092ff_row6_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 71.6%, transparent 71.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_092ff_row6_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 46.9%, transparent 46.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_092ff_row6_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 46.7%, transparent 46.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_092ff_row6_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 47.2%, transparent 47.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_092ff_row7_col0, #T_092ff_row7_col1, #T_092ff_row7_col2, #T_092ff_row7_col3 {
#   text-align: center;
#   color: #251e1b;
#   font-size: 12px;
# }
# </style>
# <table id="T_092ff_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >accuracy</th>
#       <th class="col_heading level0 col1" >f1_score</th>
#       <th class="col_heading level0 col2" >precision</th>
#       <th class="col_heading level0 col3" >recall</th>
#       <th class="col_heading level0 col4"

# %% [markdown]
# ## 5. Repeat submission process to improve place on leaderboard

# %%
# Train and submit model 2 using same preprocessor (note that you could save a new preprocessor, but we will use the same one for this example).
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation

feature_count=preprocessor(X_train).shape[1] #count features in input data

model_2 = Sequential()
model_2.add(Dense(128, input_dim=feature_count, activation='relu'))
model_2.add(Dropout(.3))
model_2.add(Dense(64, activation='relu'))
model_2.add(Dense(64, activation='relu'))
model_2.add(Dropout(.3))
model_2.add(Dense(64, activation='relu'))

model_2.add(Dense(2, activation='softmax')) 
                                            
# Compile model
model_2.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# Fitting the NN to the Training set
model_2.fit(preprocessor(X_train), y_train, 
               batch_size = 20, 
               epochs = 5, validation_split=0.25)
# Out:
# Epoch 1/5
# 99/99 [==============================] - 1s 6ms/step - loss: 0.5623 - accuracy: 0.8012 - val_loss: 0.4358 - val_accuracy: 0.8872
# Epoch 2/5
# 99/99 [==============================] - 0s 4ms/step - loss: 0.4249 - accuracy: 0.8622 - val_loss: 0.3614 - val_accuracy: 0.8872
# Epoch 3/5
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3849 - accuracy: 0.8622 - val_loss: 0.3230 - val_accuracy: 0.8872
# Epoch 4/5
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3527 - accuracy: 0.8627 - val_loss: 0.2838 - val_accuracy: 0.8872
# Epoch 5/5
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3081 - accuracy: 0.8719 - val_loss: 0.2391 - val_accuracy: 0.9085

# %%
# Save Model 2 to .onnx file

onnx_model = model_to_onnx(model_2, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

# Save model to local .onnx file
with open("model_2.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
# Submit Model 2

#-- Generate predicted y values (Model 2)
#Note: Keras predict returns the predicted column index location for classification models
prediction_column_index=model_2.predict(preprocessor(X_test)).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

# Submit Model 2 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model_2.onnx",
                                 prediction_submission=prediction_labels,
                                 preprocessor_filepath="preprocessor.zip")
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 9
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:1462

# %%
# Compare two or more models
data=mycompetition.compare_models([7, 8], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style type="text/css">
# #T_fb91e_ caption {
#   color: black;
#   font-size: 18px;
# }
# #T_fb91e_row0_col0, #T_fb91e_row0_col3, #T_fb91e_row1_col0, #T_fb91e_row2_col0, #T_fb91e_row2_col3, #T_fb91e_row3_col0, #T_fb91e_row3_col3, #T_fb91e_row5_col3, #T_fb91e_row6_col3 {
#   background: #fff2ae;
#   color: black;
#   color: black;
# }
# #T_fb91e_row0_col1, #T_fb91e_row0_col2, #T_fb91e_row0_col4, #T_fb91e_row0_col5, #T_fb91e_row1_col1, #T_fb91e_row1_col2, #T_fb91e_row1_col4, #T_fb91e_row1_col5, #T_fb91e_row2_col1, #T_fb91e_row2_col2, #T_fb91e_row2_col4, #T_fb91e_row2_col5, #T_fb91e_row3_col1, #T_fb91e_row3_col2, #T_fb91e_row3_col4, #T_fb91e_row3_col5, #T_fb91e_row4_col0, #T_fb91e_row4_col1, #T_fb91e_row4_col2, #T_fb91e_row4_col4, #T_fb91e_row4_col5, #T_fb91e_row5_col0, #T_fb91e_row5_col1, #T_fb91e_row5_col2, #T_fb91e_row5_col4, #T_fb91e_row5_col5, #T_fb91e_row6_col0, #T_fb91e_row6_col1, #T_fb91e_row6_col2, #T_fb91e_row6_col4, #T_fb91e_row6_col5 {
#   background: white;
#   color: black;
#   color: black;
# }
# #T_fb91e_row1_col3, #T_fb91e_row4_col3 {
#   background: #cbd5e8;
#   color: black;
#   color: black;
# }
# </style>
# <table id="T_fb91e_">
#   <caption>Model type: Neural Network</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model_8_Layer</th>
#       <th class="col_heading level0 col1" >Model_8_Shape</th>
#       <th class="col_heading level0 col2" >Model_8_Params</th>
#       <th class="col_heading level0 col3" >Model_9_Layer</th>
#       <th class="col_heading level0 col4" >Model_9_Shape</th>
#       <th class="col_heading level0 col5" >Model_9_Params</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fb91e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fb91e_row0_col0" class="data row0 col0" >Dense</td>
#       <td id="T_fb91e_row0_col1" class="data row0 col1" >[None, 64]</td>
#       <td id="T_fb91e_row0_col2" class="data row0 col2" >99776.000000</td>
#       <td id="T_fb91e_row0_col3" class="data row0 col3" >Dense</td>
#       <td id="T_fb91e_row0_col4" class="data row0 col4" >[None, 128]</td>
#       <td id="T_fb91e_row0_col5" class="data row0 col5" >199552</td>
#     </tr>
#     <tr>
#       <th id="T_fb91e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fb91e_row1_col0" class="data row1 col0" >Dense</td>
#       <td id="T_fb91e_row1_col1" class="data row1 col1" >[None, 64]</td>
#       <td id="T_fb91e_row1_col2" class="data row1 col2" >4160.000000</td>
#       <td id="T_fb91e_row1_col3" class="data row1 col3" >Dropout</td>
#       <td id="T_fb91e_row1_col4" class="data row1 col4" >[None, 128]</td>
#       <td id="T_fb91e_row1_col5" class="data row1 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fb91e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fb91e_row2_col0" class="data row2 col0" >Dense</td>
#       <td id="T_fb91e_row2_col1" class="data row2 col1" >[None, 64]</td>
#       <td id="T_fb91e_row2_col2" class="data row2 col2" >4160.000000</td>
#       <td id="T_fb91e_row2_col3" class="data row2 col3" >Dense</td>
#       <td id="T_fb91e_row2_col4" class="data row2 col4" >[None, 64]</td>
#       <td id="T_fb91e_row2_col5" class="data row2 col5" >8256</td>
#     </tr>
#     <tr>
#       <th id="T_fb91e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fb91e_row3_col0" class="data row3 col0" >Dense</td>
#       <td id="T_fb91e_row3_col1" class="data row3 col1" >[None, 2]</td>
#       <td id="T_fb91e_row3_col2" class="data row3 col2" >130.000000</td>
#       <td id="T_fb91e_row3_col3" class="data row3 col3" >Dense</td>
#       <td id="T_fb91e_row3_col4" class="data row3 col4" >[None, 64]</td>
#       <td id="T_fb91e_row3_col5" class="data row3 col5" >4160</td>
#     </tr>
#     <tr>
#       <th id="T_fb91e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fb91e_row4_col0" class="data row4 col0" >None</td>
#       <td id="T_fb91e_row4_col1" class="data row4 col1" >None</td>
#       <td id="T_fb91e_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_fb91e_row4_col3" class="data row4 col3" >Dropout</td>
#       <td id="T_fb91e_row4_col4" class="data row4 col4" >[None, 64]</td>
#       <td id="T_fb91e_row4_col5" class="data row4 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fb91e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fb91e_row5_col0" class="data row5 col0" >None</td>
#       <td id="T_fb91e_row5_col1" class="data row5 col1" >None</td>
#       <td id="T_fb91e_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_fb91e_row5_col3" class="data row5 col3" >Dense</td>
#       <td id="T_fb91e_row5_col4" class="data row5 col4" >[None, 64]</td>
#       <td id="T_fb91e_row5_col5" class="data row5 col5" >4160</td>
#     </tr>
#     <tr>
#       <th id="T_fb91e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fb91e_row6_col0" class="data row6 col0" >None</td>
#       <td id="T_fb91e_row6_col1" class="data row6 col1" >None</td>
#       <td id="T_fb91e_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_fb91e_row6_col3" class="data row6 col3" >Dense</td>
#       <td id="T_fb91e_row6_col4" class="data row6 col4" >[None, 2]</td>
#       <td id="T_fb91e_row6_col5" class="data row6 col5" >130</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Optional: Tune model within range of hyperparameters with Keras Tuner
#
# *Simple example shown below. Consult [documentation](https://keras.io/guides/keras_tuner/getting_started/) to see full functionality.*

# %%
! pip install keras_tuner

# %%
#Separate validation data 
from sklearn.model_selection import train_test_split
x_train_split, x_val, y_train_split, y_val = train_test_split(
     X_train, y_train, test_size=0.2, random_state=42)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, BatchNormalization
from keras.regularizers import l1, l2, l1_l2
import keras_tuner as kt


#Define model structure & parameter search space with function
feature_count=preprocessor(X_train).shape[1] #count features in input data

def build_model(hp):
    model = keras.Sequential()
    model.add(Dense(64, input_dim=feature_count, activation='relu', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
    model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
    model.add(Dense(units=hp.Int("units", min_value=32, max_value=512, step=32), #range 32-512 inclusive, minimum step between tested values is 32
                    activation='relu', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
    model.add(Dense(2, activation='softmax')) 
    model.compile(
        optimizer="rmsprop", loss="binary_crossentropy", metrics=["accuracy"],
    )
    return model

#initialize the tuner (which will search through parameters)
tuner = kt.RandomSearch(
    hypermodel=build_model, 
    objective="val_accuracy", # objective to optimize
    max_trials=3, #max number of trials to run during search
    executions_per_trial=3, #higher number reduces variance of results; guages model performance more accurately 
    overwrite=True,
    directory="tuning_model",
    project_name="tuning_units",
)

tuner.search(preprocessor(x_train_split), y_train_split, epochs=1, validation_data=(preprocessor(x_val), y_val))
# Out:
# Trial 3 Complete [00h 00m 06s]
# val_accuracy: 0.9453968207041422
#
# Best val_accuracy So Far: 0.9453968207041422
# Total elapsed time: 00h 00m 20s

# %%
# Build model with best hyperparameters

# Get the top 2 hyperparameters.
best_hps = tuner.get_best_hyperparameters(5)
# Build the model with the best hp.
tuned_model = build_model(best_hps[0])
# Fit with the entire dataset.
tuned_model.fit(x=preprocessor(X_train), y=y_train, epochs=5)
# Out:
# Epoch 1/5
# 82/82 [==============================] - 1s 5ms/step - loss: 1.2357 - accuracy: 0.9077
# Epoch 2/5
# 82/82 [==============================] - 0s 5ms/step - loss: 0.3031 - accuracy: 0.9665
# Epoch 3/5
# 82/82 [==============================] - 0s 5ms/step - loss: 0.1954 - accuracy: 0.9714
# Epoch 4/5
# 82/82 [==============================] - 0s 5ms/step - loss: 0.1715 - accuracy: 0.9764
# Epoch 5/5
# 82/82 [==============================] - 0s 5ms/step - loss: 0.1639 - accuracy: 0.9748

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model = model_to_onnx(tuned_model, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("tuned_model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Submit Model 3: 

#-- Generate predicted y values (Model 3)
prediction_column_index=tuned_model.predict(preprocessor(X_test)).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

# Submit to Competition Leaderboard
mycompetition.submit_model(model_filepath = "tuned_model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 10
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:1462

# %%
# Get leaderboard

data = mycompetition.get_leaderboard()
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_1fb6b_row0_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 96.6%, transparent 96.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_1fb6b_row0_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 94.2%, transparent 94.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_1fb6b_row0_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 94.2%, transparent 94.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_1fb6b_row0_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 94.2%, transparent 94.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_1fb6b_row0_col4, #T_1fb6b_row0_col5, #T_1fb6b_row0_col6, #T_1fb6b_row0_col7, #T_1fb6b_row0_col8, #T_1fb6b_row0_col9, #T_1fb6b_row0_col10, #T_1fb6b_row0_col11, #T_1fb6b_row0_col12, #T_1fb6b_row0_col13, #T_1fb6b_row0_col14, #T_1fb6b_row0_col15, #T_1fb6b_row0_col16, #T_1fb6b_row0_col17, #T_1fb6b_row0_col18, #T_1fb6b_row1_col4, #T_1fb6b_row1_col5, #T_1fb6b_row1_col6, #T_1fb6b_row1_col7, #T_1fb6b_row1_col8, #T_1fb6b_row1_col9, #T_1fb6b_row1_col10, #T_1fb6b_row1_col11, #T_1fb6b_row1_col12, #T_1fb6b_row1_col13, #T_1fb6b_row1_col14, #T_1fb6b_row1_col15, #T_1fb6b_row1_col16, #T_1fb6b_row1_col17, #T_1fb6b_row1_col18, #T_1fb6b_row2_col4, #T_1fb6b_row2_col5, #T_1fb6b_row2_col6, #T_1fb6b_row2_col7, #T_1fb6b_row2_col8, #T_1fb6b_row2_col9, #T_1fb6b_row2_col10, #T_1fb6b_row2_col11, #T_1fb6b_row2_col12, #T_1fb6b_row2_col13, #T_1fb6b_row2_col14, #T_1fb6b_row2_col15, #T_1fb6b_row2_col16, #T_1fb6b_row2_col17, #T_1fb6b_row2_col18, #T_1fb6b_row3_col4, #T_1fb6b_row3_col5, #T_1fb6b_row3_col6, #T_1fb6b_row3_col7, #T_1fb6b_row3_col8, #T_1fb6b_row3_col9, #T_1fb6b_row3_col10, #T_1fb6b_row3_col11, #T_1fb6b_row3_col12, #T_1fb6b_row3_col13, #T_1fb6b_row3_col14, #T_1fb6b_row3_col15, #T_1fb6b_row3_col16, #T_1fb6b_row3_col17, #T_1fb6b_row3_col18, #T_1fb6b_row4_col4, #T_1fb6b_row4_col5, #T_1fb6b_row4_col6, #T_1fb6b_row4_col7, #T_1fb6b_row4_col8, #T_1fb6b_row4_col9, #T_1fb6b_row4_col10, #T_1fb6b_row4_col11, #T_1fb6b_row4_col12, #T_1fb6b_row4_col13, #T_1fb6b_row4_col14, #T_1fb6b_row4_col15, #T_1fb6b_row4_col16, #T_1fb6b_row4_col17, #T_1fb6b_row4_col18, #T_1fb6b_row5_col4, #T_1fb6b_row5_col5, #T_1fb6b_row5_col6, #T_1fb6b_row5_col7, #T_1fb6b_row5_col8, #T_1fb6b_row5_col9, #T_1fb6b_row5_col10, #T_1fb6b_row5_col11, #T_1fb6b_row5_col12, #T_1fb6b_row5_col13, #T_1fb6b_row5_col14, #T_1fb6b_row5_col15, #T_1fb6b_row5_col16, #T_1fb6b_row5_col17, #T_1fb6b_row5_col18, #T_1fb6b_row6_col4, #T_1fb6b_row6_col5, #T_1fb6b_row6_col6, #T_1fb6b_row6_col7, #T_1fb6b_row6_col8, #T_1fb6b_row6_col9, #T_1fb6b_row6_col10, #T_1fb6b_row6_col11, #T_1fb6b_row6_col12, #T_1fb6b_row6_col13, #T_1fb6b_row6_col14, #T_1fb6b_row6_col15, #T_1fb6b_row6_col16, #T_1fb6b_row6_col17, #T_1fb6b_row6_col18, #T_1fb6b_row7_col4, #T_1fb6b_row7_col5, #T_1fb6b_row7_col6, #T_1fb6b_row7_col7, #T_1fb6b_row7_col8, #T_1fb6b_row7_col9, #T_1fb6b_row7_col10, #T_1fb6b_row7_col11, #T_1fb6b_row7_col12, #T_1fb6b_row7_col13, #T_1fb6b_row7_col14, #T_1fb6b_row7_col15, #T_1fb6b_row7_col16, #T_1fb6b_row7_col17, #T_1fb6b_row7_col18, #T_1fb6b_row8_col4, #T_1fb6b_row8_col5, #T_1fb6b_row8_col6, #T_1fb6b_row8_col7, #T_1fb6b_row8_col8, #T_1fb6b_row8_col9, #T_1fb6b_row8_col10, #T_1fb6b_row8_col11, #T_1fb6b_row8_col12, #T_1fb6b_row8_col13, #T_1fb6b_row8_col14, #T_1fb6b_row8_col15, #T_1fb6b_row8_col16, #T_1fb6b_row8_col17, #T_1fb6b_row8_col18, #T_1fb6b_row9_col4, #T_1fb6b_row9_col5, #T_1fb6b_row9_col6, #T_1fb6b_row9_col7, #T_1fb6b_row9_col8, #T_1fb6b_row9_col9, #T_1fb6b_row9_col10, #T_1fb6b_row9_col11, #T_1fb6b_row9_col12, #T_1fb6b_row9_col13, #T_1fb6b_row9_col14, #T_1fb6b_row9_col15, #T_1fb6b_row9_col16, #T_1fb6b_row9_col17, #T_1fb6b_row9_col18 {
#   text-align: center;
# }
# #T_1fb6b_row1_col0, #T_1fb6b_row2_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 95.3%, transparent 95.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_1fb6b_row1_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 91.1%, transparent 91.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_1fb6b_row1_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 95.0%, transparent 95.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_1fb6b_row1_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 88.1%, transparent 88.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_1fb6b_row2_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 91.4%, transparent 91.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_1fb6b_row2_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 93.2%, transparent 93.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_1fb6b_row2_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 89.9%, transparent 89.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_1fb6b_row3_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 91.3%, transparent 91.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_1fb6b_row3_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 81.4%, transparent 81.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_1fb6b_row3_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 93.1%, transparent 93.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_1fb6b_row3_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 76.0%, transparent 76.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_1fb6b_row4_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 90.2%, transparent 90.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_1fb6b_row4_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 77.9%, transparent 77.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_1fb6b_row4_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 93.8%, transparent 93.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_1fb6b_row4_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 72.3%, transparent 72.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_1fb6b_row5_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 86.6%, transparent 86.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_1fb6b_row5_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 67.6%, transparent 67.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_1fb6b_row5_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 84.7%, transparent 84.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_1fb6b_row5_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 63.8%, transparent 63.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_1fb6b_row6_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 72.9%, transparent 72.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_1fb6b_row6_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 48.7%, transparent 48.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_1fb6b_row6_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 48.7%, transparent 48.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_1fb6b_row6_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   backgrou

# %%
# Compare two or more models
data=mycompetition.compare_models([7, 8, 9], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style type="text/css">
# #T_e7ce5_ caption {
#   color: black;
#   font-size: 18px;
# }
# #T_e7ce5_row0_col0, #T_e7ce5_row0_col3, #T_e7ce5_row0_col6, #T_e7ce5_row1_col0, #T_e7ce5_row1_col6, #T_e7ce5_row2_col0, #T_e7ce5_row2_col3, #T_e7ce5_row2_col6, #T_e7ce5_row3_col0, #T_e7ce5_row3_col3, #T_e7ce5_row3_col6, #T_e7ce5_row5_col3, #T_e7ce5_row6_col3 {
#   background: #fff2ae;
#   color: black;
#   color: black;
# }
# #T_e7ce5_row0_col1, #T_e7ce5_row0_col2, #T_e7ce5_row0_col4, #T_e7ce5_row0_col5, #T_e7ce5_row0_col7, #T_e7ce5_row0_col8, #T_e7ce5_row1_col1, #T_e7ce5_row1_col2, #T_e7ce5_row1_col4, #T_e7ce5_row1_col5, #T_e7ce5_row1_col7, #T_e7ce5_row1_col8, #T_e7ce5_row2_col1, #T_e7ce5_row2_col2, #T_e7ce5_row2_col4, #T_e7ce5_row2_col5, #T_e7ce5_row2_col7, #T_e7ce5_row2_col8, #T_e7ce5_row3_col1, #T_e7ce5_row3_col2, #T_e7ce5_row3_col4, #T_e7ce5_row3_col5, #T_e7ce5_row3_col7, #T_e7ce5_row3_col8, #T_e7ce5_row4_col0, #T_e7ce5_row4_col1, #T_e7ce5_row4_col2, #T_e7ce5_row4_col4, #T_e7ce5_row4_col5, #T_e7ce5_row4_col6, #T_e7ce5_row4_col7, #T_e7ce5_row4_col8, #T_e7ce5_row5_col0, #T_e7ce5_row5_col1, #T_e7ce5_row5_col2, #T_e7ce5_row5_col4, #T_e7ce5_row5_col5, #T_e7ce5_row5_col6, #T_e7ce5_row5_col7, #T_e7ce5_row5_col8, #T_e7ce5_row6_col0, #T_e7ce5_row6_col1, #T_e7ce5_row6_col2, #T_e7ce5_row6_col4, #T_e7ce5_row6_col5, #T_e7ce5_row6_col6, #T_e7ce5_row6_col7, #T_e7ce5_row6_col8 {
#   background: white;
#   color: black;
#   color: black;
# }
# #T_e7ce5_row1_col3, #T_e7ce5_row4_col3 {
#   background: #cbd5e8;
#   color: black;
#   color: black;
# }
# </style>
# <table id="T_e7ce5_">
#   <caption>Model type: Neural Network</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model_8_Layer</th>
#       <th class="col_heading level0 col1" >Model_8_Shape</th>
#       <th class="col_heading level0 col2" >Model_8_Params</th>
#       <th class="col_heading level0 col3" >Model_9_Layer</th>
#       <th class="col_heading level0 col4" >Model_9_Shape</th>
#       <th class="col_heading level0 col5" >Model_9_Params</th>
#       <th class="col_heading level0 col6" >Model_10_Layer</th>
#       <th class="col_heading level0 col7" >Model_10_Shape</th>
#       <th class="col_heading level0 col8" >Model_10_Params</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7ce5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e7ce5_row0_col0" class="data row0 col0" >Dense</td>
#       <td id="T_e7ce5_row0_col1" class="data row0 col1" >[None, 64]</td>
#       <td id="T_e7ce5_row0_col2" class="data row0 col2" >99776.000000</td>
#       <td id="T_e7ce5_row0_col3" class="data row0 col3" >Dense</td>
#       <td id="T_e7ce5_row0_col4" class="data row0 col4" >[None, 128]</td>
#       <td id="T_e7ce5_row0_col5" class="data row0 col5" >199552</td>
#       <td id="T_e7ce5_row0_col6" class="data row0 col6" >Dense</td>
#       <td id="T_e7ce5_row0_col7" class="data row0 col7" >[None, 64]</td>
#       <td id="T_e7ce5_row0_col8" class="data row0 col8" >99776.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e7ce5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e7ce5_row1_col0" class="data row1 col0" >Dense</td>
#       <td id="T_e7ce5_row1_col1" class="data row1 col1" >[None, 64]</td>
#       <td id="T_e7ce5_row1_col2" class="data row1 col2" >4160.000000</td>
#       <td id="T_e7ce5_row1_col3" class="data row1 col3" >Dropout</td>
#       <td id="T_e7ce5_row1_col4" class="data row1 col4" >[None, 128]</td>
#       <td id="T_e7ce5_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_e7ce5_row1_col6" class="data row1 col6" >Dense</td>
#       <td id="T_e7ce5_row1_col7" class="data row1 col7" >[None, 64]</td>
#       <td id="T_e7ce5_row1_col8" class="data row1 col8" >4160.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e7ce5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e7ce5_row2_col0" class="data row2 col0" >Dense</td>
#       <td id="T_e7ce5_row2_col1" class="data row2 col1" >[None, 64]</td>
#       <td id="T_e7ce5_row2_col2" class="data row2 col2" >4160.000000</td>
#       <td id="T_e7ce5_row2_col3" class="data row2 col3" >Dense</td>
#       <td id="T_e7ce5_row2_col4" class="data row2 col4" >[None, 64]</td>
#       <td id="T_e7ce5_row2_col5" class="data row2 col5" >8256</td>
#       <td id="T_e7ce5_row2_col6" class="data row2 col6" >Dense</td>
#       <td id="T_e7ce5_row2_col7" class="data row2 col7" >[None, 352]</td>
#       <td id="T_e7ce5_row2_col8" class="data row2 col8" >22880.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e7ce5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e7ce5_row3_col0" class="data row3 col0" >Dense</td>
#       <td id="T_e7ce5_row3_col1" class="data row3 col1" >[None, 2]</td>
#       <td id="T_e7ce5_row3_col2" class="data row3 col2" >130.000000</td>
#       <td id="T_e7ce5_row3_col3" class="data row3 col3" >Dense</td>
#       <td id="T_e7ce5_row3_col4" class="data row3 col4" >[None, 64]</td>
#       <td id="T_e7ce5_row3_col5" class="data row3 col5" >4160</td>
#       <td id="T_e7ce5_row3_col6" class="data row3 col6" >Dense</td>
#       <td id="T_e7ce5_row3_col7" class="data row3 col7" >[None, 2]</td>
#       <td id="T_e7ce5_row3_col8" class="data row3 col8" >706.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e7ce5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e7ce5_row4_col0" class="data row4 col0" >None</td>
#       <td id="T_e7ce5_row4_col1" class="data row4 col1" >None</td>
#       <td id="T_e7ce5_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_e7ce5_row4_col3" class="data row4 col3" >Dropout</td>
#       <td id="T_e7ce5_row4_col4" class="data row4 col4" >[None, 64]</td>
#       <td id="T_e7ce5_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_e7ce5_row4_col6" class="data row4 col6" >None</td>
#       <td id="T_e7ce5_row4_col7" class="data row4 col7" >None</td>
#       <td id="T_e7ce5_row4_col8" class="data row4 col8" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_e7ce5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e7ce5_row5_col0" class="data row5 col0" >None</td>
#       <td id="T_e7ce5_row5_col1" class="data row5 col1" >None</td>
#       <td id="T_e7ce5_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_e7ce5_row5_col3" class="data row5 col3" >Dense</td>
#       <td id="T_e7ce5_row5_col4" class="data row5 col4" >[None, 64]</td>
#       <td id="T_e7ce5_row5_col5" class="data row5 col5" >4160</td>
#       <td id="T_e7ce5_row5_col6" class="data row5 col6" >None</td>
#       <td id="T_e7ce5_row5_col7" class="data row5 col7" >None</td>
#       <td id="T_e7ce5_row5_col8" class="data row5 col8" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_e7ce5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e7ce5_row6_col0" class="data row6 col0" >None</td>
#       <td id="T_e7ce5_row6_col1" class="data row6 col1" >None</td>
#       <td id="T_e7ce5_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_e7ce5_row6_col3" class="data row6 col3" >Dense</td>
#       <td id="T_e7ce5_row6_col4" class="data row6 col4" >[None, 2]</td>
#       <td id="T_e7ce5_row6_col5" class="data row6 col5" >130</td>
#       <td id="T_e7ce5_row6_col6" class="data row6 col6" >None</td>
#       <td id="T_e7ce5_row6_col7" class="data row6 col7" >None</td>
#       <td id="T_e7ce5_row6_col8" class="data row6 col8" >nan</td>
#     </tr>
#   </tbody>
# </table>
